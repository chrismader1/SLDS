# %%
# Plot RelCAGR vs Delta ELBO and vs CPLL, CPLL Gap
# Smooth CPLL: conditional predictive log-likelihood; out-of-sample accuracy # Smooth CPLL: overestimates OOS accuracy due to look-ahead bias
# ELBO: Evidence lower bound; lower bound on the true log-likelihood (lowest start minus highest end accross all runs)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.metrics import adjusted_rand_score as _ARI

# %%
# params
vmin_cagr, vmax_cagr = -0.10, 0.10
vmax_cpll = 200000
vmax_elbo = 1000000

# %%
# import data
filename_results = '/Users/chrismader/Python/SLDS/Results/gridsearch_results.csv'
filename_static = '/Users/chrismader/Python/SLDS/Data/static_data.csv'
res = pd.read_csv(filename_results)
static = pd.read_csv(filename_static, usecols=[0,1,2])

# %%
# Prep data
res['sector'] = res['security'].map(static.set_index('Ticker')['SectorID'])
res['CPLL Gap'] = res['max cpll (proxy bound, paired)'] - res['cpll (max all runs)']
res.insert(res.columns.get_loc('security') + 1, 'sector', res.pop('sector'))
res = res[np.isfinite(pd.to_numeric(res['cagr_rel_ex_ante'], errors='coerce'))].copy()
res = res[np.isfinite(pd.to_numeric(res['score'], errors='coerce'))].copy()

print(list(np.unique(res.config)))
print(list(np.unique(res.sector)))
print(list(np.unique(res.security)))
print(res.columns)

# Settings
configs = np.unique(res.config)
unrestricted = [x for x in configs if x.startswith('[')]
restricted = [x for x in configs if not x.startswith('[')]
print(unrestricted)
print(restricted)
# Out:
# ['[g,v,h]', '[g,v]', '[y,g,v,h]', '[y,h]', '[y]', 'factor1', 'factor1_vix', 'factor2_ff3', 'factor2_ff3mom', 'factor2_ff5', 'factor2_ff5mom', 'fund1', 'fund1_vix', 'fund2', 'fund2_vix', 'fund3', 'fund3_vix']
# ['CD', 'CS', 'EN', 'FN', 'HC', 'IN', 'IT', 'MT', 'RL', 'TC', 'UT']
# ['AAPL', 'ABBV', 'ABT', 'ACN', 'ADBE', 'AEP', 'AMAT', 'AMD', 'AMGN', 'AMT', 'AMZN', 'AVGO', 'AXP', 'BA', 'BAC', 'BKNG', 'BLK', 'BSX', 'C', 'CAT', 'CBRE', 'COST', 'CRM', 'CSCO', 'CVX', 'D', 'DIS', 'DUK', 'EQIX', 'GE', 'GOOGL', 'GS', 'HD', 'HON', 'IBM', 'INTU', 'ISRG', 'JNJ', 'JPM', 'KO', 'LIN', 'LLY', 'MA', 'MCD', 'META', 'MRK', 'MS', 'MSFT', 'NEE', 'NFLX', 'NOW', 'NVDA', 'O', 'ORCL', 'PEP', 'PG', 'PGR', 'PLD', 'PM', 'QCOM', 'RTX', 'SCHW', 'SO', 'SPGI', 'T', 'TMO', 'TSLA', 'TXN', 'UNH', 'V', 'VZ', 'WFC', 'WMT', 'XOM']
# Index(['security', 'sector', 'config', 'rank', 'score', 'dt', 'n_regimes',
#        'dim_latent', 'single_subspace', 'train_window', 'overlap_window',
#        'avg_inferred_regime_length', 'elbo_start (min all runs)',
#        'elbo_end (max all runs)', 'elbo_delta (max all runs)',
#        'cpll (max all runs)', 'max cpll (proxy bound, paired)', 'mode_usage',
#        'cagr_rel', 'cagr_strat', 'cagr_bench', 'cagr_rel_cusum',
#        'cagr_strat_cusum', 'cagr_bench_cusum', 'cagr_rel_ex_ante',
#        'cagr_strat_ex_ante', 'cagr_bench_ex_ante', 'CPLL Gap'],
#       dtype='object')
# ['[g,v,h]', '[g,v]', '[y,g,v,h]', '[y,h]', '[y]']
# ['factor1', 'factor1_vix', 'factor2_ff3', 'factor2_ff3mom', 'factor2_ff5', 'factor2_ff5mom', 'fund1', 'fund1_vix', 'fund2', 'fund2_vix', 'fund3', 'fund3_vix']

# %%
# Helpers

def performance(df, value_sel):
    
    idx = ['config','n_regimes','dim_latent']
    sector_cols = sorted(df['sector'].unique())
    
    # sector means
    pt = (df.pivot_table(index=idx, columns='sector', values=value_sel, aggfunc='mean')
            .sort_index().reindex(sector_cols, axis=1))
    
    # true stats across ALL securities (not avg of sectors)
    stats = (df.groupby(idx)[value_sel]
               .agg(avg='mean', std='std', min='min', max='max'))
    stats['range'] = stats['max'] - stats['min']
    
    # join, order, sort
    finite_mask = np.isfinite(pt.to_numpy()).all(axis=1)
    pt_sel = (pt.loc[finite_mask]
                .join(stats, how='left')
                .loc[:, sector_cols + ['avg','std','min','max','range']]
                .sort_values('avg', ascending=False))
    
    # style
    styled = (pt_sel.style
               .format('{:.3f}')
               .background_gradient(cmap='RdBu', vmin=vmin_cagr, vmax=vmax_cagr,
                                    subset=sector_cols + ['avg'])
               .highlight_null())
    
    # lock in order
    base_idx  = pt_sel.index                                 # exact rows + order
    cols_tail = ['avg','std','min','max','range']            # trailing stats
    cols_all = sector_cols + cols_tail                      # exact columns

    return styled, base_idx, cols_tail, cols_all

def performance_securities(df, value_sel, base_idx):
    """Rows = (config, n_regimes, dim_latent).
    Cols = (sector, security). Styled. No right-hand stats."""
    idx = ['config','n_regimes','dim_latent']
    tbl = (df.pivot_table(index=idx,
                          columns=['sector','security'],
                          values=value_sel,
                          aggfunc='mean')
             .sort_index(axis=1)
             .reindex(base_idx))   # preserve exact row order

    styled = (tbl.style
                .format('{:.3f}')
                .background_gradient(cmap='RdBu',
                                     vmin=vmin_cagr, vmax=vmax_cagr)
                .highlight_null())
    return styled

def _metric_table_core(value_sel, df, base_idx, cols_tail, cols_all):
    idx = list(base_idx.names)
    sector_cols = [c for c in cols_all if c not in cols_tail]

    pt_m = (
        df.pivot_table(index=idx, columns='sector', values=value_sel, aggfunc='mean')
          .reindex(sector_cols, axis=1)
          .reindex(base_idx)
    )

    stats_m = (
        df.groupby(idx)[value_sel]
          .agg(avg='mean', std='std', min='min', max='max')
          .reindex(base_idx)
    )
    stats_m['range'] = stats_m['max'] - stats_m['min']

    tbl = pd.concat([pt_m, stats_m[cols_tail]], axis=1).reindex(columns=cols_all)

    # this is what you wanted: expose the max of the colored cols
    data_max = tbl[sector_cols + ['avg']].to_numpy().max()

    return tbl, sector_cols, float(data_max)

def cpll_table(df, base_idx, cols_tail, cols_all,
               vmax=None, fmt='{:,.1f}'):
    value_sel = 'CPLL Gap'
    tbl, sector_cols, data_max = _metric_table_core(
        value_sel, df, base_idx, cols_tail, cols_all
    )
    vmin = 0.0
    if vmax is None:
        vmax = data_max

    return (tbl.style
                .format(fmt)
                .background_gradient(
                    cmap='Reds',
                    vmin=vmin,
                    vmax=vmax,
                    subset=sector_cols + ['avg'],
                )
                .highlight_null())


def elbo_table(df, base_idx, cols_tail, cols_all,
               vmax=None, fmt='{:,.1f}'):
    value_sel = 'elbo_delta (max all runs)'
    tbl, sector_cols, data_max = _metric_table_core(
        value_sel, df, base_idx, cols_tail, cols_all
    )
    vmin = 0.0
    if vmax is None:
        vmax = data_max

    return (tbl.style
                .format(fmt)
                .background_gradient(
                    cmap='Blues',     # high → blue
                    vmin=vmin,
                    vmax=vmax,
                    subset=sector_cols + ['avg'],
                )
                .highlight_null())

# Formatting
CAPTION_CSS = [{'selector': 'caption',
                'props': [('caption-side','top'),
                          ('text-align','left'),
                          ('font-weight','700')]}]

# %%
# Model performance - unrestricted
df_unrestr = res[res['config'].isin(unrestricted)]
df_unrestr.to_csv('Out/df_unrestr.csv')
styled_unrestr, base_idx_unrestr, cols_tail_unrestr, cols_all_unrestr = performance(df_unrestr, 'cagr_rel_ex_ante')
styled_unrestr.set_caption("Rel CAGR - Unrestricted Models")
styled_unrestr.set_table_styles(CAPTION_CSS, overwrite=False)
styled_unrestr.data.to_csv('Out/unrestr_rel_cagr.csv')
styled_unrestr
# Out:
# <style type="text/css">
# #T_b733c caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_b733c_row0_col0, #T_b733c_row23_col2 {
#   background-color: #3a87bd;
#   color: #f1f1f1;
# }
# #T_b733c_row0_col1, #T_b733c_row8_col6, #T_b733c_row16_col8, #T_b733c_row17_col9 {
#   background-color: #a5cee3;
#   color: #000000;
# }
# #T_b733c_row0_col2, #T_b733c_row0_col5, #T_b733c_row1_col5, #T_b733c_row2_col2, #T_b733c_row4_col6 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_b733c_row0_col3, #T_b733c_row8_col5 {
#   background-color: #5fa5cd;
#   color: #f1f1f1;
# }
# #T_b733c_row0_col4, #T_b733c_row8_col9 {
#   background-color: #4291c2;
#   color: #f1f1f1;
# }
# #T_b733c_row0_col6, #T_b733c_row20_col2 {
#   background-color: #327cb7;
#   color: #f1f1f1;
# }
# #T_b733c_row0_col7, #T_b733c_row21_col1, #T_b733c_row22_col7, #T_b733c_row24_col1, #T_b733c_row28_col9 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_b733c_row0_col8, #T_b733c_row1_col4, #T_b733c_row1_col9, #T_b733c_row3_col8, #T_b733c_row6_col9, #T_b733c_row15_col5, #T_b733c_row26_col7 {
#   background-color: #65a9cf;
#   color: #f1f1f1;
# }
# #T_b733c_row0_col9, #T_b733c_row1_col8, #T_b733c_row9_col5, #T_b733c_row12_col6 {
#   background-color: #4f9bc7;
#   color: #f1f1f1;
# }
# #T_b733c_row0_col10, #T_b733c_row2_col5, #T_b733c_row18_col9 {
#   background-color: #3885bc;
#   color: #f1f1f1;
# }
# #T_b733c_row0_col11, #T_b733c_row1_col2, #T_b733c_row21_col6 {
#   background-color: #3c8abe;
#   color: #f1f1f1;
# }
# #T_b733c_row1_col0, #T_b733c_row5_col9 {
#   background-color: #2a71b2;
#   color: #f1f1f1;
# }
# #T_b733c_row1_col1, #T_b733c_row6_col0, #T_b733c_row6_col11, #T_b733c_row9_col6 {
#   background-color: #90c4dd;
#   color: #000000;
# }
# #T_b733c_row1_col3, #T_b733c_row1_col6, #T_b733c_row1_col10 {
#   background-color: #62a7ce;
#   color: #f1f1f1;
# }
# #T_b733c_row1_col7, #T_b733c_row3_col0, #T_b733c_row13_col0, #T_b733c_row14_col3, #T_b733c_row18_col1, #T_b733c_row30_col9 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_b733c_row1_col11, #T_b733c_row14_col5 {
#   background-color: #529dc8;
#   color: #f1f1f1;
# }
# #T_b733c_row2_col0, #T_b733c_row4_col11, #T_b733c_row20_col0 {
#   background-color: #7bb6d6;
#   color: #000000;
# }
# #T_b733c_row2_col1, #T_b733c_row7_col8, #T_b733c_row13_col10, #T_b733c_row17_col8 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_b733c_row2_col3, #T_b733c_row12_col8 {
#   background-color: #9dcbe1;
#   color: #000000;
# }
# #T_b733c_row2_col4, #T_b733c_row10_col10, #T_b733c_row16_col10, #T_b733c_row17_col0 {
#   background-color: #b6d7e8;
#   color: #000000;
# }
# #T_b733c_row2_col6, #T_b733c_row3_col5, #T_b733c_row4_col9 {
#   background-color: #2267ac;
#   color: #f1f1f1;
# }
# #T_b733c_row2_col7, #T_b733c_row3_col11, #T_b733c_row10_col2, #T_b733c_row10_col9, #T_b733c_row18_col6 {
#   background-color: #6eaed2;
#   color: #f1f1f1;
# }
# #T_b733c_row2_col8, #T_b733c_row13_col9, #T_b733c_row19_col2 {
#   background-color: #71b0d3;
#   color: #f1f1f1;
# }
# #T_b733c_row2_col9, #T_b733c_row3_col2, #T_b733c_row3_col6, #T_b733c_row16_col2 {
#   background-color: #337eb8;
#   color: #f1f1f1;
# }
# #T_b733c_row2_col10, #T_b733c_row5_col4, #T_b733c_row6_col2, #T_b733c_row6_col10, #T_b733c_row7_col4, #T_b733c_row8_col0, #T_b733c_row16_col6, #T_b733c_row21_col8 {
#   background-color: #cfe4ef;
#   color: #000000;
# }
# #T_b733c_row2_col11, #T_b733c_row10_col5, #T_b733c_row25_col9 {
#   background-color: #68abd0;
#   color: #f1f1f1;
# }
# #T_b733c_row3_col1, #T_b733c_row6_col8, #T_b733c_row19_col8 {
#   background-color: #a7d0e4;
#   color: #000000;
# }
# #T_b733c_row3_col3, #T_b733c_row9_col10, #T_b733c_row22_col9 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_b733c_row3_col4, #T_b733c_row3_col10, #T_b733c_row5_col10, #T_b733c_row9_col2, #T_b733c_row11_col11 {
#   background-color: #b3d6e8;
#   color: #000000;
# }
# #T_b733c_row3_col7 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# #T_b733c_row3_col9 {
#   background-color: #195696;
#   color: #f1f1f1;
# }
# #T_b733c_row4_col0, #T_b733c_row5_col1, #T_b733c_row10_col7, #T_b733c_row14_col8, #T_b733c_row17_col3, #T_b733c_row18_col10, #T_b733c_row22_col10 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_b733c_row4_col1, #T_b733c_row4_col7, #T_b733c_row13_col3, #T_b733c_row18_col8 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_b733c_row4_col2, #T_b733c_row11_col6, #T_b733c_row15_col9 {
#   background-color: #98c8e0;
#   color: #000000;
# }
# #T_b733c_row4_col3, #T_b733c_row11_col4, #T_b733c_row12_col11, #T_b733c_row13_col11, #T_b733c_row14_col11, #T_b733c_row18_col2, #T_b733c_row20_col5, #T_b733c_row26_col2, #T_b733c_row31_col2 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_b733c_row4_col4, #T_b733c_row14_col0 {
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_b733c_row4_col5, #T_b733c_row10_col4, #T_b733c_row13_col8, #T_b733c_row15_col3, #T_b733c_row15_col8, #T_b733c_row20_col6, #T_b733c_row28_col7 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_b733c_row4_col8, #T_b733c_row7_col0, #T_b733c_row7_col11, #T_b733c_row8_col11 {
#   background-color: #acd2e5;
#   color: #000000;
# }
# #T_b733c_row4_col10, #T_b733c_row16_col9, #T_b733c_row23_col6 {
#   background-color: #8dc2dc;
#   color: #000000;
# }
# #T_b733c_row5_col0, #T_b733c_row5_col5, #T_b733c_row6_col3 {
#   background-color: #59a1ca;
#   color: #f1f1f1;
# }
# #T_b733c_row5_col2, #T_b733c_row27_col5 {
#   background-color: #0d3f76;
#   color: #f1f1f1;
# }
# #T_b733c_row5_col3, #T_b733c_row20_col8 {
#   background-color: #96c7df;
#   color: #000000;
# }
# #T_b733c_row5_col6, #T_b733c_row5_col8, #T_b733c_row17_col5, #T_b733c_row19_col9 {
#   background-color: #6bacd1;
#   color: #f1f1f1;
# }
# #T_b733c_row5_col7 {
#   background-color: #2b73b3;
#   color: #f1f1f1;
# }
# #T_b733c_row5_col11, #T_b733c_row21_col9 {
#   background-color: #84bcd9;
#   color: #000000;
# }
# #T_b733c_row6_col1, #T_b733c_row16_col0, #T_b733c_row19_col4, #T_b733c_row22_col6, #T_b733c_row24_col11, #T_b733c_row26_col1, #T_b733c_row26_col5, #T_b733c_row29_col2, #T_b733c_row31_col5 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_b733c_row6_col4, #T_b733c_row8_col4, #T_b733c_row15_col11, #T_b733c_row16_col11 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_b733c_row6_col5 {
#   background-color: #1b5a9c;
#   color: #f1f1f1;
# }
# #T_b733c_row6_col6, #T_b733c_row10_col8, #T_b733c_row11_col9, #T_b733c_row12_col5, #T_b733c_row27_col10 {
#   background-color: #81bad8;
#   color: #000000;
# }
# #T_b733c_row6_col7, #T_b733c_row13_col7, #T_b733c_row25_col0, #T_b733c_row29_col9 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_b733c_row7_col1, #T_b733c_row20_col3, #T_b733c_row26_col11, #T_b733c_row28_col5 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_b733c_row7_col2, #T_b733c_row22_col0, #T_b733c_row24_col5, #T_b733c_row27_col3 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_b733c_row7_col3, #T_b733c_row12_col3, #T_b733c_row15_col7 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_b733c_row7_col5 {
#   background-color: #569fc9;
#   color: #f1f1f1;
# }
# #T_b733c_row7_col6, #T_b733c_row10_col0 {
#   background-color: #307ab6;
#   color: #f1f1f1;
# }
# #T_b733c_row7_col7 {
#   background-color: #4c99c6;
#   color: #f1f1f1;
# }
# #T_b733c_row7_col9, #T_b733c_row8_col10, #T_b733c_row9_col8, #T_b733c_row22_col5, #T_b733c_row23_col5 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_b733c_row7_col10, #T_b733c_row14_col4, #T_b733c_row19_col11, #T_b733c_row20_col10, #T_b733c_row20_col11 {
#   background-color: #cae1ee;
#   color: #000000;
# }
# #T_b733c_row8_col1, #T_b733c_row18_col5 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# #T_b733c_row8_col2, #T_b733c_row22_col2 {
#   background-color: #3e8cbf;
#   color: #f1f1f1;
# }
# #T_b733c_row8_col3, #T_b733c_row10_col3, #T_b733c_row11_col0, #T_b733c_row20_col9 {
#   background-color: #d2e6f0;
#   color: #000000;
# }
# #T_b733c_row8_col7, #T_b733c_row19_col1, #T_b733c_row30_col10 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_b733c_row8_col8, #T_b733c_row9_col3, #T_b733c_row9_col4, #T_b733c_row9_col7, #T_b733c_row27_col0 {
#   background-color: #c7e0ed;
#   color: #000000;
# }
# #T_b733c_row9_col0, #T_b733c_row16_col4, #T_b733c_row20_col4, #T_b733c_row21_col11, #T_b733c_row22

# %%
styled_unrestr_securities = performance_securities(df_unrestr, 'cagr_rel_ex_ante', base_idx_unrestr)
styled_unrestr_securities.data.to_csv('Out/unrestr_rel_cagr_securities.csv')
# styled_unrestr_securities

# %%
# Smooth CPLL - unrestricted
styled_cpll_all = cpll_table(
    df_unrestr,
    base_idx_unrestr,
    cols_tail_unrestr,
    cols_all_unrestr,
    vmax=vmax_cpll,
)
styled_cpll_all = (
    styled_cpll_all
    .set_caption("Smooth CPLL Gap - Unrestricted Models")
    .set_table_styles(CAPTION_CSS, overwrite=False)
)
styled_cpll_all.data.to_csv('Out/unrestr_cpll_gap.csv')
styled_cpll_all
# Out:
# <style type="text/css">
# #T_3eb98 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_3eb98_row0_col0, #T_3eb98_row0_col6, #T_3eb98_row0_col9, #T_3eb98_row1_col0, #T_3eb98_row1_col6, #T_3eb98_row1_col9, #T_3eb98_row2_col0, #T_3eb98_row2_col6, #T_3eb98_row2_col9, #T_3eb98_row3_col0, #T_3eb98_row3_col6, #T_3eb98_row3_col9, #T_3eb98_row27_col0, #T_3eb98_row27_col6, #T_3eb98_row27_col9 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_3eb98_row0_col1, #T_3eb98_row0_col10, #T_3eb98_row1_col1, #T_3eb98_row1_col10, #T_3eb98_row2_col1, #T_3eb98_row2_col10, #T_3eb98_row3_col1, #T_3eb98_row3_col10, #T_3eb98_row27_col1, #T_3eb98_row27_col10 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_3eb98_row0_col2, #T_3eb98_row0_col3, #T_3eb98_row0_col4, #T_3eb98_row0_col5, #T_3eb98_row0_col8, #T_3eb98_row0_col11, #T_3eb98_row1_col2, #T_3eb98_row1_col3, #T_3eb98_row1_col4, #T_3eb98_row1_col5, #T_3eb98_row1_col8, #T_3eb98_row1_col11, #T_3eb98_row2_col2, #T_3eb98_row2_col3, #T_3eb98_row2_col4, #T_3eb98_row2_col5, #T_3eb98_row2_col8, #T_3eb98_row2_col11, #T_3eb98_row3_col2, #T_3eb98_row3_col3, #T_3eb98_row3_col4, #T_3eb98_row3_col5, #T_3eb98_row3_col8, #T_3eb98_row3_col11, #T_3eb98_row27_col2, #T_3eb98_row27_col3, #T_3eb98_row27_col4, #T_3eb98_row27_col5, #T_3eb98_row27_col8, #T_3eb98_row27_col11 {
#   background-color: #fee1d3;
#   color: #000000;
# }
# #T_3eb98_row0_col7, #T_3eb98_row1_col7, #T_3eb98_row2_col7, #T_3eb98_row3_col7, #T_3eb98_row27_col7 {
#   background-color: #fee0d2;
#   color: #000000;
# }
# #T_3eb98_row4_col0, #T_3eb98_row5_col0, #T_3eb98_row11_col0, #T_3eb98_row14_col0, #T_3eb98_row28_col0 {
#   background-color: #fcbca2;
#   color: #000000;
# }
# #T_3eb98_row4_col1, #T_3eb98_row5_col1, #T_3eb98_row11_col1, #T_3eb98_row14_col1, #T_3eb98_row28_col1 {
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_3eb98_row4_col2, #T_3eb98_row5_col2, #T_3eb98_row11_col2, #T_3eb98_row14_col2, #T_3eb98_row28_col2 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_3eb98_row4_col3, #T_3eb98_row5_col3, #T_3eb98_row11_col3, #T_3eb98_row14_col3, #T_3eb98_row28_col3 {
#   background-color: #fcb398;
#   color: #000000;
# }
# #T_3eb98_row4_col4, #T_3eb98_row5_col4, #T_3eb98_row11_col4, #T_3eb98_row14_col4, #T_3eb98_row28_col4 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_3eb98_row4_col5, #T_3eb98_row5_col5, #T_3eb98_row11_col5, #T_3eb98_row14_col5, #T_3eb98_row28_col5 {
#   background-color: #fcbda4;
#   color: #000000;
# }
# #T_3eb98_row4_col6, #T_3eb98_row5_col6, #T_3eb98_row11_col6, #T_3eb98_row14_col6, #T_3eb98_row28_col6 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_3eb98_row4_col7, #T_3eb98_row5_col7, #T_3eb98_row11_col7, #T_3eb98_row14_col7, #T_3eb98_row28_col7 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_3eb98_row4_col8, #T_3eb98_row5_col8, #T_3eb98_row11_col8, #T_3eb98_row14_col8, #T_3eb98_row28_col8 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_3eb98_row4_col9, #T_3eb98_row5_col9, #T_3eb98_row11_col9, #T_3eb98_row14_col9, #T_3eb98_row28_col9 {
#   background-color: #fcb79c;
#   color: #000000;
# }
# #T_3eb98_row4_col10, #T_3eb98_row5_col10, #T_3eb98_row11_col10, #T_3eb98_row14_col10, #T_3eb98_row28_col10 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_3eb98_row4_col11, #T_3eb98_row5_col11, #T_3eb98_row11_col11, #T_3eb98_row14_col11, #T_3eb98_row28_col11 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_3eb98_row6_col0, #T_3eb98_row6_col5, #T_3eb98_row7_col0, #T_3eb98_row7_col5, #T_3eb98_row9_col0, #T_3eb98_row9_col5, #T_3eb98_row13_col0, #T_3eb98_row13_col5, #T_3eb98_row16_col0, #T_3eb98_row16_col5, #T_3eb98_row19_col0, #T_3eb98_row19_col5, #T_3eb98_row24_col0, #T_3eb98_row24_col5, #T_3eb98_row26_col0, #T_3eb98_row26_col5, #T_3eb98_row29_col0, #T_3eb98_row29_col5, #T_3eb98_row31_col0, #T_3eb98_row31_col5 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_3eb98_row6_col1, #T_3eb98_row7_col1, #T_3eb98_row9_col1, #T_3eb98_row13_col1, #T_3eb98_row16_col1, #T_3eb98_row19_col1, #T_3eb98_row24_col1, #T_3eb98_row26_col1, #T_3eb98_row29_col1, #T_3eb98_row31_col1 {
#   background-color: #fc9272;
#   color: #000000;
# }
# #T_3eb98_row6_col2, #T_3eb98_row7_col2, #T_3eb98_row9_col2, #T_3eb98_row13_col2, #T_3eb98_row16_col2, #T_3eb98_row19_col2, #T_3eb98_row24_col2, #T_3eb98_row26_col2, #T_3eb98_row29_col2, #T_3eb98_row31_col2 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_3eb98_row6_col3, #T_3eb98_row7_col3, #T_3eb98_row9_col3, #T_3eb98_row13_col3, #T_3eb98_row16_col3, #T_3eb98_row19_col3, #T_3eb98_row24_col3, #T_3eb98_row26_col3, #T_3eb98_row29_col3, #T_3eb98_row31_col3 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_3eb98_row6_col4, #T_3eb98_row7_col4, #T_3eb98_row9_col4, #T_3eb98_row13_col4, #T_3eb98_row16_col4, #T_3eb98_row19_col4, #T_3eb98_row24_col4, #T_3eb98_row26_col4, #T_3eb98_row29_col4, #T_3eb98_row31_col4 {
#   background-color: #fc9777;
#   color: #000000;
# }
# #T_3eb98_row6_col6, #T_3eb98_row7_col6, #T_3eb98_row9_col6, #T_3eb98_row13_col6, #T_3eb98_row16_col6, #T_3eb98_row19_col6, #T_3eb98_row24_col6, #T_3eb98_row26_col6, #T_3eb98_row29_col6, #T_3eb98_row31_col6 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_3eb98_row6_col7, #T_3eb98_row7_col7, #T_3eb98_row9_col7, #T_3eb98_row13_col7, #T_3eb98_row16_col7, #T_3eb98_row19_col7, #T_3eb98_row24_col7, #T_3eb98_row26_col7, #T_3eb98_row29_col7, #T_3eb98_row31_col7 {
#   background-color: #fdd2bf;
#   color: #000000;
# }
# #T_3eb98_row6_col8, #T_3eb98_row7_col8, #T_3eb98_row9_col8, #T_3eb98_row13_col8, #T_3eb98_row16_col8, #T_3eb98_row19_col8, #T_3eb98_row24_col8, #T_3eb98_row26_col8, #T_3eb98_row29_col8, #T_3eb98_row31_col8 {
#   background-color: #fca082;
#   color: #000000;
# }
# #T_3eb98_row6_col9, #T_3eb98_row6_col11, #T_3eb98_row7_col9, #T_3eb98_row7_col11, #T_3eb98_row9_col9, #T_3eb98_row9_col11, #T_3eb98_row13_col9, #T_3eb98_row13_col11, #T_3eb98_row16_col9, #T_3eb98_row16_col11, #T_3eb98_row19_col9, #T_3eb98_row19_col11, #T_3eb98_row24_col9, #T_3eb98_row24_col11, #T_3eb98_row26_col9, #T_3eb98_row26_col11, #T_3eb98_row29_col9, #T_3eb98_row29_col11, #T_3eb98_row31_col9, #T_3eb98_row31_col11 {
#   background-color: #fc9c7d;
#   color: #000000;
# }
# #T_3eb98_row6_col10, #T_3eb98_row7_col10, #T_3eb98_row9_col10, #T_3eb98_row13_col10, #T_3eb98_row16_col10, #T_3eb98_row19_col10, #T_3eb98_row24_col10, #T_3eb98_row26_col10, #T_3eb98_row29_col10, #T_3eb98_row31_col10 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_3eb98_row8_col0, #T_3eb98_row12_col0, #T_3eb98_row18_col0, #T_3eb98_row20_col0, #T_3eb98_row21_col0, #T_3eb98_row22_col0, #T_3eb98_row25_col0, #T_3eb98_row32_col0 {
#   background-color: #f6553c;
#   color: #f1f1f1;
# }
# #T_3eb98_row8_col1, #T_3eb98_row12_col1, #T_3eb98_row18_col1, #T_3eb98_row20_col1, #T_3eb98_row21_col1, #T_3eb98_row22_col1, #T_3eb98_row25_col1, #T_3eb98_row32_col1 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_3eb98_row8_col2, #T_3eb98_row12_col2, #T_3eb98_row18_col2, #T_3eb98_row20_col2, #T_3eb98_row21_col2, #T_3eb98_row22_col2, #T_3eb98_row25_col2, #T_3eb98_row32_col2 {
#   background-color: #f96245;
#   color: #f1f1f1;
# }
# #T_3eb98_row8_col3, #T_3eb98_row8_col4, #T_3eb98_row12_col3, #T_3eb98_row12_col4, #T_3eb98_row18_col3, #T_3eb98_row18_col4, #T_3eb98_row20_col3, #T_3eb98_row20_col4, #T_3eb98_row21_col3, #T_3eb98_row21_col4, #T_3eb98_row22_col3, #T_3eb98_row22_col4, #T_3eb98_row25_col3, #T_3eb98_row25_col4, #T_3eb98_row32_col3, #T_3eb98_row32_col4 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_3eb98_row8_col5, #T_3eb98_row12_col5, #T_3eb98_row18_col5, #T_3eb98_row20_col5, #T_3eb98_row21_col5, #T_3eb98_row22_col5, #T_3eb98_row25_col5, #T_3eb98_row32_col5 {
#   background-color: #f5533b;
#   color: #f1f1f1;
# }
# #T_3eb98_row8_col6, #T_3eb98_row18_col6, #T_3eb98_row20_col6, #T_3eb98_row21_col6 {
#   background-color: #f34c37;
#   color: #f1f1f1;
# }
# #T_3eb98_row8_col7, #T_3eb98_row12_col7, #T_3eb98_row18_col7, #T_3eb98_row20_col7, #T_3eb98_row21_col7, #T_3eb98_row22_col7, #T_3eb98_row25_col7, #T_3eb98_row32_col7 {
#   background-color: #fcaa8d;
#   color: #000000;
# }
# #T_3eb98_row8_col8,

# %%
# Delta ELBO - unrestricted
styled_elbo_all = elbo_table(
    df_unrestr,
    base_idx_unrestr,
    cols_tail_unrestr,
    cols_all_unrestr,
    vmax=vmax_elbo,
)
styled_elbo_all = (
    styled_elbo_all
    .set_caption("Delta ELBO - Unrestricted Models")
    .set_table_styles(CAPTION_CSS, overwrite=False)
)
styled_elbo_all.data.to_csv('Out/unrestr_delta_elbo.csv')
styled_elbo_all
# Out:
# <style type="text/css">
# #T_9cd47 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_9cd47_row0_col0, #T_9cd47_row0_col1, #T_9cd47_row0_col2, #T_9cd47_row0_col4, #T_9cd47_row0_col5, #T_9cd47_row0_col6, #T_9cd47_row0_col8, #T_9cd47_row0_col11, #T_9cd47_row1_col0, #T_9cd47_row1_col3, #T_9cd47_row1_col4, #T_9cd47_row1_col7, #T_9cd47_row1_col9, #T_9cd47_row1_col11, #T_9cd47_row2_col0, #T_9cd47_row2_col1, #T_9cd47_row2_col3, #T_9cd47_row2_col6, #T_9cd47_row2_col7, #T_9cd47_row2_col8, #T_9cd47_row2_col9, #T_9cd47_row2_col10, #T_9cd47_row2_col11, #T_9cd47_row3_col2, #T_9cd47_row3_col3, #T_9cd47_row3_col4, #T_9cd47_row3_col5, #T_9cd47_row3_col7, #T_9cd47_row3_col11, #T_9cd47_row27_col1, #T_9cd47_row27_col2, #T_9cd47_row27_col3, #T_9cd47_row27_col5, #T_9cd47_row27_col6, #T_9cd47_row27_col7, #T_9cd47_row27_col8, #T_9cd47_row27_col9, #T_9cd47_row27_col10, #T_9cd47_row27_col11 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_9cd47_row0_col3, #T_9cd47_row0_col7, #T_9cd47_row0_col9, #T_9cd47_row1_col2, #T_9cd47_row1_col5, #T_9cd47_row1_col6, #T_9cd47_row1_col8, #T_9cd47_row1_col10, #T_9cd47_row2_col2, #T_9cd47_row2_col5, #T_9cd47_row3_col0, #T_9cd47_row3_col6, #T_9cd47_row3_col9, #T_9cd47_row27_col0 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_9cd47_row0_col10, #T_9cd47_row1_col1, #T_9cd47_row2_col4, #T_9cd47_row3_col1, #T_9cd47_row3_col8, #T_9cd47_row3_col10, #T_9cd47_row27_col4 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_9cd47_row4_col0, #T_9cd47_row7_col11, #T_9cd47_row9_col11, #T_9cd47_row26_col11, #T_9cd47_row28_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_9cd47_row4_col1, #T_9cd47_row4_col10, #T_9cd47_row5_col9, #T_9cd47_row6_col3, #T_9cd47_row6_col4, #T_9cd47_row6_col10, #T_9cd47_row7_col1, #T_9cd47_row7_col3, #T_9cd47_row7_col4, #T_9cd47_row9_col1, #T_9cd47_row9_col3, #T_9cd47_row9_col4, #T_9cd47_row9_col9, #T_9cd47_row11_col9, #T_9cd47_row26_col3, #T_9cd47_row28_col7, #T_9cd47_row28_col10, #T_9cd47_row29_col4, #T_9cd47_row29_col9, #T_9cd47_row29_col10 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_9cd47_row4_col2, #T_9cd47_row5_col2, #T_9cd47_row9_col8, #T_9cd47_row11_col2, #T_9cd47_row11_col8, #T_9cd47_row14_col8, #T_9cd47_row29_col8 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T
{
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_9cd47_row8_col6, #T_9cd47_row18_col6, #T_9cd47_row32_col6 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_9cd47_row8_col7, #T_9cd47_row18_col7, #T_9cd47_row21_col7 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_9cd47_row8_col8, #T_9cd47_row20_col8 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_9cd47_row8_col11, #T_9cd47_row18_col11, #T_9cd47_row20_col2, #T_9cd47_row21_col2, #T_9cd47_row21_col11, #T_9cd47_row32_col2, #T_9cd47_row32_col11 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_9cd47_row9_col5, #T_9cd47_row11_col5 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_9cd47_row10_col0, #T_9cd47_row10_col6, #T_9cd47_row15_col6, #T_9cd47_row17_col0, #T_9cd47_row17_col1, #T_9cd47_row17_col3, #T_9cd47_row23_col1, #T_9cd47_row23_col6, #T_9cd47_row30_col5, #T_9cd47_row30_col6 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_9cd47_row10_col1, #T_9cd47_row10_col2, #T_9cd47_row10_col3, #T_9cd47_row10_col4, #T_9cd47_row10_col11, #T_9cd47_row15_col0, #T_9cd47_row15_col8, #T_9cd47_row15_col9, #T_9cd47_row15_col10, #T_9cd47_row15_col11, #T_9cd47_row17_col2, #T_9cd47_row17_col4, #T_9cd47_row17_col6, #T_9cd47_row17_col8, #T_9cd47_row17_col10, #T_9cd47_row17_col11, #T_9cd47_row23_col0, #T_9cd47_row23_col3, #T_9cd47_row23_col8, #T_9cd47_row23_col9, #T_9cd47_row23_col11, #T_9cd47_row30_col0, #T_9cd47_row30_col1, #T_9cd47_row30_col4, #T_9cd47_row30_col8, #T_9cd47_row30_col9, #T_9cd47_row30_col11 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_9cd47_row10_col5, #T_9cd47_row17_col5 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_9cd47_row10_col7, #T_9cd47_row10_col8, #T_9cd47_row10_col9, #T_9cd47_row10_col10, #T_9cd47_row15_col1, #T_9cd47_row15_col3, #T_9cd47_row15_col4, #T_9cd47_row15_col5, #T_9cd47_row17_col9, #T_9cd47_row23_col2, #T_9cd47_row23_col4, #T_9cd47_row23_col5, #T_9cd47_row23_col10, #T_9cd47_row30_col2, #T_9cd47_row30_col3 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_9cd47_row11_col7 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_9cd47_row12_col0 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_9cd47_row12_col1, #T_9cd47_row12_col3, #T_9cd47_row22_col1, #T_9cd47_row22_col4, #T_9cd47_row25_col1, #T_9cd47_row25_col3, #T_9cd47_row25_col4 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_9cd47_row12_col2, #T_9cd47_row22_col2, #T_9cd47_

# %%
# Unrestricted models: heatmaps

if 'CPLL Gap' not in res.columns:
    res['CPLL Gap'] = res['max cpll (proxy bound, paired)'] - res['cpll (max all runs)']

configs = np.unique(res['config'])
unrestricted = [x for x in configs if str(x).startswith('[')]
df = res[res['config'].isin(unrestricted)].copy()

finite = (
    pd.to_numeric(df['cagr_rel_ex_ante'], errors='coerce').notna()
    & pd.to_numeric(df['CPLL Gap'], errors='coerce').notna()
    & pd.to_numeric(df['elbo_delta (max all runs)'], errors='coerce').notna()
    & pd.to_numeric(df['n_regimes'], errors='coerce').notna()
    & pd.to_numeric(df['dim_latent'], errors='coerce').notna()
)
df = df.loc[finite].copy()

m = (df.groupby(['n_regimes','dim_latent'], as_index=False)
         .agg(rel_cagr=('cagr_rel_ex_ante','mean'),
              cpll_gap=('CPLL Gap','mean'),
              delta_elbo=('elbo_delta (max all runs)','mean')))

# Multiply CAGR by 100 to express as percentage
m['rel_cagr'] *= 100

def pivotKD(frame, value):
    p = frame.pivot(index='dim_latent', columns='n_regimes', values=value)
    return p.sort_index().sort_index(axis=1)

def _annotate(ax, Z, fmt):
    """Write value inside each heatmap cell."""
    nrows, ncols = Z.shape
    for i in range(nrows):
        for j in range(ncols):
            v = Z[i, j]
            if np.isfinite(v):
                ax.text(j, i, fmt(v), ha='center', va='center')

# Pivots
pivot_cagr = pivotKD(m, 'rel_cagr')
pivot_gap  = pivotKD(m, 'cpll_gap')
pivot_elbo = pivotKD(m, 'delta_elbo')


# ---------------- Rel-CAGR % | CPLL Gap | ΔELBO — single figure ----------------
fig, axes = plt.subplots(1, 3, figsize=(18, 4), constrained_layout=True)

# ---- Rel-CAGR (%)
im0 = axes[0].imshow(pivot_cagr, aspect='auto', cmap='RdBu', vmin=vmin_cagr*100, vmax=vmax_cagr*100)
axes[0].set_title("Mean Rel-CAGR (%)")
axes[0].set_xlabel('K'); axes[0].set_ylabel('D')
axes[0].set_xticks(range(len(pivot_cagr.columns))); axes[0].set_xticklabels(pivot_cagr.columns)
axes[0].set_yticks(range(len(pivot_cagr.index)));   axes[0].set_yticklabels(pivot_cagr.index)
_annotate(axes[0], pivot_cagr.values, fmt=lambda v: f"{v:.1f}%")
fig.colorbar(im0, ax=axes[0], format='%d%%', fraction=0.046, pad=0.04)

# ---- CPLL Gap
im1 = axes[1].imshow(pivot_gap, aspect='auto', cmap='Reds', vmin=0.0, vmax=vmax_cpll)
axes[1].set_title("Mean CPLL Gap")
axes[1].set_xlabel('K'); axes[1].set_ylabel('D')
axes[1].set_xticks(range(len(pivot_gap.columns))); axes[1].set_xticklabels(pivot_gap.columns)
axes[1].set_yticks(range(len(pivot_gap.index)));   axes[1].set_yticklabels(pivot_gap.index)
_annotate(axes[1], pivot_gap.values, fmt=lambda v: f"{v:,.0f}")
fig.colorbar(im1, ax=axes[1], format='%d', fraction=0.046, pad=0.04)

# ---- ΔELBO
im2 = axes[2].imshow(pivot_elbo, aspect='auto', cmap='Blues', vmin=0.0, vmax=vmax_elbo)
axes[2].set_title("Mean ΔELBO")
axes[2].set_xlabel('K'); axes[2].set_ylabel('D')
axes[2].set_xticks(range(len(pivot_elbo.columns))); axes[2].set_xticklabels(pivot_elbo.columns)
axes[2].set_yticks(range(len(pivot_elbo.index)));   axes[2].set_yticklabels(pivot_elbo.index)
_annotate(axes[2], pivot_elbo.values, fmt=lambda v: f"{v:,.0f}")
fig.colorbar(im2, ax=axes[2], format='%d', fraction=0.046, pad=0.04)

plt.show()

# %%
# Model performance - restricted
df_restr = res[res['config'].isin(restricted)]
styled_restr, base_idx_restr, cols_tail_restr, cols_all_restr = performance(
    df_restr, 'cagr_rel_ex_ante'
)
styled_restr = (
    styled_restr
    .set_caption("Rel CAGR - Restricted Models")
    .set_table_styles(CAPTION_CSS, overwrite=False)
)
styled_restr.data.to_csv('Out/restr_rel_cagr.csv')
styled_restr
# Out:
# <style type="text/css">
# #T_34ac1 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T
{
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_34ac1_row3_col8, #T_34ac1_row8_col0, #T_34ac1_row15_col6, #T_34ac1_row21_col9 {
#   background-color: #68abd0;
#   color: #f1f1f1;
# }
# #T_34ac1_row3_col9 {
#   background-color: #4997c5;
#   color: #f1f1f1;
# }
# #T_34ac1_row4_col1, #T_34ac1_row7_col4, #T_34ac1_row29_col11, #T_34ac1_row30_col11, #T_34ac1_row31_col11, #T_34ac1_row38_col9 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_34ac1_row4_col2, #T_34ac1_row8_col9, #T_34ac1_row11_col11, #T_34ac1_row12_col11, #T_34ac1_row19_col10, #T_34ac1_row23_col5, #T_34ac1_row24_col5, #T_34ac1_row33_col8 {
#   background-color: #cae1ee;
#   color: #000000;
# }
# #T_34ac1_row4_col4, #T_34ac1_row8_col4, #T_34ac1_row14_col8, #T_34ac1_row23_col11, #T_34ac1_row24_col11, #T_34ac1_row25_col0, #T_34ac1_row25_col11, #T_34ac1_row26_col3, #T_34ac1_row26_col11, #T_34ac1_row27_col11, #T_34ac1_row28_col11 {
#   background-color: #d8e9f1;
#   color: #000000;
# }
# #T_34ac1_row4_col5, #T_34ac1_row9_col6 {
#   background-color: #337eb8;
#   color: #f1f1f1;
# }
# #T_34ac1_row4_col7, #T_34ac1_row14_col6, #T_34ac1_row16_col2, #T_34ac1_row16_col6, #T_34ac1_row16_col10, #T_34ac1_row32_col0, #T_34ac1_row37_col5 {
#   background-color: #cce2ef;
#   color: #000000;
# }
# #T_34ac1_row4_col8 {
#   background-color: #b1d5e7;
#   color: #000000;
# }
# #T_34ac1_row4_col10, #T_34ac1_row13_col6, #T_34ac1_row13_col11, #T_34ac1_row25_col10, #T_34ac1_row29_col5, #T_34ac1_row42_col5 {
#   background-color: #cfe4ef;
#   color: #000000;
# }
# #T_34ac1_row5_col0, #T_34ac1_row31_col9, #T_34ac1_row34_col0, #T_34ac1_row37_col6 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_34ac1_row5_col3, #T_34ac1_row7_col9, #T_34ac1_row11_col8, #T_34ac1_row33_col2 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_34ac1_row5_col5, #T_34ac1_row22_col9 {
#   background-color: #78b4d5;
#   color: #000000;
# }
# #T_34ac1_row5_col6, #T_34ac1_row33_col6 {
#   background-color: #93c6de;
#   color: #000000;
# }
# #T_34ac1_row5_col7, #T_34ac1_row12_col10, #T_34ac1_row19_col4, #T_34ac1_row21_col6, #T_34ac1_row30_col8, #T_34ac1_row39_col11, #T_34ac1_row40_col9, #T_34ac1_row41_col2, #T_34ac1_row43_col5, #T_34ac1_row46_col5 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_34ac1_row5_col8, #T_34ac1_row5_col11, #T_34ac1_row20_col5, #T_34ac1_row20_col8, #T_34ac1_row30_col9, #T_34ac1_row39_col5 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_34ac1_row5_col10, #T_34ac1_row20_col6, #T_34ac1_row26_col6 {
#   background-color: #eff3f5;
#   c

# %%
# Smooth CPLL - restricted
styled_cpll_all = cpll_table(
    df_restr,
    base_idx_restr,
    cols_tail_restr,
    cols_all_restr,
    vmax=vmax_cpll,
)
styled_cpll_all = (
    styled_cpll_all
    .set_caption("Smooth CPLL - Restricted Models")
    .set_table_styles(CAPTION_CSS, overwrite=False)
)
styled_cpll_all.data.to_csv('Out/restr_cpll_gap.csv')
styled_cpll_all
# Out:
# <style type="text/css">
# #T_8ff64 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T
64_row20_col3, #T_8ff64_row21_col0, #T_8ff64_row21_col1, #T_8ff64_row21_col2, #T_8ff64_row21_col3, #T_8ff64_row21_col4, #T_8ff64_row21_col5, #T_8ff64_row21_col6, #T_8ff64_row21_col7, #T_8ff64_row21_col8, #T_8ff64_row21_col9, #T_8ff64_row21_col10, #T_8ff64_row21_col11, #T_8ff64_row23_col0, #T_8ff64_row23_col1, #T_8ff64_row23_col2, #T_8ff64_row23_col3, #T_8ff64_row23_col4, #T_8ff64_row23_col5, #T_8ff64_row23_col6, #T_8ff64_row23_col7, #T_8ff64_row23_col8, #T_8ff64_row23_col9, #T_8ff64_row23_col10, #T_8ff64_row23_col11, #T_8ff64_row24_col3, #T_8ff64_row26_col0, #T_8ff64_row26_col1, #T_8ff64_row26_col2, #T_8ff64_row26_col3, #T_8ff64_row26_col4, #T_8ff64_row26_col5, #T_8ff64_ro

# %%
# Delta ELBO - restricted
styled_elbo_all = elbo_table(
    df_restr,
    base_idx_restr,
    cols_tail_restr,
    cols_all_restr,
    vmax=vmax_elbo,
)
styled_elbo_all = (
    styled_elbo_all
    .set_caption("Delta ELBO - Unrestricted Models")
    .set_table_styles(CAPTION_CSS, overwrite=False)
)
styled_elbo_all.data.to_csv('Out/restr_delta_elbo.csv')
styled_elbo_all
# Out:
# <style type="text/css">
# #T_f5594 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_f5594_row0_col0, #T_f5594_row0_col1, #T_f5594_row0_col2, #T_f5594_row0_col3, #T_f5594_row0_col4, #T_f5594_row0_col5, #T_f5594_row0_col6, #T_f5594_row0_col7, #T_f5594_row0_col8, #T_f5594_row0_col9, #T_f5594_row0_col10, #T_f5594_row0_col11, #T_f5594_row6_col0, #T_f5594_row6_col1, #T_f5594_row6_col2, #T_f5594_row6_col3, #T_f5594_row6_col4, #T_f5594_row6_col5, #T_f5594_row6_col6, #T_f5594_row6_col7, #T_f5594_row6_col8, #T_f5594_row6_col9, #T_f5594_row6_col10, #T_f5594_row6_col11, #T_f5594_row11_col0, #T_f5594_row11_col1, #T_f5594_row11_col2, #T_f5594_row11_col3, #T_f5594_row11_col4, #T_f5594_row11_col5, #T_f5594_row11_col6, #T_f5594_row11_col7, #T_f5594_row11_col8, #T_f5594_row11_col9, #T_f5594_row11_col10, #T_f5594_row11_col11, #T_f5594_row12_col5, #T_f5594_row14_col2, #T_f5594_row14_col5, #T_f5594_row16_col0, #T_f5594_row16_col1, #T_f5594_row16_col2, #T_f5594_row16_col3, #T_f5594_row16_col4, #T_f5594_row16_col5, #T_f5594_row16_col6, #T_f5594_row16_col7, #T_f5594_row16_col8, #T_f5594_row16_col9, #T_f5594_row16_col10, #T_f5594_row16_col11, #T_f5594_row21_col5, #T_f5594_row22_col0, #T_f5594_row22_col1, #T_f5594_row22_col2, #T_f5594_row22_col3, #T_f5594_row22_col4, #T_f5594_row22_col5, #T_f5594_row22_col6, #T_f5594_row22_col7, #T_f5594_row22_col8, #T_f5594_row22_col9, #T_f5594_row22_col10, #T_f5594_row22_col11, #T_f5
{
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_f5594_row4_col0, #T_f5594_row4_col1, #T_f5594_row4_col2, #T_f5594_row4_col4, #T_f5594_row4_col5, #T_f5594_row4_col6, #T_f5594_row4_col9, #T_f5594_row4_col10, #T_f5594_row4_col11, #T_f5594_row7_col0, #T_f5594_row7_col1, #T_f5594_row7_col4, #T_f5594_row7_col8, #T_f5594_row7_col9, #T_f5594_row7_col10, #T_f5594_row7_col11, #T_f5594_row10_col0, #T_f5594_row10_col1, #T_f5594_row10_col2, #T_f5594_row10_col4, #T_f5594_row10_col5, #T_f5594_row10_col6, #T_f5594_row10_col7, #T_f5594_row10_col8, #T_f5594_row10_col9, #T_f5594_row10_col11, #T_f5594_row38_col0, #T_f5594_row38_col1, #T_f5594_row38_col2, #T_f5594_row38_col3, #T_f5594_row38_col4, #T_f5594_row38_col5, #T_f5594_row38_col6, #T_f5594_row38_col7, #T_f5594_row38_col8, #T_f5594_row38_col9, #T_f5594_row38_col10, #T_f5594_row38_col11, #T_f5594_row49_col0, #T_f5594_row49_col1, #T_f5594_row49_col2, #T_f5594_row49_col3, #T_f5594_row49_col4, #T_f5594_row49_col5, #T_f5594_row49_col6, #T_f5594_row49_col7, #T_f5594_row49_col8, #T_f5594_row49_col9, #T_f5594_row49_col10, #T_f5594_row49_col11 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_f5594_row12_col0, #T_f5594_row12_col1, #T_f5594_row12_col2, #T_f5594_row12_col3, #T_f5594_row12_col4, #T_f5594_row12_col6, #T_f5594_row12_col7, #T_f5594_row12_col8, #T_f5594_row12_col9, #T_f5594_row12_col10, #T_f5594_row12_col11, #T_f5594_row13_col0, #T_f5594_row13_col1, #T_f5594_row13_col2, #T_f5594_row13_col3, #T_f5594_row13_col4, #T_f5594_row13_col5, #T_f5594_row13_col6, #T_f5594_row13_col7, #T_f5594_row13_col8, #T_f5594_row13_col9, #T_f5594_row13_col10, #T_f5594_row13_col11, #T_f5594_row14_col0, #T_f5594_row14_col1, #T_f5594_row14_col3, #T_f559

# %%
# Unrestricted models: heatmaps

if 'CPLL Gap' not in res.columns:
    res['CPLL Gap'] = res['max cpll (proxy bound, paired)'] - res['cpll (max all runs)']

configs = np.unique(res['config'])
restricted = [x for x in configs if not str(x).startswith('[')]
df = res[res['config'].isin(restricted)].copy()

finite = (
    pd.to_numeric(df['cagr_rel_ex_ante'], errors='coerce').notna()
    & pd.to_numeric(df['CPLL Gap'], errors='coerce').notna()
    & pd.to_numeric(df['elbo_delta (max all runs)'], errors='coerce').notna()
    & pd.to_numeric(df['n_regimes'], errors='coerce').notna()
    & pd.to_numeric(df['dim_latent'], errors='coerce').notna()
)
df = df.loc[finite].copy()

m = (df.groupby(['n_regimes','dim_latent'], as_index=False)
         .agg(rel_cagr=('cagr_rel_ex_ante','mean'),
              cpll_gap=('CPLL Gap','mean'),
              delta_elbo=('elbo_delta (max all runs)','mean')))

# Multiply CAGR by 100 to express as percentage
m['rel_cagr'] *= 100

def pivotKD(frame, value):
    p = frame.pivot(index='dim_latent', columns='n_regimes', values=value)
    return p.sort_index().sort_index(axis=1)

def _annotate(ax, Z, fmt):
    """Write value inside each heatmap cell."""
    nrows, ncols = Z.shape
    for i in range(nrows):
        for j in range(ncols):
            v = Z[i, j]
            if np.isfinite(v):
                ax.text(j, i, fmt(v), ha='center', va='center')

# Pivots
pivot_cagr = pivotKD(m, 'rel_cagr')
pivot_gap  = pivotKD(m, 'cpll_gap')
pivot_elbo = pivotKD(m, 'delta_elbo')


# ---------------- Rel-CAGR % | CPLL Gap | ΔELBO — single figure ----------------
fig, axes = plt.subplots(1, 3, figsize=(18, 4), constrained_layout=True)

# ---- Rel-CAGR (%)
im0 = axes[0].imshow(pivot_cagr, aspect='auto', cmap='RdBu', vmin=vmin_cagr*100, vmax=vmax_cagr*100)
axes[0].set_title("Mean Rel-CAGR (%)")
axes[0].set_xlabel('K'); axes[0].set_ylabel('D')
axes[0].set_xticks(range(len(pivot_cagr.columns))); axes[0].set_xticklabels(pivot_cagr.columns)
axes[0].set_yticks(range(len(pivot_cagr.index)));   axes[0].set_yticklabels(pivot_cagr.index)
_annotate(axes[0], pivot_cagr.values, fmt=lambda v: f"{v:.1f}%")
fig.colorbar(im0, ax=axes[0], format='%d%%', fraction=0.046, pad=0.04)

# ---- CPLL Gap
im1 = axes[1].imshow(pivot_gap, aspect='auto', cmap='Reds', vmin=0.0, vmax=vmax_cpll)
axes[1].set_title("Mean CPLL Gap")
axes[1].set_xlabel('K'); axes[1].set_ylabel('D')
axes[1].set_xticks(range(len(pivot_gap.columns))); axes[1].set_xticklabels(pivot_gap.columns)
axes[1].set_yticks(range(len(pivot_gap.index)));   axes[1].set_yticklabels(pivot_gap.index)
_annotate(axes[1], pivot_gap.values, fmt=lambda v: f"{v:,.0f}")
fig.colorbar(im1, ax=axes[1], format='%d', fraction=0.046, pad=0.04)

# ---- ΔELBO
im2 = axes[2].imshow(pivot_elbo, aspect='auto', cmap='Blues', vmin=0.0, vmax=vmax_elbo)
axes[2].set_title("Mean ΔELBO")
axes[2].set_xlabel('K'); axes[2].set_ylabel('D')
axes[2].set_xticks(range(len(pivot_elbo.columns))); axes[2].set_xticklabels(pivot_elbo.columns)
axes[2].set_yticks(range(len(pivot_elbo.index)));   axes[2].set_yticklabels(pivot_elbo.index)
_annotate(axes[2], pivot_elbo.values, fmt=lambda v: f"{v:,.0f}")
fig.colorbar(im2, ax=axes[2], format='%d', fraction=0.046, pad=0.04)

plt.show()

# %%
# Highest performing stock - Unrestricted

value_sel = "cagr_rel_ex_ante"  # "cagr_rel_ex_ante"

subset = res[
    (res["config"] == "[g,v]") &
    (res["n_regimes"] == 4) &
    (res["dim_latent"] == 2)
]

best_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmax()])

best_security = best_row["security"]
best_security, best_row[value_sel]
# Out:
# ('NVDA', 0.4071476467703363)

# %%
# Worst performing stock - Unestricted

subset = res[
    (res["config"] == "[y,g,v,h]") &
    (res["n_regimes"] == 2) &
    (res["dim_latent"] == 3)
]

worst_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmin()])

worst_security = worst_row["security"]
worst_security, worst_row[value_sel]
# Out:
# ('NVDA', -0.1646480230130672)

# %%
# Highest performing stock - Restricted

value_sel = "cagr_rel_ex_ante"  # "cagr_rel_ex_ante"

subset = res[
    (res["config"] == "factor2_ff3") &
    (res["n_regimes"] == 6) &
    (res["dim_latent"] == 3)
]

best_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmax()])

best_security = best_row["security"]
best_security, best_row[value_sel]
# Out:
# ('GE', 0.1697327203445688)

# %%
# Worst performing stock - Restricted

subset = res[
    (res["config"] == "factor2_ff3") &
    (res["n_regimes"] == 6) &
    (res["dim_latent"] == 3)
]

worst_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmin()])

worst_security = worst_row["security"]
worst_security, worst_row[value_sel]
# Out:
# ('AVGO', -0.0118377898888546)

# %%
# --------------------------------------------------------------------------------------
# IMPORT MODULES
# --------------------------------------------------------------------------------------

# BLAS/threads
import os, multiprocessing
n_cpu = multiprocessing.cpu_count()

# Max speed on Mac: let Accelerate (vecLib) use all cores
for k in ["OMP_NUM_THREADS","OPENBLAS_NUM_THREADS","MKL_NUM_THREADS",
          "VECLIB_MAXIMUM_THREADS","NUMEXPR_NUM_THREADS"]:
    os.environ[k] = str(n_cpu)

# TQDM widget off
os.environ["TQDM_NOTEBOOK"] = "0"

# Light / general imports
import numpy as np
import pandas as pd
import tqdm
import tqdm.auto as tqa
from tqdm.std import tqdm as tqdm_std

def _trange_no_widget(n, *a, **k):
    k.setdefault("disable", True)
    return tqdm_std(range(n), *a, **k)
tqdm.tqdm = tqdm_std
tqdm.trange = _trange_no_widget
tqa.tqdm = tqdm_std
tqa.trange = _trange_no_widget

# Import your pipeline AFTER env + tqdm config
from gridsearch import pipeline_actual

# %%
# --------------------------------------------------------------------------------------
# CONFIG
# --------------------------------------------------------------------------------------

PATHS = {
        "data_excel": "/Users/chrismader/Python/SLDS/Data/bbg_data.xlsx",
        "ff_dir": "/Users/chrismader/Python/SLDS/Data/",
        "ff_files": {
            "ff5": "F-F_Research_Data_5_Factors_2x3_daily.csv",
            "ff3": "F-F_Research_Data_Factors_daily.csv",
            "mom": "F-F_Momentum_Factor_daily.csv",},
        "results_csv": "/Users/chrismader/Python/SLDS/Output/gridsearch_results1.csv",
        "segments_parquet": "/Users/chrismader/Python/SLDS/Output/gridsearch_segments1.parquet",
        "tmp_dir":          "/Users/chrismader/Python/SLDS/tmp_slds/",
        "segments_tmp_csv": "/Users/chrismader/Python/SLDS/tmp_slds/segments_tmp.csv",
    }
    
CONFIG = {
    
    # Core defaults
    "n_jobs": -1,  # multi-threading
    "dt": 1.0 / 252.0,
    "n_iters": 50,
    "h_z": 3.0,  # CUSUM parameter
    
    # Batch windows
    "batch_grid": [
        {"train_window": 1260, "overlap_window": 1008},
    ],

    # Number of regimes
    "K_grid": [4],
    
    # Unrestricted models: 
    "unrestricted_models": [
        # {"label": "[y]",         "channels": ["y"],                "dim_latent": [1]},
        # {"label": "[y,h]",       "channels": ["y","h"],            "dim_latent": [2]},
        {"label": "[g,v]",       "channels": ["g","v"],            "dim_latent": [2]},
        # {"label": "[g,v,h]",     "channels": ["g","v","h"],        "dim_latent": [2,3]},
        # ORIGNIAL: {"label": "[y,g,v,h]",   "channels": ["y","g","v","h"],    "dim_latent": [3,4]}, ORIGINAL
        # {"label": "[y,g,v,h]",   "channels": ["y","g","v","h"],    "dim_latent": [3]},
    ],

    # Restricted models: 
    "restricted_models": [
        # {"label": "fund1",        "channels": ["y"],                 "dim_latent": [2],    "C_type": "fund1"},
        # {"label": "fund1_vix",    "channels": ["y","h"],             "dim_latent": [3],    "C_type": "fund1_vix"},
        # {"label": "fund2",        "channels": ["y","g"],             "dim_latent": [2],    "C_type": "fund2"},
        # {"label": "fund2_vix",    "channels": ["y","g","h"],         "dim_latent": [3],    "C_type": "fund2_vix"},
        # {"label": "fund3",        "channels": ["y","v","g"],         "dim_latent": [2],    "C_type": "fund3"},
        # {"label": "fund3_vix",    "channels": ["y","v","g","h"],     "dim_latent": [3],    "C_type": "fund3_vix"},   

        # {"label": "factor1",      "channels": ["y"],                 "dim_latent": [2],    "C_type": "factor1"},
        # {"label": "factor1_vix",  "channels": ["y","h"],             "dim_latent": [3],    "C_type": "factor1_vix"},

        # {"label": "factor2_ff3",   "channels": ["y","mkt","smb","hml"],                   "dim_latent": [3], "C_type": "factor2"},
        # {"label": "factor2_ff3mom","channels": ["y","mkt","smb","hml","mom"],             "dim_latent": [4], "C_type": "factor2"},
        # {"label": "factor2_ff5",   "channels": ["y","mkt","smb","hml","rmw","cma"],       "dim_latent": [5], "C_type": "factor2"},
        # {"label": "factor2_ff5mom","channels": ["y","mkt","smb","hml","rmw","cma","mom"], "dim_latent": [6], "C_type": "factor2"},
    ],

    # Model selection
    "run_unrestricted": True,
    "run_restricted": False,
    "predict_oos": False,

    # Output
    "verbose": True,
    "display": True,
}

for k, v in PATHS.items(): 
    CONFIG[k] = v
# per-security temp file templates used by IOManager
CONFIG["tmp_results_fmt"]  = "{tmp_dir}/tmp_res_{security}.csv"
CONFIG["tmp_segments_fmt"] = "{tmp_dir}/tmp_seg_{security}.csv"

# %%
# --------------------------------------------------------------------------------------
# EXECUTE
# --------------------------------------------------------------------------------------

# IO from CONFIG
csv_path = CONFIG["results_csv"]
filename = CONFIG["data_excel"]
out_path = os.path.dirname(CONFIG["results_csv"]) + "/"

securities_master = ["NVDA"]
    
# resume if CSV exists; otherwise start from beginning
if os.path.exists(csv_path) and os.path.getsize(csv_path) > 0:
    df = pd.read_csv(csv_path)
    assert "security" in df.columns, "results_csv missing 'security' column"
    done_set = set(df["security"].dropna().astype(str))
    done = [s for s in securities_master if s in done_set]
    securities = [s for s in securities_master if s not in done_set]
    print("Resuming from CSV:", csv_path)
    print("Already completed:", done)
else:
    securities = securities_master
    print("Resuming from: START (no/empty CSV)")

print("Remaining tickers:", len(securities), securities)

if len(securities) == 0:
    print("Nothing to do.")

_ = pipeline_actual(securities=securities, CONFIG=CONFIG)
# Out:
# Resuming from: START (no/empty CSV)
# Remaining tickers: 1 ['NVDA']
#
#
# ========================================================================
# NVDA
# ========================================================================
# combo_total= 1
#
#
# ------------------------------------------------------------------------
# (1/1) unrestricted | Params: {'n_regimes': 4, 'dim_latent': 2, 'single_subspace': True};{'train_window': 1260, 'overlap_window': 1008}
# ------------------------------------------------------------------------
#
# ========== FITTED MODEL ==========
#
# Cs  (K, N, D) = (1, 2, 2)
# [ 0.0104  0.0175]
# [ 0.0173 -0.0157]
#
# ds  (K, N) = (1, 2)
# [ 0.0024 -0.0002]
#
# inv_etas  (K, N) = (1, 2)
# [-6.9415 -6.2520]
#
# As  (K, D, D) = (4, 2, 2)
# [ 0.9249 -0.0028]    [ 0.9249 -0.0028]    [ 0.9249 -0.0028]    [ 0.9249 -0.0028]
# [-0.0025  0.9293]    [-0.0025  0.9293]    [-0.0025  0.9293]    [-0.0025  0.9293]
#
# bs  (K, D) = (4, 2)
# [-0.0000 -0.0001]    [-0.0000 -0.0001]    [-0.0000 -0.0001]    [-0.0000 -0.0001]
#
# sigmasq  (K, D) = (4, 2)
# [ 0.0001  0.0001]    [ 0.0001  0.0001]    [ 0.0001  0.0001]    [ 0.0001  0.0001]
#
# Rs  (K, D) = (4, 2)
# [-0.0094  0.0104]    [ 0.0048 -0.0142]    [ 0.0036  0.0003]    [-0.0006  0.0051]
#
# r  (K,) = (4,)
# [-0.0014  0.0011  0.0005 -0.0002]
#
# Dynamics: xₜ = a⋅xₜ₋₁ + b + ε
#
# Inferred Regime Types:
# Regime 0:  xₜ = a xₜ₋₁ + ε    (ar1)
# Regime 1:  xₜ = a xₜ₋₁ + ε    (ar1)
# Regime 2:  xₜ = a xₜ₋₁ + ε    (ar1)
# Regime 3:  xₜ = a xₜ₋₁ + ε    (ar1)
# ========== EVALUATION SUMMARY ==========
#
# ELBO Diagnostics (all runs)
# ----------------
# ELBO start            : -265744.69
# ELBO end              : 5958.79
# ELBO delta            : 271703.48
#
# Mode Usage
# ----------
# {1: 2261, 2: 1008, 0: 252}
#
# Regime Properties
# -----------------
# Avg inferred regime length : 440.1
#
# Performance
# -----------------
# CAGR Relative     : -0.0596
# CAGR Strategy     : 0.4666
# CAGR Benchmark    : 0.5595
#
# Hypothesis Test
# H0: CAGR Rel = 0 vs H1: CAGR Rel > 0. P-val = 0.9631. H0 accepted at 0.95.
#
# Spectral Radius Test
# --------------------
# Stability margins : [0.07 0.07 0.07 0.07]
# Stability decision: accept
#
# CPLL
# ----
# CPLL (best run)   : -29690.0
# Upper bound       : 17693.6
#
# fits succeeded: 10
#
# LEADERBOARD:
#  rank     score  n_regimes  dim_latent  single_subspace
#     1 -0.059601          4           2             True
# Gridsearch completed.

# %%
# NOT IN USE

# %%
def collect_seed_rolling_params(cfg, securities, n_runs=10, master_seed=123):
    """
    PURE WRAPPER with stability aggregation:
      • Per security → rolling batches → per-seed fits (unchanged logic).
      • NEW: For each batch, aggregate params across seeds (mean/std elementwise)
             for {Cs, ds, inv_etas, As, bs, sigmasq, Rs, r}.
      • NEW: For each batch, compute regime occupancies averaged across seeds
             for {zhat_raw, zhat_cusum} and store ARI (mean pairwise across seeds).
    The return structure now includes per-batch "params_agg" and "occ".
    """
    import numpy as np
    from gridsearch import import_data, import_factors, _intersect_indexes, _build_restrictions
    from rSLDS import fit_rSLDS, fit_rSLDS_restricted, cusum_overlay

    # pick active model (CONFIG guarantees mutual exclusivity)
    assert bool(cfg.get("run_unrestricted", False)) ^ bool(cfg.get("run_restricted", False)), \
       "[CFG] Exactly one of run_unrestricted or run_restricted must be True."
    
    if cfg["run_unrestricted"]:
        assert len(cfg["unrestricted_models"]) > 0, \
            "[CFG] run_unrestricted=True but unrestricted_models is empty."
        m = cfg["unrestricted_models"][0]; restricted = False; C_type = None
    else:
        assert len(cfg["restricted_models"]) > 0, \
            "[CFG] run_restricted=True but restricted_models is empty."
        m = cfg["restricted_models"][0];  restricted = True;  C_type = m["C_type"]
        
    channels   = list(m["channels"])
    D          = int(m["dim_latent"][0])
    K          = int(cfg["K_grid"][0])
    dt         = float(cfg["dt"])
    n_iters    = int(cfg["n_iters"])
    h_z        = float(cfg["h_z"])
    batch_conf = cfg["batch_grid"][0]
    train_window = int(batch_conf["train_window"])
    overlap      = int(batch_conf["overlap_window"])

    print(f"[CFG] restricted={restricted} C_type={C_type} channels={channels} K={K} D={D} "
          f"dt={dt} n_iters={n_iters} h_z={h_z} train_window={train_window} overlap={overlap} n_runs={n_runs}")

    # data
    px_all, eps_all, pe_all, ser_vix = import_data(cfg["data_excel"])
    ff = import_factors(cfg["ff_dir"], cfg["ff_files"])

    def _series_by_key_for(sec):
        ser_px  = px_all[sec].dropna()
        ser_eps = eps_all[sec].dropna().where(lambda s: s > 0).dropna()
        ser_pe  = (ser_px / ser_eps).where(lambda s: s > 0).dropna()
        series = {
            "y": np.log(ser_px).diff().dropna(),
            "g": np.log(ser_eps).diff().dropna(),
            "v": np.log(ser_pe).diff().dropna(),
            "h": np.log(ser_vix).diff().dropna(),
        }
        for col, key in [("MKT","mkt"),("SMB","smb"),("HML","hml"),("RMW","rmw"),("CMA","cma"),("MOM","mom")]:
            if col in ff.columns:
                series[key] = ff[col]
        return series, ser_px

    rng = np.random.RandomState(master_seed)
    out = {}

    # ---------- small helpers ----------
    def _stack(arrs, expected_ndim=None):
        A = np.stack(arrs, axis=0)  # (R, ...)
        if expected_ndim is not None:
            assert A.ndim == expected_ndim + 1, f"[ASSERT] rank mismatch: got {A.ndim}, want {expected_ndim+1}"
        return A

    def _agg_mean_std(A):
        mu = A.mean(axis=0)
        sd = A.std(axis=0, ddof=1) if A.shape[0] > 1 else np.zeros_like(mu)
        return mu, sd

    def _occ_by_seed(Z, K_):
        # Z: shape (R, T) ints in {0..K-1} or {1..K}
        if Z.size == 0:
            return np.full((Z.shape[0], K_), np.nan)
        Zp = Z.copy()
        if Zp.min() == 1:
            Zp = Zp - 1
        R, T = Zp.shape
        occ = np.zeros((R, K_), float)
        for i in range(R):
            bc = np.bincount(Zp[i], minlength=K_).astype(float)
            occ[i] = bc / max(T, 1)
        return occ

    from sklearn.metrics import adjusted_rand_score as _ARI
    def _mean_pairwise_ARI(Z):
        Z = np.asarray(Z, dtype=int)
        if Z.size == 0:
            return np.nan
        if Z.min() == 1:
            Z = Z - 1
        R, _ = Z.shape
        vals = []
        for i in range(R):
            for j in range(i+1, R):
                vals.append(_ARI(Z[i], Z[j]))
        return float(np.mean(vals)) if vals else np.nan

    # ------------------------------------

    for sec in securities:

        print(f"\n[SEC] {sec}")
        series_by_key, ser_px = _series_by_key_for(sec)
        need = [series_by_key[k].dropna() for k in channels]
        common_idx = _intersect_indexes(need)
        if common_idx is None or getattr(common_idx, "empty", False):
            print(f"[WARN] {sec}: no overlap for channels {channels} — skipping")
            continue

        Y_full  = np.concatenate([series_by_key[k].loc[common_idx].values.reshape(-1,1) for k in channels], axis=1)
        px_full = ser_px.loc[common_idx].astype(float)
        T, N = Y_full.shape
        assert N == len(channels), f"[ASSERT] N={N} must equal len(channels)={len(channels)}"

        print(f"[DATA] T={T} N={N} idx[{common_idx[0]} → {common_idx[-1]}]")

        # batch schedule
        t0s, t1s, t0 = [], [], 0
        while t0 < T:
            t1s.append(min(t0 + train_window, T))
            t0s.append(t0)
            if t1s[-1] == T: break
            t0 += train_window - overlap
        print(f"[BATCH] batches={len(t0s)}")

        rec = {
            "meta": {
                "channels": channels, "K": K, "D": D,
                "train_window": train_window, "overlap_window": overlap,
                "common_index": common_idx, "restricted": restricted, "dt": dt},
            "batches": []}

        params_spec = dict(n_regimes=K, dim_latent=D, single_subspace=True)

        for bi, (b0, b1) in enumerate(zip(t0s, t1s)):
            Yb = Y_full[b0:b1, :]
            pxb = px_full.iloc[b0:b1]
            idx_slice = pxb.index
            print(f"[B{bi}] slice t0={b0} t1={b1} len={len(idx_slice)}")

            restrictions = None
            if restricted:
                restrictions = _build_restrictions(C_type, Y_obs=Yb, base_channels=channels, D=D)
                assert "C" in restrictions and "d" in restrictions, "[ASSERT] restrictions must contain 'C' and 'd'"
                print(f"[B{bi}] restrictions keys={list(restrictions.keys())}")

            seeds = rng.randint(1, 2**31 - 1, size=n_runs).tolist()
          
            per_seed_records = []
            Z_raw_list, Z_cusum_list = [], []
            Cs_list, ds_list, inv_list = [], [], []
            As_list, bs_list, sigmasq_list, Rs_list, r_list = [], [], [], [], []

            for si, s in enumerate(seeds):
                
                if restricted:
                    xhat, zhat_raw, elbo, q, mdl = fit_rSLDS_restricted(
                        Yb, params_spec,
                        C=restrictions["C"], d=restrictions["d"],
                        n_iter_em=n_iters, seed=s,
                        b_pattern=restrictions.get("b_pattern"),
                        enforce_diag_A=True,
                        C_mask=restrictions.get("C_mask"),
                        d_mask=restrictions.get("d_mask"))
                else:
                    xhat, zhat_raw, elbo, q, mdl = fit_rSLDS(Yb, params_spec, n_iter_em=n_iters, seed=s)

                y_cus = Yb[:, 0].ravel()
                zhat_cusum = cusum_overlay(pxb, y_cus, xhat, mdl, h_z)

                Z_raw_list.append(np.asarray(zhat_raw).ravel())
                if zhat_cusum is None:
                    Z_cusum_list.append(np.asarray(zhat_raw).ravel())
                else:
                    Z_cusum_list.append(np.asarray(zhat_cusum).ravel())

                # params (copy to detach)
                Cs      = np.array(mdl.emissions.Cs,       copy=True)
                ds      = np.array(mdl.emissions.ds,       copy=True)
                inv_eta = np.array(mdl.emissions.inv_etas, copy=True)
                As      = np.array(mdl.dynamics.As,        copy=True)
                bs      = np.array(mdl.dynamics.bs,        copy=True)
                sigmasq = np.array(mdl.dynamics.sigmasq,   copy=True)
                Rs      = np.array(mdl.transitions.Rs,     copy=True)
                r       = np.array(mdl.transitions.r,      copy=True)

                # sanity on leading K (allow shared emissions with leading 1)
                assert As.shape[0] == K and bs.shape[0] == K and sigmasq.shape[0] == K \
                    and Rs.shape[0] == K and r.shape[0] == K, "[ASSERT] K mismatch in dynamics/transitions"
                assert Cs.ndim == 3 and ds.ndim == 2 and inv_eta.ndim == 2, "[ASSERT] emissions rank mismatch"
                assert Cs.shape[0] in (1, K) and ds.shape[0] in (1, K) and inv_eta.shape[0] in (1, K), \
                    "[ASSERT] emissions leading axis must be 1 or K"

                Cs_list.append(Cs)
                ds_list.append(ds)
                inv_list.append(inv_eta)
                As_list.append(As)
                bs_list.append(bs)
                sigmasq_list.append(sigmasq)
                Rs_list.append(Rs)
                r_list.append(r)

                per_seed_records.append({
                    "seed": int(s),
                    "params": {"Cs": Cs, "ds": ds, "inv_etas": inv_eta, "As": As, "bs": bs,
                               "sigmasq": sigmasq, "Rs": Rs, "r": r},
                    "outputs": {"zhat_raw": zhat_raw, "zhat_cusum": zhat_cusum,
                                "xhat": xhat, "elbo": elbo}
                })

            # ---------- aggregate across seeds (elementwise mean/std) ----------
            def _agg_block(block_list):
                A = _stack(block_list)  # (R, ...)
                mu, sd = _agg_mean_std(A)
                return {"mean": mu, "std": sd}

            params_agg = {
                "Cs": _agg_block(Cs_list),
                "ds": _agg_block(ds_list),
                "inv_etas": _agg_block(inv_list),
                "As": _agg_block(As_list),
                "bs": _agg_block(bs_list),
                "sigmasq": _agg_block(sigmasq_list),
                "Rs": _agg_block(Rs_list),
                "r": _agg_block(r_list),
            }

            # ---------- regime occupancy (avg across seeds) + ARI ----------
            Zr = np.stack(Z_raw_list, axis=0)   if len(Z_raw_list)  else np.zeros((0, 0), int)
            Zc = np.stack(Z_cusum_list, axis=0) if len(Z_cusum_list) else np.zeros((0, 0), int)

            occ_raw_seed = _occ_by_seed(Zr, K)  # (R,K)
            occ_cus_seed = _occ_by_seed(Zc, K)  # (R,K)

            occ = {
                "raw": {
                    "by_seed": occ_raw_seed,                      # (R,K), fractions
                    "mean":    np.nanmean(occ_raw_seed, axis=0),  # (K,)
                    "std":     np.nanstd(occ_raw_seed, axis=0, ddof=1) if occ_raw_seed.shape[0] > 1
                               else np.zeros(K)
                },
                "cusum": {
                    "by_seed": occ_cus_seed,
                    "mean":    np.nanmean(occ_cus_seed, axis=0),
                    "std":     np.nanstd(occ_cus_seed, axis=0, ddof=1) if occ_cus_seed.shape[0] > 1
                               else np.zeros(K)
                }
            }

            metrics = {
                "ARI_raw":  _mean_pairwise_ARI(Zr),
                "ARI_cusum": _mean_pairwise_ARI(Zc),
            }

            rec["batches"].append({
                "t0": int(b0), "t1": int(b1),
                "idx_slice": idx_slice,
                "seeds": seeds,
                "records": per_seed_records,
                "Z_raw":  Zr,
                "Z_cusum": Zc,
                "params_agg": params_agg,
                "occ": occ,
                "metrics": metrics,
            })
        
        out[sec] = rec

    return out

# %%
def print_seed_rolling_stability(rolled, security, batch_indices=None):
    """
    Pretty printer for stability:
      • Emissions & latent blocks: entries as mean (std) across seeds.
      • Regime occupancies per batch: mean% (std%).
      • ARI per batch: raw & cusum.
    Inputs
      rolled: dict returned by collect_seed_rolling_params
      security: key inside rolled
      batch_indices: optional list of batch indices to print (default: all)
    """
    import numpy as np

    rec = rolled.get(security)
    assert rec is not None, f"[print] security '{security}' not found"
    K = rec["meta"]["K"]; D = rec["meta"]["D"]; dt = rec["meta"]["dt"]; restricted = rec["meta"]["restricted"]
    B = len(rec["batches"])
    if batch_indices is None:
        batch_indices = list(range(B))

    def _fmt(m, s, fp=4):
        return f"{m: .{fp}f} ({s: .{fp}f})"

    def _pmat(mu, sd, label, semantic_key):
        shape_str = {
            "Cs": "(K_or_1, N, D)",
            "ds": "(K_or_1, N)",
            "inv_etas": "(K_or_1, N)",
            "As": "(K, D, D)",
            "bs": "(K, D)",
            "sigmasq": "(K, D)",
            "Rs": "(K, D)",
            "r": "(K,)",
        }[semantic_key]
        print(f"{label}  {shape_str} = {mu.shape}")
        if mu.ndim == 3:
            K0, R0, C0 = mu.shape
            for r in range(R0):
                line = ""
                for k in range(K0):
                    row_entries = []
                    for c in range(C0):
                        row_entries.append(_fmt(mu[k, r, c], sd[k, r, c]))
                    row_str = " ".join(row_entries)
                    line += f"[{row_str}]    "
                print(line)
        elif mu.ndim == 2:
            K0, C0 = mu.shape
            line = ""
            for k in range(K0):
                row_entries = [_fmt(mu[k, c], sd[k, c]) for c in range(C0)]
                line += f"[{' '.join(row_entries)}]" + "    "
            print(line)
        elif mu.ndim == 1:
            row_entries = [_fmt(mu[k], sd[k]) for k in range(mu.shape[0])]
            print(f"[{' '.join(row_entries)}]")
        print()

    for bi in batch_indices:
        b = rec["batches"][bi]
        t0, t1 = b["t0"], b["t1"]
        print("\n========== STABILITY (security={}, batch={}  t0={}  t1={}) ==========\n"
              .format(security, bi, t0, t1))

        P = b["params_agg"]
        _pmat(P["Cs"]["mean"],      P["Cs"]["std"],      "Cs",       "Cs")
        _pmat(P["ds"]["mean"],      P["ds"]["std"],      "ds",       "ds")
        _pmat(P["inv_etas"]["mean"],P["inv_etas"]["std"],"inv_etas", "inv_etas")
        _pmat(P["As"]["mean"],      P["As"]["std"],      "As",       "As")
        _pmat(P["bs"]["mean"],      P["bs"]["std"],      "bs",       "bs")
        _pmat(P["sigmasq"]["mean"], P["sigmasq"]["std"], "sigmasq",  "sigmasq")
        _pmat(P["Rs"]["mean"],      P["Rs"]["std"],      "Rs",       "Rs")
        _pmat(P["r"]["mean"],       P["r"]["std"],       "r",        "r")

        # interpretable AR(1) params (restricted models)
        if restricted:
            print("Interpretable AR(1) parameters (mean±std over seeds)")
            mu_As, sd_As   = P["As"]["mean"], P["As"]["std"]         # (K,D,D)
            mu_bs, sd_bs   = P["bs"]["mean"], P["bs"]["std"]         # (K,D)
            mu_sig, sd_sig = P["sigmasq"]["mean"], P["sigmasq"]["std"] # (K,D)
            eps = 1e-8
            for k in range(mu_As.shape[0]):
                print(f"Regime {k}:")
                for d in range(min(D, mu_As.shape[2])):
                    rho_m, rho_s = mu_As[k, d, d], sd_As[k, d, d]
                    b_m, b_s     = mu_bs[k, d],    sd_bs[k, d]
                    # μ = b / (1-ρ), Var_stat = σ²/(1-ρ²) for |ρ|<1
                    mu_stat_m = (b_m / (1.0 - rho_m)) if abs(1.0 - rho_m) > eps else np.nan
                    # delta-method-ish SD approximation (optional: coarse; keep concise)
                    mu_stat_s = np.nan
                    s2_m, s2_s = mu_sig[k, d], sd_sig[k, d]
                    var_stat_m = (s2_m / (1.0 - rho_m**2)) if abs(rho_m) < 1 else np.nan
                    var_stat_s = np.nan
                    # half-life in steps: log(2)/|log ρ|
                    if rho_m > 0 and abs(rho_m) < 1:
                        hl_steps_m = float(np.log(2.0) / abs(np.log(rho_m)))
                    else:
                        hl_steps_m = float("inf")
                    hl_years_m = (hl_steps_m * rec["meta"]["dt"]) if np.isfinite(hl_steps_m) else np.nan
                    print(f"  latent{d}: rho={_fmt(rho_m, rho_s)}  b={_fmt(b_m, b_s)}  "
                          f"mu_stat≈{mu_stat_m: .6f}  var_stat≈{var_stat_m: .6e}  "
                          f"half_life_steps≈{hl_steps_m: .2f}  half_life_years≈{hl_years_m: .4f}")
                print()

        # occupancy + ARI
        occ = b["occ"]
        raw_mean = (occ["raw"]["mean"] * 100.0).astype(float)
        raw_std  = (occ["raw"]["std"]  * 100.0).astype(float)
        cus_mean = (occ["cusum"]["mean"] * 100.0).astype(float)
        cus_std  = (occ["cusum"]["std"]  * 100.0).astype(float)

        def _fmt_occ(mean_vec, std_vec):
            return ", ".join([f"{mean_vec[j]:.1f}% ({std_vec[j]:.1f}%)" for j in range(mean_vec.size)])

        print("Occupancy per regime (mean% (std%) across seeds):")
        print(f"  RAW:   [{_fmt_occ(raw_mean,  raw_std)}]")
        print(f"  CUSUM: [{_fmt_occ(cus_mean, cus_std)}]")

        ARI_raw   = b["metrics"]["ARI_raw"]
        ARI_cusum = b["metrics"]["ARI_cusum"]
        print(f"ARI (mean pairwise across seeds):  RAW={ARI_raw:.3f}   CUSUM={ARI_cusum:.3f}")

# %%
securities = [""]
# rolled = collect_seed_rolling_params(CONFIG, securities, n_runs=10, master_seed=123)

# %%
# print_seed_rolling_stability(rolled, "")
