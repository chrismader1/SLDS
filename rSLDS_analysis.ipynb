# %%
# Plot RelCAGR vs Delta ELBO and vs CPLL, CPLL Gap
# Smooth CPLL: conditional predictive log-likelihood; out-of-sample accuracy # Smooth CPLL: overestimates OOS accuracy due to look-ahead bias
# ELBO: Evidence lower bound; lower bound on the true log-likelihood (lowest start minus highest end accross all runs)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import adjusted_rand_score as _ARI

# %%
# import data
filename_results = '/Users/chrismader/Python/SLDS/Output/gridsearch_results.csv'
filename_static = '/Users/chrismader/Python/SLDS/Data/static_data.csv'
res = pd.read_csv(filename_results)
static = pd.read_csv(filename_static, usecols=[0,1,2])

# %%
# Prep data
res['sector'] = res['security'].map(static.set_index('Ticker')['SectorID'])
res['CPLL Gap'] = res['max cpll (proxy bound, paired)'] - res['cpll (max all runs)']
res.insert(res.columns.get_loc('security') + 1, 'sector', res.pop('sector'))
res = res[np.isfinite(pd.to_numeric(res['cagr_rel_ex_ante'], errors='coerce'))].copy()
res = res[np.isfinite(pd.to_numeric(res['score'], errors='coerce'))].copy()

print(list(np.unique(res.config)))
print(list(np.unique(res.sector)))
print(list(np.unique(res.security)))
print(res.columns)

# Settings
configs = np.unique(res.config)
unrestricted = [x for x in configs if x.startswith('[')]
restricted = [x for x in configs if not x.startswith('[')]
print(unrestricted)
print(restricted)
# Out:
# ['[g,v,h]', '[g,v]', '[y,g,v,h]', '[y,h]', '[y]', 'factor1', 'factor1_vix', 'factor2_ff3', 'factor2_ff3mom', 'factor2_ff5', 'factor2_ff5mom', 'fund1', 'fund1_vix', 'fund2', 'fund2_vix', 'fund3', 'fund3_vix']
# ['CD', 'CS', 'EN', 'FN', 'HC', 'IN', 'IT', 'MT', 'RL', 'TC', 'UT']
# ['AAPL', 'ABBV', 'ABT', 'ACN', 'ADBE', 'AEP', 'AMAT', 'AMD', 'AMGN', 'AMT', 'AMZN', 'AVGO', 'AXP', 'BA', 'BAC', 'BKNG', 'BLK', 'BSX', 'C', 'CAT', 'CBRE', 'COST', 'CRM', 'CSCO', 'CVX', 'D', 'DIS', 'DUK', 'EQIX', 'GE', 'GOOGL', 'GS', 'HD', 'HON', 'IBM', 'INTU', 'ISRG', 'JNJ', 'JPM', 'KO', 'LIN', 'LLY', 'MA', 'MCD', 'META', 'MRK', 'MS', 'MSFT', 'NEE', 'NFLX', 'NOW', 'NVDA', 'O', 'ORCL', 'PEP', 'PG', 'PGR', 'PLD', 'PM', 'QCOM', 'RTX', 'SCHW', 'SO', 'SPGI', 'T', 'TMO', 'TSLA', 'TXN', 'UNH', 'V', 'VZ', 'WFC', 'WMT', 'XOM']
# Index(['security', 'sector', 'config', 'rank', 'score', 'dt', 'n_regimes',
#        'dim_latent', 'single_subspace', 'train_window', 'overlap_window',
#        'avg_inferred_regime_length', 'elbo_start (min all runs)',
#        'elbo_end (max all runs)', 'elbo_delta (max all runs)',
#        'cpll (max all runs)', 'max cpll (proxy bound, paired)', 'mode_usage',
#        'cagr_rel', 'cagr_strat', 'cagr_bench', 'cagr_rel_cusum',
#        'cagr_strat_cusum', 'cagr_bench_cusum', 'cagr_rel_ex_ante',
#        'cagr_strat_ex_ante', 'cagr_bench_ex_ante', 'CPLL Gap'],
#       dtype='object')
# ['[g,v,h]', '[g,v]', '[y,g,v,h]', '[y,h]', '[y]']
# ['factor1', 'factor1_vix', 'factor2_ff3', 'factor2_ff3mom', 'factor2_ff5', 'factor2_ff5mom', 'fund1', 'fund1_vix', 'fund2', 'fund2_vix', 'fund3', 'fund3_vix']

# %%
# Helpers

def performance(df, value_sel):
    
    idx = ['config','n_regimes','dim_latent']
    sector_cols = sorted(df['sector'].unique())
    
    # sector means
    pt = (df.pivot_table(index=idx, columns='sector', values=value_sel, aggfunc='mean')
            .sort_index().reindex(sector_cols, axis=1))
    
    # true stats across ALL securities (not avg of sectors)
    stats = (df.groupby(idx)[value_sel]
               .agg(avg='mean', std='std', min='min', max='max'))
    stats['range'] = stats['max'] - stats['min']
    
    # join, order, sort
    finite_mask = np.isfinite(pt.to_numpy()).all(axis=1)
    pt_sel = (pt.loc[finite_mask]
                .join(stats, how='left')
                .loc[:, sector_cols + ['avg','std','min','max','range']]
                .sort_values('avg', ascending=False))
    
    # style
    styled = (pt_sel.style
               .format('{:.3f}')
               .background_gradient(cmap='RdBu', vmin=-0.1, vmax=0.1,
                                    subset=sector_cols + ['avg'])
               .highlight_null())
    
    # lock in order
    base_idx  = pt_sel.index                                 # exact rows + order
    cols_tail = ['avg','std','min','max','range']            # trailing stats
    cols_all = sector_cols + cols_tail                      # exact columns

    return styled, base_idx, cols_tail, cols_all
    
def metric_table(value_sel, df, base_idx, cols_tail, cols_all, vmin, vmax):

    # recover index/sector context from performance() output
    idx = list(base_idx.names)
    sector_cols = [c for c in cols_all if c not in cols_tail]
    
    # sector means for this metric (no sorting, no filtering)
    pt_m = (df.pivot_table(index=idx, columns='sector', values=value_sel, aggfunc='mean')
              .reindex(sector_cols, axis=1)              # same sector columns
              .reindex(base_idx))                        # SAME ROWS + ORDER as score

    # overall stats across ALL securities for this metric
    stats_m = (df.groupby(idx)[value_sel]
                 .agg(avg='mean', std='std', min='min', max='max'))
    stats_m['range'] = stats_m['max'] - stats_m['min']
    stats_m = stats_m.reindex(base_idx)                  # align rows/order

    # combine and enforce identical column order
    tbl = pd.concat([pt_m, stats_m[cols_tail]], axis=1).reindex(columns=cols_all)

    return (tbl.style
                .format('{:,.1f}')
                .background_gradient(cmap='RdBu', vmin=vmin, vmax=vmax, subset=sector_cols + ['avg'])
                .highlight_null())

# Formatting
CAPTION_CSS = [{'selector': 'caption',
                'props': [('caption-side','top'),
                          ('text-align','left'),
                          ('font-weight','700')]}]

# %%
# Model performance - unrestricted
df_unrestr = res[res['config'].isin(unrestricted)]
styled_unrestr, base_idx_unrestr, cols_tail_unrestr, cols_all_unrestr = performance(df_unrestr, 'cagr_rel_ex_ante')
styled_unrestr.set_caption("Rel CAGR - Unrestricted Models")
styled_unrestr.set_table_styles(CAPTION_CSS, overwrite=False)
styled_unrestr
# Out:
# <style type="text/css">
# #T_9280a caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_9280a_row0_col0, #T_9280a_row23_col2 {
#   background-color: #3a87bd;
#   color: #f1f1f1;
# }
# #T_9280a_row0_col1, #T_9280a_row8_col6, #T_9280a_row16_col8, #T_9280a_row17_col9 {
#   background-color: #a5cee3;
#   color: #000000;
# }
# #T_9280a_row0_col2, #T_9280a_row0_col5, #T_9280a_row1_col5, #T_9280a_row2_col2, #T_9280a_row4_col6 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_9280a_row0_col3, #T_9280a_row8_col5 {
#   background-color: #5fa5cd;
#   color: #f1f1f1;
# }
# #T_9280a_row0_col4, #T_9280a_row8_col9 {
#   background-color: #4291c2;
#   color: #f1f1f1;
# }
# #T_9280a_row0_col6, #T_9280a_row20_col2 {
#   background-color: #327cb7;
#   color: #f1f1f1;
# }
# #T_9280a_row0_col7, #T_9280a_row21_col1, #T_9280a_row22_col7, #T_9280a_row24_col1, #T_9280a_row28_col9 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_9280a_row0_col8, #T_9280a_row1_col4, #T_9280a_row1_col9, #T_9280a_row3_col8, #T_9280a_row6_col9, #T_9280a_row15_col5, #T_9280a_row26_col7 {
#   background-color: #65a9cf;
#   color: #f1f1f1;
# }
# #T_9280a_row0_col9, #T_9280a_row1_col8, #T_9280a_row9_col5, #T_9280a_row12_col6 {
#   background-color: #4f9bc7;
#   color: #f1f1f1;
# }
# #T_9280a_row0_col10, #T_9280a_row2_col5, #T_9280a_row18_col9 {
#   background-color: #3885bc;
#   color: #f1f1f1;
# }
# #T_9280a_row0_col11, #T_9280a_row1_col2, #T_9280a_row21_col6 {
#   background-color: #3c8abe;
#   color: #f1f1f1;
# }
# #T_9280a_row1_col0, #T_9280a_row5_col9 {
#   background-color: #2a71b2;
#   color: #f1f1f1;
# }
# #T_9280a_row1_col1, #T_9280a_row6_col0, #T_9280a_row6_col11, #T_9280a_row9_col6 {
#   background-color: #90c4dd;
#   color: #000000;
# }
# #T_9280a_row1_col3, #T_9280a_row1_col6, #T_9280a_row1_col10 {
#   background-color: #62a7ce;
#   color: #f1f1f1;
# }
# #T_9280a_row1_col7, #T_9280a_row3_col0, #T_9280a_row13_col0, #T_9280a_row14_col3, #T_9280a_row18_col1, #T_9280a_row30_col9 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_9280a_row1_col11, #T_9280a_row14_col5 {
#   background-color: #529dc8;
#   color: #f1f1f1;
# }
# #T_9280a_row2_col0, #T_9280a_row4_col11, #T_9280a_row20_col0 {
#   background-color: #7bb6d6;
#   color: #000000;
# }
# #T_9280a_row2_col1, #T_9280a_row7_col8, #T_9280a_row13_col10, #T_9280a_row17_col8 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_9280a_row2_col3, #T_9280a_row12_col8 {
#   background-color: #9dcbe1;
#   color: #000000;
# }
# #T_9280a_row2_col4, #T_9280a_row10_col10, #T_9280a_row16_col10, #T_9280a_row17_col0 {
#   background-color: #b6d7e8;
#   color: #000000;
# }
# #T_9280a_row2_col6, #T_9280a_row3_col5, #T_9280a_row4_col9 {
#   background-color: #2267ac;
#   color: #f1f1f1;
# }
# #T_9280a_row2_col7, #T_9280a_row3_col11, #T_9280a_row10_col2, #T_9280a_row10_col9, #T_9280a_row18_col6 {
#   background-color: #6eaed2;
#   color: #f1f1f1;
# }
# #T_9280a_row2_col8, #T_9280a_row13_col9, #T_9280a_row19_col2 {
#   background-color: #71b0d3;
#   color: #f1f1f1;
# }
# #T_9280a_row2_col9, #T_9280a_row3_col2, #T_9280a_row3_col6, #T_9280a_row16_col2 {
#   background-color: #337eb8;
#   color: #f1f1f1;
# }
# #T_9280a_row2_col10, #T_9280a_row5_col4, #T_9280a_row6_col2, #T_9280a_row6_col10, #T_9280a_row7_col4, #T_9280a_row8_col0, #T_9280a_row16_col6, #T_9280a_row21_col8 {
#   background-color: #cfe4ef;
#   color: #000000;
# }
# #T_9280a_row2_col11, #T_9280a_row10_col5, #T_9280a_row25_col9 {
#   background-color: #68abd0;
#   color: #f1f1f1;
# }
# #T_9280a_row3_col1, #T_9280a_row6_col8, #T_9280a_row19_col8 {
#   background-color: #a7d0e4;
#   color: #000000;
# }
# #T_9280a_row3_col3, #T_9280a_row9_col10, #T_9280a_row22_col9 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_9280a_row3_col4, #T_9280a_row3_col10, #T_9280a_row5_col10, #T_9280a_row9_col2, #T_9280a_row11_col11 {
#   background-color: #b3d6e8;
#   color: #000000;
# }
# #T_9280a_row3_col7 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# #T_9280a_row3_col9 {
#   background-color: #195696;
#   color: #f1f1f1;
# }
# #T_9280a_row4_col0, #T_9280a_row5_col1, #T_9280a_row10_col7, #T_9280a_row14_col8, #T_9280a_row17_col3, #T_9280a_row18_col10, #T_9280a_row22_col10 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_9280a_row4_col1, #T_9280a_row4_col7, #T_9280a_row13_col3, #T_9280a_row18_col8 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_9280a_row4_col2, #T_9280a_row11_col6, #T_9280a_row15_col9 {
#   background-color: #98c8e0;
#   color: #000000;
# }
# #T_9280a_row4_col3, #T_9280a_row11_col4, #T_9280a_row12_col11, #T_9280a_row13_col11, #T_9280a_row14_col11, #T_9280a_row18_col2, #T_9280a_row20_col5, #T_9280a_row26_col2, #T_9280a_row31_col2 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_9280a_row4_col4, #T_9280a_row14_col0 {
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_9280a_row4_col5, #T_9280a_row10_col4, #T_9280a_row13_col8, #T_9280a_row15_col3, #T_9280a_row15_col8, #T_9280a_row20_col6, #T_9280a_row28_col7 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_9280a_row4_col8, #T_9280a_row7_col0, #T_9280a_row7_col11, #T_9280a_row8_col11 {
#   background-color: #acd2e5;
#   color: #000000;
# }
# #T_9280a_row4_col10, #T_9280a_row16_col9, #T_9280a_row23_col6 {
#   background-color: #8dc2dc;
#   color: #000000;
# }
# #T_9280a_row5_col0, #T_9280a_row5_col5, #T_9280a_row6_col3 {
#   background-color: #59a1ca;
#   color: #f1f1f1;
# }
# #T_9280a_row5_col2, #T_9280a_row27_col5 {
#   background-color: #0d3f76;
#   color: #f1f1f1;
# }
# #T_9280a_row5_col3, #T_9280a_row20_col8 {
#   background-color: #96c7df;
#   color: #000000;
# }
# #T_9280a_row5_col6, #T_9280a_row5_col8, #T_9280a_row17_col5, #T_9280a_row19_col9 {
#   background-color: #6bacd1;
#   color: #f1f1f1;
# }
# #T_9280a_row5_col7 {
#   background-color: #2b73b3;
#   color: #f1f1f1;
# }
# #T_9280a_row5_col11, #T_9280a_row21_col9 {
#   background-color: #84bcd9;
#   color: #000000;
# }
# #T_9280a_row6_col1, #T_9280a_row16_col0, #T_9280a_row19_col4, #T_9280a_row22_col6, #T_9280a_row24_col11, #T_9280a_row26_col1, #T_9280a_row26_col5, #T_9280a_row29_col2, #T_9280a_row31_col5 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_9280a_row6_col4, #T_9280a_row8_col4, #T_9280a_row15_col11, #T_9280a_row16_col11 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_9280a_row6_col5 {
#   background-color: #1b5a9c;
#   color: #f1f1f1;
# }
# #T_9280a_row6_col6, #T_9280a_row10_col8, #T_9280a_row11_col9, #T_9280a_row12_col5, #T_9280a_row27_col10 {
#   background-color: #81bad8;
#   color: #000000;
# }
# #T_9280a_row6_col7, #T_9280a_row13_col7, #T_9280a_row25_col0, #T_9280a_row29_col9 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_9280a_row7_col1, #T_9280a_row20_col3, #T_9280a_row26_col11, #T_9280a_row28_col5 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_9280a_row7_col2, #T_9280a_row22_col0, #T_9280a_row24_col5, #T_9280a_row27_col3 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_9280a_row7_col3, #T_9280a_row12_col3, #T_9280a_row15_col7 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_9280a_row7_col5 {
#   background-color: #569fc9;
#   color: #f1f1f1;
# }
# #T_9280a_row7_col6, #T_9280a_row10_col0 {
#   background-color: #307ab6;
#   color: #f1f1f1;
# }
# #T_9280a_row7_col7 {
#   background-color: #4c99c6;
#   color: #f1f1f1;
# }
# #T_9280a_row7_col9, #T_9280a_row8_col10, #T_9280a_row9_col8, #T_9280a_row22_col5, #T_9280a_row23_col5 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_9280a_row7_col10, #T_9280a_row14_col4, #T_9280a_row19_col11, #T_9280a_row20_col10, #T_9280a_row20_col11 {
#   background-color: #cae1ee;
#   color: #000000;
# }
# #T_9280a_row8_col1, #T_9280a_row18_col5 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# #T_9280a_row8_col2, #T_9280a_row22_col2 {
#   background-color: #3e8cbf;
#   color: #f1f1f1;
# }
# #T_9280a_row8_col3, #T_9280a_row10_col3, #T_9280a_row11_col0, #T_9280a_row20_col9 {
#   background-color: #d2e6f0;
#   color: #000000;
# }
# #T_9280a_row8_col7, #T_9280a_row19_col1, #T_9280a_row30_col10 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_9280a_row8_col8, #T_9280a_row9_col3, #T_9280a_row9_col4, #T_9280a_row9_col7, #T_9280a_row27_col0 {
#   background-color: #c7e0ed;
#   color: #000000;
# }
# #T_9280a_row9_col0, #T_9280a_row16_col4, #T_9280a_row20_col4, #T_9280a_row21_col11, #T_9280a_row22

# %%
# Smooth CPLL - unrestricted
styled_cpll_all = metric_table('CPLL Gap', df_unrestr, base_idx_unrestr, cols_tail_unrestr, cols_all_unrestr, vmin=-100000,  vmax=100000)
styled_cpll_all.set_caption("Smooth CPLL Gap - Unrestricted Models")
styled_cpll_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_cpll_all
# Out:
# <style type="text/css">
# #T_3b9e8 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_3b9e8_row0_col0, #T_3b9e8_row0_col6, #T_3b9e8_row0_col9, #T_3b9e8_row1_col0, #T_3b9e8_row1_col6, #T_3b9e8_row1_col9, #T_3b9e8_row2_col0, #T_3b9e8_row2_col6, #T_3b9e8_row2_col9, #T_3b9e8_row3_col0, #T_3b9e8_row3_col6, #T_3b9e8_row3_col9, #T_3b9e8_row27_col0, #T_3b9e8_row27_col6, #T_3b9e8_row27_col9 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_3b9e8_row0_col1, #T_3b9e8_row0_col10, #T_3b9e8_row1_col1, #T_3b9e8_row1_col10, #T_3b9e8_row2_col1, #T_3b9e8_row2_col10, #T_3b9e8_row3_col1, #T_3b9e8_row3_col10, #T_3b9e8_row27_col1, #T_3b9e8_row27_col10 {
#   background-color: #bddbea;
#   color: #000000;
# }
# #T_3b9e8_row0_col2, #T_3b9e8_row0_col3, #T_3b9e8_row0_col4, #T_3b9e8_row0_col5, #T_3b9e8_row0_col8, #T_3b9e8_row0_col11, #T_3b9e8_row1_col2, #T_3b9e8_row1_col3, #T_3b9e8_row1_col4, #T_3b9e8_row1_col5, #T_3b9e8_row1_col8, #T_3b9e8_row1_col11, #T_3b9e8_row2_col2, #T_3b9e8_row2_col3, #T_3b9e8_row2_col4, #T_3b9e8_row2_col5, #T_3b9e8_row2_col8, #T_3b9e8_row2_col11, #T_3b9e8_row3_col2, #T_3b9e8_row3_col3, #T_3b9e8_row3_col4, #T_3b9e8_row3_col5, #T_3b9e8_row3_col8, #T_3b9e8_row3_col11, #T_3b9e8_row27_col2, #T_3b9e8_row27_col3, #T_3b9e8_row27_col4, #T_3b9e8_row27_col5, #T_3b9e8_row27_col8, #T_3b9e8_row27_col11 {
#   background-color: #c2ddec;
#   color: #000000;
# }
# #T_3b9e8_row0_col7, #T_3b9e8_row1_col7, #T_3b9e8_row2_col7, #T_3b9e8_row3_col7, #T_3b9e8_row27_col7 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_3b9e8_row4_col0, #T_3b9e8_row5_col0, #T_3b9e8_row11_col0, #T_3b9e8_row14_col0, #T_3b9e8_row28_col0 {
#   background-color: #6bacd1;
#   color: #f1f1f1;
# }
# #T_3b9e8_row4_col1, #T_3b9e8_row5_col1, #T_3b9e8_row11_col1, #T_3b9e8_row14_col1, #T_3b9e8_row28_col1 {
#   background-color: #4695c4;
#   color: #f1f1f1;
# }
# #T_3b9e8_row4_col2, #T_3b9e8_row5_col2, #T_3b9e8_row11_col2, #T_3b9e8_row14_col2, #T_3b9e8_row28_col2 {
#   background-color: #71b0d3;
#   color: #f1f1f1;
# }
# #T_3b9e8_row4_col3, #T_3b9e8_row5_col3, #T_3b9e8_row11_col3, #T_3b9e8_row14_col3, #T_3b9e8_row28_col3 {
#   background-color: #569fc9;
#   color: #f1f1f1;
# }
# #T_3b9e8_row4_col4, #T_3b9e8_row5_col4, #T_3b9e8_row11_col4, #T_3b9e8_row14_col4, #T_3b9e8_row28_col4 {
#   background-color: #529dc8;
#   color: #f1f1f1;
# }
# #T_3b9e8_row4_col5, #T_3b9e8_row5_col5, #T_3b9e8_row11_col5, #T_3b9e8_row14_col5, #T_3b9e8_row28_col5 {
#   background-color: #6eaed2;
#   color: #f1f1f1;
# }
# #T_3b9e8_row4_col6, #T_3b9e8_row5_col6, #T_3b9e8_row11_col6, #T_3b9e8_row14_col6, #T_3b9e8_row28_col6 {
#   background-color: #65a9cf;
#   color: #f1f1f1;
# }
# #T_3b9e8_row4_col7, #T_3b9e8_row5_col7, #T_3b9e8_row11_col7, #T_3b9e8_row14_col7, #T_3b9e8_row28_col7 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_3b9e8_row4_col8, #T_3b9e8_row5_col8, #T_3b9e8_row11_col8, #T_3b9e8_row14_col8, #T_3b9e8_row28_col8 {
#   background-color: #68abd0;
#   color: #f1f1f1;
# }
# #T_3b9e8_row4_col9, #T_3b9e8_row5_col9, #T_3b9e8_row11_col9, #T_3b9e8_row14_col9, #T_3b9e8_row28_col9 {
#   background-color: #5fa5cd;
#   color: #f1f1f1;
# }
# #T_3b9e8_row4_col10, #T_3b9e8_row5_col10, #T_3b9e8_row11_col10, #T_3b9e8_row14_col10, #T_3b9e8_row28_col10 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# #T_3b9e8_row4_col11, #T_3b9e8_row5_col11, #T_3b9e8_row11_col11, #T_3b9e8_row14_col11, #T_3b9e8_row28_col11 {
#   background-color: #5ca3cb;
#   color: #f1f1f1;
# }
# #T_3b9e8_row6_col0, #T_3b9e8_row6_col5, #T_3b9e8_row7_col0, #T_3b9e8_row7_col5, #T_3b9e8_row9_col0, #T_3b9e8_row9_col5, #T_3b9e8_row13_col0, #T_3b9e8_row13_col5, #T_3b9e8_row16_col0, #T_3b9e8_row16_col5, #T_3b9e8_row19_col0, #T_3b9e8_row19_col5, #T_3b9e8_row24_col0, #T_3b9e8_row24_col5, #T_3b9e8_row26_col0, #T_3b9e8_row26_col5, #T_3b9e8_row29_col0, #T_3b9e8_row29_col5, #T_3b9e8_row31_col0, #T_3b9e8_row31_col5 {
#   background-color: #3a87bd;
#   color: #f1f1f1;
# }
# #T_3b9e8_row6_col1, #T_3b9e8_row7_col1, #T_3b9e8_row9_col1, #T_3b9e8_row13_col1, #T_3b9e8_row16_col1, #T_3b9e8_row19_col1, #T_3b9e8_row24_col1, #T_3b9e8_row26_col1, #T_3b9e8_row29_col1, #T_3b9e8_row31_col1 {
#   background-color: #2870b1;
#   color: #f1f1f1;
# }
# #T_3b9e8_row6_col2, #T_3b9e8_row7_col2, #T_3b9e8_row9_col2, #T_3b9e8_row13_col2, #T_3b9e8_row16_col2, #T_3b9e8_row19_col2, #T_3b9e8_row24_col2, #T_3b9e8_row26_col2, #T_3b9e8_row29_col2, #T_3b9e8_row31_col2 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# #T_3b9e8_row6_col3, #T_3b9e8_row7_col3, #T_3b9e8_row9_col3, #T_3b9e8_row13_col3, #T_3b9e8_row16_col3, #T_3b9e8_row19_col3, #T_3b9e8_row24_col3, #T_3b9e8_row26_col3, #T_3b9e8_row29_col3, #T_3b9e8_row31_col3 {
#   background-color: #2f79b5;
#   color: #f1f1f1;
# }
# #T_3b9e8_row6_col4, #T_3b9e8_row7_col4, #T_3b9e8_row9_col4, #T_3b9e8_row13_col4, #T_3b9e8_row16_col4, #T_3b9e8_row19_col4, #T_3b9e8_row24_col4, #T_3b9e8_row26_col4, #T_3b9e8_row29_col4, #T_3b9e8_row31_col4 {
#   background-color: #2e77b5;
#   color: #f1f1f1;
# }
# #T_3b9e8_row6_col6, #T_3b9e8_row7_col6, #T_3b9e8_row9_col6, #T_3b9e8_row13_col6, #T_3b9e8_row16_col6, #T_3b9e8_row19_col6, #T_3b9e8_row24_col6, #T_3b9e8_row26_col6, #T_3b9e8_row29_col6, #T_3b9e8_row31_col6 {
#   background-color: #3681ba;
#   color: #f1f1f1;
# }
# #T_3b9e8_row6_col7, #T_3b9e8_row7_col7, #T_3b9e8_row9_col7, #T_3b9e8_row13_col7, #T_3b9e8_row16_col7, #T_3b9e8_row19_col7, #T_3b9e8_row24_col7, #T_3b9e8_row26_col7, #T_3b9e8_row29_col7, #T_3b9e8_row31_col7 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_3b9e8_row6_col8, #T_3b9e8_row7_col8, #T_3b9e8_row9_col8, #T_3b9e8_row13_col8, #T_3b9e8_row16_col8, #T_3b9e8_row19_col8, #T_3b9e8_row24_col8, #T_3b9e8_row26_col8, #T_3b9e8_row29_col8, #T_3b9e8_row31_col8 {
#   background-color: #3783bb;
#   color: #f1f1f1;
# }
# #T_3b9e8_row6_col9, #T_3b9e8_row6_col11, #T_3b9e8_row7_col9, #T_3b9e8_row7_col11, #T_3b9e8_row9_col9, #T_3b9e8_row9_col11, #T_3b9e8_row13_col9, #T_3b9e8_row13_col11, #T_3b9e8_row16_col9, #T_3b9e8_row16_col11, #T_3b9e8_row19_col9, #T_3b9e8_row19_col11, #T_3b9e8_row24_col9, #T_3b9e8_row24_col11, #T_3b9e8_row26_col9, #T_3b9e8_row26_col11, #T_3b9e8_row29_col9, #T_3b9e8_row29_col11, #T_3b9e8_row31_col9, #T_3b9e8_row31_col11 {
#   background-color: #337eb8;
#   color: #f1f1f1;
# }
# #T_3b9e8_row6_col10, #T_3b9e8_row7_col10, #T_3b9e8_row9_col10, #T_3b9e8_row13_col10, #T_3b9e8_row16_col10, #T_3b9e8_row19_col10, #T_3b9e8_row24_col10, #T_3b9e8_row26_col10, #T_3b9e8_row29_col10, #T_3b9e8_row31_col10 {
#   background-color: #266caf;
#   color: #f1f1f1;
# }
# #T_3b9e8_row8_col0, #T_3b9e8_row8_col1, #T_3b9e8_row8_col2, #T_3b9e8_row8_col3, #T_3b9e8_row8_col4, #T_3b9e8_row8_col5, #T_3b9e8_row8_col6, #T_3b9e8_row8_col8, #T_3b9e8_row8_col9, #T_3b9e8_row8_col10, #T_3b9e8_row8_col11, #T_3b9e8_row12_col0, #T_3b9e8_row12_col1, #T_3b9e8_row12_col2, #T_3b9e8_row12_col3, #T_3b9e8_row12_col4, #T_3b9e8_row12_col5, #T_3b9e8_row12_col6, #T_3b9e8_row12_col8, #T_3b9e8_row12_col9, #T_3b9e8_row12_col10, #T_3b9e8_row12_col11, #T_3b9e8_row18_col0, #T_3b9e8_row18_col1, #T_3b9e8_row18_col2, #T_3b9e8_row18_col3, #T_3b9e8_row18_col4, #T_3b9e8_row18_col5, #T_3b9e8_row18_col6, #T_3b9e8_row18_col8, #T_3b9e8_row18_col9, #T_3b9e8_row18_col10, #T_3b9e8_row18_col11, #T_3b9e8_row20_col0, #T_3b9e8_row20_col1, #T_3b9e8_row20_col2, #T_3b9e8_row20_col3, #T_3b9e8_row20_col4, #T_3b9e8_row20_col5, #T_3b9e8_row20_col6, #T_3b9e8_row20_col8, #T_3b9e8_row20_col9, #T_3b9e8_row20_col10, #T_3b9e8_row20_col11, #T_3b9e8_row21_col0, #T_3b9e8_row21_col1, #T_3b9e8_row21_col2, #T_3b9e8_row21_col3, #T_3b9e8_row21_col4, #T_3b9e8_row21_col5, #T_3b9e8_row21_col6, #T_3b9e8_row21_col8, #T_3b9e8_row21_col9, #T_3b9e8_row21_col10, #T_3b9e8_row21_col11, #T_3b9e8_row22_col0, #T_3b9e8_row22_col1, #T_3b9e8_row22_col2, #T_3b9e8_row22_col3, #T_3b9e8_row22_col4, #T_3b9e8_row22_col5, #T_3b9e8_row22_col6, #T_3b9e8_row22_col8, #T_3b9e8_row22_col9, #T_3b9e8_row22_col10, #T_3b9e8_row22_col11, #T_3b9e8_row25_col0, #T_3b9e8_row25_col1, #T_3b9e8_row25_col2, #T_3b9e8_row25_col3, #T_3b9e8_row25_col4, #T_3b9e8_row25_col5, #T_3b9e8_row25_col6, #T_3b9e8_row25_col8, #T_3b9e8_row25_col9, #T_3b9e8_row25_col10, #T_3b9e8_row25_col11, #T

# %%
# Delta ELBO - unrestricted
styled_elbo_all = metric_table('elbo_delta (max all runs)', df_unrestr, base_idx_unrestr, cols_tail_unrestr, cols_all_unrestr, vmin=-1000000, vmax=1000000)
styled_elbo_all.set_caption("Delta ELBO - Unrestricted Models")
styled_elbo_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_elbo_all
# Out:
# <style type="text/css">
# #T_60eee caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_60eee_row0_col0, #T_60eee_row0_col1, #T_60eee_row0_col2, #T_60eee_row0_col4, #T_60eee_row0_col5, #T_60eee_row0_col6, #T_60eee_row0_col8, #T_60eee_row0_col10, #T_60eee_row0_col11, #T_60eee_row1_col0, #T_60eee_row1_col1, #T_60eee_row1_col3, #T_60eee_row1_col4, #T_60eee_row1_col7, #T_60eee_row1_col9, #T_60eee_row1_col11, #T_60eee_row2_col0, #T_60eee_row2_col1, #T_60eee_row2_col3, #T_60eee_row2_col4, #T_60eee_row2_col6, #T_60eee_row2_col7, #T_60eee_row2_col8, #T_60eee_row2_col9, #T_60eee_row2_col10, #T_60eee_row2_col11, #T_60eee_row3_col1, #T_60eee_row3_col2, #T_60eee_row3_col3, #T_60eee_row3_col4, #T_60eee_row3_col5, #T_60eee_row3_col7, #T_60eee_row3_col8, #T_60eee_row3_col10, #T_60eee_row3_col11, #T_60eee_row27_col1, #T_60eee_row27_col2, #T_60eee_row27_col3, #T_60eee_row27_col4, #T_60eee_row27_col5, #T_60eee_row27_col6, #T_60eee_row27_col7, #T_60eee_row27_col8, #T_60eee_row27_col9, #T_60eee_row27_col10, #T_60eee_row27_col11 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_60eee_row0_col3, #T_60eee_row0_col7, #T_60eee_row0_col9, #T_60eee_row1_col2, #T_60eee_row1_col5, #T_60eee_row1_col6, #T_60eee_row1_col8, #T_60eee_row1_col10, #T_60eee_row2_col2, #T_60eee_row2_col5, #T_60eee_row3_col0, #T_60eee_row3_col6, #T_60eee_row3_col9, #T_60eee_row27_col0 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_60eee_row4_col0, #T_60eee_row6_col2, #T_60eee_row6_col11, #T_60eee_row7_col2, #T_60eee_row7_col11, #T_60eee_row9_col11, #T_60eee_row11_col0, #T_60eee_row26_col8, #T_60eee_row26_col11, #T_60eee_row28_col0, #T_60eee_row29_col2, #T_60eee_row29_col11 {
#   background-color: #b1d5e7;
#   color: #000000;
# }
# #T_60eee_row4_col1, #T_60eee_row4_col10, #T_60eee_row5_col9, #T_60eee_row6_col3, #T_60eee_row6_col4, #T_60eee_row6_col9, #T_60eee_row6_col10, #T_60eee_row7_col1, #T_60eee_row7_col3, #T_60eee_row7_col4, #T_60eee_row7_col7, #T_60eee_row7_col9, #T_60eee_row7_col10, #T_60eee_row9_col1, #T_60eee_row9_col3, #T_60eee_row9_col4, #T_60eee_row9_col9, #T_60eee_row11_col9, #T_60eee_row26_col1, #T_60eee_row26_col3, #T_60eee_row26_col4, #T_60eee_row26_col10, #T_60eee_row28_col7, #T_60eee_row28_col10, #T_60eee_row29_col1, #T_60eee_row29_col3, #T_60eee_row29_col4, #T_60eee_row29_col9, #T_60eee_row29_col10 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_60eee_row4_col2, #T_60eee_row4_col11, #T_60eee_row5_col2, #T_60eee_row5_col11, #T_60eee_row6_col8, #T_60eee_row7_col8, #T_60eee_row9_col2, #T_60eee_row9_col8, #T_60eee_row11_col2, #T_60eee_row11_col8, #T_60eee_row11_col11, #T_60eee_row14_col8, #T_60eee_row14_col11, #T_60eee_row26_col2, #T_60eee_row28_col11, #T_60eee_row29_col8 {
#   background-color: #b3d6e8;
#   color: #000000;
# }
# #T_60eee_row4_col3, #T_60eee_row4_col4, #T_60eee_row4_col7, #T_60eee_row4_col9, #T_60eee_row5_col1, #T_60eee_row5_col3, #T_60eee_row5_col4, #T_60eee_row5_col10, #T_60eee_row6_col1, #T_60eee_row9_col7, #T_60eee_row9_col10, #T_60eee_row11_col1, #T_60eee_row11_col3, #T_60eee_row11_col4, #T_60eee_row11_col10, #T_60eee_row14_col1, #T_60eee_row14_col3, #T_60eee_row14_col4, #T_60eee_row14_col9, #T_60eee_row14_col10, #T_60eee_row26_col7, #T_60eee_row28_col1, #T_60eee_row28_col3, #T_60eee_row28_col4, #T_60eee_row28_col9, #T_60eee_row29_col7 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_60eee_row4_col5, #T_60eee_row6_col5, #T_60eee_row7_col5, #T_60eee_row14_col5, #T_60eee_row26_col5, #T_60eee_row29_col5 {
#   background-color: #98c8e0;
#   color: #000000;
# }
# #T_60eee_row4_col6, #T_60eee_row11_col6 {
#   background-color: #a9d1e5;
#   color: #000000;
# }
# #T_60eee_row4_col8, #T_60eee_row5_col8, #T_60eee_row14_col2, #T_60eee_row26_col9, #T_60eee_row28_col2, #T_60eee_row28_col8 {
#   background-color: #b6d7e8;
#   color: #000000;
# }
# #T_60eee_row5_col0, #T_60eee_row6_col0, #T_60eee_row14_col0, #T_60eee_row29_col0 {
#   background-color: #aed3e6;
#   color: #000000;
# }
# #T_60eee_row5_col5, #T_60eee_row9_col5, #T_60eee_row11_col5 {
#   background-color: #96c7df;
#   color: #000000;
# }
# #T_60eee_row5_col6, #T_60eee_row14_col6, #T_60eee_row28_col6, #T_60eee_row29_col6 {
#   background-color: #a7d0e4;
#   color: #000000;
# }
# #T_60eee_row5_col7 {
#   background-color: #c2ddec;
#   color: #000000;
# }
# #T_60eee_row6_col6, #T_60eee_row7_col6, #T_60eee_row9_col6, #T_60eee_row15_col7, #T_60eee_row23_col7, #T_60eee_row26_col6 {
#   background-color: #a5cee3;
#   color: #000000;
# }
# #T_60eee_row6_col7, #T_60eee_row11_col7, #T_60eee_row14_col7 {
#   background-color: #bddbea;
#   color: #000000;
# }
# #T_60eee_row7_col0, #T_60eee_row9_col0, #T_60eee_row26_col0 {
#   background-color: #acd2e5;
#   color: #000000;
# }
# #T_60eee_row8_col0, #T_60eee_row20_col0, #T_60eee_row21_col0, #T_60eee_row24_col7, #T_60eee_row32_col0 {
#   background-color: #7eb8d7;
#   color: #000000;
# }
# #T_60eee_row8_col1, #T_60eee_row8_col3, #T_60eee_row8_col9, #T_60eee_row18_col1, #T_60eee_row18_col3, #T_60eee_row18_col4, #T_60eee_row18_col10, #T_60eee_row20_col3, #T_60eee_row20_col4, #T_60eee_row20_col7, #T_60eee_row20_col9, #T_60eee_row21_col1, #T_60eee_row21_col3, #T_60eee_row21_col4, #T_60eee_row21_col9, #T_60eee_row21_col10, #T_60eee_row32_col1, #T_60eee_row32_col3, #T_60eee_row32_col4, #T_60eee_row32_col9, #T_60eee_row32_col10 {
#   background-color: #8dc2dc;
#   color: #000000;
# }
# #T_60eee_row8_col2, #T_60eee_row8_col11, #T_60eee_row18_col11, #T_60eee_row20_col2, #T_60eee_row20_col11, #T_60eee_row21_col2, #T_60eee_row21_col11, #T_60eee_row32_col2, #T_60eee_row32_col11 {
#   background-color: #84bcd9;
#   color: #000000;
# }
# #T_60eee_row8_col4, #T_60eee_row8_col10, #T_60eee_row20_col1, #T_60eee_row20_col10 {
#   background-color: #90c4dd;
#   color: #000000;
# }
# #T_60eee_row8_col5, #T_60eee_row13_col0, #T_60eee_row16_col0, #T_60eee_row18_col5, #T_60eee_row19_col0, #T_60eee_row19_col2, #T_60eee_row24_col0, #T_60eee_row31_col2, #T_60eee_row32_col5 {
#   background-color: #65a9cf;
#   color: #f1f1f1;
# }
# #T_60eee_row8_col6, #T_60eee_row18_col6, #T_60eee_row32_col6 {
#   background-color: #78b4d5;
#   color: #000000;
# }
# #T_60eee_row8_col7, #T_60eee_row18_col7, #T_60eee_row21_col7, #T_60eee_row32_col7 {
#   background-color: #93c6de;
#   color: #000000;
# }
# #T_60eee_row8_col8, #T_60eee_row20_col8 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_60eee_row10_col0, #T_60eee_row10_col1, #T_60eee_row10_col2, #T_60eee_row10_col3, #T_60eee_row10_col4, #T_60eee_row10_col6, #T_60eee_row10_col11, #T_60eee_row15_col0, #T_60eee_row15_col6, #T_60eee_row15_col8, #T_60eee_row15_col9, #T_60eee_row15_col10, #T_60eee_row15_col11, #T_60eee_row17_col0, #T_60eee_row17_col1, #T_60eee_row17_col2, #T_60eee_row17_col3, #T_60eee_row17_col4, #T_60eee_row17_col6, #T_60eee_row17_col8, #T_60eee_row17_col10, #T_60eee_row17_col11, #T_60eee_row23_col0, #T_60eee_row23_col1, #T_60eee_row23_col3, #T_60eee_row23_col6, #T_60eee_row23_col8, #T_60eee_row23_col9, #T_60eee_row23_col11, #T_60eee_row30_col0, #T_60eee_row30_col1, #T_60eee_row30_col4, #T_60eee_row30_col5, #T_60eee_row30_col6, #T_60eee_row30_col8, #T_60eee_row30_col9, #T_60eee_row30_col11 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_60eee_row10_col5, #T_60eee_row17_col5 {
#   background-color: #9dcbe1;
#   color: #000000;
# }
# #T_60eee_row10_col7, #T_60eee_row10_col8, #T_60eee_row10_col9, #T_60eee_row10_col10, #T_60eee_row15_col1, #T_60eee_row15_col3, #T_60eee_row15_col4, #T_60eee_row15_col5, #T_60eee_row17_col9, #T_60eee_row23_col2, #T_60eee_row23_col4, #T_60eee_row23_col5, #T_60eee_row23_col10, #T_60eee_row30_col2, #T_60eee_row30_col3, #T_60eee_row30_col10 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_60eee_row12_col0 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# #T_60eee_row12_col1, #T_60eee_row12_col3, #T_60eee_row12_col4, #T_60eee_row12_col9, #T_60eee_row22_col1, #T_60eee_row22_col4, #T_60eee_row22_col9, #T_60eee_row22_col10, #T_60eee_row25_col1, #T_60eee_row25_col3, #T_60eee_row25_col4, #T_60eee_row25_col9, #T_60eee_row25_col10 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# #T_60eee_row12_col2, #T_60eee_row22_col2, #T_60eee_row22_col8 {

# %%
# Model performance - restricted
df_restr = res[res['config'].isin(restricted)]
styled_restr, base_idx_restr, cols_tail_restr, cols_all_restr = performance(df_restr, 'cagr_rel_ex_ante')
styled_restr.set_caption("Rel CAGR - Restricted Models")
styled_restr.set_table_styles(CAPTION_CSS, overwrite=False)
styled_restr
# Out:
# <style type="text/css">
# #T_cedc2 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_cedc2_row0_col0, #T_cedc2_row26_col2 {
#   background-color: #4695c4;
#   color: #f1f1f1;
# }
# #T_cedc2_row0_col1, #T_cedc2_row2_col4, #T_cedc2_row2_col8, #T_cedc2_row5_col1, #T_cedc2_row6_col8, #T_cedc2_row11_col7, #T_cedc2_row24_col4, #T_cedc2_row26_col4 {
#   background-color: #e1edf3;
#   color: #000000;
# }
# #T_cedc2_row0_col2, #T_cedc2_row1_col0, #T_cedc2_row4_col6, #T_cedc2_row6_col11, #T_cedc2_row8_col6, #T_cedc2_row11_col6 {
#   background-color: #bddbea;
#   color: #000000;
# }
# #T_cedc2_row0_col3, #T_cedc2_row1_col5, #T_cedc2_row1_col6, #T_cedc2_row3_col2, #T_cedc2_row5_col9, #T_cedc2_row22_col5, #T_cedc2_row24_col9 {
#   background-color: #9bc9e0;
#   color: #000000;
# }
# #T_cedc2_row0_col4, #T_cedc2_row0_col10, #T_cedc2_row1_col1, #T_cedc2_row4_col9, #T_cedc2_row4_col11, #T_cedc2_row9_col0, #T_cedc2_row35_col2, #T_cedc2_row42_col2 {
#   background-color: #b6d7e8;
#   color: #000000;
# }
# #T_cedc2_row0_col5 {
#   background-color: #2065ab;
#   color: #f1f1f1;
# }
# #T_cedc2_row0_col6, #T_cedc2_row1_col8, #T_cedc2_row3_col6, #T_cedc2_row24_col10, #T_cedc2_row42_col6 {
#   background-color: #a9d1e5;
#   color: #000000;
# }
# #T_cedc2_row0_col7, #T_cedc2_row3_col1, #T_cedc2_row6_col0, #T_cedc2_row6_col1, #T_cedc2_row6_col10, #T_cedc2_row10_col3, #T_cedc2_row15_col4, #T_cedc2_row15_col8, #T_cedc2_row18_col4, #T_cedc2_row29_col2, #T_cedc2_row29_col10, #T_cedc2_row33_col0, #T_cedc2_row36_col2, #T_cedc2_row37_col11, #T_cedc2_row47_col9, #T_cedc2_row54_col2 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_cedc2_row0_col8, #T_cedc2_row7_col10, #T_cedc2_row11_col1, #T_cedc2_row21_col11, #T_cedc2_row22_col11, #T_cedc2_row25_col8, #T_cedc2_row27_col9, #T_cedc2_row32_col2, #T_cedc2_row33_col9, #T_cedc2_row35_col10, #T_cedc2_row38_col5 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_cedc2_row0_col9, #T_cedc2_row3_col5, #T_cedc2_row11_col5, #T_cedc2_row12_col9, #T_cedc2_row13_col5, #T_cedc2_row17_col2, #T_cedc2_row41_col6 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_cedc2_row0_col11, #T_cedc2_row4_col3, #T_cedc2_row40_col2, #T_cedc2_row43_col6 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_cedc2_row1_col2, #T_cedc2_row7_col5 {
#   background-color: #307ab6;
#   color: #f1f1f1;
# }
# #T_cedc2_row1_col3, #T_cedc2_row1_col10, #T_cedc2_row4_col0, #T_cedc2_row11_col0, #T_cedc2_row11_col9, #T_cedc2_row13_col10, #T_cedc2_row20_col10, #T_cedc2_row31_col10, #T_cedc2_row34_col6, #T_cedc2_row44_col6 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_cedc2_row1_col4, #T_cedc2_row8_col8, #T_cedc2_row11_col3, #T_cedc2_row15_col11, #T_cedc2_row16_col11, #T_cedc2_row51_col2 {
#   background-color: #d2e6f0;
#   color: #000000;
# }
# #T_cedc2_row1_col7, #T_cedc2_row3_col10, #T_cedc2_row8_col1, #T_cedc2_row11_col10, #T_cedc2_row14_col2, #T_cedc2_row15_col10, #T_cedc2_row16_col0, #T_cedc2_row17_col10, #T_cedc2_row18_col8, #T_cedc2_row19_col0, #T_cedc2_row22_col6, #T_cedc2_row25_col6, #T_cedc2_row28_col6, #T_cedc2_row29_col8, #T_cedc2_row38_col2, #T_cedc2_row40_col5, #T_cedc2_row44_col9 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_cedc2_row1_col9, #T_cedc2_row6_col9, #T_cedc2_row9_col2, #T_cedc2_row25_col9 {
#   background-color: #7eb8d7;
#   color: #000000;
# }
# #T_cedc2_row1_col11, #T_cedc2_row2_col11, #T_cedc2_row3_col0, #T_cedc2_row3_col11, #T_cedc2_row19_col2, #T_cedc2_row21_col2 {
#   background-color: #aed3e6;
#   color: #000000;
# }
# #T_cedc2_row2_col0, #T_cedc2_row3_col3, #T_cedc2_row22_col2, #T_cedc2_row37_col2 {
#   background-color: #98c8e0;
#   color: #000000;
# }
# #T_cedc2_row2_col1, #T_cedc2_row5_col2, #T_cedc2_row7_col1, #T_cedc2_row13_col3, #T_cedc2_row15_col3, #T_cedc2_row16_col8, #T_cedc2_row21_col4, #T_cedc2_row31_col3, #T_cedc2_row31_col4, #T_cedc2_row34_col5, #T_cedc2_row35_col11, #T_cedc2_row36_col11, #T_cedc2_row38_col0, #T_cedc2_row42_col9 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_cedc2_row2_col2, #T_cedc2_row10_col9, #T_cedc2_row16_col5, #T_cedc2_row29_col6, #T_cedc2_row30_col5 {
#   background-color: #84bcd9;
#   color: #000000;
# }
# #T_cedc2_row2_col3, #T_cedc2_row2_col10, #T_cedc2_row5_col4, #T_cedc2_row8_col3, #T_cedc2_row13_col8, #T_cedc2_row14_col4, #T_cedc2_row15_col5, #T_cedc2_row16_col4, #T_cedc2_row18_col10, #T_cedc2_row19_col11, #T_cedc2_row20_col4, #T_cedc2_row20_col11, #T_cedc2_row21_col8, #T_cedc2_row23_col6 {
#   background-color: #d5e7f1;
#   color: #000000;
# }
# #T_cedc2_row2_col5, #T_cedc2_row7_col11, #T_cedc2_row22_col8 {
#   background-color: #c2ddec;
#   color: #000000;
# }
# #T_cedc2_row2_col6, #T_cedc2_row17_col9 {
#   background-color: #3783bb;
#   color: #f1f1f1;
# }
# #T_cedc2_row2_col7, #T_cedc2_row9_col10, #T_cedc2_row15_col0, #T_cedc2_row18_col1, #T_cedc2_row19_col6, #T_cedc2_row26_col8, #T_cedc2_row27_col1, #T_cedc2_row27_col5, #T_cedc2_row28_col4, #T_cedc2_row34_col8, #T_cedc2_row36_col6, #T_cedc2_row40_col11, #T_cedc2_row44_col2 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_cedc2_row2_col9, #T_cedc2_row31_col2 {
#   background-color: #6eaed2;
#   color: #f1f1f1;
# }
# #T_cedc2_row3_col4, #T_cedc2_row7_col3, #T_cedc2_row8_col10, #T_cedc2_row10_col5, #T_cedc2_row12_col5, #T_cedc2_row14_col10, #T_cedc2_row20_col0, #T_cedc2_row22_col10, #T_cedc2_row32_col11, #T_cedc2_row33_col10 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_cedc2_row3_col7, #T_cedc2_row6_col3, #T_cedc2_row13_col4, #T_cedc2_row17_col11, #T_cedc2_row18_col11, #T_cedc2_row19_col8, #T_cedc2_row21_col10, #T_cedc2_row24_col8, #T_cedc2_row28_col0, #T_cedc2_row28_col5, #T_cedc2_row36_col5, #T_cedc2_row36_col10 {
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_cedc2_row3_col8, #T_cedc2_row8_col0, #T_cedc2_row15_col6, #T_cedc2_row21_col9 {
#   background-color: #68abd0;
#   color: #f1f1f1;
# }
# #T_cedc2_row3_col9 {
#   background-color: #4997c5;
#   color: #f1f1f1;
# }
# #T_cedc2_row4_col1, #T_cedc2_row7_col4, #T_cedc2_row29_col11, #T_cedc2_row30_col11, #T_cedc2_row31_col11, #T_cedc2_row38_col9 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_cedc2_row4_col2, #T_cedc2_row8_col9, #T_cedc2_row11_col11, #T_cedc2_row12_col11, #T_cedc2_row19_col10, #T_cedc2_row23_col5, #T_cedc2_row24_col5, #T_cedc2_row33_col8 {
#   background-color: #cae1ee;
#   color: #000000;
# }
# #T_cedc2_row4_col4, #T_cedc2_row8_col4, #T_cedc2_row14_col8, #T_cedc2_row23_col11, #T_cedc2_row24_col11, #T_cedc2_row25_col0, #T_cedc2_row25_col11, #T_cedc2_row26_col3, #T_cedc2_row26_col11, #T_cedc2_row27_col11, #T_cedc2_row28_col11 {
#   background-color: #d8e9f1;
#   color: #000000;
# }
# #T_cedc2_row4_col5, #T_cedc2_row9_col6 {
#   background-color: #337eb8;
#   color: #f1f1f1;
# }
# #T_cedc2_row4_col7, #T_cedc2_row14_col6, #T_cedc2_row16_col2, #T_cedc2_row16_col6, #T_cedc2_row16_col10, #T_cedc2_row32_col0, #T_cedc2_row37_col5 {
#   background-color: #cce2ef;
#   color: #000000;
# }
# #T_cedc2_row4_col8 {
#   background-color: #b1d5e7;
#   color: #000000;
# }
# #T_cedc2_row4_col10, #T_cedc2_row13_col6, #T_cedc2_row13_col11, #T_cedc2_row25_col10, #T_cedc2_row29_col5, #T_cedc2_row42_col5 {
#   background-color: #cfe4ef;
#   color: #000000;
# }
# #T_cedc2_row5_col0, #T_cedc2_row31_col9, #T_cedc2_row34_col0, #T_cedc2_row37_col6 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_cedc2_row5_col3, #T_cedc2_row7_col9, #T_cedc2_row11_col8, #T_cedc2_row33_col2 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_cedc2_row5_col5, #T_cedc2_row22_col9 {
#   background-color: #78b4d5;
#   color: #000000;
# }
# #T_cedc2_row5_col6, #T_cedc2_row33_col6 {
#   background-color: #93c6de;
#   color: #000000;
# }
# #T_cedc2_row5_col7, #T_cedc2_row12_col10, #T_cedc2_row19_col4, #T_cedc2_row21_col6, #T_cedc2_row30_col8, #T_cedc2_row39_col11, #T_cedc2_row40_col9, #T_cedc2_row41_col2, #T_cedc2_row43_col5, #T_cedc2_row46_col5 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_cedc2_row5_col8, #T_cedc2_row5_col11, #T_cedc2_row20_col5, #T_cedc2_row20_col8, #T_cedc2_row30_col9, #T_cedc2_row39_col5 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_cedc2_row5_col10, #T_cedc2_row20_col6, #T_cedc2_row26_col6 {
#   background-color: #eff3f5;
#   c

# %%
# Smooth CPLL
styled_cpll_all = metric_table('CPLL Gap', df_restr, base_idx_restr, cols_tail_restr, cols_all_restr, vmin=-100000,  vmax=100000)
styled_cpll_all.set_caption("Smooth CPLL - Restricted Models")
styled_cpll_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_cpll_all
# Out:
# <style type="text/css">
# #T_5e334 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_5e334_row0_col0, #T_5e334_row0_col2, #T_5e334_row0_col5, #T_5e334_row0_col6, #T_5e334_row0_col7, #T_5e334_row0_col8, #T_5e334_row0_col11, #T_5e334_row1_col0, #T_5e334_row1_col1, #T_5e334_row1_col4, #T_5e334_row1_col8, #T_5e334_row1_col9, #T_5e334_row1_col10, #T_5e334_row1_col11, #T_5e334_row2_col0, #T_5e334_row2_col1, #T_5e334_row2_col4, #T_5e334_row2_col8, #T_5e334_row2_col9, #T_5e334_row2_col10, #T_5e334_row2_col11, #T_5e334_row6_col2, #T_5e334_row6_col5, #T_5e334_row6_col6, #T_5e334_row6_col7, #T_5e334_row6_col11, #T_5e334_row8_col0, #T_5e334_row8_col1, #T_5e334_row8_col4, #T_5e334_row8_col8, #T_5e334_row8_col9, #T_5e334_row8_col10, #T_5e334_row8_col11, #T_5e334_row11_col2, #T_5e334_row11_col5, #T_5e334_row11_col6, #T_5e334_row11_col7, #T_5e334_row11_col11, #T_5e334_row17_col10, #T_5e334_row20_col10, #T_5e334_row24_col10, #T_5e334_row34_col2, #T_5e334_row34_col5, #T_5e334_row34_col6, #T_5e334_row34_col7, #T_5e334_row34_col11, #T_5e334_row37_col10, #T_5e334_row39_col0, #T_5e334_row39_col1, #T_5e334_row39_col4, #T_5e334_row39_col8, #T_5e334_row39_col9, #T_5e334_row39_col10, #T_5e334_row39_col11, #T_5e334_row46_col10, #T_5e334_row50_col0, #T_5e334_row50_col2, #T_5e334_row50_col5, #T_5e334_row50_col6, #T_5e334_row50_col7, #T_5e334_row50_col11, #T_5e334_row51_col0, #T_5e334_row51_col1, #T_5e334_row51_col4, #T_5e334_row51_col8, #T_5e334_row51_col9, #T_5e334_row51_col10 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_5e334_row0_col1, #T_5e334_row0_col4, #T_5e334_row0_col9, #T_5e334_row0_col10, #T_5e334_row6_col0, #T_5e334_row6_col1, #T_5e334_row6_col4, #T_5e334_row6_col8, #T_5e334_row6_col9, #T_5e334_row6_col10, #T_5e334_row11_col0, #T_5e334_row11_col1, #T_5e334_row11_col4, #T_5e334_row11_col8, #T_5e334_row11_col9, #T_5e334_row11_col10, #T_5e334_row15_col1, #T_5e334_row17_col1, #T_5e334_row17_col8, #T_5e334_row20_col1, #T_5e334_row20_col8, #T_5e334_row24_col1, #T_5e334_row24_col8, #T_5e334_row28_col5, #T_5e334_row28_col8, #T_5e334_row31_col1, #T_5e334_row33_col5, #T_5e334_row33_col8, #T_5e334_row34_col0, #T_5e334_row34_col1, #T_5e334_row34_col4, #T_5e334_row34_col8, #T_5e334_row34_col9, #T_5e334_row34_col10, #T_5e334_row37_col1, #T_5e334_row37_col5, #T_5e334_row37_col8, #T_5e334_row42_col1, #T_5e334_row42_col10, #T_5e334_row45_col1, #T_5e334_row45_col7, #T_5e334_row45_col10, #T_5e334_row46_col1, #T_5e334_row46_col5, #T_5e334_row46_col8, #T_5e334_row48_col5, #T_5e334_row48_col8, #T_5e334_row50_col1, #T_5e334_row50_col4, #T_5e334_row50_col8, #T_5e334_row50_col9, #T_5e334_row50_col10 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_5e334_row0_col3, #T_5e334_row1_col2, #T_5e334_row1_col3, #T_5e334_row1_col5, #T_5e334_row1_col6, #T_5e334_row1_col7, #T_5e334_row2_col2, #T_5e334_row2_col3, #T_5e334_row2_col5, #T_5e334_row2_col6, #T_5e334_row2_col7, #T_5e334_row3_col4, #T_5e334_row3_col9, #T_5e334_row3_col10, #T_5e334_row5_col9, #T_5e334_row5_col10, #T_5e334_row6_col3, #T_5e334_row8_col2, #T_5e334_row8_col3, #T_5e334_row8_col5, #T_5e334_row8_col6, #T_5e334_row8_col7, #T_5e334_row9_col10, #T_5e334_row11_col3, #T_5e334_row32_col1, #T_5e334_row32_col4, #T_5e334_row32_col9, #T_5e334_row32_col10, #T_5e334_row34_col3, #T_5e334_row39_col2, #T_5e334_row39_col3, #T_5e334_row39_col5, #T_5e334_row39_col6, #T_5e334_row39_col7, #T_5e334_row50_col3, #T_5e334_row51_col2, #T_5e334_row51_col5, #T_5e334_row51_col6, #T_5e334_row51_col7, #T_5e334_row51_col11, #T_5e334_row55_col4, #T_5e334_row55_col9, #T_5e334_row55_col10 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_5e334_row3_col0, #T_5e334_row3_col1, #T_5e334_row3_col5, #T_5e334_row3_col6, #T_5e334_row3_col7, #T_5e334_row3_col8, #T_5e334_row3_col11, #T_5e334_row4_col4, #T_5e334_row4_col9, #T_5e334_row4_col10, #T_5e334_row5_col0, #T_5e334_row5_col1, #T_5e334_row5_col2, #T_5e334_row5_col4, #T_5e334_row5_col5, #T_5e334_row5_col6, #T_5e334_row5_col8, #T_5e334_row5_col11, #T_5e334_row7_col1, #T_5e334_row7_col4, #T_5e334_row7_col9, #T_5e334_row7_col10, #T_5e334_row9_col0, #T_5e334_row9_col1, #T_5e334_row9_col2, #T_5e334_row9_col4, #T_5e334_row9_col5, #T_5e334_row9_col6, #T_5e334_row9_col7, #T_5e334_row9_col8, #T_5e334_row9_col9, #T_5e334_row9_col11, #T_5e334_row10_col1, #T_5e334_row10_col4, #T_5e334_row10_col9, #T_5e334_row10_col10, #T_5e334_row17_col9, #T_5e334_row20_col9, #T_5e334_row24_col9, #T_5e334_row28_col9, #T_5e334_row32_col0, #T_5e334_row32_col2, #T_5e334_row32_col5, #T_5e334_row32_col6, #T_5e334_row32_col7, #T_5e334_row32_col8, #T_5e334_row32_col11, #T_5e334_row33_col9, #T_5e334_row37_col9, #T_5e334_row38_col1, #T_5e334_row38_col4, #T_5e334_row38_col9, #T_5e334_row38_col10, #T_5e334_row46_col9, #T_5e334_row48_col9, #T_5e334_row49_col1, #T_5e334_row49_col4, #T_5e334_row49_col9, #T_5e334_row49_col10, #T_5e334_row51_col3, #T_5e334_row55_col0, #T_5e334_row55_col1, #T_5e334_row55_col2, #T_5e334_row55_col5, #T_5e334_row55_col6, #T_5e334_row55_col7, #T_5e334_row55_col8, #T_5e334_row55_col11 {
#   background-color: #eff3f5;
#   color: #000000;
# }
# #T_5e334_row3_col2, #T_5e334_row3_col3, #T_5e334_row4_col0, #T_5e334_row4_col1, #T_5e334_row4_col2, #T_5e334_row4_col5, #T_5e334_row4_col6, #T_5e334_row4_col7, #T_5e334_row4_col8, #T_5e334_row4_col11, #T_5e334_row5_col3, #T_5e334_row5_col7, #T_5e334_row7_col0, #T_5e334_row7_col2, #T_5e334_row7_col5, #T_5e334_row7_col6, #T_5e334_row7_col7, #T_5e334_row7_col8, #T_5e334_row7_col11, #T_5e334_row9_col3, #T_5e334_row10_col0, #T_5e334_row10_col2, #T_5e334_row10_col5, #T_5e334_row10_col6, #T_5e334_row10_col8, #T_5e334_row10_col11, #T_5e334_row32_col3, #T_5e334_row38_col0, #T_5e334_row38_col2, #T_5e334_row38_col5, #T_5e334_row38_col6, #T_5e334_row38_col7, #T_5e334_row38_col8, #T_5e334_row38_col11, #T_5e334_row49_col0, #T_5e334_row49_col2, #T_5e334_row49_col5, #T_5e334_row49_col6, #T_5e334_row49_col7, #T_5e334_row49_col8, #T_5e334_row49_col11, #T_5e334_row55_col3 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_5e334_row4_col3, #T_5e334_row7_col3, #T_5e334_row10_col3, #T_5e334_row10_col7, #T_5e334_row38_col3, #T_5e334_row49_col3 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_5e334_row12_col0, #T_5e334_row12_col1, #T_5e334_row12_col2, #T_5e334_row12_col3, #T_5e334_row12_col4, #T_5e334_row12_col5, #T_5e334_row12_col6, #T_5e334_row12_col7, #T_5e334_row12_col8, #T_5e334_row12_col9, #T_5e334_row12_col10, #T_5e334_row12_col11, #T_5e334_row13_col0, #T_5e334_row13_col1, #T_5e334_row13_col2, #T_5e334_row13_col3, #T_5e334_row13_col4, #T_5e334_row13_col5, #T_5e334_row13_col6, #T_5e334_row13_col7, #T_5e334_row13_col8, #T_5e334_row13_col9, #T_5e334_row13_col10, #T_5e334_row13_col11, #T_5e334_row15_col0, #T_5e334_row15_col2, #T_5e334_row15_col3, #T_5e334_row15_col5, #T_5e334_row15_col6, #T_5e334_row15_col8, #T_5e334_row15_col9, #T_5e334_row17_col3, #T_5e334_row18_col0, #T_5e334_row18_col1, #T_5e334_row18_col2, #T_5e334_row18_col3, #T_5e334_row18_col4, #T_5e334_row18_col5, #T_5e334_row18_col6, #T_5e334_row18_col7, #T_5e334_row18_col8, #T_5e334_row18_col9, #T_5e334_row18_col10, #T_5e334_row18_col11, #T_5e334_row19_col0, #T_5e334_row19_col2, #T_5e334_row19_col3, #T_5e334_row19_col4, #T_5e334_row19_col5, #T_5e334_row19_col6, #T_5e334_row19_col8, #T_5e334_row19_col9, #T_5e334_row19_col10, #T_5e334_row19_col11, #T_5e334_row20_col3, #T_5e334_row21_col0, #T_5e334_row21_col1, #T_5e334_row21_col2, #T_5e334_row21_col3, #T_5e334_row21_col4, #T_5e334_row21_col5, #T_5e334_row21_col6, #T_5e334_row21_col7, #T_5e334_row21_col8, #T_5e334_row21_col9, #T_5e334_row21_col10, #T_5e334_row21_col11, #T_5e334_row23_col0, #T_5e334_row23_col1, #T_5e334_row23_col2, #T_5e334_row23_col3, #T_5e334_row23_col4, #T_5e334_row23_col5, #T_5e334_row23_col6, #T_5e334_row23_col7, #T_5e334_row23_col8, #T_5e334_row23_col9, #T_5e334_row23_col10, #T_5e334_row23_col11, #T_5e334_row24_col3, #T_5e334_row26_col0, #T_5e334_row26_col1, #T_5e334_row26_col2, #T_5e334_row26_col3, #T_5e334_row26_col4, #T_5e334_row26_col5, #T_5e334_ro

# %%
# Delta ELBO — ALL models, SAME rows/cols/order as "# Model performance"
styled_elbo_all = metric_table('elbo_delta (max all runs)', df_restr, base_idx_restr, cols_tail_restr, cols_all_restr, vmin=-1000000, vmax=1000000)
styled_elbo_all.set_caption("Delta ELBO - Restricted Models")
styled_elbo_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_elbo_all
# Out:
# <style type="text/css">
# #T_08754 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_08754_row0_col0, #T_08754_row0_col1, #T_08754_row0_col2, #T_08754_row0_col3, #T_08754_row0_col4, #T_08754_row0_col5, #T_08754_row0_col6, #T_08754_row0_col7, #T_08754_row0_col8, #T_08754_row0_col9, #T_08754_row0_col10, #T_08754_row0_col11, #T_08754_row1_col0, #T_08754_row1_col1, #T_08754_row1_col2, #T_08754_row1_col3, #T_08754_row1_col4, #T_08754_row1_col5, #T_08754_row1_col6, #T_08754_row1_col7, #T_08754_row1_col8, #T_08754_row1_col9, #T_08754_row1_col10, #T_08754_row1_col11, #T_08754_row2_col0, #T_08754_row2_col1, #T_08754_row2_col2, #T_08754_row2_col3, #T_08754_row2_col4, #T_08754_row2_col5, #T_08754_row2_col6, #T_08754_row2_col7, #T_08754_row2_col8, #T_08754_row2_col9, #T_08754_row2_col10, #T_08754_row2_col11, #T_08754_row6_col0, #T_08754_row6_col1, #T_08754_row6_col2, #T_08754_row6_col3, #T_08754_row6_col4, #T_08754_row6_col5, #T_08754_row6_col6, #T_08754_row6_col7, #T_08754_row6_col8, #T_08754_row6_col9, #T_08754_row6_col10, #T_08754_row6_col11, #T_08754_row8_col0, #T_08754_row8_col1, #T_08754_row8_col2, #T_08754_row8_col3, #T_08754_row8_col4, #T_08754_row8_col5, #T_08754_row8_col6, #T_08754_row8_col7, #T_08754_row8_col8, #T_08754_row8_col9, #T_08754_row8_col10, #T_08754_row8_col11, #T_08754_row11_col0, #T_08754_row11_col1, #T_08754_row11_col2, #T_08754_row11_col3, #T_08754_row11_col4, #T_08754_row11_col5, #T_08754_row11_col6, #T_08754_row11_col7, #T_08754_row11_col8, #T_08754_row11_col9, #T_08754_row11_col10, #T_08754_row11_col11, #T_08754_row12_col5, #T_08754_row14_col2, #T_08754_row14_col5, #T_08754_row16_col0, #T_08754_row16_col1, #T_08754_row16_col2, #T_08754_row16_col3, #T_08754_row16_col4, #T_08754_row16_col5, #T_08754_row16_col6, #T_08754_row16_col7, #T_08754_row16_col8, #T_08754_row16_col9, #T_08754_row16_col10, #T_08754_row16_col11, #T_08754_row21_col5, #T_08754_row22_col0, #T_08754_row22_col1, #T_08754_row22_col2, #T_08754_row22_col3, #T_08754_row22_col4, #T_08754_row22_col5, #T_08754_row22_col6, #T_08754_row22_col7, #T_08754_row22_col8, #T_08754_row22_col9, #T_08754_row22_col10, #T_08754_row22_col11, #T_08754_row23_col5, #T_08754_row25_col2, #T_08754_row25_col5, #T_08754_row26_col2, #T_08754_row26_col5, #T_08754_row27_col5, #T_08754_row28_col0, #T_08754_row28_col1, #T_08754_row28_col2, #T_08754_row28_col3, #T_08754_row28_col4, #T_08754_row28_col5, #T_08754_row28_col6, #T_08754_row28_col7, #T_08754_row28_col8, #T_08754_row28_col9, #T_08754_row28_col10, #T_08754_row28_col11, #T_08754_row29_col2, #T_08754_row29_col5, #T_08754_row30_col0, #T_08754_row30_col1, #T_08754_row30_col2, #T_08754_row30_col3, #T_08754_row30_col4, #T_08754_row30_col5, #T_08754_row30_col6, #T_08754_row30_col7, #T_08754_row30_col8, #T_08754_row30_col9, #T_08754_row30_col10, #T_08754_row30_col11, #T_08754_row33_col0, #T_08754_row33_col1, #T_08754_row33_col2, #T_08754_row33_col3, #T_08754_row33_col4, #T_08754_row33_col5, #T_08754_row33_col6, #T_08754_row33_col7, #T_08754_row33_col8, #T_08754_row33_col9, #T_08754_row33_col10, #T_08754_row33_col11, #T_08754_row34_col0, #T_08754_row34_col1, #T_08754_row34_col2, #T_08754_row34_col3, #T_08754_row34_col4, #T_08754_row34_col5, #T_08754_row34_col6, #T_08754_row34_col7, #T_08754_row34_col8, #T_08754_row34_col9, #T_08754_row34_col10, #T_08754_row34_col11, #T_08754_row35_col5, #T_08754_row39_col0, #T_08754_row39_col1, #T_08754_row39_col2, #T_08754_row39_col3, #T_08754_row39_col4, #T_08754_row39_col5, #T_08754_row39_col6, #T_08754_row39_col7, #T_08754_row39_col8, #T_08754_row39_col9, #T_08754_row39_col10, #T_08754_row39_col11, #T_08754_row41_col2, #T_08754_row41_col5, #T_08754_row43_col5, #T_08754_row44_col5, #T_08754_row47_col5, #T_08754_row48_col0, #T_08754_row48_col1, #T_08754_row48_col2, #T_08754_row48_col3, #T_08754_row48_col4, #T_08754_row48_col5, #T_08754_row48_col6, #T_08754_row48_col7, #T_08754_row48_col8, #T_08754_row48_col9, #T_08754_row48_col10, #T_08754_row48_col11, #T_08754_row50_col0, #T_08754_row50_col1, #T_08754_row50_col2, #T_08754_row50_col3, #T_08754_row50_col4, #T_08754_row50_col5,  ...
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_08754_row3_col0, #T_08754_row3_col1, #T_08754_row3_col2, #T_08754_row3_col3, #T_08754_row3_col4, #T_08754_row3_col5, #T_08754_row3_col6, #T_08754_row3_col7, #T_08754_row3_col8, #T_08754_row3_col9, #T_08754_row3_col10, #T_08754_row3_col11, #T_08754_row4_col0, #T_08754_row4_col1, #T_08754_row4_col2, #T_08754_row4_col3, #T_08754_row4_col4, #T_08754_row4_col5, #T_08754_row4_col6, #T_08754_row4_col7, #T_08754_row4_col8, #T_08754_row4_col9, #T_08754_row4_col10, #T_08754_row4_col11, #T_08754_row5_col0, #T_08754_row5_col1, #T_08754_row5_col2, #T_08754_row5_col3, #T_08754_row5_col4, #T_08754_row5_col5, #T_08754_row5_col6, #T_08754_row5_col7, #T_08754_row5_col8, #T_08754_row5_col9, #T_08754_row5_col10, #T_08754_row5_col11, #T_08754_row7_col0, #T_08754_row7_col1, #T_08754_row7_col2, #T_08754_row7_col3, #T_08754_row7_col4, #T_08754_row7_col5, #T_08754_row7_col6, #T_08754_row7_col7, #T_08754_row7_col8, #T_08754_row7_col9, #T_08754_row7_col10, #T_08754_row7_col11, #T_08754_row9_col0, #T_08754_row9_col1, #T_08754_row9_col2, #T_08754_row9_col3, #T_08754_row9_col4, #T_08754_row9_col5, #T_08754_row9_col6, #T_08754_row9_col7, #T_08754_row9_col8, #T_08754_row9_col9, #T_08754_row9_col10, #T_08754_row9_col11, #T_08754_row10_col0, #T_08754_row10_col1, #T_08754_row10_col2, #T_08754_row10_col3, #T_08754_row10_col4, #T_08754_row10_col5, #T_08754_row10_col6, #T_08754_row10_col7, #T_08754_row10_col8, #T_08754_row10_col9, #T_08754_row10_col10, #T_08754_row10_col11, #T_08754_row32_col0, #T_08754_row32_col1, #T_08754_row32_col2, #T_08754_row32_col3, #T_08754_row32_col4, #T_08754_row32_col5, #T_08754_row32_col6, #T_08754_row32_col7, #T_08754_row32_col8, #T_08754_row32_col9, #T_08754_row32_col10, #T_08754_row32_col11, #T_08754_row38_col0, #T_08754_row38_col1, #T_08754_row38_col2, #T_08754_row38_col3, #T_08754_row38_col4, #T_08754_row38_col5, #T_08754_row38_col6, #T_08754_row38_col7, #T_08754_row38_col8, #T_08754_row38_col9, #T_08754_row38_col10, #T_08754_row38_col11, #T_08754_row49_col0, #T_08754_row49_col1, #T_08754_row49_col2, #T_08754_row49_col3, #T_08754_row49_col4, #T_08754_row49_col5, #T_08754_row49_col6, #T_08754_row49_col7, #T_08754_row49_col8, #T_08754_row49_col9, #T_08754_row49_col10, #T_08754_row49_col11, #T_08754_row55_col0, #T_08754_row55_col1, #T_08754_row55_col2, #T_08754_row55_col3, #T_08754_row55_col4, #T_08754_row55_col5, #T_08754_row55_col6, #T_08754_row55_col7, #T_08754_row55_col8, #T_08754_row55_col9, #T_08754_row55_col10, #T_08754_row55_col11 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_08754_row12_col0, #T_08754_row12_col1, #T_08754_row12_col2, #T_08754_row12_col3, #T_08754_row12_col4, #T_08754_row12_col6, #T_08754_row12_col7, #T_08754_row12_col8, #T_08754_row12_col9, #T_08754_row12_col10, #T_08754_row12_col11, #T_08754_row13_col0, #T_08754_row13_col1, #T_08754_row13_col2, #T_08754_row13_col3, #T_08754_row13_col4, #T_08754_row13_col5, #T_08754_row13_col6, #T_08754_row13_col7, #T_08754_row13_col8, #T_08754_row13_col9, #T_08754_row13_col10, #T_08754_row13_col11, #T_08754_row14_col0, #T_08754_row14_col1, #T_08754_row14_col3, #T_08754_row14_col4, #T_08754_row14_col6, #T_08754_row14_col7, #T_08754_row14_col8, #T_08754_row14_col9, #T

# %%
# Highest performing stock - Unrestricted

value_sel = "cagr_rel_ex_ante"  # "cagr_rel_ex_ante"

subset = res[
    (res["config"] == "[y]") &
    (res["n_regimes"] == 6) &
    (res["dim_latent"] == 1)
]

best_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmax()])

best_security = best_row["security"]
best_security, best_row[value_sel]
# Out:
# ('QCOM', 0.2294381306893915)

# %%
# Worst performing stock - Unestricted

subset = res[
    (res["config"] == "[y]") &
    (res["n_regimes"] == 6) &
    (res["dim_latent"] == 1)
]

worst_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmin()])

worst_security = worst_row["security"]
worst_security, worst_row[value_sel]
# Out:
# ('LIN', -0.004130841254103)

# %%
# Highest performing stock - Restricted

value_sel = "cagr_rel_ex_ante"  # "cagr_rel_ex_ante"

subset = res[
    (res["config"] == "factor2_ff3") &
    (res["n_regimes"] == 6) &
    (res["dim_latent"] == 3)
]

best_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmax()])

best_security = best_row["security"]
best_security, best_row[value_sel]
# Out:
# ('GE', 0.1697327203445688)

# %%
# Worst performing stock - Restricted

subset = res[
    (res["config"] == "factor2_ff3") &
    (res["n_regimes"] == 6) &
    (res["dim_latent"] == 3)
]

worst_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmin()])

worst_security = worst_row["security"]
worst_security, worst_row[value_sel]
# Out:
# ('AVGO', -0.0118377898888546)

# %%
# --------------------------------------------------------------------------------------
# CONFIG
# --------------------------------------------------------------------------------------

PATHS = {
        "data_excel": "/Users/chrismader/Python/SLDS/Data/bbg_data.xlsx",
        "ff_dir": "/Users/chrismader/Python/SLDS/Data/",
        "ff_files": {
            "ff5": "F-F_Research_Data_5_Factors_2x3_daily.csv",
            "ff3": "F-F_Research_Data_Factors_daily.csv",
            "mom": "F-F_Momentum_Factor_daily.csv",},
        "results_csv": "/Users/chrismader/Python/SLDS/Output/gridsearch_results1.csv",
        "segments_parquet": "/Users/chrismader/Python/SLDS/Output/gridsearch_segments1.parquet",
        "tmp_dir":          "/Users/chrismader/Python/SLDS/tmp_slds/",
        "segments_tmp_csv": "/Users/chrismader/Python/SLDS/tmp_slds/segments_tmp.csv",
    }
    
CONFIG = {
    
    # Core defaults
    "n_jobs": -1,  # multi-threading
    "dt": 1.0 / 252.0,
    "n_iters": 50,
    "h_z": 3.0,  # CUSUM parameter
    
    # Batch windows
    "batch_grid": [
        {"train_window": 1260, "overlap_window": 1008},
    ],

    # Number of regimes
    "K_grid": [6],
    
    # Unrestricted models: 
    "unrestricted_models": [
        {"label": "[y]",         "channels": ["y"],                "dim_latent": [1]},
        # {"label": "[y,h]",       "channels": ["y","h"],            "dim_latent": [2]},
        # {"label": "[g,v]",       "channels": ["g","v"],            "dim_latent": [2]},
        # {"label": "[g,v,h]",     "channels": ["g","v","h"],        "dim_latent": [2,3]},
        # {"label": "[y,g,v,h]",   "channels": ["y","g","v","h"],    "dim_latent": [3,4]},
    ],

    # Restricted models: 
    "restricted_models": [
        # {"label": "fund1",        "channels": ["y"],                 "dim_latent": [2],    "C_type": "fund1"},
        # {"label": "fund1_vix",    "channels": ["y","h"],             "dim_latent": [3],    "C_type": "fund1_vix"},
        # {"label": "fund2",        "channels": ["y","g"],             "dim_latent": [2],    "C_type": "fund2"},
        # {"label": "fund2_vix",    "channels": ["y","g","h"],         "dim_latent": [3],    "C_type": "fund2_vix"},
        # {"label": "fund3",        "channels": ["y","v","g"],         "dim_latent": [2],    "C_type": "fund3"},
        # {"label": "fund3_vix",    "channels": ["y","v","g","h"],     "dim_latent": [3],    "C_type": "fund3_vix"},   

        # {"label": "factor1",      "channels": ["y"],                 "dim_latent": [2],    "C_type": "factor1"},
        # {"label": "factor1_vix",  "channels": ["y","h"],             "dim_latent": [3],    "C_type": "factor1_vix"},

        {"label": "factor2_ff3",   "channels": ["y","mkt","smb","hml"],                   "dim_latent": [3], "C_type": "factor2"},
        # {"label": "factor2_ff3mom","channels": ["y","mkt","smb","hml","mom"],             "dim_latent": [4], "C_type": "factor2"},
        # {"label": "factor2_ff5",   "channels": ["y","mkt","smb","hml","rmw","cma"],       "dim_latent": [5], "C_type": "factor2"},
        # {"label": "factor2_ff5mom","channels": ["y","mkt","smb","hml","rmw","cma","mom"], "dim_latent": [6], "C_type": "factor2"},
    ],

    # Model selection
    "run_unrestricted": False,
    "run_restricted": True,
    "predict_oos": False,

    # Output
    "verbose": False,
    "display": False,
}

for k, v in PATHS.items(): 
    CONFIG[k] = v
# per-security temp file templates used by IOManager
CONFIG["tmp_results_fmt"]  = "{tmp_dir}/tmp_res_{security}.csv"
CONFIG["tmp_segments_fmt"] = "{tmp_dir}/tmp_seg_{security}.csv"

# %%
def collect_seed_rolling_params(cfg, securities, n_runs=10, master_seed=123):
    """
    PURE WRAPPER with stability aggregation:
      • Per security → rolling batches → per-seed fits (unchanged logic).
      • NEW: For each batch, aggregate params across seeds (mean/std elementwise)
             for {Cs, ds, inv_etas, As, bs, sigmasq, Rs, r}.
      • NEW: For each batch, compute regime occupancies averaged across seeds
             for {zhat_raw, zhat_cusum} and store ARI (mean pairwise across seeds).
    The return structure now includes per-batch "params_agg" and "occ".
    """
    import numpy as np
    from gridsearch import import_data, import_factors, _intersect_indexes, _build_restrictions
    from rSLDS import fit_rSLDS, fit_rSLDS_restricted, cusum_overlay

    # pick active model (CONFIG guarantees mutual exclusivity)
    assert bool(cfg.get("run_unrestricted", False)) ^ bool(cfg.get("run_restricted", False)), \
       "[CFG] Exactly one of run_unrestricted or run_restricted must be True."
    
    if cfg["run_unrestricted"]:
        assert len(cfg["unrestricted_models"]) > 0, \
            "[CFG] run_unrestricted=True but unrestricted_models is empty."
        m = cfg["unrestricted_models"][0]; restricted = False; C_type = None
    else:
        assert len(cfg["restricted_models"]) > 0, \
            "[CFG] run_restricted=True but restricted_models is empty."
        m = cfg["restricted_models"][0];  restricted = True;  C_type = m["C_type"]
        
    channels   = list(m["channels"])
    D          = int(m["dim_latent"][0])
    K          = int(cfg["K_grid"][0])
    dt         = float(cfg["dt"])
    n_iters    = int(cfg["n_iters"])
    h_z        = float(cfg["h_z"])
    batch_conf = cfg["batch_grid"][0]
    train_window = int(batch_conf["train_window"])
    overlap      = int(batch_conf["overlap_window"])

    print(f"[CFG] restricted={restricted} C_type={C_type} channels={channels} K={K} D={D} "
          f"dt={dt} n_iters={n_iters} h_z={h_z} train_window={train_window} overlap={overlap} n_runs={n_runs}")

    # data
    px_all, eps_all, pe_all, ser_vix = import_data(cfg["data_excel"])
    ff = import_factors(cfg["ff_dir"], cfg["ff_files"])

    def _series_by_key_for(sec):
        ser_px  = px_all[sec].dropna()
        ser_eps = eps_all[sec].dropna().where(lambda s: s > 0).dropna()
        ser_pe  = (ser_px / ser_eps).where(lambda s: s > 0).dropna()
        series = {
            "y": np.log(ser_px).diff().dropna(),
            "g": np.log(ser_eps).diff().dropna(),
            "v": np.log(ser_pe).diff().dropna(),
            "h": np.log(ser_vix).diff().dropna(),
        }
        for col, key in [("MKT","mkt"),("SMB","smb"),("HML","hml"),("RMW","rmw"),("CMA","cma"),("MOM","mom")]:
            if col in ff.columns:
                series[key] = ff[col]
        return series, ser_px

    rng = np.random.RandomState(master_seed)
    out = {}

    # ---------- small helpers ----------
    def _stack(arrs, expected_ndim=None):
        A = np.stack(arrs, axis=0)  # (R, ...)
        if expected_ndim is not None:
            assert A.ndim == expected_ndim + 1, f"[ASSERT] rank mismatch: got {A.ndim}, want {expected_ndim+1}"
        return A

    def _agg_mean_std(A):
        mu = A.mean(axis=0)
        sd = A.std(axis=0, ddof=1) if A.shape[0] > 1 else np.zeros_like(mu)
        return mu, sd

    def _occ_by_seed(Z, K_):
        # Z: shape (R, T) ints in {0..K-1} or {1..K}
        if Z.size == 0:
            return np.full((Z.shape[0], K_), np.nan)
        Zp = Z.copy()
        if Zp.min() == 1:
            Zp = Zp - 1
        R, T = Zp.shape
        occ = np.zeros((R, K_), float)
        for i in range(R):
            bc = np.bincount(Zp[i], minlength=K_).astype(float)
            occ[i] = bc / max(T, 1)
        return occ

    from sklearn.metrics import adjusted_rand_score as _ARI
    def _mean_pairwise_ARI(Z):
        Z = np.asarray(Z, dtype=int)
        if Z.size == 0:
            return np.nan
        if Z.min() == 1:
            Z = Z - 1
        R, _ = Z.shape
        vals = []
        for i in range(R):
            for j in range(i+1, R):
                vals.append(_ARI(Z[i], Z[j]))
        return float(np.mean(vals)) if vals else np.nan

    # ------------------------------------

    for sec in securities:

        print(f"\n[SEC] {sec}")
        series_by_key, ser_px = _series_by_key_for(sec)
        need = [series_by_key[k].dropna() for k in channels]
        common_idx = _intersect_indexes(need)
        if common_idx is None or getattr(common_idx, "empty", False):
            print(f"[WARN] {sec}: no overlap for channels {channels} — skipping")
            continue

        Y_full  = np.concatenate([series_by_key[k].loc[common_idx].values.reshape(-1,1) for k in channels], axis=1)
        px_full = ser_px.loc[common_idx].astype(float)
        T, N = Y_full.shape
        assert N == len(channels), f"[ASSERT] N={N} must equal len(channels)={len(channels)}"

        print(f"[DATA] T={T} N={N} idx[{common_idx[0]} → {common_idx[-1]}]")

        # batch schedule
        t0s, t1s, t0 = [], [], 0
        while t0 < T:
            t1s.append(min(t0 + train_window, T))
            t0s.append(t0)
            if t1s[-1] == T: break
            t0 += train_window - overlap
        print(f"[BATCH] batches={len(t0s)}")

        rec = {
            "meta": {
                "channels": channels, "K": K, "D": D,
                "train_window": train_window, "overlap_window": overlap,
                "common_index": common_idx, "restricted": restricted, "dt": dt},
            "batches": []}

        params_spec = dict(n_regimes=K, dim_latent=D, single_subspace=True)

        for bi, (b0, b1) in enumerate(zip(t0s, t1s)):
            Yb = Y_full[b0:b1, :]
            pxb = px_full.iloc[b0:b1]
            idx_slice = pxb.index
            print(f"[B{bi}] slice t0={b0} t1={b1} len={len(idx_slice)}")

            restrictions = None
            if restricted:
                restrictions = _build_restrictions(C_type, Y_obs=Yb, base_channels=channels, D=D)
                assert "C" in restrictions and "d" in restrictions, "[ASSERT] restrictions must contain 'C' and 'd'"
                print(f"[B{bi}] restrictions keys={list(restrictions.keys())}")

            seeds = rng.randint(1, 2**31 - 1, size=n_runs).tolist()
          
            per_seed_records = []
            Z_raw_list, Z_cusum_list = [], []
            Cs_list, ds_list, inv_list = [], [], []
            As_list, bs_list, sigmasq_list, Rs_list, r_list = [], [], [], [], []

            for si, s in enumerate(seeds):
                
                if restricted:
                    xhat, zhat_raw, elbo, q, mdl = fit_rSLDS_restricted(
                        Yb, params_spec,
                        C=restrictions["C"], d=restrictions["d"],
                        n_iter_em=n_iters, seed=s,
                        b_pattern=restrictions.get("b_pattern"),
                        enforce_diag_A=True,
                        C_mask=restrictions.get("C_mask"),
                        d_mask=restrictions.get("d_mask"))
                else:
                    xhat, zhat_raw, elbo, q, mdl = fit_rSLDS(Yb, params_spec, n_iter_em=n_iters, seed=s)

                y_cus = Yb[:, 0].ravel()
                zhat_cusum = cusum_overlay(pxb, y_cus, xhat, mdl, h_z)

                Z_raw_list.append(np.asarray(zhat_raw).ravel())
                if zhat_cusum is None:
                    Z_cusum_list.append(np.asarray(zhat_raw).ravel())
                else:
                    Z_cusum_list.append(np.asarray(zhat_cusum).ravel())

                # params (copy to detach)
                Cs      = np.array(mdl.emissions.Cs,       copy=True)
                ds      = np.array(mdl.emissions.ds,       copy=True)
                inv_eta = np.array(mdl.emissions.inv_etas, copy=True)
                As      = np.array(mdl.dynamics.As,        copy=True)
                bs      = np.array(mdl.dynamics.bs,        copy=True)
                sigmasq = np.array(mdl.dynamics.sigmasq,   copy=True)
                Rs      = np.array(mdl.transitions.Rs,     copy=True)
                r       = np.array(mdl.transitions.r,      copy=True)

                # sanity on leading K (allow shared emissions with leading 1)
                assert As.shape[0] == K and bs.shape[0] == K and sigmasq.shape[0] == K \
                    and Rs.shape[0] == K and r.shape[0] == K, "[ASSERT] K mismatch in dynamics/transitions"
                assert Cs.ndim == 3 and ds.ndim == 2 and inv_eta.ndim == 2, "[ASSERT] emissions rank mismatch"
                assert Cs.shape[0] in (1, K) and ds.shape[0] in (1, K) and inv_eta.shape[0] in (1, K), \
                    "[ASSERT] emissions leading axis must be 1 or K"

                Cs_list.append(Cs)
                ds_list.append(ds)
                inv_list.append(inv_eta)
                As_list.append(As)
                bs_list.append(bs)
                sigmasq_list.append(sigmasq)
                Rs_list.append(Rs)
                r_list.append(r)

                per_seed_records.append({
                    "seed": int(s),
                    "params": {"Cs": Cs, "ds": ds, "inv_etas": inv_eta, "As": As, "bs": bs,
                               "sigmasq": sigmasq, "Rs": Rs, "r": r},
                    "outputs": {"zhat_raw": zhat_raw, "zhat_cusum": zhat_cusum,
                                "xhat": xhat, "elbo": elbo}
                })

            # ---------- aggregate across seeds (elementwise mean/std) ----------
            def _agg_block(block_list):
                A = _stack(block_list)  # (R, ...)
                mu, sd = _agg_mean_std(A)
                return {"mean": mu, "std": sd}

            params_agg = {
                "Cs": _agg_block(Cs_list),
                "ds": _agg_block(ds_list),
                "inv_etas": _agg_block(inv_list),
                "As": _agg_block(As_list),
                "bs": _agg_block(bs_list),
                "sigmasq": _agg_block(sigmasq_list),
                "Rs": _agg_block(Rs_list),
                "r": _agg_block(r_list),
            }

            # ---------- regime occupancy (avg across seeds) + ARI ----------
            Zr = np.stack(Z_raw_list, axis=0)   if len(Z_raw_list)  else np.zeros((0, 0), int)
            Zc = np.stack(Z_cusum_list, axis=0) if len(Z_cusum_list) else np.zeros((0, 0), int)

            occ_raw_seed = _occ_by_seed(Zr, K)  # (R,K)
            occ_cus_seed = _occ_by_seed(Zc, K)  # (R,K)

            occ = {
                "raw": {
                    "by_seed": occ_raw_seed,                      # (R,K), fractions
                    "mean":    np.nanmean(occ_raw_seed, axis=0),  # (K,)
                    "std":     np.nanstd(occ_raw_seed, axis=0, ddof=1) if occ_raw_seed.shape[0] > 1
                               else np.zeros(K)
                },
                "cusum": {
                    "by_seed": occ_cus_seed,
                    "mean":    np.nanmean(occ_cus_seed, axis=0),
                    "std":     np.nanstd(occ_cus_seed, axis=0, ddof=1) if occ_cus_seed.shape[0] > 1
                               else np.zeros(K)
                }
            }

            metrics = {
                "ARI_raw":  _mean_pairwise_ARI(Zr),
                "ARI_cusum": _mean_pairwise_ARI(Zc),
            }

            rec["batches"].append({
                "t0": int(b0), "t1": int(b1),
                "idx_slice": idx_slice,
                "seeds": seeds,
                "records": per_seed_records,
                "Z_raw":  Zr,
                "Z_cusum": Zc,
                "params_agg": params_agg,
                "occ": occ,
                "metrics": metrics,
            })
        
        out[sec] = rec

    return out

# %%
def print_seed_rolling_stability(rolled, security, batch_indices=None):
    """
    Pretty printer for stability:
      • Emissions & latent blocks: entries as mean (std) across seeds.
      • Regime occupancies per batch: mean% (std%).
      • ARI per batch: raw & cusum.
    Inputs
      rolled: dict returned by collect_seed_rolling_params
      security: key inside rolled
      batch_indices: optional list of batch indices to print (default: all)
    """
    import numpy as np

    rec = rolled.get(security)
    assert rec is not None, f"[print] security '{security}' not found"
    K = rec["meta"]["K"]; D = rec["meta"]["D"]; dt = rec["meta"]["dt"]; restricted = rec["meta"]["restricted"]
    B = len(rec["batches"])
    if batch_indices is None:
        batch_indices = list(range(B))

    def _fmt(m, s, fp=4):
        return f"{m: .{fp}f} ({s: .{fp}f})"

    def _pmat(mu, sd, label, semantic_key):
        shape_str = {
            "Cs": "(K_or_1, N, D)",
            "ds": "(K_or_1, N)",
            "inv_etas": "(K_or_1, N)",
            "As": "(K, D, D)",
            "bs": "(K, D)",
            "sigmasq": "(K, D)",
            "Rs": "(K, D)",
            "r": "(K,)",
        }[semantic_key]
        print(f"{label}  {shape_str} = {mu.shape}")
        if mu.ndim == 3:
            K0, R0, C0 = mu.shape
            for r in range(R0):
                line = ""
                for k in range(K0):
                    row_entries = []
                    for c in range(C0):
                        row_entries.append(_fmt(mu[k, r, c], sd[k, r, c]))
                    row_str = " ".join(row_entries)
                    line += f"[{row_str}]    "
                print(line)
        elif mu.ndim == 2:
            K0, C0 = mu.shape
            line = ""
            for k in range(K0):
                row_entries = [_fmt(mu[k, c], sd[k, c]) for c in range(C0)]
                line += f"[{' '.join(row_entries)}]" + "    "
            print(line)
        elif mu.ndim == 1:
            row_entries = [_fmt(mu[k], sd[k]) for k in range(mu.shape[0])]
            print(f"[{' '.join(row_entries)}]")
        print()

    for bi in batch_indices:
        b = rec["batches"][bi]
        t0, t1 = b["t0"], b["t1"]
        print("\n========== STABILITY (security={}, batch={}  t0={}  t1={}) ==========\n"
              .format(security, bi, t0, t1))

        P = b["params_agg"]
        _pmat(P["Cs"]["mean"],      P["Cs"]["std"],      "Cs",       "Cs")
        _pmat(P["ds"]["mean"],      P["ds"]["std"],      "ds",       "ds")
        _pmat(P["inv_etas"]["mean"],P["inv_etas"]["std"],"inv_etas", "inv_etas")
        _pmat(P["As"]["mean"],      P["As"]["std"],      "As",       "As")
        _pmat(P["bs"]["mean"],      P["bs"]["std"],      "bs",       "bs")
        _pmat(P["sigmasq"]["mean"], P["sigmasq"]["std"], "sigmasq",  "sigmasq")
        _pmat(P["Rs"]["mean"],      P["Rs"]["std"],      "Rs",       "Rs")
        _pmat(P["r"]["mean"],       P["r"]["std"],       "r",        "r")

        # interpretable AR(1) params (restricted models)
        if restricted:
            print("Interpretable AR(1) parameters (mean±std over seeds)")
            mu_As, sd_As   = P["As"]["mean"], P["As"]["std"]         # (K,D,D)
            mu_bs, sd_bs   = P["bs"]["mean"], P["bs"]["std"]         # (K,D)
            mu_sig, sd_sig = P["sigmasq"]["mean"], P["sigmasq"]["std"] # (K,D)
            eps = 1e-8
            for k in range(mu_As.shape[0]):
                print(f"Regime {k}:")
                for d in range(min(D, mu_As.shape[2])):
                    rho_m, rho_s = mu_As[k, d, d], sd_As[k, d, d]
                    b_m, b_s     = mu_bs[k, d],    sd_bs[k, d]
                    # μ = b / (1-ρ), Var_stat = σ²/(1-ρ²) for |ρ|<1
                    mu_stat_m = (b_m / (1.0 - rho_m)) if abs(1.0 - rho_m) > eps else np.nan
                    # delta-method-ish SD approximation (optional: coarse; keep concise)
                    mu_stat_s = np.nan
                    s2_m, s2_s = mu_sig[k, d], sd_sig[k, d]
                    var_stat_m = (s2_m / (1.0 - rho_m**2)) if abs(rho_m) < 1 else np.nan
                    var_stat_s = np.nan
                    # half-life in steps: log(2)/|log ρ|
                    if rho_m > 0 and abs(rho_m) < 1:
                        hl_steps_m = float(np.log(2.0) / abs(np.log(rho_m)))
                    else:
                        hl_steps_m = float("inf")
                    hl_years_m = (hl_steps_m * rec["meta"]["dt"]) if np.isfinite(hl_steps_m) else np.nan
                    print(f"  latent{d}: rho={_fmt(rho_m, rho_s)}  b={_fmt(b_m, b_s)}  "
                          f"mu_stat≈{mu_stat_m: .6f}  var_stat≈{var_stat_m: .6e}  "
                          f"half_life_steps≈{hl_steps_m: .2f}  half_life_years≈{hl_years_m: .4f}")
                print()

        # occupancy + ARI
        occ = b["occ"]
        raw_mean = (occ["raw"]["mean"] * 100.0).astype(float)
        raw_std  = (occ["raw"]["std"]  * 100.0).astype(float)
        cus_mean = (occ["cusum"]["mean"] * 100.0).astype(float)
        cus_std  = (occ["cusum"]["std"]  * 100.0).astype(float)

        def _fmt_occ(mean_vec, std_vec):
            return ", ".join([f"{mean_vec[j]:.1f}% ({std_vec[j]:.1f}%)" for j in range(mean_vec.size)])

        print("Occupancy per regime (mean% (std%) across seeds):")
        print(f"  RAW:   [{_fmt_occ(raw_mean,  raw_std)}]")
        print(f"  CUSUM: [{_fmt_occ(cus_mean, cus_std)}]")

        ARI_raw   = b["metrics"]["ARI_raw"]
        ARI_cusum = b["metrics"]["ARI_cusum"]
        print(f"ARI (mean pairwise across seeds):  RAW={ARI_raw:.3f}   CUSUM={ARI_cusum:.3f}")

# %%
securities = ["TLSA, AVGO, IT"]
# rolled = collect_seed_rolling_params(CONFIG, securities, n_runs=10, master_seed=123)
# print_seed_rolling_stability(rolled, "MSFT")
