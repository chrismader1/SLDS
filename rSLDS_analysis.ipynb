# %%
# Plot RelCAGR vs Delta ELBO and vs CPLL, CPLL Gap
# Smooth CPLL: conditional predictive log-likelihood; out-of-sample accuracy # Smooth CPLL: overestimates OOS accuracy due to look-ahead bias
# ELBO: Evidence lower bound; lower bound on the true log-likelihood (lowest start minus highest end accross all runs)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import adjusted_rand_score as _ARI

# %%
# import data
filename_results = '/Users/chrismader/Python/SLDS/Output/gridsearch_results1.csv'
filename_static = '/Users/chrismader/Python/SLDS/Data/static_data.csv'
res = pd.read_csv(filename_results)
static = pd.read_csv(filename_static, usecols=[0,1,2])

# %%
# Prep data
res['sector'] = res['security'].map(static.set_index('Ticker')['SectorID'])
res['CPLL Gap'] = res['max cpll (proxy bound, paired)'] - res['cpll (max all runs)']
res.insert(res.columns.get_loc('security') + 1, 'sector', res.pop('sector'))
res = res[np.isfinite(pd.to_numeric(res['cagr_rel_ex_ante'], errors='coerce'))].copy()
res = res[np.isfinite(pd.to_numeric(res['score'], errors='coerce'))].copy()

print(list(np.unique(res.config)))
print(list(np.unique(res.sector)))
print(list(np.unique(res.security)))
print(res.columns)

# Settings
configs = np.unique(res.config)
unrestricted = [x for x in configs if x.startswith('[')]
restricted = [x for x in configs if not x.startswith('[')]
print(unrestricted)
print(restricted)
# Out:
# ['[y,h]', '[y]', 'factor2_ff3', 'factor2_ff3mom', 'fund1', 'fund1_vix']
# ['CD', 'CS', 'IT', 'TC']
# ['AAPL', 'ACN', 'ADBE', 'AMAT', 'AMD', 'AMZN', 'AVGO', 'BKNG', 'COST', 'CRM', 'CSCO', 'DIS', 'GOOGL', 'HD', 'IBM', 'INTU', 'KO', 'MCD', 'META', 'MSFT', 'NFLX', 'NOW', 'NVDA', 'ORCL', 'PG', 'PM', 'QCOM', 'T', 'TSLA', 'TXN', 'VZ', 'WMT']
# Index(['security', 'sector', 'config', 'rank', 'score', 'dt', 'n_regimes',
#        'dim_latent', 'single_subspace', 'train_window', 'overlap_window',
#        'avg_inferred_regime_length', 'elbo_start (min all runs)',
#        'elbo_end (max all runs)', 'elbo_delta (max all runs)',
#        'cpll (max all runs)', 'max cpll (proxy bound, paired)', 'mode_usage',
#        'cagr_rel', 'cagr_strat', 'cagr_bench', 'cagr_rel_cusum',
#        'cagr_strat_cusum', 'cagr_bench_cusum', 'cagr_rel_ex_ante',
#        'cagr_strat_ex_ante', 'cagr_bench_ex_ante', 'CPLL Gap'],
#       dtype='object')
# ['[y,h]', '[y]']
# ['factor2_ff3', 'factor2_ff3mom', 'fund1', 'fund1_vix']

# %%
# Helpers

def performance(df, value_sel):
    
    idx = ['config','n_regimes','dim_latent']
    sector_cols = sorted(df['sector'].unique())
    
    # sector means
    pt = (df.pivot_table(index=idx, columns='sector', values=value_sel, aggfunc='mean')
            .sort_index().reindex(sector_cols, axis=1))
    
    # true stats across ALL securities (not avg of sectors)
    stats = (df.groupby(idx)[value_sel]
               .agg(avg='mean', std='std', min='min', max='max'))
    stats['range'] = stats['max'] - stats['min']
    
    # join, order, sort
    finite_mask = np.isfinite(pt.to_numpy()).all(axis=1)
    pt_sel = (pt.loc[finite_mask]
                .join(stats, how='left')
                .loc[:, sector_cols + ['avg','std','min','max','range']]
                .sort_values('avg', ascending=False))
    
    # style
    styled = (pt_sel.style
               .format('{:.3f}')
               .background_gradient(cmap='RdBu', vmin=-0.1, vmax=0.1,
                                    subset=sector_cols + ['avg'])
               .highlight_null())
    
    # lock in order
    base_idx  = pt_sel.index                                 # exact rows + order
    cols_tail = ['avg','std','min','max','range']            # trailing stats
    cols_all = sector_cols + cols_tail                      # exact columns

    return styled, base_idx, cols_tail, cols_all
    
def metric_table(value_sel, df, base_idx, cols_tail, cols_all, vmin, vmax):

    # recover index/sector context from performance() output
    idx = list(base_idx.names)
    sector_cols = [c for c in cols_all if c not in cols_tail]
    
    # sector means for this metric (no sorting, no filtering)
    pt_m = (df.pivot_table(index=idx, columns='sector', values=value_sel, aggfunc='mean')
              .reindex(sector_cols, axis=1)              # same sector columns
              .reindex(base_idx))                        # SAME ROWS + ORDER as score

    # overall stats across ALL securities for this metric
    stats_m = (df.groupby(idx)[value_sel]
                 .agg(avg='mean', std='std', min='min', max='max'))
    stats_m['range'] = stats_m['max'] - stats_m['min']
    stats_m = stats_m.reindex(base_idx)                  # align rows/order

    # combine and enforce identical column order
    tbl = pd.concat([pt_m, stats_m[cols_tail]], axis=1).reindex(columns=cols_all)

    return (tbl.style
                .format('{:,.0f}')
                .background_gradient(cmap='RdBu', vmin=vmin, vmax=vmax, subset=sector_cols + ['avg'])
                .highlight_null())

# Formatting
CAPTION_CSS = [{'selector': 'caption',
                'props': [('caption-side','top'),
                          ('text-align','left'),
                          ('font-weight','700')]}]

# %%
# Model performance - unrestricted
df_unrestr = res[res['config'].isin(unrestricted)]
styled_unrestr, base_idx_unrestr, cols_tail_unrestr, cols_all_unrestr = performance(df_unrestr, 'cagr_rel_ex_ante')
styled_unrestr.set_caption("Rel CAGR - Unrestricted Models")
styled_unrestr.set_table_styles(CAPTION_CSS, overwrite=False)
styled_unrestr
# Out:
# <style type="text/css">
# #T_6f41c caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_6f41c_row0_col0 {
#   background-color: #10457e;
#   color: #f1f1f1;
# }
# #T_6f41c_row0_col1, #T_6f41c_row4_col1, #T_6f41c_row5_col2 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_6f41c_row0_col2 {
#   background-color: #5fa5cd;
#   color: #f1f1f1;
# }
# #T_6f41c_row0_col3 {
#   background-color: #3783bb;
#   color: #f1f1f1;
# }
# #T_6f41c_row0_col4, #T_6f41c_row6_col3 {
#   background-color: #4f9bc7;
#   color: #f1f1f1;
# }
# #T_6f41c_row1_col0 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# #T_6f41c_row1_col1, #T_6f41c_row4_col2 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_6f41c_row1_col2, #T_6f41c_row4_col3 {
#   background-color: #59a1ca;
#   color: #f1f1f1;
# }
# #T_6f41c_row1_col3 {
#   background-color: #3885bc;
#   color: #f1f1f1;
# }
# #T_6f41c_row1_col4, #T_6f41c_row2_col0 {
#   background-color: #62a7ce;
#   color: #f1f1f1;
# }
# #T_6f41c_row2_col1 {
#   background-color: #cae1ee;
#   color: #000000;
# }
# #T_6f41c_row2_col2 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_6f41c_row2_col3 {
#   background-color: #266caf;
#   color: #f1f1f1;
# }
# #T_6f41c_row2_col4, #T_6f41c_row3_col3 {
#   background-color: #78b4d5;
#   color: #000000;
# }
# #T_6f41c_row3_col0 {
#   background-color: #2a71b2;
#   color: #f1f1f1;
# }
# #T_6f41c_row3_col1 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_6f41c_row3_col2 {
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_6f41c_row3_col4 {
#   background-color: #b6d7e8;
#   color: #000000;
# }
# #T_6f41c_row4_col0 {
#   background-color: #7eb8d7;
#   color: #000000;
# }
# #T_6f41c_row4_col4 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_6f41c_row5_col0 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_6f41c_row5_col1 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_6f41c_row5_col3 {
#   background-color: #327cb7;
#   color: #f1f1f1;
# }
# #T_6f41c_row5_col4 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_6f41c_row6_col0, #T_6f41c_row6_col2 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_6f41c_row6_col1 {
#   background-color: #f8f4f2;
#   color: #000000;
# }
# #T_6f41c_row6_col4 {
#   background-color: #e6eff4;
#   color: #000000;
# }
# #T_6f41c_row7_col0 {
#   background-color: #faeae1;
#   color: #000000;
# }
# #T_6f41c_row7_col1 {
#   background-color: #fcdfcf;
#   color: #000000;
# }
# #T_6f41c_row7_col2, #T_6f41c_row7_col4 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_6f41c_row7_col3 {
#   background-color: #bddbea;
#   color: #000000;
# }
# </style>
# <table id="T_6f41c">
#   <caption>Rel CAGR - Unrestricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f41c_level0_col0" class="col_heading level0 col0" >CD</th>
#       <th id="T_6f41c_level0_col1" class="col_heading level0 col1" >CS</th>
#       <th id="T_6f41c_level0_col2" class="col_heading level0 col2" >IT</th>
#       <th id="T_6f41c_level0_col3" class="col_heading level0 col3" >TC</th>
#       <th id="T_6f41c_level0_col4" class="col_heading level0 col4" >avg</th>
#       <th id="T_6f41c_level0_col5" class="col_heading level0 col5" >std</th>
#       <th id="T_6f41c_level0_col6" class="col_heading level0 col6" >min</th>
#       <th id="T_6f41c_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_6f41c_level0_col8" class="col_heading level0 col8" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f41c_level0_row0" class="row_heading level0 row0" rowspan="4">[y]</th>
#       <th id="T_6f41c_level1_row0" class="row_heading level1 row0" >6</th>
#       <th id="T_6f41c_level2_row0" class="row_heading level2 row0" >1</th>
#       <td id="T_6f41c_row0_col0" class="data row0 col0" >0.092</td>
#       <td id="T_6f41c_row0_col1" class="data row0 col1" >0.024</td>
#       <td id="T_6f41c_row0_col2" class="data row0 col2" >0.053</td>
#       <td id="T_6f41c_row0_col3" class="data row0 col3" >0.067</td>
#       <td id="T_6f41c_row0_col4" class="data row0 col4" >0.057</td>
#       <td id="T_6f41c_row0_col5" class="data row0 col5" >0.057</td>
#       <td id="T_6f41c_row0_col6" class="data row0 col6" >-0.010</td>
#       <td id="T_6f41c_row0_col7" class="data row0 col7" >0.288</td>
#       <td id="T_6f41c_row0_col8" class="data row0 col8" >0.298</td>
#     </tr>
#     <tr>
#       <th id="T_6f41c_level1_row1" class="row_heading level1 row1" >5</th>
#       <th id="T_6f41c_level2_row1" class="row_heading level2 row1" >1</th>
#       <td id="T_6f41c_row1_col0" class="data row1 col0" >0.061</td>
#       <td id="T_6f41c_row1_col1" class="data row1 col1" >0.017</td>
#       <td id="T_6f41c_row1_col2" class="data row1 col2" >0.054</td>
#       <td id="T_6f41c_row1_col3" class="data row1 col3" >0.066</td>
#       <td id="T_6f41c_row1_col4" class="data row1 col4" >0.052</td>
#       <td id="T_6f41c_row1_col5" class="data row1 col5" >0.042</td>
#       <td id="T_6f41c_row1_col6" class="data row1 col6" >-0.021</td>
#       <td id="T_6f41c_row1_col7" class="data row1 col7" >0.173</td>
#       <td id="T_6f41c_row1_col8" class="data row1 col8" >0.194</td>
#     </tr>
#     <tr>
#       <th id="T_6f41c_level1_row2" class="row_heading level1 row2" >4</th>
#       <th id="T_6f41c_level2_row2" class="row_heading level2 row2" >1</th>
#       <td id="T_6f41c_row2_col0" class="data row2 col0" >0.052</td>
#       <td id="T_6f41c_row2_col1" class="data row2 col1" >0.022</td>
#       <td id="T_6f41c_row2_col2" class="data row2 col2" >0.043</td>
#       <td id="T_6f41c_row2_col3" class="data row2 col3" >0.077</td>
#       <td id="T_6f41c_row2_col4" class="data row2 col4" >0.047</td>
#       <td id="T_6f41c_row2_col5" class="data row2 col5" >0.064</td>
#       <td id="T_6f41c_row2_col6" class="data row2 col6" >-0.027</td>
#       <td id="T_6f41c_row2_col7" class="data row2 col7" >0.245</td>
#       <td id="T_6f41c_row2_col8" class="data row2 col8" >0.273</td>
#     </tr>
#     <tr>
#       <th id="T_6f41c_level1_row3" class="row_heading level1 row3" >3</th>
#       <th id="T_6f41c_level2_row3" class="row_heading level2 row3" >1</th>
#       <td id="T_6f41c_row3_col0" class="data row3 col0" >0.075</td>
#       <td id="T_6f41c_row3_col1" class="data row3 col1" >0.007</td>
#       <td id="T_6f41c_row3_col2" class="data row3 col2" >0.018</td>
#       <td id="T_6f41c_row3_col3" class="data row3 col3" >0.047</td>
#       <td id="T_6f41c_row3_col4" class="data row3 col4" >0.029</td>
#       <td id="T_6f41c_row3_col5" class="data row3 col5" >0.074</td>
#       <td id="T_6f41c_row3_col6" class="data row3 col6" >-0.134</td>
#       <td id="T_6f41c_row3_col7" class="data row3 col7" >0.244</td>
#       <td id="T_6f41c_row3_col8" class="data row3 col8" >0.379</td>
#     </tr>
#     <tr>
#       <th id="T_6f41c_level0_row4" class="row_heading level0 row4" rowspan="4">[y,h]</th>
#       <th id="T_6f41c_level1_row4" class="row_heading level1 row4" >6</th>
#       <th id="T_6f41c_level2_row4" class="row_heading level2 row4" >2</th>
#       <td id="T_6f41c_row4_col0" class="data row4 col0" >0.045</td>
#       <td id="T_6f41c_row4_col1" class="data row4 col1" >0.024</td>
#       <td id="T_6f41c_row4_col2" class="data row4 col2" >0.017</td>
#       <td id="T_6f41c_row4_col3" class="data row4 col3" >0.055</td>
#       <td id="T_6f41c_row4_col4" class="data row4 col4" >0.028</td>
#       <td id="T_6f41c_row4_col5" class="data row4 col5" >0.027</td>
#       <td id="T_6f41c_row4_col6" class="data row4 col6" >-0.010</td>
#       <td id="T_6f41c_row4_col7" class="data row4 col7" >0.094</td>
#       <td id="T_6f41c_row4_col8" class="da

# %%
# Smooth CPLL - unrestricted
styled_cpll_all = metric_table('CPLL Gap', df_unrestr, base_idx_unrestr, cols_tail_unrestr, cols_all_unrestr, vmin=-100000,  vmax=100000)
styled_cpll_all.set_caption("Smooth CPLL Gap - Unrestricted Models")
styled_cpll_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_cpll_all
# Out:
# <style type="text/css">
# #T_058eb caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_058eb_row0_col0, #T_058eb_row0_col2, #T_058eb_row0_col3, #T_058eb_row0_col4, #T_058eb_row1_col0, #T_058eb_row1_col2, #T_058eb_row1_col3, #T_058eb_row1_col4, #T_058eb_row2_col0, #T_058eb_row2_col2, #T_058eb_row2_col3, #T_058eb_row2_col4, #T_058eb_row3_col0, #T_058eb_row3_col2, #T_058eb_row3_col3, #T_058eb_row3_col4 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_058eb_row0_col1, #T_058eb_row1_col1, #T_058eb_row2_col1, #T_058eb_row3_col1 {
#   background-color: #bddbea;
#   color: #000000;
# }
# #T_058eb_row4_col0, #T_058eb_row4_col2, #T_058eb_row4_col3, #T_058eb_row5_col0, #T_058eb_row5_col2, #T_058eb_row5_col3, #T_058eb_row6_col0, #T_058eb_row6_col2, #T_058eb_row6_col3, #T_058eb_row7_col0, #T_058eb_row7_col2, #T_058eb_row7_col3 {
#   background-color: #90c4dd;
#   color: #000000;
# }
# #T_058eb_row4_col1, #T_058eb_row5_col1, #T_058eb_row6_col1, #T_058eb_row7_col1 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_058eb_row4_col4, #T_058eb_row5_col4, #T_058eb_row6_col4, #T_058eb_row7_col4 {
#   background-color: #8dc2dc;
#   color: #000000;
# }
# </style>
# <table id="T_058eb">
#   <caption>Smooth CPLL Gap - Unrestricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_058eb_level0_col0" class="col_heading level0 col0" >CD</th>
#       <th id="T_058eb_level0_col1" class="col_heading level0 col1" >CS</th>
#       <th id="T_058eb_level0_col2" class="col_heading level0 col2" >IT</th>
#       <th id="T_058eb_level0_col3" class="col_heading level0 col3" >TC</th>
#       <th id="T_058eb_level0_col4" class="col_heading level0 col4" >avg</th>
#       <th id="T_058eb_level0_col5" class="col_heading level0 col5" >std</th>
#       <th id="T_058eb_level0_col6" class="col_heading level0 col6" >min</th>
#       <th id="T_058eb_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_058eb_level0_col8" class="col_heading level0 col8" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_058eb_level0_row0" class="row_heading level0 row0" rowspan="4">[y]</th>
#       <th id="T_058eb_level1_row0" class="row_heading level1 row0" >6</th>
#       <th id="T_058eb_level2_row0" class="row_heading level2 row0" >1</th>
#       <td id="T_058eb_row0_col0" class="data row0 col0" >23,973</td>
#       <td id="T_058eb_row0_col1" class="data row0 col1" >26,065</td>
#       <td id="T_058eb_row0_col2" class="data row0 col2" >23,807</td>
#       <td id="T_058eb_row0_col3" class="data row0 col3" >24,137</td>
#       <td id="T_058eb_row0_col4" class="data row0 col4" >24,188</td>
#       <td id="T_058eb_row0_col5" class="data row0 col5" >1,501</td>
#       <td id="T_058eb_row0_col6" class="data row0 col6" >20,697</td>
#       <td id="T_058eb_row0_col7" class="data row0 col7" >26,565</td>
#       <td id="T_058eb_row0_col8" class="data row0 col8" >5,868</td>
#     </tr>
#     <tr>
#       <th id="T_058eb_level1_row1" class="row_heading level1 row1" >5</th>
#       <th id="T_058eb_level2_row1" class="row_heading level2 row1" >1</th>
#       <td id="T_058eb_row1_col0" class="data row1 col0" >23,973</td>
#       <td id="T_058eb_row1_col1" class="data row1 col1" >26,065</td>
#       <td id="T_058eb_row1_col2" class="data row1 col2" >23,807</td>
#       <td id="T_058eb_row1_col3" class="data row1 col3" >24,137</td>
#       <td id="T_058eb_row1_col4" class="data row1 col4" >24,188</td>
#       <td id="T_058eb_row1_col5" class="data row1 col5" >1,501</td>
#       <td id="T_058eb_row1_col6" class="data row1 col6" >20,697</td>
#       <td id="T_058eb_row1_col7" class="data row1 col7" >26,565</td>
#       <td id="T_058eb_row1_col8" class="data row1 col8" >5,869</td>
#     </tr>
#     <tr>
#       <th id="T_058eb_level1_row2" class="row_heading level1 row2" >4</th>
#       <th id="T_058eb_level2_row2" class="row_heading level2 row2" >1</th>
#       <td id="T_058eb_row2_col0" class="data row2 col0" >23,973</td>
#       <td id="T_058eb_row2_col1" class="data row2 col1" >26,065</td>
#       <td id="T_058eb_row2_col2" class="data row2 col2" >23,807</td>
#       <td id="T_058eb_row2_col3" class="data row2 col3" >24,137</td>
#       <td id="T_058eb_row2_col4" class="data row2 col4" >24,188</td>
#       <td id="T_058eb_row2_col5" class="data row2 col5" >1,501</td>
#       <td id="T_058eb_row2_col6" class="data row2 col6" >20,698</td>
#       <td id="T_058eb_row2_col7" class="data row2 col7" >26,565</td>
#       <td id="T_058eb_row2_col8" class="data row2 col8" >5,867</td>
#     </tr>
#     <tr>
#       <th id="T_058eb_level1_row3" class="row_heading level1 row3" >3</th>
#       <th id="T_058eb_level2_row3" class="row_heading level2 row3" >1</th>
#       <td id="T_058eb_row3_col0" class="data row3 col0" >23,973</td>
#       <td id="T_058eb_row3_col1" class="data row3 col1" >26,065</td>
#       <td id="T_058eb_row3_col2" class="data row3 col2" >23,806</td>
#       <td id="T_058eb_row3_col3" class="data row3 col3" >24,137</td>
#       <td id="T_058eb_row3_col4" class="data row3 col4" >24,188</td>
#       <td id="T_058eb_row3_col5" class="data row3 col5" >1,501</td>
#       <td id="T_058eb_row3_col6" class="data row3 col6" >20,697</td>
#       <td id="T_058eb_row3_col7" class="data row3 col7" >26,565</td>
#       <td id="T_058eb_row3_col8" class="data row3 col8" >5,868</td>
#     </tr>
#     <tr>
#       <th id="T_058eb_level0_row4" class="row_heading level0 row4" rowspan="4">[y,h]</th>
#       <th id="T_058eb_level1_row4" class="row_heading level1 row4" >6</th>
#       <th id="T_058eb_level2_row4" class="row_heading level2 row4" >2</th>
#       <td id="T_058eb_row4_col0" class="data row4 col0" >40,503</td>
#       <td id="T_058eb_row4_col1" class="data row4 col1" >42,466</td>
#       <td id="T_058eb_row4_col2" class="data row4 col2" >40,417</td>
#       <td id="T_058eb_row4_col3" class="data row4 col3" >40,504</td>
#       <td id="T_058eb_row4_col4" class="data row4 col4" >40,728</td>
#       <td id="T_058eb_row4_col5" class="data row4 col5" >1,572</td>
#       <td id="T_058eb_row4_col6" class="data row4 col6" >37,089</td>
#       <td id="T_058eb_row4_col7" class="data row4 col7" >42,992</td>
#       <td id="T_058eb_row4_col8" class="data row4 col8" >5,903</td>
#     </tr>
#     <tr>
#       <th id="T_058eb_level1_row5" class="row_heading level1 row5" >5</th>
#       <th id="T_058eb_level2_row5" class="row_heading level2 row5" >2</th>
#       <td id="T_058eb_row5_col0" class="data row5 col0" >40,503</td>
#       <td id="T_058eb_row5_col1" class="data row5 col1" >42,466</td>
#       <td id="T_058eb_row5_col2" class="data row5 col2" >40,417</td>
#       <td id="T_058eb_row5_col3" class="data row5 col3" >40,505</td>
#       <td id="T_058eb_row5_col4" class="data row5 col4" >40,728</td>
#       <td id="T_058eb_row5_col5" class="data row5 col5" >1,571</td>
#       <td id="T_058eb_row5_col6" class="data row5 col6" >37,088</td>
#       <td id="T_058eb_row5_col7" class="data row5 col7" >42,991</td>
#       <td id="T_058eb_row5_col8" class="data row5 col8" >5,903</td>
#     </tr>
#     <tr>
#       <th id="T_058eb_level1_row6" class="row_heading level1 row6" >4</th>
#       <th id="T_058eb_level2_row6" class="row_heading level2 row6" >2</th>
#       <td id="T_058eb_row6_col0" class="data row6 col0" >40,504</td>
#       <td id="T_058eb_row6_col1" class="data row6 col1" >42,466</td>
#       <td id="T_058eb_row6_col2" class="data row6 col2" >40,417</td>
#       <td id="T_058eb_row6_col3" class="data row6 col3" >40,504</td>

# %%
# Delta ELBO - unrestricted
styled_elbo_all = metric_table('elbo_delta (max all runs)', df_unrestr, base_idx_unrestr, cols_tail_unrestr, cols_all_unrestr, vmin=-1000000, vmax=1000000)
styled_elbo_all.set_caption("Delta ELBO - Unrestricted Models")
styled_elbo_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_elbo_all
# Out:
# <style type="text/css">
# #T_4a5e0 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_4a5e0_row0_col0, #T_4a5e0_row0_col2, #T_4a5e0_row0_col4, #T_4a5e0_row1_col2, #T_4a5e0_row2_col0, #T_4a5e0_row2_col2, #T_4a5e0_row3_col0, #T_4a5e0_row3_col2, #T_4a5e0_row3_col3, #T_4a5e0_row3_col4 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_4a5e0_row0_col1, #T_4a5e0_row0_col3, #T_4a5e0_row1_col0, #T_4a5e0_row1_col1, #T_4a5e0_row1_col3, #T_4a5e0_row1_col4, #T_4a5e0_row2_col1, #T_4a5e0_row2_col3, #T_4a5e0_row2_col4, #T_4a5e0_row3_col1 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_4a5e0_row4_col0, #T_4a5e0_row5_col0 {
#   background-color: #9dcbe1;
#   color: #000000;
# }
# #T_4a5e0_row4_col1, #T_4a5e0_row4_col2, #T_4a5e0_row4_col3, #T_4a5e0_row4_col4, #T_4a5e0_row5_col1, #T_4a5e0_row5_col2, #T_4a5e0_row5_col4, #T_4a5e0_row6_col1, #T_4a5e0_row6_col2, #T_4a5e0_row6_col4, #T_4a5e0_row7_col0, #T_4a5e0_row7_col2, #T_4a5e0_row7_col3, #T_4a5e0_row7_col4 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_4a5e0_row5_col3, #T_4a5e0_row6_col0, #T_4a5e0_row6_col3, #T_4a5e0_row7_col1 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# </style>
# <table id="T_4a5e0">
#   <caption>Delta ELBO - Unrestricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a5e0_level0_col0" class="col_heading level0 col0" >CD</th>
#       <th id="T_4a5e0_level0_col1" class="col_heading level0 col1" >CS</th>
#       <th id="T_4a5e0_level0_col2" class="col_heading level0 col2" >IT</th>
#       <th id="T_4a5e0_level0_col3" class="col_heading level0 col3" >TC</th>
#       <th id="T_4a5e0_level0_col4" class="col_heading level0 col4" >avg</th>
#       <th id="T_4a5e0_level0_col5" class="col_heading level0 col5" >std</th>
#       <th id="T_4a5e0_level0_col6" class="col_heading level0 col6" >min</th>
#       <th id="T_4a5e0_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_4a5e0_level0_col8" class="col_heading level0 col8" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a5e0_level0_row0" class="row_heading level0 row0" rowspan="4">[y]</th>
#       <th id="T_4a5e0_level1_row0" class="row_heading level1 row0" >6</th>
#       <th id="T_4a5e0_level2_row0" class="row_heading level2 row0" >1</th>
#       <td id="T_4a5e0_row0_col0" class="data row0 col0" >142,686</td>
#       <td id="T_4a5e0_row0_col1" class="data row0 col1" >137,192</td>
#       <td id="T_4a5e0_row0_col2" class="data row0 col2" >142,483</td>
#       <td id="T_4a5e0_row0_col3" class="data row0 col3" >140,447</td>
#       <td id="T_4a5e0_row0_col4" class="data row0 col4" >141,465</td>
#       <td id="T_4a5e0_row0_col5" class="data row0 col5" >4,956</td>
#       <td id="T_4a5e0_row0_col6" class="data row0 col6" >132,924</td>
#       <td id="T_4a5e0_row0_col7" class="data row0 col7" >156,029</td>
#       <td id="T_4a5e0_row0_col8" class="data row0 col8" >23,105</td>
#     </tr>
#     <tr>
#       <th id="T_4a5e0_level1_row1" class="row_heading level1 row1" >5</th>
#       <th id="T_4a5e0_level2_row1" class="row_heading level2 row1" >1</th>
#       <td id="T_4a5e0_row1_col0" class="data row1 col0" >139,403</td>
#       <td id="T_4a5e0_row1_col1" class="data row1 col1" >138,043</td>
#       <td id="T_4a5e0_row1_col2" class="data row1 col2" >142,105</td>
#       <td id="T_4a5e0_row1_col3" class="data row1 col3" >138,518</td>
#       <td id="T_4a5e0_row1_col4" class="data row1 col4" >140,610</td>
#       <td id="T_4a5e0_row1_col5" class="data row1 col5" >5,363</td>
#       <td id="T_4a5e0_row1_col6" class="data row1 col6" >133,054</td>
#       <td id="T_4a5e0_row1_col7" class="data row1 col7" >152,134</td>
#       <td id="T_4a5e0_row1_col8" class="data row1 col8" >19,080</td>
#     </tr>
#     <tr>
#       <th id="T_4a5e0_level1_row2" class="row_heading level1 row2" >4</th>
#       <th id="T_4a5e0_level2_row2" class="row_heading level2 row2" >1</th>
#       <td id="T_4a5e0_row2_col0" class="data row2 col0" >141,645</td>
#       <td id="T_4a5e0_row2_col1" class="data row2 col1" >137,817</td>
#       <td id="T_4a5e0_row2_col2" class="data row2 col2" >140,815</td>
#       <td id="T_4a5e0_row2_col3" class="data row2 col3" >139,275</td>
#       <td id="T_4a5e0_row2_col4" class="data row2 col4" >140,273</td>
#       <td id="T_4a5e0_row2_col5" class="data row2 col5" >5,730</td>
#       <td id="T_4a5e0_row2_col6" class="data row2 col6" >130,627</td>
#       <td id="T_4a5e0_row2_col7" class="data row2 col7" >158,053</td>
#       <td id="T_4a5e0_row2_col8" class="data row2 col8" >27,426</td>
#     </tr>
#     <tr>
#       <th id="T_4a5e0_level1_row3" class="row_heading level1 row3" >3</th>
#       <th id="T_4a5e0_level2_row3" class="row_heading level2 row3" >1</th>
#       <td id="T_4a5e0_row3_col0" class="data row3 col0" >141,664</td>
#       <td id="T_4a5e0_row3_col1" class="data row3 col1" >139,630</td>
#       <td id="T_4a5e0_row3_col2" class="data row3 col2" >141,312</td>
#       <td id="T_4a5e0_row3_col3" class="data row3 col3" >141,709</td>
#       <td id="T_4a5e0_row3_col4" class="data row3 col4" >141,197</td>
#       <td id="T_4a5e0_row3_col5" class="data row3 col5" >5,105</td>
#       <td id="T_4a5e0_row3_col6" class="data row3 col6" >133,867</td>
#       <td id="T_4a5e0_row3_col7" class="data row3 col7" >151,558</td>
#       <td id="T_4a5e0_row3_col8" class="data row3 col8" >17,691</td>
#     </tr>
#     <tr>
#       <th id="T_4a5e0_level0_row4" class="row_heading level0 row4" rowspan="4">[y,h]</th>
#       <th id="T_4a5e0_level1_row4" class="row_heading level1 row4" >6</th>
#       <th id="T_4a5e0_level2_row4" class="row_heading level2 row4" >2</th>
#       <td id="T_4a5e0_row4_col0" class="data row4 col0" >364,281</td>
#       <td id="T_4a5e0_row4_col1" class="data row4 col1" >354,070</td>
#       <td id="T_4a5e0_row4_col2" class="data row4 col2" >352,326</td>
#       <td id="T_4a5e0_row4_col3" class="data row4 col3" >354,779</td>
#       <td id="T_4a5e0_row4_col4" class="data row4 col4" >354,637</td>
#       <td id="T_4a5e0_row4_col5" class="data row4 col5" >9,503</td>
#       <td id="T_4a5e0_row4_col6" class="data row4 col6" >337,936</td>
#       <td id="T_4a5e0_row4_col7" class="data row4 col7" >381,637</td>
#       <td id="T_4a5e0_row4_col8" class="data row4 col8" >43,701</td>
#     </tr>
#     <tr>
#       <th id="T_4a5e0_level1_row5" class="row_heading level1 row5" >5</th>
#       <th id="T_4a5e0_level2_row5" class="row_heading level2 row5" >2</th>
#       <td id="T_4a5e0_row5_col0" class="data row5 col0" >361,805</td>
#       <td id="T_4a5e0_row5_col1" class="data row5 col1" >357,499</td>
#       <td id="T_4a5e0_row5_col2" class="data row5 col2" >356,309</td>
#       <td id="T_4a5e0_row5_col3" class="data row5 col3" >350,628</td>
#       <td id="T_4a5e0_row5_col4" class="data row5 col4" >356,291</td>
#       <td id="T_4a5e0_row5_col5" class="data row5 col5" >9,682</td>
#       <td id="T_4a5e0_row5_col6" class="data row5 col6" >338,300</td>
#       <td id="T_4a5e0_row5_col7" class="data row5 col7" >384,762</td>
#       <td id="T_4a5e0_row5_col8" class="data row5 col8" >46,462</td>
#     </tr>
#     <tr>
#       <th id="T_4a5e0_level1_row6" class="row_heading level1 row6" >4</th>
#       <th id="T_4a5e0_level2_row6" class="row_heading level2 row6" >2</th>
#       <td id="T_4a5e0_row6_col0" class="data row6 col0" >350,769</td>
#       <td id="T_4a5e0_row6_col1" class="data row6 col1" >354,509</td>
#       <td id="T_4a5e0_row6_col2" class="data row6 col2" >356,426</td>
#       <td id="T_4a5e0_row6_

# %%
# Model performance - restricted
df_restr = res[res['config'].isin(restricted)]
styled_restr, base_idx_restr, cols_tail_restr, cols_all_restr = performance(df_restr, 'cagr_rel_ex_ante')
styled_restr.set_caption("Rel CAGR - Restricted Models")
styled_restr.set_table_styles(CAPTION_CSS, overwrite=False)
styled_restr
# Out:
# <style type="text/css">
# #T_8986c caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_8986c_row0_col0, #T_8986c_row3_col3 {
#   background-color: #6eaed2;
#   color: #f1f1f1;
# }
# #T_8986c_row0_col1, #T_8986c_row15_col3 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_8986c_row0_col2 {
#   background-color: #a7d0e4;
#   color: #000000;
# }
# #T_8986c_row0_col3 {
#   background-color: #4c99c6;
#   color: #f1f1f1;
# }
# #T_8986c_row0_col4, #T_8986c_row4_col0, #T_8986c_row9_col3, #T_8986c_row12_col3 {
#   background-color: #9dcbe1;
#   color: #000000;
# }
# #T_8986c_row1_col0 {
#   background-color: #3b88be;
#   color: #f1f1f1;
# }
# #T_8986c_row1_col1 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_8986c_row1_col2, #T_8986c_row1_col4 {
#   background-color: #a5cee3;
#   color: #000000;
# }
# #T_8986c_row1_col3, #T_8986c_row3_col4 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_8986c_row2_col0 {
#   background-color: #6bacd1;
#   color: #f1f1f1;
# }
# #T_8986c_row2_col1 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_8986c_row2_col2 {
#   background-color: #b6d7e8;
#   color: #000000;
# }
# #T_8986c_row2_col3, #T_8986c_row5_col3 {
#   background-color: #9bc9e0;
#   color: #000000;
# }
# #T_8986c_row2_col4 {
#   background-color: #b1d5e7;
#   color: #000000;
# }
# #T_8986c_row3_col0, #T_8986c_row3_col1, #T_8986c_row4_col2, #T_8986c_row4_col4 {
#   background-color: #cfe4ef;
#   color: #000000;
# }
# #T_8986c_row3_col2 {
#   background-color: #c5dfec;
#   color: #000000;
# }
# #T_8986c_row4_col1, #T_8986c_row6_col2 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_8986c_row4_col3 {
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_8986c_row5_col0, #T_8986c_row10_col0, #T_8986c_row12_col4 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_8986c_row5_col1, #T_8986c_row11_col4 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_8986c_row5_col2, #T_8986c_row13_col3 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_8986c_row5_col4, #T_8986c_row6_col4 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_8986c_row6_col0, #T_8986c_row13_col4 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_8986c_row6_col1, #T_8986c_row9_col4 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_8986c_row6_col3 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# #T_8986c_row7_col0, #T_8986c_row11_col2 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_8986c_row7_col1 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_8986c_row7_col2, #T_8986c_row8_col2 {
#   background-color: #e3edf3;
#   color: #000000;
# }
# #T_8986c_row7_col3 {
#   background-color: #87beda;
#   color: #000000;
# }
# #T_8986c_row7_col4 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_8986c_row8_col0, #T_8986c_row9_col2, #T_8986c_row10_col4 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_8986c_row8_col1, #T_8986c_row13_col0, #T_8986c_row15_col4 {
#   background-color: #fce0d0;
#   color: #000000;
# }
# #T_8986c_row8_col3 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_8986c_row8_col4 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_8986c_row9_col0 {
#   background-color: #fae9df;
#   color: #000000;
# }
# #T_8986c_row9_col1 {
#   background-color: #fae8de;
#   color: #000000;
# }
# #T_8986c_row10_col1 {
#   background-color: #e6eff4;
#   color: #000000;
# }
# #T_8986c_row10_col2 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_8986c_row10_col3 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_8986c_row11_col0 {
#   background-color: #f9efe9;
#   color: #000000;
# }
# #T_8986c_row11_col1 {
#   background-color: #f9f0eb;
#   color: #000000;
# }
# #T_8986c_row11_col3 {
#   background-color: #e1edf3;
#   color: #000000;
# }
# #T_8986c_row12_col0 {
#   background-color: #f8f3f0;
#   color: #000000;
# }
# #T_8986c_row12_col1 {
#   background-color: #fcdecd;
#   color: #000000;
# }
# #T_8986c_row12_col2 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_8986c_row13_col1, #T_8986c_row13_col2 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# #T_8986c_row14_col0 {
#   background-color: #fbd0b9;
#   color: #000000;
# }
# #T_8986c_row14_col1, #T_8986c_row14_col4 {
#   background-color: #fbe3d4;
#   color: #000000;
# }
# #T_8986c_row14_col2 {
#   background-color: #fac8af;
#   color: #000000;
# }
# #T_8986c_row14_col3 {
#   background-color: #acd2e5;
#   color: #000000;
# }
# #T_8986c_row15_col0 {
#   background-color: #fbceb7;
#   color: #000000;
# }
# #T_8986c_row15_col1 {
#   background-color: #fae7dc;
#   color: #000000;
# }
# #T_8986c_row15_col2 {
#   background-color: #fcd3bc;
#   color: #000000;
# }
# </style>
# <table id="T_8986c">
#   <caption>Rel CAGR - Restricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8986c_level0_col0" class="col_heading level0 col0" >CD</th>
#       <th id="T_8986c_level0_col1" class="col_heading level0 col1" >CS</th>
#       <th id="T_8986c_level0_col2" class="col_heading level0 col2" >IT</th>
#       <th id="T_8986c_level0_col3" class="col_heading level0 col3" >TC</th>
#       <th id="T_8986c_level0_col4" class="col_heading level0 col4" >avg</th>
#       <th id="T_8986c_level0_col5" class="col_heading level0 col5" >std</th>
#       <th id="T_8986c_level0_col6" class="col_heading level0 col6" >min</th>
#       <th id="T_8986c_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_8986c_level0_col8" class="col_heading level0 col8" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8986c_level0_row0" class="row_heading level0 row0" >factor2_ff3</th>
#       <th id="T_8986c_level1_row0" class="row_heading level1 row0" >6</th>
#       <th id="T_8986c_level2_row0" class="row_heading level2 row0" >3</th>
#       <td id="T_8986c_row0_col0" class="data row0 col0" >0.049</td>
#       <td id="T_8986c_row0_col1" class="data row0 col1" >0.009</td>
#       <td id="T_8986c_row0_col2" class="data row0 col2" >0.033</td>
#       <td id="T_8986c_row0_col3" class="data row0 col3" >0.058</td>
#       <td id="T_8986c_row0_col4" class="data row0 col4" >0.036</td>
#       <td id="T_8986c_row0_col5" class="data row0 col5" >0.039</td>
#       <td id="T_8986c_row0_col6" class="data row0 col6" >-0.008</td>
#       <td id="T_8986c_row0_col7" class="data row0 col7" >0.154</td>
#       <td id="T_8986c_row0_col8" class="data row0 col8" >0.163</td>
#     </tr>
#     <tr>
#       <th id="T_8986c_level0_row1" class="row_heading level0 row1" >factor2_ff3mom</th>
#       <th id="T_8986c_level1_row1" class="row_heading level1 row1" >5</th>
#       <th id="T_8986c_level2_row1" class="row_heading level2 row1" >4</th>
#       <td id="T_8986c_row1_col0" class="data row1 col0" >0.064</td>
#       <td id="T_8986c_row1_col1" class="data row1 col1" >0.014</td>
#       <td id="T_8986c_row1_col2" class="data row1 col2" >0.034</td>
#       <td id="T_8986c_row1_col3" class="data row1 col3" >0.027</td>
#       <td id="T_8986c_row1_col4" class="data row1 col4" >0.034</td>
#       <td id="T_8986c_row1_col5" class="data row1 col5" >0.043</td>
#       <td id="T_8986c_row1_col6" class="data row1 col6" >-0.021</td>
#       <td id="T_8986c_row1_col7" class="data row1 col7" >0.199</td>
#       <td id="T_8986c_row1_col8" class="data row1 col8" >0.220</td>
#     </tr>
#     <tr>
#       <th id="T_8986c_level0_row2" class="row_heading level0 row2" >factor2_ff3</th>
#       <th id="T_8986c_level1_row2" class="row_heading level1 row2" >5</th>
#       <th id="T_8986c_level2_row2" class="row_heading level2 row2" >3</th>
#       <td id="T_8986c_row2_col0" class="data row2 col0" >0.050</td>
#       <td id="T_8986c_row2_col1" class="data row2 col1" >0.008</td>
#       <

# %%
# Smooth CPLL
styled_cpll_all = metric_table('CPLL Gap', df_restr, base_idx_restr, cols_tail_restr, cols_all_restr, vmin=-100000,  vmax=100000)
styled_cpll_all.set_caption("Smooth CPLL - Restricted Models")
styled_cpll_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_cpll_all
# Out:
# <style type="text/css">
# #T_cc42b caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_cc42b_row0_col0, #T_cc42b_row0_col2, #T_cc42b_row0_col4, #T_cc42b_row1_col0, #T_cc42b_row1_col1, #T_cc42b_row1_col3, #T_cc42b_row1_col4, #T_cc42b_row2_col0, #T_cc42b_row2_col2, #T_cc42b_row2_col4, #T_cc42b_row3_col0, #T_cc42b_row3_col1, #T_cc42b_row3_col3, #T_cc42b_row3_col4, #T_cc42b_row4_col0, #T_cc42b_row4_col1, #T_cc42b_row4_col3, #T_cc42b_row4_col4, #T_cc42b_row5_col2, #T_cc42b_row5_col4, #T_cc42b_row11_col0, #T_cc42b_row11_col1, #T_cc42b_row11_col3, #T_cc42b_row11_col4, #T_cc42b_row13_col2, #T_cc42b_row13_col4 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_cc42b_row0_col1, #T_cc42b_row0_col3, #T_cc42b_row2_col1, #T_cc42b_row2_col3, #T_cc42b_row5_col0, #T_cc42b_row5_col1, #T_cc42b_row5_col3, #T_cc42b_row10_col1, #T_cc42b_row12_col1, #T_cc42b_row13_col0, #T_cc42b_row13_col1, #T_cc42b_row13_col3, #T_cc42b_row15_col1 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_cc42b_row1_col2, #T_cc42b_row3_col2, #T_cc42b_row4_col2, #T_cc42b_row11_col2 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_cc42b_row6_col0, #T_cc42b_row6_col1, #T_cc42b_row6_col2, #T_cc42b_row6_col3, #T_cc42b_row6_col4, #T_cc42b_row7_col0, #T_cc42b_row7_col2, #T_cc42b_row7_col3, #T_cc42b_row7_col4, #T_cc42b_row8_col0, #T_cc42b_row8_col1, #T_cc42b_row8_col2, #T_cc42b_row8_col3, #T_cc42b_row8_col4, #T_cc42b_row9_col0, #T_cc42b_row9_col1, #T_cc42b_row9_col2, #T_cc42b_row9_col3, #T_cc42b_row9_col4, #T_cc42b_row10_col0, #T_cc42b_row10_col2, #T_cc42b_row10_col3, #T_cc42b_row10_col4, #T_cc42b_row12_col0, #T_cc42b_row12_col2, #T_cc42b_row12_col3, #T_cc42b_row12_col4, #T_cc42b_row14_col0, #T_cc42b_row14_col1, #T_cc42b_row14_col2, #T_cc42b_row14_col3, #T_cc42b_row14_col4, #T_cc42b_row15_col0, #T_cc42b_row15_col2, #T_cc42b_row15_col3, #T_cc42b_row15_col4 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_cc42b_row7_col1 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# </style>
# <table id="T_cc42b">
#   <caption>Smooth CPLL - Restricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc42b_level0_col0" class="col_heading level0 col0" >CD</th>
#       <th id="T_cc42b_level0_col1" class="col_heading level0 col1" >CS</th>
#       <th id="T_cc42b_level0_col2" class="col_heading level0 col2" >IT</th>
#       <th id="T_cc42b_level0_col3" class="col_heading level0 col3" >TC</th>
#       <th id="T_cc42b_level0_col4" class="col_heading level0 col4" >avg</th>
#       <th id="T_cc42b_level0_col5" class="col_heading level0 col5" >std</th>
#       <th id="T_cc42b_level0_col6" class="col_heading level0 col6" >min</th>
#       <th id="T_cc42b_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_cc42b_level0_col8" class="col_heading level0 col8" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc42b_level0_row0" class="row_heading level0 row0" >factor2_ff3</th>
#       <th id="T_cc42b_level1_row0" class="row_heading level1 row0" >6</th>
#       <th id="T_cc42b_level2_row0" class="row_heading level2 row0" >3</th>
#       <td id="T_cc42b_row0_col0" class="data row0 col0" >2,364</td>
#       <td id="T_cc42b_row0_col1" class="data row0 col1" >2,078</td>
#       <td id="T_cc42b_row0_col2" class="data row0 col2" >2,741</td>
#       <td id="T_cc42b_row0_col3" class="data row0 col3" >2,085</td>
#       <td id="T_cc42b_row0_col4" class="data row0 col4" >2,464</td>
#       <td id="T_cc42b_row0_col5" class="data row0 col5" >458</td>
#       <td id="T_cc42b_row0_col6" class="data row0 col6" >1,655</td>
#       <td id="T_cc42b_row0_col7" class="data row0 col7" >3,468</td>
#       <td id="T_cc42b_row0_col8" class="data row0 col8" >1,813</td>
#     </tr>
#     <tr>
#       <th id="T_cc42b_level0_row1" class="row_heading level0 row1" >factor2_ff3mom</th>
#       <th id="T_cc42b_level1_row1" class="row_heading level1 row1" >5</th>
#       <th id="T_cc42b_level2_row1" class="row_heading level2 row1" >4</th>
#       <td id="T_cc42b_row1_col0" class="data row1 col0" >2,897</td>
#       <td id="T_cc42b_row1_col1" class="data row1 col1" >2,523</td>
#       <td id="T_cc42b_row1_col2" class="data row1 col2" >3,272</td>
#       <td id="T_cc42b_row1_col3" class="data row1 col3" >2,693</td>
#       <td id="T_cc42b_row1_col4" class="data row1 col4" >2,988</td>
#       <td id="T_cc42b_row1_col5" class="data row1 col5" >465</td>
#       <td id="T_cc42b_row1_col6" class="data row1 col6" >2,250</td>
#       <td id="T_cc42b_row1_col7" class="data row1 col7" >4,016</td>
#       <td id="T_cc42b_row1_col8" class="data row1 col8" >1,766</td>
#     </tr>
#     <tr>
#       <th id="T_cc42b_level0_row2" class="row_heading level0 row2" >factor2_ff3</th>
#       <th id="T_cc42b_level1_row2" class="row_heading level1 row2" >5</th>
#       <th id="T_cc42b_level2_row2" class="row_heading level2 row2" >3</th>
#       <td id="T_cc42b_row2_col0" class="data row2 col0" >2,403</td>
#       <td id="T_cc42b_row2_col1" class="data row2 col1" >2,060</td>
#       <td id="T_cc42b_row2_col2" class="data row2 col2" >2,664</td>
#       <td id="T_cc42b_row2_col3" class="data row2 col3" >2,157</td>
#       <td id="T_cc42b_row2_col4" class="data row2 col4" >2,440</td>
#       <td id="T_cc42b_row2_col5" class="data row2 col5" >448</td>
#       <td id="T_cc42b_row2_col6" class="data row2 col6" >1,647</td>
#       <td id="T_cc42b_row2_col7" class="data row2 col7" >3,412</td>
#       <td id="T_cc42b_row2_col8" class="data row2 col8" >1,765</td>
#     </tr>
#     <tr>
#       <th id="T_cc42b_level0_row3" class="row_heading level0 row3" rowspan="2">factor2_ff3mom</th>
#       <th id="T_cc42b_level1_row3" class="row_heading level1 row3" >6</th>
#       <th id="T_cc42b_level2_row3" class="row_heading level2 row3" >4</th>
#       <td id="T_cc42b_row3_col0" class="data row3 col0" >2,979</td>
#       <td id="T_cc42b_row3_col1" class="data row3 col1" >2,711</td>
#       <td id="T_cc42b_row3_col2" class="data row3 col2" >3,276</td>
#       <td id="T_cc42b_row3_col3" class="data row3 col3" >2,741</td>
#       <td id="T_cc42b_row3_col4" class="data row3 col4" >3,041</td>
#       <td id="T_cc42b_row3_col5" class="data row3 col5" >432</td>
#       <td id="T_cc42b_row3_col6" class="data row3 col6" >2,280</td>
#       <td id="T_cc42b_row3_col7" class="data row3 col7" >4,022</td>
#       <td id="T_cc42b_row3_col8" class="data row3 col8" >1,742</td>
#     </tr>
#     <tr>
#       <th id="T_cc42b_level1_row4" class="row_heading level1 row4" >4</th>
#       <th id="T_cc42b_level2_row4" class="row_heading level2 row4" >4</th>
#       <td id="T_cc42b_row4_col0" class="data row4 col0" >2,939</td>
#       <td id="T_cc42b_row4_col1" class="data row4 col1" >2,612</td>
#       <td id="T_cc42b_row4_col2" class="data row4 col2" >3,321</td>
#       <td id="T_cc42b_row4_col3" class="data row4 col3" >2,698</td>
#       <td id="T_cc42b_row4_col4" class="data row4 col4" >3,034</td>
#       <td id="T_cc42b_row4_col5" class="data row4 col5" >468</td>
#       <td id="T_cc42b_row4_col6" class="data row4 col6" >2,170</td>
#       <td id="T_cc42b_row4_col7" class="data row4 col7" >4,189</td>
#       <td id="T_cc42b_row4_col8" class="data row4 col8" >2,019</td>
#     </tr>
#     <tr>
#       <th id="T_cc42b_level0_row5" class="row_heading level0 row5" >factor2_ff3</th>
#       <th id="T_cc42b_level1_row5" class="row_heading level1 row5" >4</th>
#       <th id="T_cc42b_level2_row5" class="row_heading level2 row5" >3</th>
#       <td id="T_cc42b_row

# %%
# Delta ELBO — ALL models, SAME rows/cols/order as "# Model performance"
styled_elbo_all = metric_table('elbo_delta (max all runs)', df_restr, base_idx_restr, cols_tail_restr, cols_all_restr, vmin=-1000000, vmax=1000000)
styled_elbo_all.set_caption("Delta ELBO - Restricted Models")
styled_elbo_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_elbo_all
# Out:
# <style type="text/css">
# #T_20fa4 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_20fa4_row0_col0, #T_20fa4_row0_col1, #T_20fa4_row0_col2, #T_20fa4_row0_col3, #T_20fa4_row0_col4, #T_20fa4_row1_col0, #T_20fa4_row1_col1, #T_20fa4_row1_col2, #T_20fa4_row1_col3, #T_20fa4_row1_col4, #T_20fa4_row2_col0, #T_20fa4_row2_col1, #T_20fa4_row2_col2, #T_20fa4_row2_col3, #T_20fa4_row2_col4, #T_20fa4_row3_col0, #T_20fa4_row3_col1, #T_20fa4_row3_col2, #T_20fa4_row3_col3, #T_20fa4_row3_col4, #T_20fa4_row4_col0, #T_20fa4_row4_col1, #T_20fa4_row4_col2, #T_20fa4_row4_col3, #T_20fa4_row4_col4, #T_20fa4_row5_col0, #T_20fa4_row5_col1, #T_20fa4_row5_col2, #T_20fa4_row5_col3, #T_20fa4_row5_col4, #T_20fa4_row11_col0, #T_20fa4_row11_col1, #T_20fa4_row11_col2, #T_20fa4_row11_col3, #T_20fa4_row11_col4, #T_20fa4_row13_col0, #T_20fa4_row13_col1, #T_20fa4_row13_col2, #T_20fa4_row13_col3, #T_20fa4_row13_col4 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_20fa4_row6_col0, #T_20fa4_row6_col1, #T_20fa4_row6_col2, #T_20fa4_row6_col3, #T_20fa4_row6_col4, #T_20fa4_row7_col0, #T_20fa4_row7_col1, #T_20fa4_row7_col2, #T_20fa4_row7_col3, #T_20fa4_row7_col4, #T_20fa4_row8_col0, #T_20fa4_row8_col1, #T_20fa4_row8_col2, #T_20fa4_row8_col3, #T_20fa4_row8_col4, #T_20fa4_row9_col0, #T_20fa4_row9_col1, #T_20fa4_row9_col2, #T_20fa4_row9_col3, #T_20fa4_row9_col4, #T_20fa4_row10_col0, #T_20fa4_row10_col1, #T_20fa4_row10_col2, #T_20fa4_row10_col3, #T_20fa4_row10_col4, #T_20fa4_row12_col0, #T_20fa4_row12_col1, #T_20fa4_row12_col2, #T_20fa4_row12_col3, #T_20fa4_row12_col4, #T_20fa4_row14_col0, #T_20fa4_row14_col1, #T_20fa4_row14_col2, #T_20fa4_row14_col3, #T_20fa4_row14_col4, #T_20fa4_row15_col0, #T_20fa4_row15_col1, #T_20fa4_row15_col2, #T_20fa4_row15_col3, #T_20fa4_row15_col4 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# </style>
# <table id="T_20fa4">
#   <caption>Delta ELBO - Restricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20fa4_level0_col0" class="col_heading level0 col0" >CD</th>
#       <th id="T_20fa4_level0_col1" class="col_heading level0 col1" >CS</th>
#       <th id="T_20fa4_level0_col2" class="col_heading level0 col2" >IT</th>
#       <th id="T_20fa4_level0_col3" class="col_heading level0 col3" >TC</th>
#       <th id="T_20fa4_level0_col4" class="col_heading level0 col4" >avg</th>
#       <th id="T_20fa4_level0_col5" class="col_heading level0 col5" >std</th>
#       <th id="T_20fa4_level0_col6" class="col_heading level0 col6" >min</th>
#       <th id="T_20fa4_level0_col7" class="col_heading level0 col7" >max</th>
#       <th id="T_20fa4_level0_col8" class="col_heading level0 col8" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20fa4_level0_row0" class="row_heading level0 row0" >factor2_ff3</th>
#       <th id="T_20fa4_level1_row0" class="row_heading level1 row0" >6</th>
#       <th id="T_20fa4_level2_row0" class="row_heading level2 row0" >3</th>
#       <td id="T_20fa4_row0_col0" class="data row0 col0" >10,595</td>
#       <td id="T_20fa4_row0_col1" class="data row0 col1" >10,642</td>
#       <td id="T_20fa4_row0_col2" class="data row0 col2" >10,632</td>
#       <td id="T_20fa4_row0_col3" class="data row0 col3" >10,894</td>
#       <td id="T_20fa4_row0_col4" class="data row0 col4" >10,676</td>
#       <td id="T_20fa4_row0_col5" class="data row0 col5" >269</td>
#       <td id="T_20fa4_row0_col6" class="data row0 col6" >9,603</td>
#       <td id="T_20fa4_row0_col7" class="data row0 col7" >11,537</td>
#       <td id="T_20fa4_row0_col8" class="data row0 col8" >1,934</td>
#     </tr>
#     <tr>
#       <th id="T_20fa4_level0_row1" class="row_heading level0 row1" >factor2_ff3mom</th>
#       <th id="T_20fa4_level1_row1" class="row_heading level1 row1" >5</th>
#       <th id="T_20fa4_level2_row1" class="row_heading level2 row1" >4</th>
#       <td id="T_20fa4_row1_col0" class="data row1 col0" >14,055</td>
#       <td id="T_20fa4_row1_col1" class="data row1 col1" >14,101</td>
#       <td id="T_20fa4_row1_col2" class="data row1 col2" >13,966</td>
#       <td id="T_20fa4_row1_col3" class="data row1 col3" >14,246</td>
#       <td id="T_20fa4_row1_col4" class="data row1 col4" >14,053</td>
#       <td id="T_20fa4_row1_col5" class="data row1 col5" >350</td>
#       <td id="T_20fa4_row1_col6" class="data row1 col6" >12,537</td>
#       <td id="T_20fa4_row1_col7" class="data row1 col7" >15,024</td>
#       <td id="T_20fa4_row1_col8" class="data row1 col8" >2,487</td>
#     </tr>
#     <tr>
#       <th id="T_20fa4_level0_row2" class="row_heading level0 row2" >factor2_ff3</th>
#       <th id="T_20fa4_level1_row2" class="row_heading level1 row2" >5</th>
#       <th id="T_20fa4_level2_row2" class="row_heading level2 row2" >3</th>
#       <td id="T_20fa4_row2_col0" class="data row2 col0" >10,581</td>
#       <td id="T_20fa4_row2_col1" class="data row2 col1" >10,605</td>
#       <td id="T_20fa4_row2_col2" class="data row2 col2" >10,619</td>
#       <td id="T_20fa4_row2_col3" class="data row2 col3" >10,893</td>
#       <td id="T_20fa4_row2_col4" class="data row2 col4" >10,661</td>
#       <td id="T_20fa4_row2_col5" class="data row2 col5" >289</td>
#       <td id="T_20fa4_row2_col6" class="data row2 col6" >9,510</td>
#       <td id="T_20fa4_row2_col7" class="data row2 col7" >11,568</td>
#       <td id="T_20fa4_row2_col8" class="data row2 col8" >2,058</td>
#     </tr>
#     <tr>
#       <th id="T_20fa4_level0_row3" class="row_heading level0 row3" rowspan="2">factor2_ff3mom</th>
#       <th id="T_20fa4_level1_row3" class="row_heading level1 row3" >6</th>
#       <th id="T_20fa4_level2_row3" class="row_heading level2 row3" >4</th>
#       <td id="T_20fa4_row3_col0" class="data row3 col0" >13,932</td>
#       <td id="T_20fa4_row3_col1" class="data row3 col1" >13,969</td>
#       <td id="T_20fa4_row3_col2" class="data row3 col2" >13,986</td>
#       <td id="T_20fa4_row3_col3" class="data row3 col3" >14,259</td>
#       <td id="T_20fa4_row3_col4" class="data row3 col4" >14,026</td>
#       <td id="T_20fa4_row3_col5" class="data row3 col5" >364</td>
#       <td id="T_20fa4_row3_col6" class="data row3 col6" >12,585</td>
#       <td id="T_20fa4_row3_col7" class="data row3 col7" >15,190</td>
#       <td id="T_20fa4_row3_col8" class="data row3 col8" >2,605</td>
#     </tr>
#     <tr>
#       <th id="T_20fa4_level1_row4" class="row_heading level1 row4" >4</th>
#       <th id="T_20fa4_level2_row4" class="row_heading level2 row4" >4</th>
#       <td id="T_20fa4_row4_col0" class="data row4 col0" >13,987</td>
#       <td id="T_20fa4_row4_col1" class="data row4 col1" >14,009</td>
#       <td id="T_20fa4_row4_col2" class="data row4 col2" >13,946</td>
#       <td id="T_20fa4_row4_col3" class="data row4 col3" >14,259</td>
#       <td id="T_20fa4_row4_col4" class="data row4 col4" >14,021</td>
#       <td id="T_20fa4_row4_col5" class="data row4 col5" >346</td>
#       <td id="T_20fa4_row4_col6" class="data row4 col6" >12,644</td>
#       <td id="T_20fa4_row4_col7" class="data row4 col7" >15,057</td>
#       <td id="T_20fa4_row4_col8" class="data row4 col8" >2,413</td>
#     </tr>
#     <tr>
#       <th id="T_20fa4_level0_row5" class="row_heading level0 row5" >factor2_ff3</th>
#       <th id="T_20fa4_level1_row5" class="row_heading level1 row5" >4</th>
#       <th id="T_20fa4_level2_row5" class="row_heading level2 row5" >3</th>
#       <td id="T_20fa4_row5_col0" class="data row5 col0" >10,561</td>
#       <td id="T_20fa4_row5_col1" class="data row5 col1" >10,611</td>

# %%
# --------------------------------------------------------------------------------------
# CONFIG
# --------------------------------------------------------------------------------------

PATHS = {
        "data_excel": "/Users/chrismader/Python/SLDS/Data/bbg_data.xlsx",
        "ff_dir": "/Users/chrismader/Python/SLDS/Data/",
        "ff_files": {
            "ff5": "F-F_Research_Data_5_Factors_2x3_daily.csv",
            "ff3": "F-F_Research_Data_Factors_daily.csv",
            "mom": "F-F_Momentum_Factor_daily.csv",},
        "results_csv": "/Users/chrismader/Python/SLDS/Output/gridsearch_results1.csv",
        "segments_parquet": "/Users/chrismader/Python/SLDS/Output/gridsearch_segments1.parquet",
        "tmp_dir":          "/Users/chrismader/Python/SLDS/tmp_slds/",
        "segments_tmp_csv": "/Users/chrismader/Python/SLDS/tmp_slds/segments_tmp.csv",
    }

CONFIG = {
    
    # Core defaults
    "n_jobs": -1,  # multi-threading
    "dt": 1.0 / 252.0,
    "n_iters": 50,
    "h_z": 3.0,  # CUSUM parameter
    
    # Batch windows
    "batch_grid": [
        {"train_window": 1260, "overlap_window": 0},
    ],

    # Number of regimes
    "K_grid": [4],
    
    # Unrestricted models: 
    "unrestricted_models": [
        # {"label": "[y]",         "channels": ["y"],                "dim_latent": [1]},
        # {"label": "[y,h]",       "channels": ["y","h"],            "dim_latent": [2]},
        # {"label": "[g,v]",       "channels": ["g","v"],            "dim_latent": [2]},
        # {"label": "[g,v,h]",     "channels": ["g","v","h"],        "dim_latent": [2,3]},
        # {"label": "[y,g,v,h]",   "channels": ["y","g","v","h"],    "dim_latent": [3,4]},
    ],

    # Restricted models: 
    "restricted_models": [
        # {"label": "fund1",        "channels": ["y"],                 "dim_latent": [2],    "C_type": "fund1"},
        {"label": "fund1_vix",    "channels": ["y","h"],             "dim_latent": [3],    "C_type": "fund1_vix"},
        # {"label": "fund2",        "channels": ["y","g"],             "dim_latent": [2],    "C_type": "fund2"},
        # {"label": "fund2_vix",    "channels": ["y","g","h"],         "dim_latent": [3],    "C_type": "fund2_vix"},
        # {"label": "fund3",        "channels": ["y","v","g"],         "dim_latent": [2],    "C_type": "fund3"},
        # {"label": "fund3_vix",    "channels": ["y","v","g","h"],     "dim_latent": [3],    "C_type": "fund3_vix"},   

        # {"label": "factor1",      "channels": ["y"],                 "dim_latent": [2],    "C_type": "factor1"},
        # {"label": "factor1_vix",  "channels": ["y","h"],             "dim_latent": [3],    "C_type": "factor1_vix"},

        {"label": "factor2_ff3",   "channels": ["y","mkt","smb","hml"],                   "dim_latent": [3], "C_type": "factor2"},
        # {"label": "factor2_ff3mom","channels": ["y","mkt","smb","hml","mom"],             "dim_latent": [4], "C_type": "factor2"},
        # {"label": "factor2_ff5",   "channels": ["y","mkt","smb","hml","rmw","cma"],       "dim_latent": [5], "C_type": "factor2"},
        # {"label": "factor2_ff5mom","channels": ["y","mkt","smb","hml","rmw","cma","mom"], "dim_latent": [6], "C_type": "factor2"},
    ],

    # Model selection
    "run_unrestricted": False,
    "run_restricted": True,
    "predict_oos": False,

    # Output
    "verbose": False,
    "display": False,
}

for k, v in PATHS.items(): 
    CONFIG[k] = v
# per-security temp file templates used by IOManager
CONFIG["tmp_results_fmt"]  = "{tmp_dir}/tmp_res_{security}.csv"
CONFIG["tmp_segments_fmt"] = "{tmp_dir}/tmp_seg_{security}.csv"

# %%
def collect_seed_rolling_params(cfg, securities, n_runs=10, master_seed=123):
    """
    PURE WRAPPER with stability aggregation:
      • Per security → rolling batches → per-seed fits (unchanged logic).
      • NEW: For each batch, aggregate params across seeds (mean/std elementwise)
             for {Cs, ds, inv_etas, As, bs, sigmasq, Rs, r}.
      • NEW: For each batch, compute regime occupancies averaged across seeds
             for {zhat_raw, zhat_cusum} and store ARI (mean pairwise across seeds).
    The return structure now includes per-batch "params_agg" and "occ".
    """
    import numpy as np
    from gridsearch import import_data, import_factors, _intersect_indexes, _build_restrictions
    from rSLDS import fit_rSLDS, fit_rSLDS_restricted, cusum_overlay

    # pick active model (CONFIG guarantees mutual exclusivity)
    assert bool(cfg.get("run_unrestricted", False)) ^ bool(cfg.get("run_restricted", False)), \
       "[CFG] Exactly one of run_unrestricted or run_restricted must be True."
    
    if cfg["run_unrestricted"]:
        assert len(cfg["unrestricted_models"]) > 0, \
            "[CFG] run_unrestricted=True but unrestricted_models is empty."
        m = cfg["unrestricted_models"][0]; restricted = False; C_type = None
    else:
        assert len(cfg["restricted_models"]) > 0, \
            "[CFG] run_restricted=True but restricted_models is empty."
        m = cfg["restricted_models"][0];  restricted = True;  C_type = m["C_type"]
        
    channels   = list(m["channels"])
    D          = int(m["dim_latent"][0])
    K          = int(cfg["K_grid"][0])
    dt         = float(cfg["dt"])
    n_iters    = int(cfg["n_iters"])
    h_z        = float(cfg["h_z"])
    batch_conf = cfg["batch_grid"][0]
    train_window = int(batch_conf["train_window"])
    overlap      = int(batch_conf["overlap_window"])

    print(f"[CFG] restricted={restricted} C_type={C_type} channels={channels} K={K} D={D} "
          f"dt={dt} n_iters={n_iters} h_z={h_z} train_window={train_window} overlap={overlap} n_runs={n_runs}")

    # data
    px_all, eps_all, pe_all, ser_vix = import_data(cfg["data_excel"])
    ff = import_factors(cfg["ff_dir"], cfg["ff_files"])

    def _series_by_key_for(sec):
        ser_px  = px_all[sec].dropna()
        ser_eps = eps_all[sec].dropna().where(lambda s: s > 0).dropna()
        ser_pe  = (ser_px / ser_eps).where(lambda s: s > 0).dropna()
        series = {
            "y": np.log(ser_px).diff().dropna(),
            "g": np.log(ser_eps).diff().dropna(),
            "v": np.log(ser_pe).diff().dropna(),
            "h": np.log(ser_vix).diff().dropna(),
        }
        for col, key in [("MKT","mkt"),("SMB","smb"),("HML","hml"),("RMW","rmw"),("CMA","cma"),("MOM","mom")]:
            if col in ff.columns:
                series[key] = ff[col]
        return series, ser_px

    rng = np.random.RandomState(master_seed)
    out = {}

    # ---------- small helpers ----------
    def _stack(arrs, expected_ndim=None):
        A = np.stack(arrs, axis=0)  # (R, ...)
        if expected_ndim is not None:
            assert A.ndim == expected_ndim + 1, f"[ASSERT] rank mismatch: got {A.ndim}, want {expected_ndim+1}"
        return A

    def _agg_mean_std(A):
        mu = A.mean(axis=0)
        sd = A.std(axis=0, ddof=1) if A.shape[0] > 1 else np.zeros_like(mu)
        return mu, sd

    def _occ_by_seed(Z, K_):
        # Z: shape (R, T) ints in {0..K-1} or {1..K}
        if Z.size == 0:
            return np.full((Z.shape[0], K_), np.nan)
        Zp = Z.copy()
        if Zp.min() == 1:
            Zp = Zp - 1
        R, T = Zp.shape
        occ = np.zeros((R, K_), float)
        for i in range(R):
            bc = np.bincount(Zp[i], minlength=K_).astype(float)
            occ[i] = bc / max(T, 1)
        return occ

    from sklearn.metrics import adjusted_rand_score as _ARI
    def _mean_pairwise_ARI(Z):
        Z = np.asarray(Z, dtype=int)
        if Z.size == 0:
            return np.nan
        if Z.min() == 1:
            Z = Z - 1
        R, _ = Z.shape
        vals = []
        for i in range(R):
            for j in range(i+1, R):
                vals.append(_ARI(Z[i], Z[j]))
        return float(np.mean(vals)) if vals else np.nan

    # ------------------------------------

    for sec in securities:

        print(f"\n[SEC] {sec}")
        series_by_key, ser_px = _series_by_key_for(sec)
        need = [series_by_key[k].dropna() for k in channels]
        common_idx = _intersect_indexes(need)
        if common_idx is None or getattr(common_idx, "empty", False):
            print(f"[WARN] {sec}: no overlap for channels {channels} — skipping")
            continue

        Y_full  = np.concatenate([series_by_key[k].loc[common_idx].values.reshape(-1,1) for k in channels], axis=1)
        px_full = ser_px.loc[common_idx].astype(float)
        T, N = Y_full.shape
        assert N == len(channels), f"[ASSERT] N={N} must equal len(channels)={len(channels)}"

        print(f"[DATA] T={T} N={N} idx[{common_idx[0]} → {common_idx[-1]}]")

        # batch schedule
        t0s, t1s, t0 = [], [], 0
        while t0 < T:
            t1s.append(min(t0 + train_window, T))
            t0s.append(t0)
            if t1s[-1] == T: break
            t0 += train_window - overlap
        print(f"[BATCH] batches={len(t0s)}")

        rec = {
            "meta": {
                "channels": channels, "K": K, "D": D,
                "train_window": train_window, "overlap_window": overlap,
                "common_index": common_idx, "restricted": restricted, "dt": dt},
            "batches": []}

        params_spec = dict(n_regimes=K, dim_latent=D, single_subspace=True)

        for bi, (b0, b1) in enumerate(zip(t0s, t1s)):
            Yb = Y_full[b0:b1, :]
            pxb = px_full.iloc[b0:b1]
            idx_slice = pxb.index
            print(f"[B{bi}] slice t0={b0} t1={b1} len={len(idx_slice)}")

            restrictions = None
            if restricted:
                restrictions = _build_restrictions(C_type, Y_obs=Yb, base_channels=channels, D=D)
                assert "C" in restrictions and "d" in restrictions, "[ASSERT] restrictions must contain 'C' and 'd'"
                print(f"[B{bi}] restrictions keys={list(restrictions.keys())}")

            seeds = rng.randint(1, 2**31 - 1, size=n_runs).tolist()
          
            per_seed_records = []
            Z_raw_list, Z_cusum_list = [], []
            Cs_list, ds_list, inv_list = [], [], []
            As_list, bs_list, sigmasq_list, Rs_list, r_list = [], [], [], [], []

            for si, s in enumerate(seeds):
                
                if restricted:
                    xhat, zhat_raw, elbo, q, mdl = fit_rSLDS_restricted(
                        Yb, params_spec,
                        C=restrictions["C"], d=restrictions["d"],
                        n_iter_em=n_iters, seed=s,
                        b_pattern=restrictions.get("b_pattern"),
                        enforce_diag_A=True,
                        C_mask=restrictions.get("C_mask"),
                        d_mask=restrictions.get("d_mask"))
                else:
                    xhat, zhat_raw, elbo, q, mdl = fit_rSLDS(Yb, params_spec, n_iter_em=n_iters, seed=s)

                y_cus = Yb[:, 0].ravel()
                zhat_cusum = cusum_overlay(pxb, y_cus, xhat, mdl, h_z)

                Z_raw_list.append(np.asarray(zhat_raw).ravel())
                if zhat_cusum is None:
                    Z_cusum_list.append(np.asarray(zhat_raw).ravel())
                else:
                    Z_cusum_list.append(np.asarray(zhat_cusum).ravel())

                # params (copy to detach)
                Cs      = np.array(mdl.emissions.Cs,       copy=True)
                ds      = np.array(mdl.emissions.ds,       copy=True)
                inv_eta = np.array(mdl.emissions.inv_etas, copy=True)
                As      = np.array(mdl.dynamics.As,        copy=True)
                bs      = np.array(mdl.dynamics.bs,        copy=True)
                sigmasq = np.array(mdl.dynamics.sigmasq,   copy=True)
                Rs      = np.array(mdl.transitions.Rs,     copy=True)
                r       = np.array(mdl.transitions.r,      copy=True)

                # sanity on leading K (allow shared emissions with leading 1)
                assert As.shape[0] == K and bs.shape[0] == K and sigmasq.shape[0] == K \
                    and Rs.shape[0] == K and r.shape[0] == K, "[ASSERT] K mismatch in dynamics/transitions"
                assert Cs.ndim == 3 and ds.ndim == 2 and inv_eta.ndim == 2, "[ASSERT] emissions rank mismatch"
                assert Cs.shape[0] in (1, K) and ds.shape[0] in (1, K) and inv_eta.shape[0] in (1, K), \
                    "[ASSERT] emissions leading axis must be 1 or K"

                Cs_list.append(Cs)
                ds_list.append(ds)
                inv_list.append(inv_eta)
                As_list.append(As)
                bs_list.append(bs)
                sigmasq_list.append(sigmasq)
                Rs_list.append(Rs)
                r_list.append(r)

                per_seed_records.append({
                    "seed": int(s),
                    "params": {"Cs": Cs, "ds": ds, "inv_etas": inv_eta, "As": As, "bs": bs,
                               "sigmasq": sigmasq, "Rs": Rs, "r": r},
                    "outputs": {"zhat_raw": zhat_raw, "zhat_cusum": zhat_cusum,
                                "xhat": xhat, "elbo": elbo}
                })

            # ---------- aggregate across seeds (elementwise mean/std) ----------
            def _agg_block(block_list):
                A = _stack(block_list)  # (R, ...)
                mu, sd = _agg_mean_std(A)
                return {"mean": mu, "std": sd}

            params_agg = {
                "Cs": _agg_block(Cs_list),
                "ds": _agg_block(ds_list),
                "inv_etas": _agg_block(inv_list),
                "As": _agg_block(As_list),
                "bs": _agg_block(bs_list),
                "sigmasq": _agg_block(sigmasq_list),
                "Rs": _agg_block(Rs_list),
                "r": _agg_block(r_list),
            }

            # ---------- regime occupancy (avg across seeds) + ARI ----------
            Zr = np.stack(Z_raw_list, axis=0)   if len(Z_raw_list)  else np.zeros((0, 0), int)
            Zc = np.stack(Z_cusum_list, axis=0) if len(Z_cusum_list) else np.zeros((0, 0), int)

            occ_raw_seed = _occ_by_seed(Zr, K)  # (R,K)
            occ_cus_seed = _occ_by_seed(Zc, K)  # (R,K)

            occ = {
                "raw": {
                    "by_seed": occ_raw_seed,                      # (R,K), fractions
                    "mean":    np.nanmean(occ_raw_seed, axis=0),  # (K,)
                    "std":     np.nanstd(occ_raw_seed, axis=0, ddof=1) if occ_raw_seed.shape[0] > 1
                               else np.zeros(K)
                },
                "cusum": {
                    "by_seed": occ_cus_seed,
                    "mean":    np.nanmean(occ_cus_seed, axis=0),
                    "std":     np.nanstd(occ_cus_seed, axis=0, ddof=1) if occ_cus_seed.shape[0] > 1
                               else np.zeros(K)
                }
            }

            metrics = {
                "ARI_raw":  _mean_pairwise_ARI(Zr),
                "ARI_cusum": _mean_pairwise_ARI(Zc),
            }

            rec["batches"].append({
                "t0": int(b0), "t1": int(b1),
                "idx_slice": idx_slice,
                "seeds": seeds,
                "records": per_seed_records,
                "Z_raw":  Zr,
                "Z_cusum": Zc,
                "params_agg": params_agg,
                "occ": occ,
                "metrics": metrics,
            })
        
        out[sec] = rec

    return out

# %%
def print_seed_rolling_stability(rolled, security, batch_indices=None):
    """
    Pretty printer for stability:
      • Emissions & latent blocks: entries as mean (std) across seeds.
      • Regime occupancies per batch: mean% (std%).
      • ARI per batch: raw & cusum.
    Inputs
      rolled: dict returned by collect_seed_rolling_params
      security: key inside rolled
      batch_indices: optional list of batch indices to print (default: all)
    """
    import numpy as np

    rec = rolled.get(security)
    assert rec is not None, f"[print] security '{security}' not found"
    K = rec["meta"]["K"]; D = rec["meta"]["D"]; dt = rec["meta"]["dt"]; restricted = rec["meta"]["restricted"]
    B = len(rec["batches"])
    if batch_indices is None:
        batch_indices = list(range(B))

    def _fmt(m, s, fp=4):
        return f"{m: .{fp}f} ({s: .{fp}f})"

    def _pmat(mu, sd, label, semantic_key):
        shape_str = {
            "Cs": "(K_or_1, N, D)",
            "ds": "(K_or_1, N)",
            "inv_etas": "(K_or_1, N)",
            "As": "(K, D, D)",
            "bs": "(K, D)",
            "sigmasq": "(K, D)",
            "Rs": "(K, D)",
            "r": "(K,)",
        }[semantic_key]
        print(f"{label}  {shape_str} = {mu.shape}")
        if mu.ndim == 3:
            K0, R0, C0 = mu.shape
            for r in range(R0):
                line = ""
                for k in range(K0):
                    row_entries = []
                    for c in range(C0):
                        row_entries.append(_fmt(mu[k, r, c], sd[k, r, c]))
                    row_str = " ".join(row_entries)
                    line += f"[{row_str}]    "
                print(line)
        elif mu.ndim == 2:
            K0, C0 = mu.shape
            line = ""
            for k in range(K0):
                row_entries = [_fmt(mu[k, c], sd[k, c]) for c in range(C0)]
                line += f"[{' '.join(row_entries)}]" + "    "
            print(line)
        elif mu.ndim == 1:
            row_entries = [_fmt(mu[k], sd[k]) for k in range(mu.shape[0])]
            print(f"[{' '.join(row_entries)}]")
        print()

    for bi in batch_indices:
        b = rec["batches"][bi]
        t0, t1 = b["t0"], b["t1"]
        print("\n========== STABILITY (security={}, batch={}  t0={}  t1={}) ==========\n"
              .format(security, bi, t0, t1))

        P = b["params_agg"]
        _pmat(P["Cs"]["mean"],      P["Cs"]["std"],      "Cs",       "Cs")
        _pmat(P["ds"]["mean"],      P["ds"]["std"],      "ds",       "ds")
        _pmat(P["inv_etas"]["mean"],P["inv_etas"]["std"],"inv_etas", "inv_etas")
        _pmat(P["As"]["mean"],      P["As"]["std"],      "As",       "As")
        _pmat(P["bs"]["mean"],      P["bs"]["std"],      "bs",       "bs")
        _pmat(P["sigmasq"]["mean"], P["sigmasq"]["std"], "sigmasq",  "sigmasq")
        _pmat(P["Rs"]["mean"],      P["Rs"]["std"],      "Rs",       "Rs")
        _pmat(P["r"]["mean"],       P["r"]["std"],       "r",        "r")

        # interpretable AR(1) params (restricted models)
        if restricted:
            print("Interpretable AR(1) parameters (mean±std over seeds)")
            mu_As, sd_As   = P["As"]["mean"], P["As"]["std"]         # (K,D,D)
            mu_bs, sd_bs   = P["bs"]["mean"], P["bs"]["std"]         # (K,D)
            mu_sig, sd_sig = P["sigmasq"]["mean"], P["sigmasq"]["std"] # (K,D)
            eps = 1e-8
            for k in range(mu_As.shape[0]):
                print(f"Regime {k}:")
                for d in range(min(D, mu_As.shape[2])):
                    rho_m, rho_s = mu_As[k, d, d], sd_As[k, d, d]
                    b_m, b_s     = mu_bs[k, d],    sd_bs[k, d]
                    # μ = b / (1-ρ), Var_stat = σ²/(1-ρ²) for |ρ|<1
                    mu_stat_m = (b_m / (1.0 - rho_m)) if abs(1.0 - rho_m) > eps else np.nan
                    # delta-method-ish SD approximation (optional: coarse; keep concise)
                    mu_stat_s = np.nan
                    s2_m, s2_s = mu_sig[k, d], sd_sig[k, d]
                    var_stat_m = (s2_m / (1.0 - rho_m**2)) if abs(rho_m) < 1 else np.nan
                    var_stat_s = np.nan
                    # half-life in steps: log(2)/|log ρ|
                    if rho_m > 0 and abs(rho_m) < 1:
                        hl_steps_m = float(np.log(2.0) / abs(np.log(rho_m)))
                    else:
                        hl_steps_m = float("inf")
                    hl_years_m = (hl_steps_m * rec["meta"]["dt"]) if np.isfinite(hl_steps_m) else np.nan
                    print(f"  latent{d}: rho={_fmt(rho_m, rho_s)}  b={_fmt(b_m, b_s)}  "
                          f"mu_stat≈{mu_stat_m: .6f}  var_stat≈{var_stat_m: .6e}  "
                          f"half_life_steps≈{hl_steps_m: .2f}  half_life_years≈{hl_years_m: .4f}")
                print()

        # occupancy + ARI
        occ = b["occ"]
        raw_mean = (occ["raw"]["mean"] * 100.0).astype(float)
        raw_std  = (occ["raw"]["std"]  * 100.0).astype(float)
        cus_mean = (occ["cusum"]["mean"] * 100.0).astype(float)
        cus_std  = (occ["cusum"]["std"]  * 100.0).astype(float)

        def _fmt_occ(mean_vec, std_vec):
            return ", ".join([f"{mean_vec[j]:.1f}% ({std_vec[j]:.1f}%)" for j in range(mean_vec.size)])

        print("Occupancy per regime (mean% (std%) across seeds):")
        print(f"  RAW:   [{_fmt_occ(raw_mean,  raw_std)}]")
        print(f"  CUSUM: [{_fmt_occ(cus_mean, cus_std)}]")

        ARI_raw   = b["metrics"]["ARI_raw"]
        ARI_cusum = b["metrics"]["ARI_cusum"]
        print(f"ARI (mean pairwise across seeds):  RAW={ARI_raw:.3f}   CUSUM={ARI_cusum:.3f}")

# %%
securities = ["MSFT"]
# rolled = collect_seed_rolling_params(CONFIG, securities, n_runs=10, master_seed=123)
# print_seed_rolling_stability(rolled, "MSFT")
