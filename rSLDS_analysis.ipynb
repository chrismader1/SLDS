# %%
# Plot RelCAGR vs Delta ELBO and vs CPLL, CPLL Gap
# Smooth CPLL: conditional predictive log-likelihood; out-of-sample accuracy # Smooth CPLL: overestimates OOS accuracy due to look-ahead bias
# ELBO: Evidence lower bound; lower bound on the true log-likelihood (lowest start minus highest end accross all runs)

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import adjusted_rand_score as _ARI

# %%
# import data
filename_results = '/Users/chrismader/Python/SLDS/DRO/gridsearch_results TSM.csv'
filename_static = '/Users/chrismader/Python/SLDS/Data/static_data.csv'
res = pd.read_csv(filename_results)
static = pd.read_csv(filename_static, usecols=[0,1,2])

# %%
# Prep data
res['sector'] = res['security'].map(static.set_index('Ticker')['SectorID'])
res['CPLL Gap'] = res['max cpll (proxy bound, paired)'] - res['cpll (max all runs)']
res.insert(res.columns.get_loc('security') + 1, 'sector', res.pop('sector'))
res = res[np.isfinite(pd.to_numeric(res['cagr_rel_ex_ante'], errors='coerce'))].copy()
res = res[np.isfinite(pd.to_numeric(res['score'], errors='coerce'))].copy()

print(list(np.unique(res.config)))
print(list(np.unique(res.sector)))
print(list(np.unique(res.security)))
print(res.columns)

# Settings
configs = np.unique(res.config)
unrestricted = [x for x in configs if x.startswith('[')]
restricted = [x for x in configs if not x.startswith('[')]
print(unrestricted)
print(restricted)
# Out:
# ['[g,v,h]', '[g,v]', '[y,g,v,h]', '[y,h]', '[y]', 'factor1', 'factor1_vix', 'factor2_ff3', 'factor2_ff3mom', 'factor2_ff5', 'factor2_ff5mom', 'fund1', 'fund1_vix', 'fund2', 'fund2_vix', 'fund3', 'fund3_vix']
# ['IT']
# ['SEC', 'TSM']
# Index(['security', 'sector', 'config', 'rank', 'score', 'dt', 'n_regimes',
#        'dim_latent', 'single_subspace', 'train_window', 'overlap_window',
#        'avg_inferred_regime_length', 'elbo_start (min all runs)',
#        'elbo_end (max all runs)', 'elbo_delta (max all runs)',
#        'cpll (max all runs)', 'max cpll (proxy bound, paired)', 'mode_usage',
#        'cagr_rel', 'cagr_strat', 'cagr_bench', 'cagr_rel_cusum',
#        'cagr_strat_cusum', 'cagr_bench_cusum', 'cagr_rel_ex_ante',
#        'cagr_strat_ex_ante', 'cagr_bench_ex_ante', 'CPLL Gap'],
#       dtype='object')
# ['[g,v,h]', '[g,v]', '[y,g,v,h]', '[y,h]', '[y]']
# ['factor1', 'factor1_vix', 'factor2_ff3', 'factor2_ff3mom', 'factor2_ff5', 'factor2_ff5mom', 'fund1', 'fund1_vix', 'fund2', 'fund2_vix', 'fund3', 'fund3_vix']

# %%
# Helpers

def performance(df, value_sel):
    
    idx = ['config','n_regimes','dim_latent']
    sector_cols = sorted(df['sector'].unique())
    
    # sector means
    pt = (df.pivot_table(index=idx, columns='sector', values=value_sel, aggfunc='mean')
            .sort_index().reindex(sector_cols, axis=1))
    
    # true stats across ALL securities (not avg of sectors)
    stats = (df.groupby(idx)[value_sel]
               .agg(avg='mean', std='std', min='min', max='max'))
    stats['range'] = stats['max'] - stats['min']
    
    # join, order, sort
    finite_mask = np.isfinite(pt.to_numpy()).all(axis=1)
    pt_sel = (pt.loc[finite_mask]
                .join(stats, how='left')
                .loc[:, sector_cols + ['avg','std','min','max','range']]
                .sort_values('avg', ascending=False))
    
    # style
    styled = (pt_sel.style
               .format('{:.3f}')
               .background_gradient(cmap='RdBu', vmin=-0.1, vmax=0.1,
                                    subset=sector_cols + ['avg'])
               .highlight_null())
    
    # lock in order
    base_idx  = pt_sel.index                                 # exact rows + order
    cols_tail = ['avg','std','min','max','range']            # trailing stats
    cols_all = sector_cols + cols_tail                      # exact columns

    return styled, base_idx, cols_tail, cols_all
    
def metric_table(value_sel, df, base_idx, cols_tail, cols_all, vmin, vmax):

    # recover index/sector context from performance() output
    idx = list(base_idx.names)
    sector_cols = [c for c in cols_all if c not in cols_tail]
    
    # sector means for this metric (no sorting, no filtering)
    pt_m = (df.pivot_table(index=idx, columns='sector', values=value_sel, aggfunc='mean')
              .reindex(sector_cols, axis=1)              # same sector columns
              .reindex(base_idx))                        # SAME ROWS + ORDER as score

    # overall stats across ALL securities for this metric
    stats_m = (df.groupby(idx)[value_sel]
                 .agg(avg='mean', std='std', min='min', max='max'))
    stats_m['range'] = stats_m['max'] - stats_m['min']
    stats_m = stats_m.reindex(base_idx)                  # align rows/order

    # combine and enforce identical column order
    tbl = pd.concat([pt_m, stats_m[cols_tail]], axis=1).reindex(columns=cols_all)

    return (tbl.style
                .format('{:,.1f}')
                .background_gradient(cmap='RdBu', vmin=vmin, vmax=vmax, subset=sector_cols + ['avg'])
                .highlight_null())

# Formatting
CAPTION_CSS = [{'selector': 'caption',
                'props': [('caption-side','top'),
                          ('text-align','left'),
                          ('font-weight','700')]}]

# %%
# Model performance - unrestricted
df_unrestr = res[res['config'].isin(unrestricted)]
styled_unrestr, base_idx_unrestr, cols_tail_unrestr, cols_all_unrestr = performance(df_unrestr, 'cagr_rel_ex_ante')
styled_unrestr.set_caption("Rel CAGR - Unrestricted Models")
styled_unrestr.set_table_styles(CAPTION_CSS, overwrite=False)
styled_unrestr
# Out:
# <style type="text/css">
# #T_7d3fa caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_7d3fa_row0_col0, #T_7d3fa_row0_col1 {
#   background-color: #0e4179;
#   color: #f1f1f1;
# }
# #T_7d3fa_row1_col0, #T_7d3fa_row1_col1 {
#   background-color: #78b4d5;
#   color: #000000;
# }
# #T_7d3fa_row2_col0, #T_7d3fa_row2_col1, #T_7d3fa_row3_col0, #T_7d3fa_row3_col1 {
#   background-color: #8dc2dc;
#   color: #000000;
# }
# #T_7d3fa_row4_col0, #T_7d3fa_row4_col1 {
#   background-color: #93c6de;
#   color: #000000;
# }
# #T_7d3fa_row5_col0, #T_7d3fa_row5_col1 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_7d3fa_row6_col0, #T_7d3fa_row6_col1, #T_7d3fa_row7_col0, #T_7d3fa_row7_col1 {
#   background-color: #b1d5e7;
#   color: #000000;
# }
# #T_7d3fa_row8_col0, #T_7d3fa_row8_col1 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_7d3fa_row9_col0, #T_7d3fa_row9_col1 {
#   background-color: #c0dceb;
#   color: #000000;
# }
# #T_7d3fa_row10_col0, #T_7d3fa_row10_col1, #T_7d3fa_row11_col0, #T_7d3fa_row11_col1 {
#   background-color: #c2ddec;
#   color: #000000;
# }
# #T_7d3fa_row12_col0, #T_7d3fa_row12_col1 {
#   background-color: #d5e7f1;
#   color: #000000;
# }
# #T_7d3fa_row13_col0, #T_7d3fa_row13_col1 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_7d3fa_row14_col0, #T_7d3fa_row14_col1 {
#   background-color: #d8e9f1;
#   color: #000000;
# }
# #T_7d3fa_row15_col0, #T_7d3fa_row15_col1 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_7d3fa_row16_col0, #T_7d3fa_row16_col1 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_7d3fa_row17_col0, #T_7d3fa_row17_col1 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_7d3fa_row18_col0, #T_7d3fa_row18_col1 {
#   background-color: #e3edf3;
#   color: #000000;
# }
# #T_7d3fa_row19_col0, #T_7d3fa_row19_col1 {
#   background-color: #e9f0f4;
#   color: #000000;
# }
# #T_7d3fa_row20_col0, #T_7d3fa_row20_col1 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_7d3fa_row21_col0, #T_7d3fa_row21_col1 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_7d3fa_row22_col0, #T_7d3fa_row22_col1 {
#   background-color: #f7f6f6;
#   color: #000000;
# }
# #T_7d3fa_row23_col0, #T_7d3fa_row23_col1 {
#   background-color: #f8f2ef;
#   color: #000000;
# }
# #T_7d3fa_row24_col0, #T_7d3fa_row24_col1 {
#   background-color: #f9efe9;
#   color: #000000;
# }
# #T_7d3fa_row25_col0, #T_7d3fa_row25_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_7d3fa_row26_col0, #T_7d3fa_row26_col1 {
#   background-color: #fae8de;
#   color: #000000;
# }
# #T_7d3fa_row27_col0, #T_7d3fa_row27_col1 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_7d3fa_row28_col0, #T_7d3fa_row28_col1 {
#   background-color: #fcdfcf;
#   color: #000000;
# }
# #T_7d3fa_row29_col0, #T_7d3fa_row29_col1 {
#   background-color: #fcd3bc;
#   color: #000000;
# }
# #T_7d3fa_row30_col0, #T_7d3fa_row30_col1 {
#   background-color: #fbd0b9;
#   color: #000000;
# }
# #T_7d3fa_row31_col0, #T_7d3fa_row31_col1 {
#   background-color: #f9c4a9;
#   color: #000000;
# }
# #T_7d3fa_row32_col0, #T_7d3fa_row32_col1 {
#   background-color: #ef9979;
#   color: #000000;
# }
# #T_7d3fa_row33_col0, #T_7d3fa_row33_col1 {
#   background-color: #e27b62;
#   color: #f1f1f1;
# }
# #T_7d3fa_row34_col0, #T_7d3fa_row34_col1 {
#   background-color: #d86551;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7d3fa">
#   <caption>Rel CAGR - Unrestricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d3fa_level0_col0" class="col_heading level0 col0" >IT</th>
#       <th id="T_7d3fa_level0_col1" class="col_heading level0 col1" >avg</th>
#       <th id="T_7d3fa_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_7d3fa_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_7d3fa_level0_col4" class="col_heading level0 col4" >max</th>
#       <th id="T_7d3fa_level0_col5" class="col_heading level0 col5" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d3fa_level0_row0" class="row_heading level0 row0" >[y]</th>
#       <th id="T_7d3fa_level1_row0" class="row_heading level1 row0" >5</th>
#       <th id="T_7d3fa_level2_row0" class="row_heading level2 row0" >1</th>
#       <td id="T_7d3fa_row0_col0" class="data row0 col0" >0.093</td>
#       <td id="T_7d3fa_row0_col1" class="data row0 col1" >0.093</td>
#       <td id="T_7d3fa_row0_col2" class="data row0 col2" >0.004</td>
#       <td id="T_7d3fa_row0_col3" class="data row0 col3" >0.091</td>
#       <td id="T_7d3fa_row0_col4" class="data row0 col4" >0.096</td>
#       <td id="T_7d3fa_row0_col5" class="data row0 col5" >0.005</td>
#     </tr>
#     <tr>
#       <th id="T_7d3fa_level0_row1" class="row_heading level0 row1" >[y,h]</th>
#       <th id="T_7d3fa_level1_row1" class="row_heading level1 row1" >6</th>
#       <th id="T_7d3fa_level2_row1" class="row_heading level2 row1" >2</th>
#       <td id="T_7d3fa_row1_col0" class="data row1 col0" >0.047</td>
#       <td id="T_7d3fa_row1_col1" class="data row1 col1" >0.047</td>
#       <td id="T_7d3fa_row1_col2" class="data row1 col2" >0.042</td>
#       <td id="T_7d3fa_row1_col3" class="data row1 col3" >0.017</td>
#       <td id="T_7d3fa_row1_col4" class="data row1 col4" >0.077</td>
#       <td id="T_7d3fa_row1_col5" class="data row1 col5" >0.060</td>
#     </tr>
#     <tr>
#       <th id="T_7d3fa_level0_row2" class="row_heading level0 row2" >[g,v]</th>
#       <th id="T_7d3fa_level1_row2" class="row_heading level1 row2" >4</th>
#       <th id="T_7d3fa_level2_row2" class="row_heading level2 row2" >2</th>
#       <td id="T_7d3fa_row2_col0" class="data row2 col0" >0.041</td>
#       <td id="T_7d3fa_row2_col1" class="data row2 col1" >0.041</td>
#       <td id="T_7d3fa_row2_col2" class="data row2 col2" >0.006</td>
#       <td id="T_7d3fa_row2_col3" class="data row2 col3" >0.037</td>
#       <td id="T_7d3fa_row2_col4" class="data row2 col4" >0.045</td>
#       <td id="T_7d3fa_row2_col5" class="data row2 col5" >0.008</td>
#     </tr>
#     <tr>
#       <th id="T_7d3fa_level0_row3" class="row_heading level0 row3" >[y]</th>
#       <th id="T_7d3fa_level1_row3" class="row_heading level1 row3" >6</th>
#       <th id="T_7d3fa_level2_row3" class="row_heading level2 row3" >1</th>
#       <td id="T_7d3fa_row3_col0" class="data row3 col0" >0.041</td>
#       <td id="T_7d3fa_row3_col1" class="data row3 col1" >0.041</td>
#       <td id="T_7d3fa_row3_col2" class="data row3 col2" >0.019</td>
#       <td id="T_7d3fa_row3_col3" class="data row3 col3" >0.028</td>
#       <td id="T_7d3fa_row3_col4" class="data row3 col4" >0.054</td>
#       <td id="T_7d3fa_row3_col5" class="data row3 col5" >0.027</td>
#     </tr>
#     <tr>
#       <th id="T_7d3fa_level0_row4" class="row_heading level0 row4" >[y,g,v,h]</th>
#       <th id="T_7d3fa_level1_row4" class="row_heading level1 row4" >5</th>
#       <th id="T_7d3fa_level2_row4" class="row_heading level2 row4" >4</th>
#       <td id="T_7d3fa_row4_col0" class="data row4 col0" >0.040</td>
#       <td id="T_7d3fa_row4_col1" class="data row4 col1" >0.040</td>
#       <td id="T_7d3fa_row4_col2" class="data row4 col2" >0.009</td>
#       <td id="T_7d3fa_row4_col3" class="data row4 col3" >0.033</td>
#       <td id="T_7d3fa_row4_col4" class="data row4 col4" >0.046</td>
#       <td id="T_7d3fa_row4_col5" class="data row4 col5" >0.013</td>
#     </tr>
#     <tr>
#       <th id="T_7d3fa_level0_row5" class="row_heading level0 row5" >[y]</th>
#       <th id="T_7d3fa_level1_row5" class="row_heading level1 row5" >3</th>
#       <th id="T_7d3fa_level2_row5" class="row_heading level2 row5" >1</th>
#       <td id="T_7d3fa_row5_col0" class="data row5 col0" >0.035</td>
#       <td id="T_7d3fa_row5_col1" class="data row5 col1" >0.035</td>
#       <td id="T_7d3fa_row5_col2" class="data row5 col2

# %%
# Smooth CPLL - unrestricted
styled_cpll_all = metric_table('CPLL Gap', df_unrestr, base_idx_unrestr, cols_tail_unrestr, cols_all_unrestr, vmin=-100000,  vmax=100000)
styled_cpll_all.set_caption("Smooth CPLL Gap - Unrestricted Models")
styled_cpll_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_cpll_all
# Out:
# <style type="text/css">
# #T_fe606 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_fe606_row0_col0, #T_fe606_row0_col1, #T_fe606_row3_col0, #T_fe606_row3_col1, #T_fe606_row5_col0, #T_fe606_row5_col1, #T_fe606_row19_col0, #T_fe606_row19_col1, #T_fe606_row28_col0, #T_fe606_row28_col1 {
#   background-color: #c2ddec;
#   color: #000000;
# }
# #T_fe606_row1_col0, #T_fe606_row1_col1, #T_fe606_row6_col0, #T_fe606_row6_col1, #T_fe606_row15_col0, #T_fe606_row15_col1, #T_fe606_row26_col0, #T_fe606_row26_col1, #T_fe606_row27_col0, #T_fe606_row27_col1 {
#   background-color: #8dc2dc;
#   color: #000000;
# }
# #T_fe606_row2_col0, #T_fe606_row2_col1, #T_fe606_row8_col0, #T_fe606_row8_col1, #T_fe606_row10_col0, #T_fe606_row10_col1, #T_fe606_row21_col0, #T_fe606_row21_col1, #T_fe606_row29_col0, #T_fe606_row29_col1 {
#   background-color: #59a1ca;
#   color: #f1f1f1;
# }
# #T_fe606_row4_col0, #T_fe606_row4_col1, #T_fe606_row7_col0, #T_fe606_row7_col1, #T_fe606_row12_col0, #T_fe606_row12_col1, #T_fe606_row13_col0, #T_fe606_row13_col1, #T_fe606_row16_col0, #T_fe606_row16_col1, #T_fe606_row18_col0, #T_fe606_row18_col1, #T_fe606_row23_col0, #T_fe606_row23_col1, #T_fe606_row30_col0, #T_fe606_row30_col1, #T_fe606_row31_col0, #T_fe606_row31_col1, #T_fe606_row32_col0, #T_fe606_row32_col1 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_fe606_row9_col0, #T_fe606_row9_col1, #T_fe606_row11_col0, #T_fe606_row11_col1, #T_fe606_row14_col0, #T_fe606_row14_col1, #T_fe606_row17_col0, #T_fe606_row17_col1, #T_fe606_row20_col0, #T_fe606_row20_col1, #T_fe606_row22_col0, #T_fe606_row22_col1, #T_fe606_row24_col0, #T_fe606_row24_col1, #T_fe606_row25_col0, #T_fe606_row25_col1, #T_fe606_row33_col0, #T_fe606_row33_col1, #T_fe606_row34_col0, #T_fe606_row34_col1 {
#   background-color: #307ab6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fe606">
#   <caption>Smooth CPLL Gap - Unrestricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe606_level0_col0" class="col_heading level0 col0" >IT</th>
#       <th id="T_fe606_level0_col1" class="col_heading level0 col1" >avg</th>
#       <th id="T_fe606_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_fe606_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_fe606_level0_col4" class="col_heading level0 col4" >max</th>
#       <th id="T_fe606_level0_col5" class="col_heading level0 col5" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe606_level0_row0" class="row_heading level0 row0" >[y]</th>
#       <th id="T_fe606_level1_row0" class="row_heading level1 row0" >5</th>
#       <th id="T_fe606_level2_row0" class="row_heading level2 row0" >1</th>
#       <td id="T_fe606_row0_col0" class="data row0 col0" >24,829.2</td>
#       <td id="T_fe606_row0_col1" class="data row0 col1" >24,829.2</td>
#       <td id="T_fe606_row0_col2" class="data row0 col2" >43.1</td>
#       <td id="T_fe606_row0_col3" class="data row0 col3" >24,798.7</td>
#       <td id="T_fe606_row0_col4" class="data row0 col4" >24,859.7</td>
#       <td id="T_fe606_row0_col5" class="data row0 col5" >61.0</td>
#     </tr>
#     <tr>
#       <th id="T_fe606_level0_row1" class="row_heading level0 row1" >[y,h]</th>
#       <th id="T_fe606_level1_row1" class="row_heading level1 row1" >6</th>
#       <th id="T_fe606_level2_row1" class="row_heading level2 row1" >2</th>
#       <td id="T_fe606_row1_col0" class="data row1 col0" >40,990.1</td>
#       <td id="T_fe606_row1_col1" class="data row1 col1" >40,990.1</td>
#       <td id="T_fe606_row1_col2" class="data row1 col2" >39.9</td>
#       <td id="T_fe606_row1_col3" class="data row1 col3" >40,961.9</td>
#       <td id="T_fe606_row1_col4" class="data row1 col4" >41,018.2</td>
#       <td id="T_fe606_row1_col5" class="data row1 col5" >56.4</td>
#     </tr>
#     <tr>
#       <th id="T_fe606_level0_row2" class="row_heading level0 row2" >[g,v]</th>
#       <th id="T_fe606_level1_row2" class="row_heading level1 row2" >4</th>
#       <th id="T_fe606_level2_row2" class="row_heading level2 row2" >2</th>
#       <td id="T_fe606_row2_col0" class="data row2 col0" >54,503.8</td>
#       <td id="T_fe606_row2_col1" class="data row2 col1" >54,503.8</td>
#       <td id="T_fe606_row2_col2" class="data row2 col2" >1,588.1</td>
#       <td id="T_fe606_row2_col3" class="data row2 col3" >53,380.8</td>
#       <td id="T_fe606_row2_col4" class="data row2 col4" >55,626.7</td>
#       <td id="T_fe606_row2_col5" class="data row2 col5" >2,245.9</td>
#     </tr>
#     <tr>
#       <th id="T_fe606_level0_row3" class="row_heading level0 row3" >[y]</th>
#       <th id="T_fe606_level1_row3" class="row_heading level1 row3" >6</th>
#       <th id="T_fe606_level2_row3" class="row_heading level2 row3" >1</th>
#       <td id="T_fe606_row3_col0" class="data row3 col0" >24,829.2</td>
#       <td id="T_fe606_row3_col1" class="data row3 col1" >24,829.2</td>
#       <td id="T_fe606_row3_col2" class="data row3 col2" >42.8</td>
#       <td id="T_fe606_row3_col3" class="data row3 col3" >24,798.9</td>
#       <td id="T_fe606_row3_col4" class="data row3 col4" >24,859.5</td>
#       <td id="T_fe606_row3_col5" class="data row3 col5" >60.6</td>
#     </tr>
#     <tr>
#       <th id="T_fe606_level0_row4" class="row_heading level0 row4" >[y,g,v,h]</th>
#       <th id="T_fe606_level1_row4" class="row_heading level1 row4" >5</th>
#       <th id="T_fe606_level2_row4" class="row_heading level2 row4" >4</th>
#       <td id="T_fe606_row4_col0" class="data row4 col0" >122,748.7</td>
#       <td id="T_fe606_row4_col1" class="data row4 col1" >122,748.7</td>
#       <td id="T_fe606_row4_col2" class="data row4 col2" >1,516.5</td>
#       <td id="T_fe606_row4_col3" class="data row4 col3" >121,676.4</td>
#       <td id="T_fe606_row4_col4" class="data row4 col4" >123,821.1</td>
#       <td id="T_fe606_row4_col5" class="data row4 col5" >2,144.7</td>
#     </tr>
#     <tr>
#       <th id="T_fe606_level0_row5" class="row_heading level0 row5" >[y]</th>
#       <th id="T_fe606_level1_row5" class="row_heading level1 row5" >3</th>
#       <th id="T_fe606_level2_row5" class="row_heading level2 row5" >1</th>
#       <td id="T_fe606_row5_col0" class="data row5 col0" >24,829.2</td>
#       <td id="T_fe606_row5_col1" class="data row5 col1" >24,829.2</td>
#       <td id="T_fe606_row5_col2" class="data row5 col2" >44.3</td>
#       <td id="T_fe606_row5_col3" class="data row5 col3" >24,797.9</td>
#       <td id="T_fe606_row5_col4" class="data row5 col4" >24,860.5</td>
#       <td id="T_fe606_row5_col5" class="data row5 col5" >62.6</td>
#     </tr>
#     <tr>
#       <th id="T_fe606_level0_row6" class="row_heading level0 row6" >[y,h]</th>
#       <th id="T_fe606_level1_row6" class="row_heading level1 row6" >5</th>
#       <th id="T_fe606_level2_row6" class="row_heading level2 row6" >2</th>
#       <td id="T_fe606_row6_col0" class="data row6 col0" >40,990.7</td>
#       <td id="T_fe606_row6_col1" class="data row6 col1" >40,990.7</td>
#       <td id="T_fe606_row6_col2" class="data row6 col2" >39.0</td>
#       <td id="T_fe606_row6_col3" class="data row6 col3" >40,963.1</td>
#       <td id="T_fe606_row6_col4" class="data row6 col4" >41,018.3</td>
#       <td id="T_fe606_row6_col5" class="data row6 col5" >55.2</td>
#     </tr>
#     <tr>
#       <th id="T_fe606_level0_row7" class="row_heading level0 row7" >[y,g,v,h]</th>
#       <th id="T_fe606_level1_row7" class="row_heading level1 row7" >6</th>
#       <th id="T_fe606_level2_row7" class="row_heading level2 row7" >3</th>
#       <td id="T_fe606_row7_col0" class="data row7 col0" >122,744.8</td>
#       <td id="T_fe606_row7_col1" class="data row7 col1" >12

# %%
# Delta ELBO - unrestricted
styled_elbo_all = metric_table('elbo_delta (max all runs)', df_unrestr, base_idx_unrestr, cols_tail_unrestr, cols_all_unrestr, vmin=-1000000, vmax=1000000)
styled_elbo_all.set_caption("Delta ELBO - Unrestricted Models")
styled_elbo_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_elbo_all
# Out:
# <style type="text/css">
# #T_9940d caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_9940d_row0_col0, #T_9940d_row0_col1, #T_9940d_row3_col0, #T_9940d_row3_col1, #T_9940d_row19_col0, #T_9940d_row19_col1 {
#   background-color: #ddebf2;
#   color: #000000;
# }
# #T_9940d_row1_col0, #T_9940d_row1_col1, #T_9940d_row6_col0, #T_9940d_row6_col1, #T_9940d_row15_col0, #T_9940d_row15_col1, #T_9940d_row26_col0, #T_9940d_row26_col1 {
#   background-color: #a0cce2;
#   color: #000000;
# }
# #T_9940d_row2_col0, #T_9940d_row2_col1, #T_9940d_row8_col0, #T_9940d_row8_col1, #T_9940d_row10_col0, #T_9940d_row10_col1, #T_9940d_row21_col0, #T_9940d_row21_col1, #T_9940d_row24_col0, #T_9940d_row24_col1, #T_9940d_row29_col0, #T_9940d_row29_col1 {
#   background-color: #bbdaea;
#   color: #000000;
# }
# #T_9940d_row4_col0, #T_9940d_row4_col1 {
#   background-color: #3f8ec0;
#   color: #f1f1f1;
# }
# #T_9940d_row5_col0, #T_9940d_row5_col1, #T_9940d_row28_col0, #T_9940d_row28_col1 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_9940d_row7_col0, #T_9940d_row7_col1, #T_9940d_row18_col0, #T_9940d_row18_col1, #T_9940d_row23_col0, #T_9940d_row23_col1, #T_9940d_row32_col0, #T_9940d_row32_col1 {
#   background-color: #8dc2dc;
#   color: #000000;
# }
# #T_9940d_row9_col0, #T_9940d_row9_col1, #T_9940d_row11_col0, #T_9940d_row11_col1, #T_9940d_row17_col0, #T_9940d_row17_col1, #T_9940d_row33_col0, #T_9940d_row33_col1 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# #T_9940d_row12_col0, #T_9940d_row12_col1, #T_9940d_row31_col0, #T_9940d_row31_col1 {
#   background-color: #408fc1;
#   color: #f1f1f1;
# }
# #T_9940d_row13_col0, #T_9940d_row13_col1, #T_9940d_row16_col0, #T_9940d_row16_col1 {
#   background-color: #4393c3;
#   color: #f1f1f1;
# }
# #T_9940d_row14_col0, #T_9940d_row14_col1 {
#   background-color: #6eaed2;
#   color: #f1f1f1;
# }
# #T_9940d_row20_col0, #T_9940d_row20_col1, #T_9940d_row22_col0, #T_9940d_row22_col1, #T_9940d_row34_col0, #T_9940d_row34_col1 {
#   background-color: #71b0d3;
#   color: #f1f1f1;
# }
# #T_9940d_row25_col0, #T_9940d_row25_col1 {
#   background-color: #75b2d4;
#   color: #f1f1f1;
# }
# #T_9940d_row27_col0, #T_9940d_row27_col1 {
#   background-color: #a2cde3;
#   color: #000000;
# }
# #T_9940d_row30_col0, #T_9940d_row30_col1 {
#   background-color: #90c4dd;
#   color: #000000;
# }
# </style>
# <table id="T_9940d">
#   <caption>Delta ELBO - Unrestricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9940d_level0_col0" class="col_heading level0 col0" >IT</th>
#       <th id="T_9940d_level0_col1" class="col_heading level0 col1" >avg</th>
#       <th id="T_9940d_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_9940d_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_9940d_level0_col4" class="col_heading level0 col4" >max</th>
#       <th id="T_9940d_level0_col5" class="col_heading level0 col5" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9940d_level0_row0" class="row_heading level0 row0" >[y]</th>
#       <th id="T_9940d_level1_row0" class="row_heading level1 row0" >5</th>
#       <th id="T_9940d_level2_row0" class="row_heading level2 row0" >1</th>
#       <td id="T_9940d_row0_col0" class="data row0 col0" >135,775.3</td>
#       <td id="T_9940d_row0_col1" class="data row0 col1" >135,775.3</td>
#       <td id="T_9940d_row0_col2" class="data row0 col2" >4,324.7</td>
#       <td id="T_9940d_row0_col3" class="data row0 col3" >132,717.3</td>
#       <td id="T_9940d_row0_col4" class="data row0 col4" >138,833.3</td>
#       <td id="T_9940d_row0_col5" class="data row0 col5" >6,116.0</td>
#     </tr>
#     <tr>
#       <th id="T_9940d_level0_row1" class="row_heading level0 row1" >[y,h]</th>
#       <th id="T_9940d_level1_row1" class="row_heading level1 row1" >6</th>
#       <th id="T_9940d_level2_row1" class="row_heading level2 row1" >2</th>
#       <td id="T_9940d_row1_col0" class="data row1 col0" >359,099.6</td>
#       <td id="T_9940d_row1_col1" class="data row1 col1" >359,099.6</td>
#       <td id="T_9940d_row1_col2" class="data row1 col2" >2,015.2</td>
#       <td id="T_9940d_row1_col3" class="data row1 col3" >357,674.6</td>
#       <td id="T_9940d_row1_col4" class="data row1 col4" >360,524.5</td>
#       <td id="T_9940d_row1_col5" class="data row1 col5" >2,849.9</td>
#     </tr>
#     <tr>
#       <th id="T_9940d_level0_row2" class="row_heading level0 row2" >[g,v]</th>
#       <th id="T_9940d_level1_row2" class="row_heading level1 row2" >4</th>
#       <th id="T_9940d_level2_row2" class="row_heading level2 row2" >2</th>
#       <td id="T_9940d_row2_col0" class="data row2 col0" >273,269.0</td>
#       <td id="T_9940d_row2_col1" class="data row2 col1" >273,269.0</td>
#       <td id="T_9940d_row2_col2" class="data row2 col2" >3,976.4</td>
#       <td id="T_9940d_row2_col3" class="data row2 col3" >270,457.3</td>
#       <td id="T_9940d_row2_col4" class="data row2 col4" >276,080.8</td>
#       <td id="T_9940d_row2_col5" class="data row2 col5" >5,623.5</td>
#     </tr>
#     <tr>
#       <th id="T_9940d_level0_row3" class="row_heading level0 row3" >[y]</th>
#       <th id="T_9940d_level1_row3" class="row_heading level1 row3" >6</th>
#       <th id="T_9940d_level2_row3" class="row_heading level2 row3" >1</th>
#       <td id="T_9940d_row3_col0" class="data row3 col0" >136,592.9</td>
#       <td id="T_9940d_row3_col1" class="data row3 col1" >136,592.9</td>
#       <td id="T_9940d_row3_col2" class="data row3 col2" >1,049.2</td>
#       <td id="T_9940d_row3_col3" class="data row3 col3" >135,851.1</td>
#       <td id="T_9940d_row3_col4" class="data row3 col4" >137,334.8</td>
#       <td id="T_9940d_row3_col5" class="data row3 col5" >1,483.7</td>
#     </tr>
#     <tr>
#       <th id="T_9940d_level0_row4" class="row_heading level0 row4" >[y,g,v,h]</th>
#       <th id="T_9940d_level1_row4" class="row_heading level1 row4" >5</th>
#       <th id="T_9940d_level2_row4" class="row_heading level2 row4" >4</th>
#       <td id="T_9940d_row4_col0" class="data row4 col0" >618,340.3</td>
#       <td id="T_9940d_row4_col1" class="data row4 col1" >618,340.3</td>
#       <td id="T_9940d_row4_col2" class="data row4 col2" >17,853.7</td>
#       <td id="T_9940d_row4_col3" class="data row4 col3" >605,715.8</td>
#       <td id="T_9940d_row4_col4" class="data row4 col4" >630,964.7</td>
#       <td id="T_9940d_row4_col5" class="data row4 col5" >25,248.9</td>
#     </tr>
#     <tr>
#       <th id="T_9940d_level0_row5" class="row_heading level0 row5" >[y]</th>
#       <th id="T_9940d_level1_row5" class="row_heading level1 row5" >3</th>
#       <th id="T_9940d_level2_row5" class="row_heading level2 row5" >1</th>
#       <td id="T_9940d_row5_col0" class="data row5 col0" >142,627.6</td>
#       <td id="T_9940d_row5_col1" class="data row5 col1" >142,627.6</td>
#       <td id="T_9940d_row5_col2" class="data row5 col2" >277.5</td>
#       <td id="T_9940d_row5_col3" class="data row5 col3" >142,431.4</td>
#       <td id="T_9940d_row5_col4" class="data row5 col4" >142,823.8</td>
#       <td id="T_9940d_row5_col5" class="data row5 col5" >392.4</td>
#     </tr>
#     <tr>
#       <th id="T_9940d_level0_row6" class="row_heading level0 row6" >[y,h]</th>
#       <th id="T_9940d_level1_row6" class="row_heading level1 row6" >5</th>
#       <th id="T_9940d_level2_row6" class="row_heading level2 row6" >2</th>
#       <td id="T_9940d_row6_col0" class="data row6 col0" >354,041.5</td>
#       <td id="T_9940d_row6_col1" class="data row6 col1" >354,041.5</td>
#       <td id="T_9940d_row6_col2" class="data row6 col2" >14,617.1</td>
#       <td id="T_9940d_row6_col3" class="data row6 col3" >343,705.6</td>
#       <td id="T_9940d_row6_

# %%
# Model performance - restricted
df_restr = res[res['config'].isin(restricted)]
styled_restr, base_idx_restr, cols_tail_restr, cols_all_restr = performance(df_restr, 'cagr_rel_ex_ante')
styled_restr.set_caption("Rel CAGR - Restricted Models")
styled_restr.set_table_styles(CAPTION_CSS, overwrite=False)
styled_restr
# Out:
# <style type="text/css">
# #T_58385 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_58385_row0_col0, #T_58385_row0_col1 {
#   background-color: #1e61a5;
#   color: #f1f1f1;
# }
# #T_58385_row1_col0, #T_58385_row1_col1 {
#   background-color: #3885bc;
#   color: #f1f1f1;
# }
# #T_58385_row2_col0, #T_58385_row2_col1 {
#   background-color: #4c99c6;
#   color: #f1f1f1;
# }
# #T_58385_row3_col0, #T_58385_row3_col1 {
#   background-color: #569fc9;
#   color: #f1f1f1;
# }
# #T_58385_row4_col0, #T_58385_row4_col1 {
#   background-color: #6eaed2;
#   color: #f1f1f1;
# }
# #T_58385_row5_col0, #T_58385_row5_col1 {
#   background-color: #78b4d5;
#   color: #000000;
# }
# #T_58385_row6_col0, #T_58385_row6_col1 {
#   background-color: #90c4dd;
#   color: #000000;
# }
# #T_58385_row7_col0, #T_58385_row7_col1 {
#   background-color: #93c6de;
#   color: #000000;
# }
# #T_58385_row8_col0, #T_58385_row8_col1 {
#   background-color: #9bc9e0;
#   color: #000000;
# }
# #T_58385_row9_col0, #T_58385_row9_col1, #T_58385_row10_col0, #T_58385_row10_col1 {
#   background-color: #a5cee3;
#   color: #000000;
# }
# #T_58385_row11_col0, #T_58385_row11_col1 {
#   background-color: #b1d5e7;
#   color: #000000;
# }
# #T_58385_row12_col0, #T_58385_row12_col1 {
#   background-color: #b6d7e8;
#   color: #000000;
# }
# #T_58385_row13_col0, #T_58385_row13_col1 {
#   background-color: #cce2ef;
#   color: #000000;
# }
# #T_58385_row14_col0, #T_58385_row14_col1 {
#   background-color: #cfe4ef;
#   color: #000000;
# }
# #T_58385_row15_col0, #T_58385_row15_col1 {
#   background-color: #d1e5f0;
#   color: #000000;
# }
# #T_58385_row16_col0, #T_58385_row16_col1 {
#   background-color: #d4e6f1;
#   color: #000000;
# }
# #T_58385_row17_col0, #T_58385_row17_col1, #T_58385_row18_col0, #T_58385_row18_col1 {
#   background-color: #d7e8f1;
#   color: #000000;
# }
# #T_58385_row19_col0, #T_58385_row19_col1, #T_58385_row20_col0, #T_58385_row20_col1, #T_58385_row21_col0, #T_58385_row21_col1 {
#   background-color: #dae9f2;
#   color: #000000;
# }
# #T_58385_row22_col0, #T_58385_row22_col1 {
#   background-color: #dbeaf2;
#   color: #000000;
# }
# #T_58385_row23_col0, #T_58385_row23_col1 {
#   background-color: #deebf2;
#   color: #000000;
# }
# #T_58385_row24_col0, #T_58385_row24_col1 {
#   background-color: #e0ecf3;
#   color: #000000;
# }
# #T_58385_row25_col0, #T_58385_row25_col1 {
#   background-color: #e1edf3;
#   color: #000000;
# }
# #T_58385_row26_col0, #T_58385_row26_col1 {
#   background-color: #e4eef4;
#   color: #000000;
# }
# #T_58385_row27_col0, #T_58385_row27_col1 {
#   background-color: #e7f0f4;
#   color: #000000;
# }
# #T_58385_row28_col0, #T_58385_row28_col1 {
#   background-color: #eaf1f5;
#   color: #000000;
# }
# #T_58385_row29_col0, #T_58385_row29_col1 {
#   background-color: #ecf2f5;
#   color: #000000;
# }
# #T_58385_row30_col0, #T_58385_row30_col1, #T_58385_row31_col0, #T_58385_row31_col1, #T_58385_row32_col0, #T_58385_row32_col1 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_58385_row33_col0, #T_58385_row33_col1, #T_58385_row34_col0, #T_58385_row34_col1 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_58385_row35_col0, #T_58385_row35_col1, #T_58385_row36_col0, #T_58385_row36_col1 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_58385_row37_col0, #T_58385_row37_col1, #T_58385_row38_col0, #T_58385_row38_col1 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_58385_row39_col0, #T_58385_row39_col1, #T_58385_row40_col0, #T_58385_row40_col1 {
#   background-color: #f7f5f4;
#   color: #000000;
# }
# #T_58385_row41_col0, #T_58385_row41_col1 {
#   background-color: #f8f3f0;
#   color: #000000;
# }
# #T_58385_row42_col0, #T_58385_row42_col1 {
#   background-color: #f9f0eb;
#   color: #000000;
# }
# #T_58385_row43_col0, #T_58385_row43_col1 {
#   background-color: #f9ede5;
#   color: #000000;
# }
# #T_58385_row44_col0, #T_58385_row44_col1 {
#   background-color: #f9ebe3;
#   color: #000000;
# }
# #T_58385_row45_col0, #T_58385_row45_col1 {
#   background-color: #fae7dc;
#   color: #000000;
# }
# #T_58385_row46_col0, #T_58385_row46_col1 {
#   background-color: #fbe6da;
#   color: #000000;
# }
# #T_58385_row47_col0, #T_58385_row47_col1 {
#   background-color: #fbe5d8;
#   color: #000000;
# }
# #T_58385_row48_col0, #T_58385_row48_col1 {
#   background-color: #fdddcb;
#   color: #000000;
# }
# #T_58385_row49_col0, #T_58385_row49_col1 {
#   background-color: #fddbc7;
#   color: #000000;
# }
# #T_58385_row50_col0, #T_58385_row50_col1 {
#   background-color: #fcd3bc;
#   color: #000000;
# }
# #T_58385_row51_col0, #T_58385_row51_col1 {
#   background-color: #f8bda1;
#   color: #000000;
# }
# #T_58385_row52_col0, #T_58385_row52_col1 {
#   background-color: #f7b799;
#   color: #000000;
# }
# #T_58385_row53_col0, #T_58385_row53_col1 {
#   background-color: #f6b394;
#   color: #000000;
# }
# #T_58385_row54_col0, #T_58385_row54_col1 {
#   background-color: #f6b191;
#   color: #000000;
# }
# #T_58385_row55_col0, #T_58385_row55_col1 {
#   background-color: #f3a481;
#   color: #000000;
# }
# #T_58385_row56_col0, #T_58385_row56_col1 {
#   background-color: #f19e7d;
#   color: #000000;
# }
# #T_58385_row57_col0, #T_58385_row57_col1 {
#   background-color: #ec9374;
#   color: #f1f1f1;
# }
# #T_58385_row58_col0, #T_58385_row58_col1 {
#   background-color: #d55d4c;
#   color: #f1f1f1;
# }
# #T_58385_row59_col0, #T_58385_row59_col1 {
#   background-color: #d05548;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_58385">
#   <caption>Rel CAGR - Restricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58385_level0_col0" class="col_heading level0 col0" >IT</th>
#       <th id="T_58385_level0_col1" class="col_heading level0 col1" >avg</th>
#       <th id="T_58385_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_58385_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_58385_level0_col4" class="col_heading level0 col4" >max</th>
#       <th id="T_58385_level0_col5" class="col_heading level0 col5" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58385_level0_row0" class="row_heading level0 row0" rowspan="2">factor2_ff3</th>
#       <th id="T_58385_level1_row0" class="row_heading level1 row0" >3</th>
#       <th id="T_58385_level2_row0" class="row_heading level2 row0" >3</th>
#       <td id="T_58385_row0_col0" class="data row0 col0" >0.082</td>
#       <td id="T_58385_row0_col1" class="data row0 col1" >0.082</td>
#       <td id="T_58385_row0_col2" class="data row0 col2" >0.064</td>
#       <td id="T_58385_row0_col3" class="data row0 col3" >0.036</td>
#       <td id="T_58385_row0_col4" class="data row0 col4" >0.127</td>
#       <td id="T_58385_row0_col5" class="data row0 col5" >0.091</td>
#     </tr>
#     <tr>
#       <th id="T_58385_level1_row1" class="row_heading level1 row1" >4</th>
#       <th id="T_58385_level2_row1" class="row_heading level2 row1" >3</th>
#       <td id="T_58385_row1_col0" class="data row1 col0" >0.066</td>
#       <td id="T_58385_row1_col1" class="data row1 col1" >0.066</td>
#       <td id="T_58385_row1_col2" class="data row1 col2" >0.078</td>
#       <td id="T_58385_row1_col3" class="data row1 col3" >0.011</td>
#       <td id="T_58385_row1_col4" class="data row1 col4" >0.121</td>
#       <td id="T_58385_row1_col5" class="data row1 col5" >0.110</td>
#     </tr>
#     <tr>
#       <th id="T_58385_level0_row2" class="row_heading level0 row2" >factor2_ff3mom</th>
#       <th id="T_58385_level1_row2" class="row_heading level1 row2" >6</th>
#       <th id="T_58385_level2_row2" class="row_heading level2 row2" >4</th>
#       <td id="T_58385_row2_col0" class="data row2 col0" >0.057</td>
#       <td id="T_58385_row2_col1" class="data row2 col1" >0.057</td>
#       <td id="T_58385_row2_col2" class="data row2 col2" >0.031</td>
#       <td id="T_58385_row2_col3" class="data row2 col3" >

# %%
# Smooth CPLL
styled_cpll_all = metric_table('CPLL Gap', df_restr, base_idx_restr, cols_tail_restr, cols_all_restr, vmin=-100000,  vmax=100000)
styled_cpll_all.set_caption("Smooth CPLL - Restricted Models")
styled_cpll_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_cpll_all
# Out:
# <style type="text/css">
# #T_27a6a caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_27a6a_row0_col0, #T_27a6a_row0_col1, #T_27a6a_row1_col0, #T_27a6a_row1_col1, #T_27a6a_row4_col0, #T_27a6a_row4_col1, #T_27a6a_row6_col0, #T_27a6a_row6_col1, #T_27a6a_row11_col0, #T_27a6a_row11_col1, #T_27a6a_row22_col0, #T_27a6a_row22_col1, #T_27a6a_row29_col0, #T_27a6a_row29_col1 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_27a6a_row2_col0, #T_27a6a_row2_col1, #T_27a6a_row25_col0, #T_27a6a_row25_col1, #T_27a6a_row27_col0, #T_27a6a_row27_col1, #T_27a6a_row34_col0, #T_27a6a_row34_col1, #T_27a6a_row39_col0, #T_27a6a_row39_col1, #T_27a6a_row44_col0, #T_27a6a_row44_col1 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_27a6a_row3_col0, #T_27a6a_row3_col1, #T_27a6a_row7_col0, #T_27a6a_row7_col1, #T_27a6a_row16_col0, #T_27a6a_row16_col1, #T_27a6a_row46_col0, #T_27a6a_row46_col1, #T_27a6a_row48_col0, #T_27a6a_row48_col1 {
#   background-color: #f0f4f6;
#   color: #000000;
# }
# #T_27a6a_row5_col0, #T_27a6a_row5_col1, #T_27a6a_row8_col0, #T_27a6a_row8_col1, #T_27a6a_row9_col0, #T_27a6a_row9_col1, #T_27a6a_row12_col0, #T_27a6a_row12_col1, #T_27a6a_row13_col0, #T_27a6a_row13_col1, #T_27a6a_row17_col0, #T_27a6a_row17_col1, #T_27a6a_row18_col0, #T_27a6a_row18_col1, #T_27a6a_row19_col0, #T_27a6a_row19_col1, #T_27a6a_row26_col0, #T_27a6a_row26_col1, #T_27a6a_row28_col0, #T_27a6a_row28_col1, #T_27a6a_row31_col0, #T_27a6a_row31_col1, #T_27a6a_row32_col0, #T_27a6a_row32_col1, #T_27a6a_row35_col0, #T_27a6a_row35_col1, #T_27a6a_row37_col0, #T_27a6a_row37_col1, #T_27a6a_row38_col0, #T_27a6a_row38_col1, #T_27a6a_row40_col0, #T_27a6a_row40_col1, #T_27a6a_row41_col0, #T_27a6a_row41_col1, #T_27a6a_row42_col0, #T_27a6a_row42_col1, #T_27a6a_row43_col0, #T_27a6a_row43_col1, #T_27a6a_row47_col0, #T_27a6a_row47_col1, #T_27a6a_row49_col0, #T_27a6a_row49_col1, #T_27a6a_row52_col0, #T_27a6a_row52_col1, #T_27a6a_row54_col0, #T_27a6a_row54_col1, #T_27a6a_row56_col0, #T_27a6a_row56_col1, #T_27a6a_row57_col0, #T_27a6a_row57_col1, #T_27a6a_row58_col0, #T_27a6a_row58_col1, #T_27a6a_row59_col0, #T_27a6a_row59_col1 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# #T_27a6a_row10_col0, #T_27a6a_row10_col1, #T_27a6a_row14_col0, #T_27a6a_row14_col1, #T_27a6a_row24_col0, #T_27a6a_row24_col1, #T_27a6a_row30_col0, #T_27a6a_row30_col1, #T_27a6a_row51_col0, #T_27a6a_row51_col1 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# #T_27a6a_row15_col0, #T_27a6a_row15_col1, #T_27a6a_row20_col0, #T_27a6a_row20_col1, #T_27a6a_row36_col0, #T_27a6a_row36_col1, #T_27a6a_row50_col0, #T_27a6a_row50_col1, #T_27a6a_row53_col0, #T_27a6a_row53_col1 {
#   background-color: #acd2e5;
#   color: #000000;
# }
# #T_27a6a_row21_col0, #T_27a6a_row21_col1, #T_27a6a_row23_col0, #T_27a6a_row23_col1, #T_27a6a_row33_col0, #T_27a6a_row33_col1, #T_27a6a_row45_col0, #T_27a6a_row45_col1, #T_27a6a_row55_col0, #T_27a6a_row55_col1 {
#   background-color: #b8d8e9;
#   color: #000000;
# }
# </style>
# <table id="T_27a6a">
#   <caption>Smooth CPLL - Restricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27a6a_level0_col0" class="col_heading level0 col0" >IT</th>
#       <th id="T_27a6a_level0_col1" class="col_heading level0 col1" >avg</th>
#       <th id="T_27a6a_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_27a6a_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_27a6a_level0_col4" class="col_heading level0 col4" >max</th>
#       <th id="T_27a6a_level0_col5" class="col_heading level0 col5" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27a6a_level0_row0" class="row_heading level0 row0" rowspan="2">factor2_ff3</th>
#       <th id="T_27a6a_level1_row0" class="row_heading level1 row0" >3</th>
#       <th id="T_27a6a_level2_row0" class="row_heading level2 row0" >3</th>
#       <td id="T_27a6a_row0_col0" class="data row0 col0" >1,154.9</td>
#       <td id="T_27a6a_row0_col1" class="data row0 col1" >1,154.9</td>
#       <td id="T_27a6a_row0_col2" class="data row0 col2" >10.0</td>
#       <td id="T_27a6a_row0_col3" class="data row0 col3" >1,147.8</td>
#       <td id="T_27a6a_row0_col4" class="data row0 col4" >1,162.0</td>
#       <td id="T_27a6a_row0_col5" class="data row0 col5" >14.1</td>
#     </tr>
#     <tr>
#       <th id="T_27a6a_level1_row1" class="row_heading level1 row1" >4</th>
#       <th id="T_27a6a_level2_row1" class="row_heading level2 row1" >3</th>
#       <td id="T_27a6a_row1_col0" class="data row1 col0" >1,138.9</td>
#       <td id="T_27a6a_row1_col1" class="data row1 col1" >1,138.9</td>
#       <td id="T_27a6a_row1_col2" class="data row1 col2" >13.7</td>
#       <td id="T_27a6a_row1_col3" class="data row1 col3" >1,129.3</td>
#       <td id="T_27a6a_row1_col4" class="data row1 col4" >1,148.6</td>
#       <td id="T_27a6a_row1_col5" class="data row1 col5" >19.3</td>
#     </tr>
#     <tr>
#       <th id="T_27a6a_level0_row2" class="row_heading level0 row2" >factor2_ff3mom</th>
#       <th id="T_27a6a_level1_row2" class="row_heading level1 row2" >6</th>
#       <th id="T_27a6a_level2_row2" class="row_heading level2 row2" >4</th>
#       <td id="T_27a6a_row2_col0" class="data row2 col0" >1,720.5</td>
#       <td id="T_27a6a_row2_col1" class="data row2 col1" >1,720.5</td>
#       <td id="T_27a6a_row2_col2" class="data row2 col2" >77.5</td>
#       <td id="T_27a6a_row2_col3" class="data row2 col3" >1,665.8</td>
#       <td id="T_27a6a_row2_col4" class="data row2 col4" >1,775.3</td>
#       <td id="T_27a6a_row2_col5" class="data row2 col5" >109.5</td>
#     </tr>
#     <tr>
#       <th id="T_27a6a_level0_row3" class="row_heading level0 row3" >factor2_ff5mom</th>
#       <th id="T_27a6a_level1_row3" class="row_heading level1 row3" >6</th>
#       <th id="T_27a6a_level2_row3" class="row_heading level2 row3" >6</th>
#       <td id="T_27a6a_row3_col0" class="data row3 col0" >3,740.5</td>
#       <td id="T_27a6a_row3_col1" class="data row3 col1" >3,740.5</td>
#       <td id="T_27a6a_row3_col2" class="data row3 col2" >217.1</td>
#       <td id="T_27a6a_row3_col3" class="data row3 col3" >3,586.9</td>
#       <td id="T_27a6a_row3_col4" class="data row3 col4" >3,894.0</td>
#       <td id="T_27a6a_row3_col5" class="data row3 col5" >307.1</td>
#     </tr>
#     <tr>
#       <th id="T_27a6a_level0_row4" class="row_heading level0 row4" >factor2_ff3</th>
#       <th id="T_27a6a_level1_row4" class="row_heading level1 row4" >6</th>
#       <th id="T_27a6a_level2_row4" class="row_heading level2 row4" >3</th>
#       <td id="T_27a6a_row4_col0" class="data row4 col0" >1,302.1</td>
#       <td id="T_27a6a_row4_col1" class="data row4 col1" >1,302.1</td>
#       <td id="T_27a6a_row4_col2" class="data row4 col2" >9.2</td>
#       <td id="T_27a6a_row4_col3" class="data row4 col3" >1,295.6</td>
#       <td id="T_27a6a_row4_col4" class="data row4 col4" >1,308.6</td>
#       <td id="T_27a6a_row4_col5" class="data row4 col5" >13.0</td>
#     </tr>
#     <tr>
#       <th id="T_27a6a_level0_row5" class="row_heading level0 row5" >factor1_vix</th>
#       <th id="T_27a6a_level1_row5" class="row_heading level1 row5" >4</th>
#       <th id="T_27a6a_level2_row5" class="row_heading level2 row5" >3</th>
#       <td id="T_27a6a_row5_col0" class="data row5 col0" >40.4</td>
#       <td id="T_27a6a_row5_col1" class="data row5 col1" >40.4</td>
#       <td id="T_27a6a_row5_col2" class="data row5 col2" >37.0</td>
#       <td id="T_27a6a_row5_col3" class="data row5 col3" >14.2</td>
#       <td id="T_27a6a_row5_col4" class="data row5 col4" >66.6</td>
#       <td id="T_27a6a_row5_col5" class="data row5 co

# %%
# Delta ELBO — ALL models, SAME rows/cols/order as "# Model performance"
styled_elbo_all = metric_table('elbo_delta (max all runs)', df_restr, base_idx_restr, cols_tail_restr, cols_all_restr, vmin=-1000000, vmax=1000000)
styled_elbo_all.set_caption("Delta ELBO - Restricted Models")
styled_elbo_all.set_table_styles(CAPTION_CSS, overwrite=False)
styled_elbo_all
# Out:
# <style type="text/css">
# #T_d8727 caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 700;
# }
# #T_d8727_row0_col0, #T_d8727_row0_col1, #T_d8727_row1_col0, #T_d8727_row1_col1, #T_d8727_row2_col0, #T_d8727_row2_col1, #T_d8727_row4_col0, #T_d8727_row4_col1, #T_d8727_row6_col0, #T_d8727_row6_col1, #T_d8727_row11_col0, #T_d8727_row11_col1, #T_d8727_row25_col0, #T_d8727_row25_col1, #T_d8727_row27_col0, #T_d8727_row27_col1, #T_d8727_row39_col0, #T_d8727_row39_col1, #T_d8727_row44_col0, #T_d8727_row44_col1 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_d8727_row3_col0, #T_d8727_row3_col1, #T_d8727_row7_col0, #T_d8727_row7_col1, #T_d8727_row10_col0, #T_d8727_row10_col1, #T_d8727_row14_col0, #T_d8727_row14_col1, #T_d8727_row16_col0, #T_d8727_row16_col1, #T_d8727_row24_col0, #T_d8727_row24_col1, #T_d8727_row30_col0, #T_d8727_row30_col1, #T_d8727_row46_col0, #T_d8727_row46_col1, #T_d8727_row48_col0, #T_d8727_row48_col1, #T_d8727_row51_col0, #T_d8727_row51_col1 {
#   background-color: #f3f5f6;
#   color: #000000;
# }
# #T_d8727_row5_col0, #T_d8727_row5_col1, #T_d8727_row8_col0, #T_d8727_row8_col1, #T_d8727_row9_col0, #T_d8727_row9_col1, #T_d8727_row12_col0, #T_d8727_row12_col1, #T_d8727_row13_col0, #T_d8727_row13_col1, #T_d8727_row15_col0, #T_d8727_row15_col1, #T_d8727_row17_col0, #T_d8727_row17_col1, #T_d8727_row18_col0, #T_d8727_row18_col1, #T_d8727_row19_col0, #T_d8727_row19_col1, #T_d8727_row20_col0, #T_d8727_row20_col1, #T_d8727_row21_col0, #T_d8727_row21_col1, #T_d8727_row22_col0, #T_d8727_row22_col1, #T_d8727_row23_col0, #T_d8727_row23_col1, #T_d8727_row26_col0, #T_d8727_row26_col1, #T_d8727_row28_col0, #T_d8727_row28_col1, #T_d8727_row29_col0, #T_d8727_row29_col1, #T_d8727_row31_col0, #T_d8727_row31_col1, #T_d8727_row32_col0, #T_d8727_row32_col1, #T_d8727_row33_col0, #T_d8727_row33_col1, #T_d8727_row34_col0, #T_d8727_row34_col1, #T_d8727_row35_col0, #T_d8727_row35_col1, #T_d8727_row36_col0, #T_d8727_row36_col1, #T_d8727_row37_col0, #T_d8727_row37_col1, #T_d8727_row38_col0, #T_d8727_row38_col1, #T_d8727_row40_col0, #T_d8727_row40_col1, #T_d8727_row41_col0, #T_d8727_row41_col1, #T_d8727_row42_col0, #T_d8727_row42_col1, #T_d8727_row43_col0, #T_d8727_row43_col1, #T_d8727_row45_col0, #T_d8727_row45_col1, #T_d8727_row47_col0, #T_d8727_row47_col1, #T_d8727_row49_col0, #T_d8727_row49_col1, #T_d8727_row50_col0, #T_d8727_row50_col1, #T_d8727_row52_col0, #T_d8727_row52_col1, #T_d8727_row53_col0, #T_d8727_row53_col1, #T_d8727_row54_col0, #T_d8727_row54_col1, #T_d8727_row55_col0, #T_d8727_row55_col1, #T_d8727_row56_col0, #T_d8727_row56_col1, #T_d8727_row57_col0, #T_d8727_row57_col1, #T_d8727_row58_col0, #T_d8727_row58_col1, #T_d8727_row59_col0, #T_d8727_row59_col1 {
#   background-color: #f6f7f7;
#   color: #000000;
# }
# </style>
# <table id="T_d8727">
#   <caption>Delta ELBO - Restricted Models</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8727_level0_col0" class="col_heading level0 col0" >IT</th>
#       <th id="T_d8727_level0_col1" class="col_heading level0 col1" >avg</th>
#       <th id="T_d8727_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_d8727_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_d8727_level0_col4" class="col_heading level0 col4" >max</th>
#       <th id="T_d8727_level0_col5" class="col_heading level0 col5" >range</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >config</th>
#       <th class="index_name level1" >n_regimes</th>
#       <th class="index_name level2" >dim_latent</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8727_level0_row0" class="row_heading level0 row0" rowspan="2">factor2_ff3</th>
#       <th id="T_d8727_level1_row0" class="row_heading level1 row0" >3</th>
#       <th id="T_d8727_level2_row0" class="row_heading level2 row0" >3</th>
#       <td id="T_d8727_row0_col0" class="data row0 col0" >10,923.4</td>
#       <td id="T_d8727_row0_col1" class="data row0 col1" >10,923.4</td>
#       <td id="T_d8727_row0_col2" class="data row0 col2" >91.6</td>
#       <td id="T_d8727_row0_col3" class="data row0 col3" >10,858.6</td>
#       <td id="T_d8727_row0_col4" class="data row0 col4" >10,988.1</td>
#       <td id="T_d8727_row0_col5" class="data row0 col5" >129.5</td>
#     </tr>
#     <tr>
#       <th id="T_d8727_level1_row1" class="row_heading level1 row1" >4</th>
#       <th id="T_d8727_level2_row1" class="row_heading level2 row1" >3</th>
#       <td id="T_d8727_row1_col0" class="data row1 col0" >10,841.7</td>
#       <td id="T_d8727_row1_col1" class="data row1 col1" >10,841.7</td>
#       <td id="T_d8727_row1_col2" class="data row1 col2" >115.9</td>
#       <td id="T_d8727_row1_col3" class="data row1 col3" >10,759.7</td>
#       <td id="T_d8727_row1_col4" class="data row1 col4" >10,923.6</td>
#       <td id="T_d8727_row1_col5" class="data row1 col5" >163.9</td>
#     </tr>
#     <tr>
#       <th id="T_d8727_level0_row2" class="row_heading level0 row2" >factor2_ff3mom</th>
#       <th id="T_d8727_level1_row2" class="row_heading level1 row2" >6</th>
#       <th id="T_d8727_level2_row2" class="row_heading level2 row2" >4</th>
#       <td id="T_d8727_row2_col0" class="data row2 col0" >14,258.7</td>
#       <td id="T_d8727_row2_col1" class="data row2 col1" >14,258.7</td>
#       <td id="T_d8727_row2_col2" class="data row2 col2" >205.2</td>
#       <td id="T_d8727_row2_col3" class="data row2 col3" >14,113.6</td>
#       <td id="T_d8727_row2_col4" class="data row2 col4" >14,403.8</td>
#       <td id="T_d8727_row2_col5" class="data row2 col5" >290.2</td>
#     </tr>
#     <tr>
#       <th id="T_d8727_level0_row3" class="row_heading level0 row3" >factor2_ff5mom</th>
#       <th id="T_d8727_level1_row3" class="row_heading level1 row3" >6</th>
#       <th id="T_d8727_level2_row3" class="row_heading level2 row3" >6</th>
#       <td id="T_d8727_row3_col0" class="data row3 col0" >19,638.5</td>
#       <td id="T_d8727_row3_col1" class="data row3 col1" >19,638.5</td>
#       <td id="T_d8727_row3_col2" class="data row3 col2" >425.8</td>
#       <td id="T_d8727_row3_col3" class="data row3 col3" >19,337.4</td>
#       <td id="T_d8727_row3_col4" class="data row3 col4" >19,939.6</td>
#       <td id="T_d8727_row3_col5" class="data row3 col5" >602.2</td>
#     </tr>
#     <tr>
#       <th id="T_d8727_level0_row4" class="row_heading level0 row4" >factor2_ff3</th>
#       <th id="T_d8727_level1_row4" class="row_heading level1 row4" >6</th>
#       <th id="T_d8727_level2_row4" class="row_heading level2 row4" >3</th>
#       <td id="T_d8727_row4_col0" class="data row4 col0" >10,816.2</td>
#       <td id="T_d8727_row4_col1" class="data row4 col1" >10,816.2</td>
#       <td id="T_d8727_row4_col2" class="data row4 col2" >103.3</td>
#       <td id="T_d8727_row4_col3" class="data row4 col3" >10,743.1</td>
#       <td id="T_d8727_row4_col4" class="data row4 col4" >10,889.2</td>
#       <td id="T_d8727_row4_col5" class="data row4 col5" >146.1</td>
#     </tr>
#     <tr>
#       <th id="T_d8727_level0_row5" class="row_heading level0 row5" >factor1_vix</th>
#       <th id="T_d8727_level1_row5" class="row_heading level1 row5" >4</th>
#       <th id="T_d8727_level2_row5" class="row_heading level2 row5" >3</th>
#       <td id="T_d8727_row5_col0" class="data row5 col0" >7,239.3</td>
#       <td id="T_d8727_row5_col1" class="data row5 col1" >7,239.3</td>
#       <td id="T_d8727_row5_col2" class="data row5 col2" >50.8</td>
#       <td id="T_d8727_row5_col3" class="data row5 col3" >7,203.4</td>
#       <td id="T_d8727_row5_col4" class="data row5 col4" >7,275.2</td>
#       <td id="T_d8727_row5_col5" class="data row5 col5" >71.8</td>
#     </tr>
#     <tr>
#       <th id="T_d8727_level0_row6" class="row_heading level0 row6" >factor2_ff3</th>
#       <th id="T_d8727_level1_row6" class="r

# %%
# Highest performing stock - Unrestricted

value_sel = "cagr_rel_ex_ante"  # "cagr_rel_ex_ante"

subset = res[
    (res["config"] == "[y]") &
    (res["n_regimes"] == 5) &
    (res["dim_latent"] == 1)
]

best_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmax()])

best_security = best_row["security"]
best_security, best_row[value_sel]
# Out:
# ('TSM', 0.0960974232843698)

# %%
# Worst performing stock - Unestricted

subset = res[
    (res["config"] == "[y]") &
    (res["n_regimes"] == 6) &
    (res["dim_latent"] == 1)
]

worst_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmin()])

worst_security = worst_row["security"]
worst_security, worst_row[value_sel]
# Out:
# ('SEC', 0.027581260950787)

# %%
# Highest performing stock - Restricted

value_sel = "cagr_rel_ex_ante"  # "cagr_rel_ex_ante"

subset = res[
    (res["config"] == "factor2_ff3") &
    (res["n_regimes"] == 6) &
    (res["dim_latent"] == 3)
]

best_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmax()])

best_security = best_row["security"]
best_security, best_row[value_sel]
# Out:
# ('SEC', 0.0862435553506488)

# %%
# Worst performing stock - Restricted

subset = res[
    (res["config"] == "factor2_ff3") &
    (res["n_regimes"] == 6) &
    (res["dim_latent"] == 3)
]

worst_row = (subset
    .dropna(subset=[value_sel])
    .loc[subset[value_sel].idxmin()])

worst_security = worst_row["security"]
worst_security, worst_row[value_sel]
# Out:
# ('TSM', 0.0120630403944783)

# %%
# --------------------------------------------------------------------------------------
# CONFIG
# --------------------------------------------------------------------------------------

PATHS = {
        "data_excel": "/Users/chrismader/Python/SLDS/Data/bbg_data.xlsx",
        "ff_dir": "/Users/chrismader/Python/SLDS/Data/",
        "ff_files": {
            "ff5": "F-F_Research_Data_5_Factors_2x3_daily.csv",
            "ff3": "F-F_Research_Data_Factors_daily.csv",
            "mom": "F-F_Momentum_Factor_daily.csv",},
        "results_csv": "/Users/chrismader/Python/SLDS/Output/gridsearch_results1.csv",
        "segments_parquet": "/Users/chrismader/Python/SLDS/Output/gridsearch_segments1.parquet",
        "tmp_dir":          "/Users/chrismader/Python/SLDS/tmp_slds/",
        "segments_tmp_csv": "/Users/chrismader/Python/SLDS/tmp_slds/segments_tmp.csv",
    }
    
CONFIG = {
    
    # Core defaults
    "n_jobs": -1,  # multi-threading
    "dt": 1.0 / 252.0,
    "n_iters": 50,
    "h_z": 3.0,  # CUSUM parameter
    
    # Batch windows
    "batch_grid": [
        {"train_window": 1260, "overlap_window": 1008},
    ],

    # Number of regimes
    "K_grid": [6],
    
    # Unrestricted models: 
    "unrestricted_models": [
        {"label": "[y]",         "channels": ["y"],                "dim_latent": [1]},
        # {"label": "[y,h]",       "channels": ["y","h"],            "dim_latent": [2]},
        # {"label": "[g,v]",       "channels": ["g","v"],            "dim_latent": [2]},
        # {"label": "[g,v,h]",     "channels": ["g","v","h"],        "dim_latent": [2,3]},
        # {"label": "[y,g,v,h]",   "channels": ["y","g","v","h"],    "dim_latent": [3,4]},
    ],

    # Restricted models: 
    "restricted_models": [
        # {"label": "fund1",        "channels": ["y"],                 "dim_latent": [2],    "C_type": "fund1"},
        # {"label": "fund1_vix",    "channels": ["y","h"],             "dim_latent": [3],    "C_type": "fund1_vix"},
        # {"label": "fund2",        "channels": ["y","g"],             "dim_latent": [2],    "C_type": "fund2"},
        # {"label": "fund2_vix",    "channels": ["y","g","h"],         "dim_latent": [3],    "C_type": "fund2_vix"},
        # {"label": "fund3",        "channels": ["y","v","g"],         "dim_latent": [2],    "C_type": "fund3"},
        # {"label": "fund3_vix",    "channels": ["y","v","g","h"],     "dim_latent": [3],    "C_type": "fund3_vix"},   

        # {"label": "factor1",      "channels": ["y"],                 "dim_latent": [2],    "C_type": "factor1"},
        # {"label": "factor1_vix",  "channels": ["y","h"],             "dim_latent": [3],    "C_type": "factor1_vix"},

        {"label": "factor2_ff3",   "channels": ["y","mkt","smb","hml"],                   "dim_latent": [3], "C_type": "factor2"},
        # {"label": "factor2_ff3mom","channels": ["y","mkt","smb","hml","mom"],             "dim_latent": [4], "C_type": "factor2"},
        # {"label": "factor2_ff5",   "channels": ["y","mkt","smb","hml","rmw","cma"],       "dim_latent": [5], "C_type": "factor2"},
        # {"label": "factor2_ff5mom","channels": ["y","mkt","smb","hml","rmw","cma","mom"], "dim_latent": [6], "C_type": "factor2"},
    ],

    # Model selection
    "run_unrestricted": False,
    "run_restricted": True,
    "predict_oos": False,

    # Output
    "verbose": False,
    "display": False,
}

for k, v in PATHS.items(): 
    CONFIG[k] = v
# per-security temp file templates used by IOManager
CONFIG["tmp_results_fmt"]  = "{tmp_dir}/tmp_res_{security}.csv"
CONFIG["tmp_segments_fmt"] = "{tmp_dir}/tmp_seg_{security}.csv"

# %%
def collect_seed_rolling_params(cfg, securities, n_runs=10, master_seed=123):
    """
    PURE WRAPPER with stability aggregation:
      • Per security → rolling batches → per-seed fits (unchanged logic).
      • NEW: For each batch, aggregate params across seeds (mean/std elementwise)
             for {Cs, ds, inv_etas, As, bs, sigmasq, Rs, r}.
      • NEW: For each batch, compute regime occupancies averaged across seeds
             for {zhat_raw, zhat_cusum} and store ARI (mean pairwise across seeds).
    The return structure now includes per-batch "params_agg" and "occ".
    """
    import numpy as np
    from gridsearch import import_data, import_factors, _intersect_indexes, _build_restrictions
    from rSLDS import fit_rSLDS, fit_rSLDS_restricted, cusum_overlay

    # pick active model (CONFIG guarantees mutual exclusivity)
    assert bool(cfg.get("run_unrestricted", False)) ^ bool(cfg.get("run_restricted", False)), \
       "[CFG] Exactly one of run_unrestricted or run_restricted must be True."
    
    if cfg["run_unrestricted"]:
        assert len(cfg["unrestricted_models"]) > 0, \
            "[CFG] run_unrestricted=True but unrestricted_models is empty."
        m = cfg["unrestricted_models"][0]; restricted = False; C_type = None
    else:
        assert len(cfg["restricted_models"]) > 0, \
            "[CFG] run_restricted=True but restricted_models is empty."
        m = cfg["restricted_models"][0];  restricted = True;  C_type = m["C_type"]
        
    channels   = list(m["channels"])
    D          = int(m["dim_latent"][0])
    K          = int(cfg["K_grid"][0])
    dt         = float(cfg["dt"])
    n_iters    = int(cfg["n_iters"])
    h_z        = float(cfg["h_z"])
    batch_conf = cfg["batch_grid"][0]
    train_window = int(batch_conf["train_window"])
    overlap      = int(batch_conf["overlap_window"])

    print(f"[CFG] restricted={restricted} C_type={C_type} channels={channels} K={K} D={D} "
          f"dt={dt} n_iters={n_iters} h_z={h_z} train_window={train_window} overlap={overlap} n_runs={n_runs}")

    # data
    px_all, eps_all, pe_all, ser_vix = import_data(cfg["data_excel"])
    ff = import_factors(cfg["ff_dir"], cfg["ff_files"])

    def _series_by_key_for(sec):
        ser_px  = px_all[sec].dropna()
        ser_eps = eps_all[sec].dropna().where(lambda s: s > 0).dropna()
        ser_pe  = (ser_px / ser_eps).where(lambda s: s > 0).dropna()
        series = {
            "y": np.log(ser_px).diff().dropna(),
            "g": np.log(ser_eps).diff().dropna(),
            "v": np.log(ser_pe).diff().dropna(),
            "h": np.log(ser_vix).diff().dropna(),
        }
        for col, key in [("MKT","mkt"),("SMB","smb"),("HML","hml"),("RMW","rmw"),("CMA","cma"),("MOM","mom")]:
            if col in ff.columns:
                series[key] = ff[col]
        return series, ser_px

    rng = np.random.RandomState(master_seed)
    out = {}

    # ---------- small helpers ----------
    def _stack(arrs, expected_ndim=None):
        A = np.stack(arrs, axis=0)  # (R, ...)
        if expected_ndim is not None:
            assert A.ndim == expected_ndim + 1, f"[ASSERT] rank mismatch: got {A.ndim}, want {expected_ndim+1}"
        return A

    def _agg_mean_std(A):
        mu = A.mean(axis=0)
        sd = A.std(axis=0, ddof=1) if A.shape[0] > 1 else np.zeros_like(mu)
        return mu, sd

    def _occ_by_seed(Z, K_):
        # Z: shape (R, T) ints in {0..K-1} or {1..K}
        if Z.size == 0:
            return np.full((Z.shape[0], K_), np.nan)
        Zp = Z.copy()
        if Zp.min() == 1:
            Zp = Zp - 1
        R, T = Zp.shape
        occ = np.zeros((R, K_), float)
        for i in range(R):
            bc = np.bincount(Zp[i], minlength=K_).astype(float)
            occ[i] = bc / max(T, 1)
        return occ

    from sklearn.metrics import adjusted_rand_score as _ARI
    def _mean_pairwise_ARI(Z):
        Z = np.asarray(Z, dtype=int)
        if Z.size == 0:
            return np.nan
        if Z.min() == 1:
            Z = Z - 1
        R, _ = Z.shape
        vals = []
        for i in range(R):
            for j in range(i+1, R):
                vals.append(_ARI(Z[i], Z[j]))
        return float(np.mean(vals)) if vals else np.nan

    # ------------------------------------

    for sec in securities:

        print(f"\n[SEC] {sec}")
        series_by_key, ser_px = _series_by_key_for(sec)
        need = [series_by_key[k].dropna() for k in channels]
        common_idx = _intersect_indexes(need)
        if common_idx is None or getattr(common_idx, "empty", False):
            print(f"[WARN] {sec}: no overlap for channels {channels} — skipping")
            continue

        Y_full  = np.concatenate([series_by_key[k].loc[common_idx].values.reshape(-1,1) for k in channels], axis=1)
        px_full = ser_px.loc[common_idx].astype(float)
        T, N = Y_full.shape
        assert N == len(channels), f"[ASSERT] N={N} must equal len(channels)={len(channels)}"

        print(f"[DATA] T={T} N={N} idx[{common_idx[0]} → {common_idx[-1]}]")

        # batch schedule
        t0s, t1s, t0 = [], [], 0
        while t0 < T:
            t1s.append(min(t0 + train_window, T))
            t0s.append(t0)
            if t1s[-1] == T: break
            t0 += train_window - overlap
        print(f"[BATCH] batches={len(t0s)}")

        rec = {
            "meta": {
                "channels": channels, "K": K, "D": D,
                "train_window": train_window, "overlap_window": overlap,
                "common_index": common_idx, "restricted": restricted, "dt": dt},
            "batches": []}

        params_spec = dict(n_regimes=K, dim_latent=D, single_subspace=True)

        for bi, (b0, b1) in enumerate(zip(t0s, t1s)):
            Yb = Y_full[b0:b1, :]
            pxb = px_full.iloc[b0:b1]
            idx_slice = pxb.index
            print(f"[B{bi}] slice t0={b0} t1={b1} len={len(idx_slice)}")

            restrictions = None
            if restricted:
                restrictions = _build_restrictions(C_type, Y_obs=Yb, base_channels=channels, D=D)
                assert "C" in restrictions and "d" in restrictions, "[ASSERT] restrictions must contain 'C' and 'd'"
                print(f"[B{bi}] restrictions keys={list(restrictions.keys())}")

            seeds = rng.randint(1, 2**31 - 1, size=n_runs).tolist()
          
            per_seed_records = []
            Z_raw_list, Z_cusum_list = [], []
            Cs_list, ds_list, inv_list = [], [], []
            As_list, bs_list, sigmasq_list, Rs_list, r_list = [], [], [], [], []

            for si, s in enumerate(seeds):
                
                if restricted:
                    xhat, zhat_raw, elbo, q, mdl = fit_rSLDS_restricted(
                        Yb, params_spec,
                        C=restrictions["C"], d=restrictions["d"],
                        n_iter_em=n_iters, seed=s,
                        b_pattern=restrictions.get("b_pattern"),
                        enforce_diag_A=True,
                        C_mask=restrictions.get("C_mask"),
                        d_mask=restrictions.get("d_mask"))
                else:
                    xhat, zhat_raw, elbo, q, mdl = fit_rSLDS(Yb, params_spec, n_iter_em=n_iters, seed=s)

                y_cus = Yb[:, 0].ravel()
                zhat_cusum = cusum_overlay(pxb, y_cus, xhat, mdl, h_z)

                Z_raw_list.append(np.asarray(zhat_raw).ravel())
                if zhat_cusum is None:
                    Z_cusum_list.append(np.asarray(zhat_raw).ravel())
                else:
                    Z_cusum_list.append(np.asarray(zhat_cusum).ravel())

                # params (copy to detach)
                Cs      = np.array(mdl.emissions.Cs,       copy=True)
                ds      = np.array(mdl.emissions.ds,       copy=True)
                inv_eta = np.array(mdl.emissions.inv_etas, copy=True)
                As      = np.array(mdl.dynamics.As,        copy=True)
                bs      = np.array(mdl.dynamics.bs,        copy=True)
                sigmasq = np.array(mdl.dynamics.sigmasq,   copy=True)
                Rs      = np.array(mdl.transitions.Rs,     copy=True)
                r       = np.array(mdl.transitions.r,      copy=True)

                # sanity on leading K (allow shared emissions with leading 1)
                assert As.shape[0] == K and bs.shape[0] == K and sigmasq.shape[0] == K \
                    and Rs.shape[0] == K and r.shape[0] == K, "[ASSERT] K mismatch in dynamics/transitions"
                assert Cs.ndim == 3 and ds.ndim == 2 and inv_eta.ndim == 2, "[ASSERT] emissions rank mismatch"
                assert Cs.shape[0] in (1, K) and ds.shape[0] in (1, K) and inv_eta.shape[0] in (1, K), \
                    "[ASSERT] emissions leading axis must be 1 or K"

                Cs_list.append(Cs)
                ds_list.append(ds)
                inv_list.append(inv_eta)
                As_list.append(As)
                bs_list.append(bs)
                sigmasq_list.append(sigmasq)
                Rs_list.append(Rs)
                r_list.append(r)

                per_seed_records.append({
                    "seed": int(s),
                    "params": {"Cs": Cs, "ds": ds, "inv_etas": inv_eta, "As": As, "bs": bs,
                               "sigmasq": sigmasq, "Rs": Rs, "r": r},
                    "outputs": {"zhat_raw": zhat_raw, "zhat_cusum": zhat_cusum,
                                "xhat": xhat, "elbo": elbo}
                })

            # ---------- aggregate across seeds (elementwise mean/std) ----------
            def _agg_block(block_list):
                A = _stack(block_list)  # (R, ...)
                mu, sd = _agg_mean_std(A)
                return {"mean": mu, "std": sd}

            params_agg = {
                "Cs": _agg_block(Cs_list),
                "ds": _agg_block(ds_list),
                "inv_etas": _agg_block(inv_list),
                "As": _agg_block(As_list),
                "bs": _agg_block(bs_list),
                "sigmasq": _agg_block(sigmasq_list),
                "Rs": _agg_block(Rs_list),
                "r": _agg_block(r_list),
            }

            # ---------- regime occupancy (avg across seeds) + ARI ----------
            Zr = np.stack(Z_raw_list, axis=0)   if len(Z_raw_list)  else np.zeros((0, 0), int)
            Zc = np.stack(Z_cusum_list, axis=0) if len(Z_cusum_list) else np.zeros((0, 0), int)

            occ_raw_seed = _occ_by_seed(Zr, K)  # (R,K)
            occ_cus_seed = _occ_by_seed(Zc, K)  # (R,K)

            occ = {
                "raw": {
                    "by_seed": occ_raw_seed,                      # (R,K), fractions
                    "mean":    np.nanmean(occ_raw_seed, axis=0),  # (K,)
                    "std":     np.nanstd(occ_raw_seed, axis=0, ddof=1) if occ_raw_seed.shape[0] > 1
                               else np.zeros(K)
                },
                "cusum": {
                    "by_seed": occ_cus_seed,
                    "mean":    np.nanmean(occ_cus_seed, axis=0),
                    "std":     np.nanstd(occ_cus_seed, axis=0, ddof=1) if occ_cus_seed.shape[0] > 1
                               else np.zeros(K)
                }
            }

            metrics = {
                "ARI_raw":  _mean_pairwise_ARI(Zr),
                "ARI_cusum": _mean_pairwise_ARI(Zc),
            }

            rec["batches"].append({
                "t0": int(b0), "t1": int(b1),
                "idx_slice": idx_slice,
                "seeds": seeds,
                "records": per_seed_records,
                "Z_raw":  Zr,
                "Z_cusum": Zc,
                "params_agg": params_agg,
                "occ": occ,
                "metrics": metrics,
            })
        
        out[sec] = rec

    return out

# %%
def print_seed_rolling_stability(rolled, security, batch_indices=None):
    """
    Pretty printer for stability:
      • Emissions & latent blocks: entries as mean (std) across seeds.
      • Regime occupancies per batch: mean% (std%).
      • ARI per batch: raw & cusum.
    Inputs
      rolled: dict returned by collect_seed_rolling_params
      security: key inside rolled
      batch_indices: optional list of batch indices to print (default: all)
    """
    import numpy as np

    rec = rolled.get(security)
    assert rec is not None, f"[print] security '{security}' not found"
    K = rec["meta"]["K"]; D = rec["meta"]["D"]; dt = rec["meta"]["dt"]; restricted = rec["meta"]["restricted"]
    B = len(rec["batches"])
    if batch_indices is None:
        batch_indices = list(range(B))

    def _fmt(m, s, fp=4):
        return f"{m: .{fp}f} ({s: .{fp}f})"

    def _pmat(mu, sd, label, semantic_key):
        shape_str = {
            "Cs": "(K_or_1, N, D)",
            "ds": "(K_or_1, N)",
            "inv_etas": "(K_or_1, N)",
            "As": "(K, D, D)",
            "bs": "(K, D)",
            "sigmasq": "(K, D)",
            "Rs": "(K, D)",
            "r": "(K,)",
        }[semantic_key]
        print(f"{label}  {shape_str} = {mu.shape}")
        if mu.ndim == 3:
            K0, R0, C0 = mu.shape
            for r in range(R0):
                line = ""
                for k in range(K0):
                    row_entries = []
                    for c in range(C0):
                        row_entries.append(_fmt(mu[k, r, c], sd[k, r, c]))
                    row_str = " ".join(row_entries)
                    line += f"[{row_str}]    "
                print(line)
        elif mu.ndim == 2:
            K0, C0 = mu.shape
            line = ""
            for k in range(K0):
                row_entries = [_fmt(mu[k, c], sd[k, c]) for c in range(C0)]
                line += f"[{' '.join(row_entries)}]" + "    "
            print(line)
        elif mu.ndim == 1:
            row_entries = [_fmt(mu[k], sd[k]) for k in range(mu.shape[0])]
            print(f"[{' '.join(row_entries)}]")
        print()

    for bi in batch_indices:
        b = rec["batches"][bi]
        t0, t1 = b["t0"], b["t1"]
        print("\n========== STABILITY (security={}, batch={}  t0={}  t1={}) ==========\n"
              .format(security, bi, t0, t1))

        P = b["params_agg"]
        _pmat(P["Cs"]["mean"],      P["Cs"]["std"],      "Cs",       "Cs")
        _pmat(P["ds"]["mean"],      P["ds"]["std"],      "ds",       "ds")
        _pmat(P["inv_etas"]["mean"],P["inv_etas"]["std"],"inv_etas", "inv_etas")
        _pmat(P["As"]["mean"],      P["As"]["std"],      "As",       "As")
        _pmat(P["bs"]["mean"],      P["bs"]["std"],      "bs",       "bs")
        _pmat(P["sigmasq"]["mean"], P["sigmasq"]["std"], "sigmasq",  "sigmasq")
        _pmat(P["Rs"]["mean"],      P["Rs"]["std"],      "Rs",       "Rs")
        _pmat(P["r"]["mean"],       P["r"]["std"],       "r",        "r")

        # interpretable AR(1) params (restricted models)
        if restricted:
            print("Interpretable AR(1) parameters (mean±std over seeds)")
            mu_As, sd_As   = P["As"]["mean"], P["As"]["std"]         # (K,D,D)
            mu_bs, sd_bs   = P["bs"]["mean"], P["bs"]["std"]         # (K,D)
            mu_sig, sd_sig = P["sigmasq"]["mean"], P["sigmasq"]["std"] # (K,D)
            eps = 1e-8
            for k in range(mu_As.shape[0]):
                print(f"Regime {k}:")
                for d in range(min(D, mu_As.shape[2])):
                    rho_m, rho_s = mu_As[k, d, d], sd_As[k, d, d]
                    b_m, b_s     = mu_bs[k, d],    sd_bs[k, d]
                    # μ = b / (1-ρ), Var_stat = σ²/(1-ρ²) for |ρ|<1
                    mu_stat_m = (b_m / (1.0 - rho_m)) if abs(1.0 - rho_m) > eps else np.nan
                    # delta-method-ish SD approximation (optional: coarse; keep concise)
                    mu_stat_s = np.nan
                    s2_m, s2_s = mu_sig[k, d], sd_sig[k, d]
                    var_stat_m = (s2_m / (1.0 - rho_m**2)) if abs(rho_m) < 1 else np.nan
                    var_stat_s = np.nan
                    # half-life in steps: log(2)/|log ρ|
                    if rho_m > 0 and abs(rho_m) < 1:
                        hl_steps_m = float(np.log(2.0) / abs(np.log(rho_m)))
                    else:
                        hl_steps_m = float("inf")
                    hl_years_m = (hl_steps_m * rec["meta"]["dt"]) if np.isfinite(hl_steps_m) else np.nan
                    print(f"  latent{d}: rho={_fmt(rho_m, rho_s)}  b={_fmt(b_m, b_s)}  "
                          f"mu_stat≈{mu_stat_m: .6f}  var_stat≈{var_stat_m: .6e}  "
                          f"half_life_steps≈{hl_steps_m: .2f}  half_life_years≈{hl_years_m: .4f}")
                print()

        # occupancy + ARI
        occ = b["occ"]
        raw_mean = (occ["raw"]["mean"] * 100.0).astype(float)
        raw_std  = (occ["raw"]["std"]  * 100.0).astype(float)
        cus_mean = (occ["cusum"]["mean"] * 100.0).astype(float)
        cus_std  = (occ["cusum"]["std"]  * 100.0).astype(float)

        def _fmt_occ(mean_vec, std_vec):
            return ", ".join([f"{mean_vec[j]:.1f}% ({std_vec[j]:.1f}%)" for j in range(mean_vec.size)])

        print("Occupancy per regime (mean% (std%) across seeds):")
        print(f"  RAW:   [{_fmt_occ(raw_mean,  raw_std)}]")
        print(f"  CUSUM: [{_fmt_occ(cus_mean, cus_std)}]")

        ARI_raw   = b["metrics"]["ARI_raw"]
        ARI_cusum = b["metrics"]["ARI_cusum"]
        print(f"ARI (mean pairwise across seeds):  RAW={ARI_raw:.3f}   CUSUM={ARI_cusum:.3f}")

# %%
securities = ["TSM", "SEC"]
rolled = collect_seed_rolling_params(CONFIG, securities, n_runs=10, master_seed=123)
# Out:
# [CFG] restricted=True C_type=factor2 channels=['y', 'mkt', 'smb', 'hml'] K=6 D=3 dt=0.003968253968253968 n_iters=50 h_z=3.0 train_window=1260 overlap=1008 n_runs=10
#
# [SEC] TSM
# [DATA] T=3392 N=4 idx[2012-01-03 00:00:00 → 2025-06-30 00:00:00]
# [BATCH] batches=10
# [B0] slice t0=0 t1=1260 len=1260
# [B0] restrictions keys=['C', 'd', 'b_pattern']
# [B1] slice t0=252 t1=1512 len=1260
# [B1] restrictions keys=['C', 'd', 'b_pattern']
# [B2] slice t0=504 t1=1764 len=1260
# [B2] restrictions keys=['C', 'd', 'b_pattern']
# [B3] slice t0=756 t1=2016 len=1260
# [B3] restrictions keys=['C', 'd', 'b_pattern']
# [B4] slice t0=1008 t1=2268 len=1260
# [B4] restrictions keys=['C', 'd', 'b_pattern']
# [B5] slice t0=1260 t1=2520 len=1260
# [B5] restrictions keys=['C', 'd', 'b_pattern']
# [B6] slice t0=1512 t1=2772 len=1260
# [B6] restrictions keys=['C', 'd', 'b_pattern']
# [B7] slice t0=1764 t1=3024 len=1260
# [B7] restrictions keys=['C', 'd', 'b_pattern']
# [B8] slice t0=2016 t1=3276 len=1260
# [B8] restrictions keys=['C', 'd', 'b_pattern']
# [B9] slice t0=2268 t1=3392 len=1124
# [B9] restrictions keys=['C', 'd', 'b_pattern']
#
# [SEC] SEC
# [DATA] T=3392 N=4 idx[2012-01-03 00:00:00 → 2025-06-30 00:00:00]
# [BATCH] batches=10
# [B0] slice t0=0 t1=1260 len=1260
# [B0] restrictions keys=['C', 'd', 'b_pattern']
# [B1] slice t0=252 t1=1512 len=1260
# [B1] restrictions keys=['C', 'd', 'b_pattern']
# [B2] slice t0=504 t1=1764 len=1260
# [B2] restrictions keys=['C', 'd', 'b_pattern']
# [B3] slice t0=756 t1=2016 len=1260
# [B3] restrictions keys=['C', 'd', 'b_pattern']
# [B4] slice t0=1008 t1=2268 len=1260
# [B4] restrictions keys=['C', 'd', 'b_pattern']
# [B5] slice t0=1260 t1=2520 len=1260
# [B5] restrictions keys=['C', 'd', 'b_pattern']
# [B6] slice t0=1512 t1=2772 len=1260
# [B6] restrictions keys=['C', 'd', 'b_pattern']
# [B7] slice t0=1764 t1=3024 len=1260
# [B7] restrictions keys=['C', 'd', 'b_pattern']
# [B8] slice t0=2016 t1=3276 len=1260
# [B8] restrictions keys=['C', 'd', 'b_pattern']
# [B9] slice t0=2268 t1=3392 len=1124
# [B9] restrictions keys=['C', 'd', 'b_pattern']

# %%
print_seed_rolling_stability(rolled, "TSM")
# Out:
# ========== STABILITY (security=TSM, batch=0  t0=0  t1=1260) ==========
#
# Cs  (K_or_1, N, D) = (1, 4, 3)
# [ 0.0026 ( 0.0000) -0.0015 ( 0.0000) -0.0003 ( 0.0000)]
# [ 1.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  1.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  1.0000 ( 0.0000)]
#
# ds  (K_or_1, N) = (1, 4)
# [ 0.0005 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
#
# inv_etas  (K_or_1, N) = (6, 4)
# [ 8.4708 ( 0.0000)  0.3755 ( 0.0000)  1.4534 ( 0.0000)  1.6124 ( 0.0000)]    [ 8.4708 ( 0.0000)  0.3755 ( 0.0000)  1.4534 ( 0.0000)  1.6124 ( 0.0000)]    [ 8.4708 ( 0.0000)  0.3755 ( 0.0000)  1.4534 ( 0.0000)  1.6124 ( 0.0000)]    [ 8.4708 ( 0.0000)  0.3755 ( 0.0000)  1.4534 ( 0.0000)  1.6124 ( 0.0000)]    [ 8.4708 ( 0.0000)  0.3755 ( 0.0000)  1.4534 ( 0.0000)  1.6124 ( 0.0000)]    [ 8.4708 ( 0.0000)  0.3755 ( 0.0000)  1.4534 ( 0.0000)  1.6124 ( 0.0000)]
#
# As  (K, D, D) = (6, 3, 3)
# [ 0.0562 ( 0.0001)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0563 ( 0.0001)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0562 ( 0.0001)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0562 ( 0.0001)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0563 ( 0.0002)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0562 ( 0.0001)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.1065 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.1065 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.1065 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.1065 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.1065 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.1065 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1193 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1193 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1193 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1193 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1193 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1193 ( 0.0000)]
#
# bs  (K, D) = (6, 3)
# [ 0.0552 ( 0.0001)  0.0023 ( 0.0000)  0.0117 ( 0.0000)]    [ 0.0551 ( 0.0002)  0.0023 ( 0.0000)  0.0117 ( 0.0000)]    [ 0.0552 ( 0.0001)  0.0023 ( 0.0000)  0.0117 ( 0.0000)]    [ 0.0552 ( 0.0001)  0.0023 ( 0.0000)  0.0117 ( 0.0000)]    [ 0.0551 ( 0.0002)  0.0023 ( 0.0000)  0.0117 ( 0.0000)]    [ 0.0552 ( 0.0001)  0.0023 ( 0.0000)  0.0117 ( 0.0000)]
#
# sigmasq  (K, D) = (6, 3)
# [ 0.0276 ( 0.0001)  0.0431 ( 0.0001)  0.0483 ( 0.0001)]    [ 0.0276 ( 0.0001)  0.0432 ( 0.0001)  0.0484 ( 0.0001)]    [ 0.0276 ( 0.0000)  0.0431 ( 0.0000)  0.0484 ( 0.0000)]    [ 0.0276 ( 0.0000)  0.0431 ( 0.0000)  0.0484 ( 0.0000)]    [ 0.0276 ( 0.0001)  0.0431 ( 0.0001)  0.0484 ( 0.0001)]    [ 0.0276 ( 0.0000)  0.0431 ( 0.0000)  0.0484 ( 0.0000)]
#
# Rs  (K, D) = (6, 3)
# [-0.0014 ( 0.0054) -0.0002 ( 0.0055) -0.0002 ( 0.0047)]    [ 0.0016 ( 0.0078)  0.0009 ( 0.0051)  0.0004 ( 0.0043)]    [-0.0005 ( 0.0051) -0.0000 ( 0.0054)  0.0000 ( 0.0044)]    [-0.0017 ( 0.0047) -0.0001 ( 0.0053) -0.0000 ( 0.0043)]    [-0.0004 ( 0.0085)  0.0006 ( 0.0053)  0.0007 ( 0.0040)]    [-0.0007 ( 0.0050) -0.0001 ( 0.0052)  0.0000 ( 0.0043)]
#
# r  (K,) = (6,)
# [-0.0284 ( 0.1015)  0.0482 ( 0.1031) -0.0129 ( 0.0297) -0.0188 ( 0.0403)  0.0170 ( 0.1374) -0.0052 ( 0.0385)]
#
# Interpretable AR(1) parameters (mean±std over seeds)
# Regime 0:
#   latent0: rho= 0.0562 ( 0.0001)  b= 0.0552 ( 0.0001)  mu_stat≈ 0.058470  var_stat≈ 2.766609e-02  half_life_steps≈ 0.24  half_life_years≈ 0.0010
#   latent1: rho= 0.1065 ( 0.0000)  b= 0.0023 ( 0.0000)  mu_stat≈ 0.002547  var_stat≈ 4.360082e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1193 ( 0.0000)  b= 0.0117 ( 0.0000)  mu_stat≈ 0.013244  var_stat≈ 4.904584e-02  half_life_steps≈ 0.33  half_life_years≈ 0.0013
#
# Regime 1:
#   latent0: rho= 0.0563 ( 0.0001)  b= 0.0551 ( 0.0002)  mu_stat≈ 0.058345  var_stat≈ 2.772298e-02  half_life_steps≈ 0.24  half_life_years≈ 0.0010
#   latent1: rho= 0.1065 ( 0.0000)  b= 0.0023 ( 0.0000)  mu_stat≈ 0.002535  var_stat≈ 4.366636e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1193 ( 0.0000)  b= 0.0117 ( 0.0000)  mu_stat≈ 0.013247  var_stat≈ 4.911940e-02  half_life_steps≈ 0.33  half_life_years≈ 0.0013
#
# Regime 2:
#   latent0: rho= 0.0562 ( 0.0001)  b= 0.0552 ( 0.0001)  mu_stat≈ 0.058466  var_stat≈ 2.767926e-02  half_life_steps≈ 0.24  half_life_years≈ 0.0010
#   latent1: rho= 0.1065 ( 0.0000)  b= 0.0023 ( 0.0000)  mu_stat≈ 0.002546  var_stat≈ 4.361908e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1193 ( 0.0000)  b= 0.0117 ( 0.0000)  mu_stat≈ 0.013245  var_stat≈ 4.906635e-02  half_life_steps≈ 0.33  half_life_years≈ 0.0013
#
# Regime 3:
#   latent0: rho= 0.0562 ( 0.0001)  b= 0.0552 ( 0.0001)  mu_stat≈ 0.058474  var_stat≈ 2.767474e-02  half_life_steps≈ 0.24  half_life_years≈ 0.0010
#   latent1: rho= 0.1065 ( 0.0000)  b= 0.0023 ( 0.0000)  mu_stat≈ 0.002547  var_stat≈ 4.361365e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1193 ( 0.0000)  b= 0.0117 ( 0.0000)  mu_stat≈ 0.013245  var_stat≈ 4.906025e-02  half_life_steps≈ 0.33  half_life_years≈ 0.0013
#
# Regime 4:
#   latent0: rho= 0.0563 ( 0.0002)  b= 0.0551 ( 0.0002)  mu_stat≈ 0.058392  var_stat≈ 2.769944e-02  half_life_steps≈ 0.24  half_life_years≈ 0.0010
#   latent1: rho= 0.1065 ( 0.0000)  b= 0.0023 ( 0.0000)  mu_stat≈ 0.002540  var_stat≈ 4.363826e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1193 ( 0.0000)  b= 0.0117 ( 0.0000)  mu_stat≈ 0.013245  var_stat≈ 4.908786e-02  half_life_steps≈ 0.33  half_life_years≈ 0.0013
#
# Regime 5:
#   latent0: rho= 0.0562 ( 0.0001)  b= 0.0552 ( 0.0001)  mu_stat≈ 0.058451  var_stat≈ 2.768491e-02  half_life_steps≈ 0.24  half_life_years≈ 0.0010
#   latent1: rho= 0.1065 ( 0.0000)  b= 0.0023 ( 0.0000)  mu_stat≈ 0.002545  var_stat≈ 4.362529e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1193 ( 0.0000)  b= 0.0117 ( 0.0000)  mu_stat≈ 0.013245  var_stat≈ 4.907332e-02  half_life_steps≈ 0.33  half_life_years≈ 0.0013
#
# Occupancy per regime (mean% (std%) across seeds):
#   RAW:   [10.1% (31.5%), 10.0% (31.6%), 29.8% (48.0%), 0.0% (0.0%), 40.2% (51.4%), 9.9% (30.7%)]
#   CUSUM: [10.0% (31.6%), 10.0% (31.6%), 40.0% (51.6%), 0.0% (0.0%), 40.0% (51.6%), 0.0% (0.0%)]
# ARI (mean pairwise across seeds):  RAW=0.441   CUSUM=1.000
#
# ========== STABILITY (security=TSM, batch=1  t0=252  t1=1512) ==========
#
# Cs  (K_or_1, N, D) = (1, 4, 3)
# [ 0.0022 ( 0.0000) -0.0015 ( 0.0000) -0.0001 ( 0.0000)]
# [ 1.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  1.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  1.0000 ( 0.0000)]
#
# ds  (K_or_1, N) = (1, 4)
# [ 0.0006 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
#
# inv_etas  (K_or_1, N) = (6, 4)
# [ 8.5851 ( 0.0000)  0.5322 ( 0.0000)  1.4185 ( 0.0000)  1.5145 ( 0.0000)]    [ 8.5851 ( 0.0000)  0.5322 ( 0.0000)  1.4185 ( 0.0000)  1.5145 ( 0.0000)]    [ 8.5851 ( 0.0000)  0.5322 ( 0.0000)  1.4185 ( 0.0000)  1.5145 ( 0.0000)]    [ 8.5851 ( 0.0000)  0.5322 ( 0.0000)  1.4185 ( 0.0000)  1.5145 ( 0.0000)]    [ 8.5851 ( 0.0000)  0.5322 ( 0.0000)  1.4185 ( 0.0000)  1.5145 ( 0.0000)]    [ 8.5851 ( 0.0000)  0.5322 ( 0.0000)  1.4185 ( 0.0000)  1.5145 ( 0.0000)]
#
# As  (K, D, D) = (6, 3, 3)
# [ 0.0493 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0493 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0493 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0493 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0493 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0493 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.1040 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.1040 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.1040 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.1040 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.1040 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.1040 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1128 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1128 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1128 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1128 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1128 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1128 ( 0.0000)]
#
# bs  (K, D) = (6, 3)
# [ 0.0574 ( 0.0000) -0.0027 ( 0.0000) -0.0020 ( 0.0000)]    [ 0.0574 ( 0.0001) -0.0027 ( 0.0000) -0.0020 ( 0.0000)]    [ 0.0574 ( 0.0000) -0.0027 ( 0.0000) -0.0020 ( 0.0000)]    [ 0.0574 ( 0.0000) -0.0027 ( 0.0000) -0.0020 ( 0.0000)]    [ 0.0574 ( 0.0000) -0.0027 ( 0.0000) -0.0020 ( 0.0000)]    [ 0.0574 ( 0.0000) -0.0027 ( 0.0000) -0.0020 ( 0.0000)]
#
# sigmasq  (K, D) = (6, 3)
# [ 0.0267 ( 0.0000)  0.0421 ( 0.0000)  0.0451 ( 0.0000)]    [ 0.0267 ( 0.0000)  0.0421 ( 0.0000)  0.0451 ( 0.0000)]    [ 0.0267 ( 0.0000)  0.0421 ( 0.0000)  0.0451 ( 0.0000)]    [ 0.0267 ( 0.0000)  0.0421 ( 0.0000)  0.0451 ( 0.0000)]    [ 0.0267 ( 0.0000)  0.0421 ( 0.0000)  0.0451 ( 0.0000)]    [ 0.0267 ( 0.0000)  0.0421 ( 0.0000)  0.0451 ( 0.0000)]
#
# Rs  (K, D) = (6, 3)
# [ 0.0002 ( 0.0036) -0.0014 ( 0.0041) -0.0000 ( 0.0032)]    [ 0.0005 ( 0.0031) -0.0014 ( 0.0041)  0.0000 ( 0.0032)]    [ 0.0001 ( 0.0031) -0.0014 ( 0.0041)  0.0000 ( 0.0032)]    [-0.0001 ( 0.0030) -0.0014 ( 0.0041)  0.0000 ( 0.0032)]    [ 0.0002 ( 0.0038) -0.0015 ( 0.0041) -0.0000 ( 0.0032)]    [-0.0001 ( 0.0037) -0.0015 ( 0.0042) -0.0001 ( 0.0031)]
#
# r  (K,) = (6,)
# [ 0.0050 ( 0.0130)  0.0020 ( 0.0384) -0.0023 ( 0.0180) -0.0013 ( 0.0094)  0.0020 ( 0.0182) -0.0055 ( 0.0302)]
#
# Interpretable AR(1) parameters (mean±std over seeds)
# Regime 0:
#   latent0: rho= 0.0493 ( 0.0000)  b= 0.0574 ( 0.0000)  mu_stat≈ 0.060401  var_stat≈ 2.676960e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent1: rho= 0.1040 ( 0.0000)  b=-0.0027 ( 0.0000)  mu_stat≈-0.003001  var_stat≈ 4.254199e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1128 ( 0.0000)  b=-0.0020 ( 0.0000)  mu_stat≈-0.002309  var_stat≈ 4.568206e-02  half_life_steps≈ 0.32  half_life_years≈ 0.0013
#
# Regime 1:
#   latent0: rho= 0.0493 ( 0.0000)  b= 0.0574 ( 0.0001)  mu_stat≈ 0.060403  var_stat≈ 2.676753e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent1: rho= 0.1040 ( 0.0000)  b=-0.0027 ( 0.0000)  mu_stat≈-0.003001  var_stat≈ 4.253914e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1128 ( 0.0000)  b=-0.0020 ( 0.0000)  mu_stat≈-0.002309  var_stat≈ 4.567900e-02  half_life_steps≈ 0.32  half_life_years≈ 0.0013
#
# Regime 2:
#   latent0: rho= 0.0493 ( 0.0000)  b= 0.0574 ( 0.0000)  mu_stat≈ 0.060412  var_stat≈ 2.676502e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent1: rho= 0.1040 ( 0.0000)  b=-0.0027 ( 0.0000)  mu_stat≈-0.003000  var_stat≈ 4.253615e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1128 ( 0.0000)  b=-0.0020 ( 0.0000)  mu_stat≈-0.002310  var_stat≈ 4.567581e-02  half_life_steps≈ 0.32  half_life_years≈ 0.0013
#
# Regime 3:
#   latent0: rho= 0.0493 ( 0.0000)  b= 0.0574 ( 0.0000)  mu_stat≈ 0.060411  var_stat≈ 2.676560e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent1: rho= 0.1040 ( 0.0000)  b=-0.0027 ( 0.0000)  mu_stat≈-0.003000  var_stat≈ 4.253693e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1128 ( 0.0000)  b=-0.0020 ( 0.0000)  mu_stat≈-0.002309  var_stat≈ 4.567665e-02  half_life_steps≈ 0.32  half_life_years≈ 0.0013
#
# Regime 4:
#   latent0: rho= 0.0493 ( 0.0000)  b= 0.0574 ( 0.0000)  mu_stat≈ 0.060407  var_stat≈ 2.676760e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent1: rho= 0.1040 ( 0.0000)  b=-0.0027 ( 0.0000)  mu_stat≈-0.003001  var_stat≈ 4.253944e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1128 ( 0.0000)  b=-0.0020 ( 0.0000)  mu_stat≈-0.002309  var_stat≈ 4.567933e-02  half_life_steps≈ 0.32  half_life_years≈ 0.0013
#
# Regime 5:
#   latent0: rho= 0.0493 ( 0.0000)  b= 0.0574 ( 0.0000)  mu_stat≈ 0.060417  var_stat≈ 2.676268e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent1: rho= 0.1040 ( 0.0000)  b=-0.0027 ( 0.0000)  mu_stat≈-0.002999  var_stat≈ 4.253307e-02  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#   latent2: rho= 0.1128 ( 0.0000)  b=-0.0020 ( 0.0000)  mu_stat≈-0.002310  var_stat≈ 4.567250e-02  half_life_steps≈ 0.32  half_life_years≈ 0.0013
#
# Occupancy per regime (mean% (std%) across seeds):
#   RAW:   [20.1% (42.1%), 20.0% (42.1%), 20.9% (41.7%), 29.0% (46.8%), 10.0% (31.6%), 0.0% (0.0%)]
#   CUSUM: [20.0% (42.2%), 20.0% (42.2%), 20.0% (42.2%), 20.0% (42.2%), 20.0% (42.2%), 0.0% (0.0%)]
# ARI (mean pairwise across seeds):  RAW=0.447   CUSUM=1.000
#
# ========== STABILITY (security=TSM, batch=2  t0=504  t1=1764) ==========
#
# Cs  (K_or_1, N, D) = (1, 4, 3)
# [ 0.0024 ( 0.0000) -0.0016 ( 0.0000)  0.0002 ( 0.0000)]
# [ 1.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  1.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  1.0000 ( 0.0000)]
#
# ds  (K_or_1, N) = (1, 4)
# [ 0.0006 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
#
# inv_etas  (K_or_1, N) = (6, 4)
# [ 8.5353 ( 0.0000)  0.3010 ( 0.0000)  1.3242 ( 0.0000)  1.3037 ( 0.0000)]    [ 8.5353 ( 0.0000)  0.3010 ( 0.0000)  1.3242 ( 0.0000)  1.3037 ( 0.0000)]    [ 8.5353 ( 0.0000)  0.3010 ( 0.0000)  1.3242 ( 0.0000)  1.3037 ( 0.0000)]    [ 8.5353 ( 0.0000)  0.3010 ( 0.0000)  1.3242 ( 0.0000)  1.3037 ( 0.0000)]    [ 8.5353 ( 0.0000)  0.3010 ( 0.0000)  1.3242 ( 0.0000)  1.3037 ( 0.0000)]    [ 8.5353 ( 0.0000)  0.3010 ( 0.0000)  1.3242 ( 0.0000)  1.3037 ( 0.0000)]
#
# As  (K, D, D) = (6, 3, 3)
# [ 0.0400 ( 0.0153)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0366 ( 0.0313)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0458 ( 0.0108)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0425 ( 0.0088)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0425 ( 0.0043)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0411 ( 0.0164)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0971 ( 0.0086)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0976 ( 0.0044)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0922 ( 0.0094)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0972 ( 0.0040)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0936 ( 0.0118)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0941 ( 0.0123)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0980 ( 0.0100)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0954 ( 0.0037)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0932 ( 0.0104)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1010 ( 0.0062)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0951 ( 0.0059)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0959 ( 0.0087)]
#
# bs  (K, D) = (6, 3)
# [ 0.0305 ( 0.0103) -0.0070 ( 0.0085) -0.0119 ( 0.0058)]    [ 0.0379 ( 0.0109) -0.0113 ( 0.0077) -0.0113 ( 0.0086)]    [ 0.0317 ( 0.0105) -0.0050 ( 0.0094) -0.0113 ( 0.0072)]    [ 0.0316 ( 0.0062) -0.0100 ( 0.0037) -0.0124 ( 0.0104)]    [ 0.0275 ( 0.0054) -0.0076 ( 0.0068) -0.0064 ( 0.0068)]    [ 0.0308 ( 0.0138) -0.0033 ( 0.0097) -0.0092 ( 0.0085)]
#
# sigmasq  (K, D) = (6, 3)
# [ 0.0293 ( 0.0116)  0.0391 ( 0.0154)  0.0385 ( 0.0151)]    [ 0.0327 ( 0.0056)  0.0436 ( 0.0079)  0.0430 ( 0.0078)]    [ 0.0301 ( 0.0098)  0.0402 ( 0.0132)  0.0397 ( 0.0130)]    [ 0.0274 ( 0.0121)  0.0366 ( 0.0163)  0.0361 ( 0.0160)]    [ 0.0293 ( 0.0116)  0.0391 ( 0.0154)  0.0385 ( 0.0151)]    [ 0.0303 ( 0.0091)  0.0405 ( 0.0122)  0.0400 ( 0.0120)]
#
# Rs  (K, D) = (6, 3)
# [ 0.1363 ( 0.4718) -0.0579 ( 0.2070)  0.1784 ( 0.4424)]    [-0.2225 ( 0.8778) -0.0985 ( 0.2995)  0.0049 ( 0.4709)]    [-0.1518 ( 0.2676)  0.1597 ( 0.5395) -0.1024 ( 0.3368)]    [-0.0718 ( 0.6787) -0.0103 ( 0.6623) -0.1175 ( 0.5212)]    [ 0.2356 ( 0.7322) -0.0036 ( 0.1121)  0.0166 ( 0.0947)]    [ 0.0670 ( 0.2094)  0.0106 ( 0.0531)  0.0162 ( 0.1769)]
#
# r  (K,) = (6,)
# [-2.2377 ( 1.0669)  3.5462 ( 4.5612) -2.1439 ( 1.2611)  0.1168 ( 2.9960)  2.1506 ( 4.9181) -1.4320 ( 1.4508)]
#
# Interpretable AR(1) parameters (mean±std over seeds)
# Regime 0:
#   latent0: rho= 0.0400 ( 0.0153)  b= 0.0305 ( 0.0103)  mu_stat≈ 0.031782  var_stat≈ 2.938515e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent1: rho= 0.0971 ( 0.0086)  b=-0.0070 ( 0.0085)  mu_stat≈-0.007699  var_stat≈ 3.943899e-02  half_life_steps≈ 0.30  half_life_years≈ 0.0012
#   latent2: rho= 0.0980 ( 0.0100)  b=-0.0119 ( 0.0058)  mu_stat≈-0.013218  var_stat≈ 3.891882e-02  half_life_steps≈ 0.30  half_life_years≈ 0.0012
#
# Regime 1:
#   latent0: rho= 0.0366 ( 0.0313)  b= 0.0379 ( 0.0109)  mu_stat≈ 0.039367  var_stat≈ 3.269649e-02  half_life_steps≈ 0.21  half_life_years≈ 0.0008
#   latent1: rho= 0.0976 ( 0.0044)  b=-0.0113 ( 0.0077)  mu_stat≈-0.012566  var_stat≈ 4.398950e-02  half_life_steps≈ 0.30  half_life_years≈ 0.0012
#   latent2: rho= 0.0954 ( 0.0037)  b=-0.0113 ( 0.0086)  mu_stat≈-0.012447  var_stat≈ 4.337804e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0012
#
# Regime 2:
#   latent0: rho= 0.0458 ( 0.0108)  b= 0.0317 ( 0.0105)  mu_stat≈ 0.033204  var_stat≈ 3.016170e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent1: rho= 0.0922 ( 0.0094)  b=-0.0050 ( 0.0094)  mu_stat≈-0.005513  var_stat≈ 4.053884e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0012
#   latent2: rho= 0.0932 ( 0.0104)  b=-0.0113 ( 0.0072)  mu_stat≈-0.012441  var_stat≈ 3.999992e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0012
#
# Regime 3:
#   latent0: rho= 0.0425 ( 0.0088)  b= 0.0316 ( 0.0062)  mu_stat≈ 0.032956  var_stat≈ 2.741286e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent1: rho= 0.0972 ( 0.0040)  b=-0.0100 ( 0.0037)  mu_stat≈-0.011046  var_stat≈ 3.694113e-02  half_life_steps≈ 0.30  half_life_years≈ 0.0012
#   latent2: rho= 0.1010 ( 0.0062)  b=-0.0124 ( 0.0104)  mu_stat≈-0.013808  var_stat≈ 3.647219e-02  half_life_steps≈ 0.30  half_life_years≈ 0.0012
#
# Regime 4:
#   latent0: rho= 0.0425 ( 0.0043)  b= 0.0275 ( 0.0054)  mu_stat≈ 0.028747  var_stat≈ 2.939120e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent1: rho= 0.0936 ( 0.0118)  b=-0.0076 ( 0.0068)  mu_stat≈-0.008371  var_stat≈ 3.941252e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0012
#   latent2: rho= 0.0951 ( 0.0059)  b=-0.0064 ( 0.0068)  mu_stat≈-0.007038  var_stat≈ 3.889694e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0012
#
# Regime 5:
#   latent0: rho= 0.0411 ( 0.0164)  b= 0.0308 ( 0.0138)  mu_stat≈ 0.032162  var_stat≈ 3.036804e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent1: rho= 0.0941 ( 0.0123)  b=-0.0033 ( 0.0097)  mu_stat≈-0.003697  var_stat≈ 4.090308e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0012
#   latent2: rho= 0.0959 ( 0.0087)  b=-0.0092 ( 0.0085)  mu_stat≈-0.010146  var_stat≈ 4.036650e-02  half_life_steps≈ 0.30  half_life_years≈ 0.0012
#
# Occupancy per regime (mean% (std%) across seeds):
#   RAW:   [0.1% (0.0%), 50.0% (52.7%), 0.0% (0.0%), 10.0% (31.6%), 40.0% (51.6%), 0.0% (0.0%)]
#   CUSUM: [50.0% (52.7%), 0.0% (0.0%), 10.0% (31.6%), 40.0% (51.6%), 0.0% (0.0%), 0.0% (0.0%)]
# ARI (mean pairwise across seeds):  RAW=1.000   CUSUM=1.000
#
# ========== STABILITY (security=TSM, batch=3  t0=756  t1=2016) ==========
#
# Cs  (K_or_1, N, D) = (1, 4, 3)
# [ 0.0024 ( 0.0000) -0.0010 ( 0.0000)  0.0009 ( 0.0000)]
# [ 1.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  1.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  1.0000 ( 0.0000)]
#
# ds  (K_or_1, N) = (1, 4)
# [ 0.0007 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
#
# inv_etas  (K_or_1, N) = (6, 4)
# [ 8.5328 ( 0.0000)  0.2925 ( 0.0000)  1.3620 ( 0.0000)  1.1795 ( 0.0000)]    [ 8.5328 ( 0.0000)  0.2925 ( 0.0000)  1.3620 ( 0.0000)  1.1795 ( 0.0000)]    [ 8.5328 ( 0.0000)  0.2925 ( 0.0000)  1.3620 ( 0.0000)  1.1795 ( 0.0000)]    [ 8.5328 ( 0.0000)  0.2925 ( 0.0000)  1.3620 ( 0.0000)  1.1795 ( 0.0000)]    [ 8.5328 ( 0.0000)  0.2925 ( 0.0000)  1.3620 ( 0.0000)  1.1795 ( 0.0000)]    [ 8.5328 ( 0.0000)  0.2925 ( 0.0000)  1.3620 ( 0.0000)  1.1795 ( 0.0000)]
#
# As  (K, D, D) = (6, 3, 3)
# [ 0.0230 ( 0.0242)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0299 ( 0.0202)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0269 ( 0.0131)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0279 ( 0.0209)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0262 ( 0.0098)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [ 0.0185 ( 0.0215)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0986 ( 0.0073)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0995 ( 0.0077)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0966 ( 0.0078)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0951 ( 0.0100)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.1001 ( 0.0077)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0972 ( 0.0116)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0924 ( 0.0100)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0890 ( 0.0092)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0881 ( 0.0035)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0919 ( 0.0073)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0887 ( 0.0066)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0884 ( 0.0067)]
#
# bs  (K, D) = (6, 3)
# [ 0.0496 ( 0.0290) -0.0092 ( 0.0108) -0.0233 ( 0.0074)]    [ 0.0421 ( 0.0069) -0.0059 ( 0.0064) -0.0155 ( 0.0050)]    [ 0.0402 ( 0.0083) -0.0105 ( 0.0021) -0.0143 ( 0.0091)]    [ 0.0413 ( 0.0288) -0.0094 ( 0.0129) -0.0197 ( 0.0073)]    [ 0.0443 ( 0.0134) -0.0082 ( 0.0081) -0.0165 ( 0.0062)]    [ 0.0524 ( 0.0253) -0.0077 ( 0.0088) -0.0175 ( 0.0097)]
#
# sigmasq  (K, D) = (6, 3)
# [ 0.0309 ( 0.0101)  0.0418 ( 0.0142)  0.0369 ( 0.0125)]    [ 0.0304 ( 0.0114)  0.0413 ( 0.0157)  0.0365 ( 0.0138)]    [ 0.0330 ( 0.0087)  0.0449 ( 0.0119)  0.0396 ( 0.0105)]    [ 0.0309 ( 0.0101)  0.0418 ( 0.0142)  0.0369 ( 0.0125)]    [ 0.0330 ( 0.0084)  0.0450 ( 0.0115)  0.0397 ( 0.0102)]    [ 0.0309 ( 0.0099)  0.0420 ( 0.0139)  0.0371 ( 0.0122)]
#
# Rs  (K, D) = (6, 3)
# [-0.0021 ( 0.1459)  0.0150 ( 0.0553) -0.0062 ( 0.0503)]    [-0.0376 ( 0.0741) -0.0118 ( 0.0780)  0.0160 ( 0.0986)]    [ 0.0943 ( 0.1190) -0.0276 ( 0.0767) -0.0027 ( 0.0708)]    [-0.0391 ( 0.0471)  0.0169 ( 0.0251)  0.0186 ( 0.0218)]    [-0.0072 ( 0.0688)  0.0091 ( 0.0262) -0.0119 ( 0.0585)]    [-0.0047 ( 0.0857) -0.0038 ( 0.0475) -0.0163 ( 0.0596)]
#
# r  (K,) = (6,)
# [-0.8546 ( 3.4910) -0.3837 ( 3.4622)  2.7817 ( 4.1164) -1.6577 ( 1.5279) -0.0626 ( 4.2626)  0.1769 ( 4.4458)]
#
# Interpretable AR(1) parameters (mean±std over seeds)
# Regime 0:
#   latent0: rho= 0.0230 ( 0.0242)  b= 0.0496 ( 0.0290)  mu_stat≈ 0.050718  var_stat≈ 3.088673e-02  half_life_steps≈ 0.18  half_life_years≈ 0.0007
#   latent1: rho= 0.0986 ( 0.0073)  b=-0.0092 ( 0.0108)  mu_stat≈-0.010206  var_stat≈ 4.225546e-02  half_life_steps≈ 0.30  half_life_years≈ 0.0012
#   latent2: rho= 0.0924 ( 0.0100)  b=-0.0233 ( 0.0074)  mu_stat≈-0.025717  var_stat≈ 3.725661e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0012
#
# Regime 1:
#   latent0: rho= 0.0299 ( 0.0202)  b= 0.0421 ( 0.0069)  mu_stat≈ 0.043439  var_stat≈ 3.039217e-02  half_life_steps≈ 0.20  half_life_years≈ 0.0008
#   latent1: rho= 0.0995 ( 0.0077)  b=-0.0059 ( 0.0064)  mu_stat≈-0.006536  var_stat≈ 4.174669e-02  half_life_steps≈ 0.30  half_life_years≈ 0.0012
#   latent2: rho= 0.0890 ( 0.0092)  b=-0.0155 ( 0.0050)  mu_stat≈-0.016960  var_stat≈ 3.677677e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0011
#
# Regime 2:
#   latent0: rho= 0.0269 ( 0.0131)  b= 0.0402 ( 0.0083)  mu_stat≈ 0.041333  var_stat≈ 3.298229e-02  half_life_steps≈ 0.19  half_life_years≈ 0.0008
#   latent1: rho= 0.0966 ( 0.0078)  b=-0.0105 ( 0.0021)  mu_stat≈-0.011657  var_stat≈ 4.530058e-02  half_life_steps≈ 0.30  half_life_years≈ 0.0012
#   latent2: rho= 0.0881 ( 0.0035)  b=-0.0143 ( 0.0091)  mu_stat≈-0.015663  var_stat≈ 3.992357e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0011
#
# Regime 3:
#   latent0: rho= 0.0279 ( 0.0209)  b= 0.0413 ( 0.0288)  mu_stat≈ 0.042438  var_stat≈ 3.089433e-02  half_life_steps≈ 0.19  half_life_years≈ 0.0008
#   latent1: rho= 0.0951 ( 0.0100)  b=-0.0094 ( 0.0129)  mu_stat≈-0.010342  var_stat≈ 4.222665e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0012
#   latent2: rho= 0.0919 ( 0.0073)  b=-0.0197 ( 0.0073)  mu_stat≈-0.021729  var_stat≈ 3.725318e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0012
#
# Regime 4:
#   latent0: rho= 0.0262 ( 0.0098)  b= 0.0443 ( 0.0134)  mu_stat≈ 0.045515  var_stat≈ 3.305079e-02  half_life_steps≈ 0.19  half_life_years≈ 0.0008
#   latent1: rho= 0.1001 ( 0.0077)  b=-0.0082 ( 0.0081)  mu_stat≈-0.009165  var_stat≈ 4.546092e-02  half_life_steps≈ 0.30  half_life_years≈ 0.0012
#   latent2: rho= 0.0887 ( 0.0066)  b=-0.0165 ( 0.0062)  mu_stat≈-0.018142  var_stat≈ 4.004173e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0011
#
# Regime 5:
#   latent0: rho= 0.0185 ( 0.0215)  b= 0.0524 ( 0.0253)  mu_stat≈ 0.053341  var_stat≈ 3.095072e-02  half_life_steps≈ 0.17  half_life_years≈ 0.0007
#   latent1: rho= 0.0972 ( 0.0116)  b=-0.0077 ( 0.0088)  mu_stat≈-0.008561  var_stat≈ 4.237235e-02  half_life_steps≈ 0.30  half_life_years≈ 0.0012
#   latent2: rho= 0.0884 ( 0.0067)  b=-0.0175 ( 0.0097)  mu_stat≈-0.019198  var_stat≈ 3.734377e-02  half_life_steps≈ 0.29  half_life_years≈ 0.0011
#
# Occupancy per regime (mean% (std%) across seeds):
#   RAW:   [10.1% (31.6%), 10.0% (31.6%), 40.0% (51.6%), 0.0% (0.0%), 20.0% (42.1%), 20.0% (42.1%)]
#   CUSUM: [10.0% (31.6%), 10.0% (31.6%), 40.0% (51.6%), 0.0% (0.0%), 20.0% (42.2%), 20.0% (42.2%)]
# ARI (mean pairwise across seeds):  RAW=0.800   CUSUM=1.000
#
# ========== STABILITY (security=TSM, batch=4  t0=1008  t1=2268) ==========
#
# Cs  (K_or_1, N, D) = (1, 4, 3)
# [ 0.0018 ( 0.0000) -0.0009 ( 0.0000)  0.0011 ( 0.0000)]
# [ 1.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  1.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  1.0000 ( 0.0000)]
#
# ds  (K_or_1, N) = (1, 4)
# [ 0.0012 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
#
# inv_etas  (K_or_1, N) = (6, 4)
# [ 8.4728 ( 0.0000) -0.4099 ( 0.0000)  0.7965 ( 0.0000)  0.2309 ( 0.0000)]    [ 8.4728 ( 0.0000) -0.4099 ( 0.0000)  0.7965 ( 0.0000)  0.2309 ( 0.0000)]    [ 8.4728 ( 0.0000) -0.4099 ( 0.0000)  0.7965 ( 0.0000)  0.2309 ( 0.0000)]    [ 8.4728 ( 0.0000) -0.4099 ( 0.0000)  0.7965 ( 0.0000)  0.2309 ( 0.0000)]    [ 8.4728 ( 0.0000) -0.4099 ( 0.0000)  0.7965 ( 0.0000)  0.2309 ( 0.0000)]    [ 8.4728 ( 0.0000) -0.4099 ( 0.0000)  0.7965 ( 0.0000)  0.2309 ( 0.0000)]
#
# As  (K, D, D) = (6, 3, 3)
# [-0.4438 ( 0.2990)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.2868 ( 0.3820)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.1358 ( 0.5584)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.4521 ( 0.6153)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.4519 ( 0.4383)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.3836 ( 0.5486)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0646 ( 0.0079)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0687 ( 0.0115)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0636 ( 0.0087)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0678 ( 0.0068)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0730 ( 0.0189)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0690 ( 0.0228)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1834 ( 0.1282)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1387 ( 0.0151)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1492 ( 0.0200)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1428 ( 0.0428)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1344 ( 0.0292)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1545 ( 0.0308)]
#
# bs  (K, D) = (6, 3)
# [-0.4459 ( 1.0873)  0.0089 ( 0.0072) -0.0126 ( 0.0441)]    [-0.2644 ( 0.8753)  0.0075 ( 0.0074) -0.0238 ( 0.0127)]    [-0.2380 ( 0.5283)  0.0056 ( 0.0089) -0.0223 ( 0.0287)]    [-0.5472 ( 1.1938)  0.0065 ( 0.0077) -0.0319 ( 0.0253)]    [-0.0615 ( 0.9417)  0.0055 ( 0.0106) -0.0254 ( 0.0307)]    [ 0.0823 ( 0.3806)  0.0100 ( 0.0176) -0.0183 ( 0.0274)]
#
# sigmasq  (K, D) = (6, 3)
# [ 2.3626 ( 3.9973)  0.0207 ( 0.0137)  0.0273 ( 0.0200)]    [ 0.3611 ( 0.3341)  0.0220 ( 0.0152)  0.0268 ( 0.0187)]    [ 0.8852 ( 0.6224)  0.0258 ( 0.0137)  0.0311 ( 0.0158)]    [ 2.4930 ( 3.9576)  0.0166 ( 0.0105)  0.0205 ( 0.0134)]    [ 1.3326 ( 2.4418)  0.0212 ( 0.0115)  0.0260 ( 0.0151)]    [ 0.7326 ( 0.8950)  0.0182 ( 0.0112)  0.0214 ( 0.0130)]
#
# Rs  (K, D) = (6, 3)
# [ 0.0280 ( 0.2976) -0.1251 ( 0.3090)  0.0664 ( 0.4223)]    [-0.2731 ( 0.2638)  0.1312 ( 0.5410)  0.0319 ( 0.7964)]    [-0.0584 ( 0.3208)  0.2700 ( 0.7590) -0.0874 ( 0.5020)]    [ 0.2335 ( 0.6520) -0.1138 ( 0.3623)  0.0197 ( 0.4243)]    [ 0.1807 ( 0.3566) -0.2257 ( 0.6966) -0.1734 ( 0.8759)]    [-0.1144 ( 0.4830)  0.0681 ( 0.4383)  0.1376 ( 0.2449)]
#
# r  (K,) = (6,)
# [ 1.1249 ( 3.4551) -0.0242 ( 3.2739)  1.2839 ( 3.8042) -1.1000 ( 1.7875)  0.6208 ( 3.4563) -1.9054 ( 1.4473)]
#
# Interpretable AR(1) parameters (mean±std over seeds)
# Regime 0:
#   latent0: rho=-0.4438 ( 0.2990)  b=-0.4459 ( 1.0873)  mu_stat≈-0.308842  var_stat≈ 2.942146e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0646 ( 0.0079)  b= 0.0089 ( 0.0072)  mu_stat≈ 0.009464  var_stat≈ 2.082878e-02  half_life_steps≈ 0.25  half_life_years≈ 0.0010
#   latent2: rho= 0.1834 ( 0.1282)  b=-0.0126 ( 0.0441)  mu_stat≈-0.015430  var_stat≈ 2.826148e-02  half_life_steps≈ 0.41  half_life_years≈ 0.0016
#
# Regime 1:
#   latent0: rho=-0.2868 ( 0.3820)  b=-0.2644 ( 0.8753)  mu_stat≈-0.205475  var_stat≈ 3.934214e-01  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0687 ( 0.0115)  b= 0.0075 ( 0.0074)  mu_stat≈ 0.008014  var_stat≈ 2.207919e-02  half_life_steps≈ 0.26  half_life_years≈ 0.0010
#   latent2: rho= 0.1387 ( 0.0151)  b=-0.0238 ( 0.0127)  mu_stat≈-0.027672  var_stat≈ 2.730198e-02  half_life_steps≈ 0.35  half_life_years≈ 0.0014
#
# Regime 2:
#   latent0: rho=-0.1358 ( 0.5584)  b=-0.2380 ( 0.5283)  mu_stat≈-0.209510  var_stat≈ 9.017919e-01  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0636 ( 0.0087)  b= 0.0056 ( 0.0089)  mu_stat≈ 0.005933  var_stat≈ 2.594417e-02  half_life_steps≈ 0.25  half_life_years≈ 0.0010
#   latent2: rho= 0.1492 ( 0.0200)  b=-0.0223 ( 0.0287)  mu_stat≈-0.026186  var_stat≈ 3.177850e-02  half_life_steps≈ 0.36  half_life_years≈ 0.0014
#
# Regime 3:
#   latent0: rho=-0.4521 ( 0.6153)  b=-0.5472 ( 1.1938)  mu_stat≈-0.376823  var_stat≈ 3.133332e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0678 ( 0.0068)  b= 0.0065 ( 0.0077)  mu_stat≈ 0.006989  var_stat≈ 1.667725e-02  half_life_steps≈ 0.26  half_life_years≈ 0.0010
#   latent2: rho= 0.1428 ( 0.0428)  b=-0.0319 ( 0.0253)  mu_stat≈-0.037162  var_stat≈ 2.094882e-02  half_life_steps≈ 0.36  half_life_years≈ 0.0014
#
# Regime 4:
#   latent0: rho=-0.4519 ( 0.4383)  b=-0.0615 ( 0.9417)  mu_stat≈-0.042350  var_stat≈ 1.674565e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0730 ( 0.0189)  b= 0.0055 ( 0.0106)  mu_stat≈ 0.005960  var_stat≈ 2.127221e-02  half_life_steps≈ 0.26  half_life_years≈ 0.0011
#   latent2: rho= 0.1344 ( 0.0292)  b=-0.0254 ( 0.0307)  mu_stat≈-0.029351  var_stat≈ 2.648042e-02  half_life_steps≈ 0.35  half_life_years≈ 0.0014
#
# Regime 5:
#   latent0: rho=-0.3836 ( 0.5486)  b= 0.0823 ( 0.3806)  mu_stat≈ 0.059474  var_stat≈ 8.589525e-01  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0690 ( 0.0228)  b= 0.0100 ( 0.0176)  mu_stat≈ 0.010787  var_stat≈ 1.828099e-02  half_life_steps≈ 0.26  half_life_years≈ 0.0010
#   latent2: rho= 0.1545 ( 0.0308)  b=-0.0183 ( 0.0274)  mu_stat≈-0.021608  var_stat≈ 2.197055e-02  half_life_steps≈ 0.37  half_life_years≈ 0.0015
#
# Occupancy per regime (mean% (std%) across seeds):
#   RAW:   [27.3% (42.4%), 19.5% (41.0%), 31.0% (47.1%), 0.6% (1.3%), 21.6% (39.9%), 0.2% (0.4%)]
#   CUSUM: [24.5% (39.2%), 19.5% (41.1%), 31.5% (47.1%), 0.5% (1.3%), 23.8% (40.6%), 0.2% (0.3%)]
# ARI (mean pairwise across seeds):  RAW=0.247   CUSUM=0.153
#
# ========== STABILITY (security=TSM, batch=5  t0=1260  t1=2520) ==========
#
# Cs  (K_or_1, N, D) = (1, 4, 3)
# [ 0.0020 ( 0.0000) -0.0013 ( 0.0000)  0.0008 ( 0.0000)]
# [ 1.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  1.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  1.0000 ( 0.0000)]
#
# ds  (K_or_1, N) = (1, 4)
# [ 0.0010 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
#
# inv_etas  (K_or_1, N) = (6, 4)
# [ 8.4256 ( 0.0000) -0.4173 ( 0.0000)  0.6286 ( 0.0000)  0.0083 ( 0.0000)]    [ 8.4256 ( 0.0000) -0.4173 ( 0.0000)  0.6286 ( 0.0000)  0.0083 ( 0.0000)]    [ 8.4256 ( 0.0000) -0.4173 ( 0.0000)  0.6286 ( 0.0000)  0.0083 ( 0.0000)]    [ 8.4256 ( 0.0000) -0.4173 ( 0.0000)  0.6286 ( 0.0000)  0.0083 ( 0.0000)]    [ 8.4256 ( 0.0000) -0.4173 ( 0.0000)  0.6286 ( 0.0000)  0.0083 ( 0.0000)]    [ 8.4256 ( 0.0000) -0.4173 ( 0.0000)  0.6286 ( 0.0000)  0.0083 ( 0.0000)]
#
# As  (K, D, D) = (6, 3, 3)
# [-0.4652 ( 0.2443)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.3075 ( 0.1559)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.3665 ( 0.3156)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.2468 ( 0.5275)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.2465 ( 0.5734)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.2314 ( 0.2152)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0557 ( 0.0132)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0494 ( 0.0150)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0547 ( 0.0087)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0582 ( 0.0077)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0560 ( 0.0045)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0594 ( 0.0088)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.2322 ( 0.2144)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.2377 ( 0.2219)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.3471 ( 0.2249)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.3759 ( 0.3083)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.3447 ( 0.2876)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.4425 ( 0.3085)]
#
# bs  (K, D) = (6, 3)
# [ 0.2204 ( 0.7345) -0.0077 ( 0.0168)  0.0031 ( 0.0840)]    [ 0.0617 ( 0.1878) -0.0027 ( 0.0172)  0.0309 ( 0.0453)]    [-0.0364 ( 0.2384) -0.0073 ( 0.0132)  0.0036 ( 0.0526)]    [-0.2932 ( 0.4718) -0.0065 ( 0.0153) -0.0047 ( 0.0795)]    [-0.1438 ( 0.5034) -0.0104 ( 0.0118)  0.0172 ( 0.0629)]    [ 0.0879 ( 0.8406) -0.0073 ( 0.0170)  0.0152 ( 0.0793)]
#
# sigmasq  (K, D) = (6, 3)
# [ 1.4600 ( 2.2659)  0.0186 ( 0.0127)  0.0792 ( 0.0618)]    [ 0.9666 ( 2.0708)  0.0228 ( 0.0124)  0.0872 ( 0.0587)]    [ 1.0581 ( 0.8788)  0.0250 ( 0.0116)  0.1166 ( 0.0772)]    [ 2.6304 ( 2.6533)  0.0221 ( 0.0106)  0.1055 ( 0.0762)]    [ 1.4508 ( 1.4439)  0.0224 ( 0.0095)  0.1043 ( 0.0649)]    [ 1.7800 ( 1.8167)  0.0230 ( 0.0113)  0.1103 ( 0.0680)]
#
# Rs  (K, D) = (6, 3)
# [ 0.0099 ( 0.4056)  0.0703 ( 0.8636)  0.4935 ( 0.8602)]    [ 0.0640 ( 0.3354) -0.0787 ( 0.4610) -0.1516 ( 0.6243)]    [ 0.1469 ( 0.1981)  0.0795 ( 0.5078)  0.3582 ( 1.0976)]    [-0.1477 ( 0.1424) -0.2117 ( 0.3091) -0.4605 ( 1.0286)]    [ 0.0220 ( 0.2130)  0.2357 ( 0.4139) -0.6794 ( 1.3510)]    [-0.0981 ( 0.1469) -0.0953 ( 0.3682)  0.4444 ( 1.0958)]
#
# r  (K,) = (6,)
# [-0.9417 ( 2.5982) -0.5651 ( 3.3264)  1.8379 ( 3.4760) -0.5473 ( 2.9933)  0.9326 ( 2.0183) -0.7164 ( 2.9329)]
#
# Interpretable AR(1) parameters (mean±std over seeds)
# Regime 0:
#   latent0: rho=-0.4652 ( 0.2443)  b= 0.2204 ( 0.7345)  mu_stat≈ 0.150406  var_stat≈ 1.863106e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0557 ( 0.0132)  b=-0.0077 ( 0.0168)  mu_stat≈-0.008196  var_stat≈ 1.860983e-02  half_life_steps≈ 0.24  half_life_years≈ 0.0010
#   latent2: rho= 0.2322 ( 0.2144)  b= 0.0031 ( 0.0840)  mu_stat≈ 0.004058  var_stat≈ 8.366441e-02  half_life_steps≈ 0.47  half_life_years≈ 0.0019
#
# Regime 1:
#   latent0: rho=-0.3075 ( 0.1559)  b= 0.0617 ( 0.1878)  mu_stat≈ 0.047181  var_stat≈ 1.067607e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0494 ( 0.0150)  b=-0.0027 ( 0.0172)  mu_stat≈-0.002813  var_stat≈ 2.288053e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.2377 ( 0.2219)  b= 0.0309 ( 0.0453)  mu_stat≈ 0.040601  var_stat≈ 9.245078e-02  half_life_steps≈ 0.48  half_life_years≈ 0.0019
#
# Regime 2:
#   latent0: rho=-0.3665 ( 0.3156)  b=-0.0364 ( 0.2384)  mu_stat≈-0.026657  var_stat≈ 1.222306e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0547 ( 0.0087)  b=-0.0073 ( 0.0132)  mu_stat≈-0.007771  var_stat≈ 2.507137e-02  half_life_steps≈ 0.24  half_life_years≈ 0.0009
#   latent2: rho= 0.3471 ( 0.2249)  b= 0.0036 ( 0.0526)  mu_stat≈ 0.005532  var_stat≈ 1.325917e-01  half_life_steps≈ 0.66  half_life_years≈ 0.0026
#
# Regime 3:
#   latent0: rho=-0.2468 ( 0.5275)  b=-0.2932 ( 0.4718)  mu_stat≈-0.235140  var_stat≈ 2.801038e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0582 ( 0.0077)  b=-0.0065 ( 0.0153)  mu_stat≈-0.006937  var_stat≈ 2.216435e-02  half_life_steps≈ 0.24  half_life_years≈ 0.0010
#   latent2: rho= 0.3759 ( 0.3083)  b=-0.0047 ( 0.0795)  mu_stat≈-0.007473  var_stat≈ 1.228310e-01  half_life_steps≈ 0.71  half_life_years≈ 0.0028
#
# Regime 4:
#   latent0: rho=-0.2465 ( 0.5734)  b=-0.1438 ( 0.5034)  mu_stat≈-0.115346  var_stat≈ 1.544682e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0560 ( 0.0045)  b=-0.0104 ( 0.0118)  mu_stat≈-0.011014  var_stat≈ 2.246238e-02  half_life_steps≈ 0.24  half_life_years≈ 0.0010
#   latent2: rho= 0.3447 ( 0.2876)  b= 0.0172 ( 0.0629)  mu_stat≈ 0.026246  var_stat≈ 1.183661e-01  half_life_steps≈ 0.65  half_life_years≈ 0.0026
#
# Regime 5:
#   latent0: rho=-0.2314 ( 0.2152)  b= 0.0879 ( 0.8406)  mu_stat≈ 0.071414  var_stat≈ 1.880693e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0594 ( 0.0088)  b=-0.0073 ( 0.0170)  mu_stat≈-0.007728  var_stat≈ 2.305955e-02  half_life_steps≈ 0.25  half_life_years≈ 0.0010
#   latent2: rho= 0.4425 ( 0.3085)  b= 0.0152 ( 0.0793)  mu_stat≈ 0.027233  var_stat≈ 1.371749e-01  half_life_steps≈ 0.85  half_life_years≈ 0.0034
#
# Occupancy per regime (mean% (std%) across seeds):
#   RAW:   [9.4% (26.3%), 26.8% (43.1%), 32.1% (42.7%), 10.1% (26.9%), 11.1% (26.3%), 10.6% (29.7%)]
#   CUSUM: [9.0% (26.0%), 26.6% (42.9%), 32.9% (43.4%), 10.2% (27.3%), 10.7% (25.6%), 10.6% (29.9%)]
# ARI (mean pairwise across seeds):  RAW=0.508   CUSUM=0.465
#
# ========== STABILITY (security=TSM, batch=6  t0=1512  t1=2772) ==========
#
# Cs  (K_or_1, N, D) = (1, 4, 3)
# [ 0.0019 ( 0.0000) -0.0010 ( 0.0000)  0.0011 ( 0.0000)]
# [ 1.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  1.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  1.0000 ( 0.0000)]
#
# ds  (K_or_1, N) = (1, 4)
# [ 0.0005 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
#
# inv_etas  (K_or_1, N) = (6, 4)
# [ 8.1893 ( 0.0000) -0.6858 ( 0.0000)  0.5902 ( 0.0000) -0.2083 ( 0.0000)]    [ 8.1893 ( 0.0000) -0.6858 ( 0.0000)  0.5902 ( 0.0000) -0.2083 ( 0.0000)]    [ 8.1893 ( 0.0000) -0.6858 ( 0.0000)  0.5902 ( 0.0000) -0.2083 ( 0.0000)]    [ 8.1893 ( 0.0000) -0.6858 ( 0.0000)  0.5902 ( 0.0000) -0.2083 ( 0.0000)]    [ 8.1893 ( 0.0000) -0.6858 ( 0.0000)  0.5902 ( 0.0000) -0.2083 ( 0.0000)]    [ 8.1893 ( 0.0000) -0.6858 ( 0.0000)  0.5902 ( 0.0000) -0.2083 ( 0.0000)]
#
# As  (K, D, D) = (6, 3, 3)
# [-0.2229 ( 0.2828)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.2831 ( 0.2612)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.3249 ( 0.2058)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.2684 ( 0.2862)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.5163 ( 0.4120)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.3943 ( 0.2733)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0461 ( 0.0051)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0446 ( 0.0068)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0495 ( 0.0053)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0475 ( 0.0090)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0442 ( 0.0072)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0498 ( 0.0076)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1123 ( 0.1183)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1265 ( 0.0846)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1124 ( 0.1097)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1407 ( 0.0999)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000) -0.0551 ( 0.2366)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1414 ( 0.2108)]
#
# bs  (K, D) = (6, 3)
# [ 0.1194 ( 0.0913) -0.0033 ( 0.0079) -0.0442 ( 0.0538)]    [ 0.1950 ( 0.3967) -0.0033 ( 0.0107)  0.0377 ( 0.1096)]    [ 0.1700 ( 0.6841) -0.0042 ( 0.0085) -0.0609 ( 0.2121)]    [-0.1925 ( 0.3504) -0.0054 ( 0.0048)  0.0276 ( 0.1033)]    [ 0.5660 ( 1.3921) -0.0023 ( 0.0045)  0.0150 ( 0.1050)]    [-0.0996 ( 0.4638) -0.0049 ( 0.0127)  0.0119 ( 0.1227)]
#
# sigmasq  (K, D) = (6, 3)
# [ 1.0441 ( 1.0939)  0.0257 ( 0.0105)  0.4666 ( 0.4942)]    [ 3.4859 ( 4.5683)  0.0194 ( 0.0098)  0.4981 ( 0.5891)]    [ 3.1516 ( 4.1550)  0.0248 ( 0.0110)  0.3808 ( 0.2075)]    [ 2.5314 ( 3.3657)  0.0224 ( 0.0104)  0.6059 ( 0.6675)]    [ 2.6060 ( 4.0224)  0.0137 ( 0.0087)  0.3880 ( 0.5715)]    [ 4.0981 ( 3.7567)  0.0234 ( 0.0110)  0.7594 ( 0.7191)]
#
# Rs  (K, D) = (6, 3)
# [-0.0130 ( 0.2322)  0.0467 ( 0.6396)  0.2017 ( 0.6139)]    [ 0.1409 ( 0.4249)  0.0776 ( 0.1836)  0.2569 ( 0.5724)]    [-0.1337 ( 0.3525) -0.0063 ( 0.5995) -0.0831 ( 1.2779)]    [-0.0076 ( 0.4150)  0.0284 ( 0.2671) -0.6165 ( 0.9228)]    [ 0.1049 ( 0.4577) -0.1452 ( 0.3183) -0.1612 ( 0.8078)]    [-0.0922 ( 0.2796) -0.0031 ( 0.3091)  0.3997 ( 1.0821)]
#
# r  (K,) = (6,)
# [ 1.3810 ( 3.5377) -0.7892 ( 2.8277) -0.0240 ( 3.3449)  0.9091 ( 2.7098) -0.4746 ( 2.9498) -1.0023 ( 3.0144)]
#
# Interpretable AR(1) parameters (mean±std over seeds)
# Regime 0:
#   latent0: rho=-0.2229 ( 0.2828)  b= 0.1194 ( 0.0913)  mu_stat≈ 0.097631  var_stat≈ 1.098700e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0461 ( 0.0051)  b=-0.0033 ( 0.0079)  mu_stat≈-0.003504  var_stat≈ 2.571736e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.1123 ( 0.1183)  b=-0.0442 ( 0.0538)  mu_stat≈-0.049812  var_stat≈ 4.725062e-01  half_life_steps≈ 0.32  half_life_years≈ 0.0013
#
# Regime 1:
#   latent0: rho=-0.2831 ( 0.2612)  b= 0.1950 ( 0.3967)  mu_stat≈ 0.151942  var_stat≈ 3.789517e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0446 ( 0.0068)  b=-0.0033 ( 0.0107)  mu_stat≈-0.003483  var_stat≈ 1.944535e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent2: rho= 0.1265 ( 0.0846)  b= 0.0377 ( 0.1096)  mu_stat≈ 0.043152  var_stat≈ 5.061492e-01  half_life_steps≈ 0.34  half_life_years≈ 0.0013
#
# Regime 2:
#   latent0: rho=-0.3249 ( 0.2058)  b= 0.1700 ( 0.6841)  mu_stat≈ 0.128300  var_stat≈ 3.523585e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0495 ( 0.0053)  b=-0.0042 ( 0.0085)  mu_stat≈-0.004369  var_stat≈ 2.482849e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.1124 ( 0.1097)  b=-0.0609 ( 0.2121)  mu_stat≈-0.068637  var_stat≈ 3.856873e-01  half_life_steps≈ 0.32  half_life_years≈ 0.0013
#
# Regime 3:
#   latent0: rho=-0.2684 ( 0.2862)  b=-0.1925 ( 0.3504)  mu_stat≈-0.151791  var_stat≈ 2.728006e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0475 ( 0.0090)  b=-0.0054 ( 0.0048)  mu_stat≈-0.005691  var_stat≈ 2.241799e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.1407 ( 0.0999)  b= 0.0276 ( 0.1033)  mu_stat≈ 0.032174  var_stat≈ 6.180854e-01  half_life_steps≈ 0.35  half_life_years≈ 0.0014
#
# Regime 4:
#   latent0: rho=-0.5163 ( 0.4120)  b= 0.5660 ( 1.3921)  mu_stat≈ 0.373266  var_stat≈ 3.553245e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0442 ( 0.0072)  b=-0.0023 ( 0.0045)  mu_stat≈-0.002417  var_stat≈ 1.372231e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent2: rho=-0.0551 ( 0.2366)  b= 0.0150 ( 0.1050)  mu_stat≈ 0.014206  var_stat≈ 3.892047e-01  half_life_steps≈ inf  half_life_years≈ nan
#
# Regime 5:
#   latent0: rho=-0.3943 ( 0.2733)  b=-0.0996 ( 0.4638)  mu_stat≈-0.071468  var_stat≈ 4.852594e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0498 ( 0.0076)  b=-0.0049 ( 0.0127)  mu_stat≈-0.005174  var_stat≈ 2.348486e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.1414 ( 0.2108)  b= 0.0119 ( 0.1227)  mu_stat≈ 0.013875  var_stat≈ 7.748978e-01  half_life_steps≈ 0.35  half_life_years≈ 0.0014
#
# Occupancy per regime (mean% (std%) across seeds):
#   RAW:   [37.3% (48.1%), 10.0% (31.5%), 19.6% (40.7%), 12.5% (30.6%), 10.1% (31.6%), 10.5% (31.2%)]
#   CUSUM: [37.3% (48.4%), 10.0% (31.6%), 19.7% (41.2%), 12.5% (31.0%), 10.1% (31.6%), 10.3% (31.4%)]
# ARI (mean pairwise across seeds):  RAW=0.279   CUSUM=0.237
#
# ========== STABILITY (security=TSM, batch=7  t0=1764  t1=3024) ==========
#
# Cs  (K_or_1, N, D) = (1, 4, 3)
# [ 0.0017 ( 0.0000) -0.0007 ( 0.0000)  0.0010 ( 0.0000)]
# [ 1.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  1.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  1.0000 ( 0.0000)]
#
# ds  (K_or_1, N) = (1, 4)
# [ 0.0007 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
#
# inv_etas  (K_or_1, N) = (6, 4)
# [ 8.2537 ( 0.0000) -0.6305 ( 0.0000)  0.5010 ( 0.0000) -0.2464 ( 0.0000)]    [ 8.2537 ( 0.0000) -0.6305 ( 0.0000)  0.5010 ( 0.0000) -0.2464 ( 0.0000)]    [ 8.2537 ( 0.0000) -0.6305 ( 0.0000)  0.5010 ( 0.0000) -0.2464 ( 0.0000)]    [ 8.2537 ( 0.0000) -0.6305 ( 0.0000)  0.5010 ( 0.0000) -0.2464 ( 0.0000)]    [ 8.2537 ( 0.0000) -0.6305 ( 0.0000)  0.5010 ( 0.0000) -0.2464 ( 0.0000)]    [ 8.2537 ( 0.0000) -0.6305 ( 0.0000)  0.5010 ( 0.0000) -0.2464 ( 0.0000)]
#
# As  (K, D, D) = (6, 3, 3)
# [-0.3399 ( 0.3087)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.4050 ( 0.3694)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.2431 ( 0.3060)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.2712 ( 0.3208)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.4559 ( 0.4235)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.2867 ( 0.2836)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0433 ( 0.0067)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0455 ( 0.0086)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0464 ( 0.0049)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0464 ( 0.0120)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0501 ( 0.0058)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0485 ( 0.0052)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0386 ( 0.1415)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000) -0.0634 ( 0.2478)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0515 ( 0.2322)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1402 ( 0.1604)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000) -0.0764 ( 0.3089)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0147 ( 0.2245)]
#
# bs  (K, D) = (6, 3)
# [-0.3241 ( 0.7213) -0.0063 ( 0.0068) -0.0609 ( 0.1856)]    [-0.3372 ( 0.6979) -0.0094 ( 0.0068)  0.0766 ( 0.2024)]    [-0.4642 ( 1.4362) -0.0080 ( 0.0085)  0.0041 ( 0.0583)]    [ 0.0122 ( 0.1625) -0.0064 ( 0.0140) -0.0093 ( 0.0846)]    [-1.1204 ( 1.5937) -0.0099 ( 0.0117) -0.0397 ( 0.1133)]    [-0.7775 ( 1.6810) -0.0068 ( 0.0082) -0.0118 ( 0.1064)]
#
# sigmasq  (K, D) = (6, 3)
# [ 2.0653 ( 4.0287)  0.0221 ( 0.0134)  0.3862 ( 0.4153)]    [ 2.6754 ( 3.9317)  0.0214 ( 0.0115)  0.4760 ( 0.5235)]    [ 2.2204 ( 3.7848)  0.0163 ( 0.0121)  0.3395 ( 0.4828)]    [ 1.1732 ( 1.7603)  0.0192 ( 0.0129)  0.4750 ( 0.5695)]    [ 3.1740 ( 4.3060)  0.0138 ( 0.0116)  0.1869 ( 0.1565)]    [ 2.9172 ( 4.3033)  0.0203 ( 0.0125)  0.3742 ( 0.4128)]
#
# Rs  (K, D) = (6, 3)
# [-0.0084 ( 0.3976)  0.0070 ( 0.3814)  0.4716 ( 0.6987)]    [-0.0689 ( 0.3967)  0.0746 ( 0.4632) -0.3860 ( 0.9907)]    [ 0.2266 ( 0.3737)  0.0968 ( 0.5567) -0.3413 ( 0.8878)]    [-0.1754 ( 0.5266) -0.1006 ( 0.2807)  0.3128 ( 0.8692)]    [ 0.0055 ( 0.2977)  0.2969 ( 0.4867) -0.2815 ( 1.1879)]    [ 0.0284 ( 0.2999) -0.3646 ( 0.7931)  0.2327 ( 0.9359)]
#
# r  (K,) = (6,)
# [-0.5033 ( 3.4088)  0.2365 ( 2.8326) -0.4704 ( 2.5634)  0.3295 ( 3.6671) -0.1048 ( 3.2259)  0.5124 ( 3.7001)]
#
# Interpretable AR(1) parameters (mean±std over seeds)
# Regime 0:
#   latent0: rho=-0.3399 ( 0.3087)  b=-0.3241 ( 0.7213)  mu_stat≈-0.241909  var_stat≈ 2.334981e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0433 ( 0.0067)  b=-0.0063 ( 0.0068)  mu_stat≈-0.006571  var_stat≈ 2.210804e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent2: rho= 0.0386 ( 0.1415)  b=-0.0609 ( 0.1856)  mu_stat≈-0.063340  var_stat≈ 3.868090e-01  half_life_steps≈ 0.21  half_life_years≈ 0.0008
#
# Regime 1:
#   latent0: rho=-0.4050 ( 0.3694)  b=-0.3372 ( 0.6979)  mu_stat≈-0.239984  var_stat≈ 3.200357e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0455 ( 0.0086)  b=-0.0094 ( 0.0068)  mu_stat≈-0.009840  var_stat≈ 2.142955e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent2: rho=-0.0634 ( 0.2478)  b= 0.0766 ( 0.2024)  mu_stat≈ 0.071995  var_stat≈ 4.779418e-01  half_life_steps≈ inf  half_life_years≈ nan
#
# Regime 2:
#   latent0: rho=-0.2431 ( 0.3060)  b=-0.4642 ( 1.4362)  mu_stat≈-0.373392  var_stat≈ 2.359829e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0464 ( 0.0049)  b=-0.0080 ( 0.0085)  mu_stat≈-0.008411  var_stat≈ 1.630488e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.0515 ( 0.2322)  b= 0.0041 ( 0.0583)  mu_stat≈ 0.004337  var_stat≈ 3.403930e-01  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#
# Regime 3:
#   latent0: rho=-0.2712 ( 0.3208)  b= 0.0122 ( 0.1625)  mu_stat≈ 0.009587  var_stat≈ 1.266386e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0464 ( 0.0120)  b=-0.0064 ( 0.0140)  mu_stat≈-0.006679  var_stat≈ 1.919912e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.1402 ( 0.1604)  b=-0.0093 ( 0.0846)  mu_stat≈-0.010803  var_stat≈ 4.845657e-01  half_life_steps≈ 0.35  half_life_years≈ 0.0014
#
# Regime 4:
#   latent0: rho=-0.4559 ( 0.4235)  b=-1.1204 ( 1.5937)  mu_stat≈-0.769572  var_stat≈ 4.006735e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0501 ( 0.0058)  b=-0.0099 ( 0.0117)  mu_stat≈-0.010427  var_stat≈ 1.378497e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho=-0.0764 ( 0.3089)  b=-0.0397 ( 0.1133)  mu_stat≈-0.036927  var_stat≈ 1.880420e-01  half_life_steps≈ inf  half_life_years≈ nan
#
# Regime 5:
#   latent0: rho=-0.2867 ( 0.2836)  b=-0.7775 ( 1.6810)  mu_stat≈-0.604244  var_stat≈ 3.178582e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0485 ( 0.0052)  b=-0.0068 ( 0.0082)  mu_stat≈-0.007159  var_stat≈ 2.029813e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.0147 ( 0.2245)  b=-0.0118 ( 0.1064)  mu_stat≈-0.011938  var_stat≈ 3.742965e-01  half_life_steps≈ 0.16  half_life_years≈ 0.0007
#
# Occupancy per regime (mean% (std%) across seeds):
#   RAW:   [19.1% (40.0%), 10.2% (31.3%), 9.9% (26.7%), 20.8% (41.5%), 18.6% (39.0%), 21.4% (41.3%)]
#   CUSUM: [19.2% (40.6%), 10.1% (31.5%), 10.2% (27.2%), 20.7% (41.7%), 18.5% (39.0%), 21.3% (41.5%)]
# ARI (mean pairwise across seeds):  RAW=0.315   CUSUM=0.272
#
# ========== STABILITY (security=TSM, batch=8  t0=2016  t1=3276) ==========
#
# Cs  (K_or_1, N, D) = (1, 4, 3)
# [ 0.0020 ( 0.0000) -0.0007 ( 0.0000)  0.0008 ( 0.0000)]
# [ 1.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  1.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  1.0000 ( 0.0000)]
#
# ds  (K_or_1, N) = (1, 4)
# [ 0.0008 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
#
# inv_etas  (K_or_1, N) = (6, 4)
# [ 8.0580 ( 0.0000) -0.6407 ( 0.0000)  0.3668 ( 0.0000) -0.2782 ( 0.0000)]    [ 8.0580 ( 0.0000) -0.6407 ( 0.0000)  0.3668 ( 0.0000) -0.2782 ( 0.0000)]    [ 8.0580 ( 0.0000) -0.6407 ( 0.0000)  0.3668 ( 0.0000) -0.2782 ( 0.0000)]    [ 8.0580 ( 0.0000) -0.6407 ( 0.0000)  0.3668 ( 0.0000) -0.2782 ( 0.0000)]    [ 8.0580 ( 0.0000) -0.6407 ( 0.0000)  0.3668 ( 0.0000) -0.2782 ( 0.0000)]    [ 8.0580 ( 0.0000) -0.6407 ( 0.0000)  0.3668 ( 0.0000) -0.2782 ( 0.0000)]
#
# As  (K, D, D) = (6, 3, 3)
# [-0.1900 ( 0.5460)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.1309 ( 0.4328)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.2394 ( 0.5348)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.3795 ( 0.4321)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.0870 ( 0.5188)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.2463 ( 0.3609)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0472 ( 0.0107)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0485 ( 0.0081)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0442 ( 0.0149)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0444 ( 0.0145)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0429 ( 0.0068)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0385 ( 0.0083)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0064 ( 0.2212)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000) -0.0612 ( 0.3934)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1421 ( 0.2936)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1068 ( 0.2708)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0155 ( 0.3974)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1247 ( 0.1239)]
#
# bs  (K, D) = (6, 3)
# [ 0.0213 ( 0.5877) -0.0034 ( 0.0094)  0.0216 ( 0.0665)]    [-0.0042 ( 0.2175) -0.0068 ( 0.0075)  0.0076 ( 0.1511)]    [-0.6125 ( 1.6941) -0.0084 ( 0.0124)  0.0440 ( 0.1765)]    [ 0.3171 ( 0.8645) -0.0102 ( 0.0132)  0.0252 ( 0.0809)]    [ 0.0027 ( 0.2492) -0.0066 ( 0.0106) -0.0062 ( 0.1228)]    [ 0.0132 ( 0.0947) -0.0092 ( 0.0071) -0.0150 ( 0.0629)]
#
# sigmasq  (K, D) = (6, 3)
# [ 2.2347 ( 2.6755)  0.0230 ( 0.0108)  0.3117 ( 0.1759)]    [ 1.5183 ( 1.5752)  0.0308 ( 0.0104)  0.7013 ( 0.5089)]    [ 3.4011 ( 3.4079)  0.0216 ( 0.0130)  0.3744 ( 0.2864)]    [ 2.4467 ( 2.7284)  0.0260 ( 0.0118)  0.4679 ( 0.2720)]    [ 1.3533 ( 1.7509)  0.0186 ( 0.0133)  0.4078 ( 0.5346)]    [ 0.9022 ( 0.6346)  0.0270 ( 0.0143)  0.4129 ( 0.2310)]
#
# Rs  (K, D) = (6, 3)
# [ 0.0481 ( 0.4030)  0.2039 ( 0.7300) -0.1762 ( 0.6355)]    [-0.0345 ( 0.2014)  0.1303 ( 0.4681)  0.5145 ( 0.7806)]    [ 0.0155 ( 0.2123) -0.0459 ( 1.0700)  0.1310 ( 1.2972)]    [-0.0701 ( 0.3876) -0.0859 ( 0.7385) -0.2633 ( 1.3263)]    [ 0.0183 ( 0.3753)  0.0024 ( 0.9544) -0.2914 ( 0.7621)]    [ 0.0185 ( 0.2303) -0.1958 ( 0.6066)  0.0753 ( 1.3168)]
#
# r  (K,) = (6,)
# [-0.1129 ( 3.0282)  1.8650 ( 4.0926) -1.3287 ( 1.4322) -0.0684 ( 3.1159) -0.9259 ( 1.7723)  0.5709 ( 4.0830)]
#
# Interpretable AR(1) parameters (mean±std over seeds)
# Regime 0:
#   latent0: rho=-0.1900 ( 0.5460)  b= 0.0213 ( 0.5877)  mu_stat≈ 0.017883  var_stat≈ 2.318354e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0472 ( 0.0107)  b=-0.0034 ( 0.0094)  mu_stat≈-0.003543  var_stat≈ 2.301045e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.0064 ( 0.2212)  b= 0.0216 ( 0.0665)  mu_stat≈ 0.021761  var_stat≈ 3.117281e-01  half_life_steps≈ 0.14  half_life_years≈ 0.0005
#
# Regime 1:
#   latent0: rho=-0.1309 ( 0.4328)  b=-0.0042 ( 0.2175)  mu_stat≈-0.003706  var_stat≈ 1.544825e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0485 ( 0.0081)  b=-0.0068 ( 0.0075)  mu_stat≈-0.007154  var_stat≈ 3.091357e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho=-0.0612 ( 0.3934)  b= 0.0076 ( 0.1511)  mu_stat≈ 0.007133  var_stat≈ 7.039006e-01  half_life_steps≈ inf  half_life_years≈ nan
#
# Regime 2:
#   latent0: rho=-0.2394 ( 0.5348)  b=-0.6125 ( 1.6941)  mu_stat≈-0.494214  var_stat≈ 3.607924e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0442 ( 0.0149)  b=-0.0084 ( 0.0124)  mu_stat≈-0.008757  var_stat≈ 2.162661e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent2: rho= 0.1421 ( 0.2936)  b= 0.0440 ( 0.1765)  mu_stat≈ 0.051341  var_stat≈ 3.821142e-01  half_life_steps≈ 0.36  half_life_years≈ 0.0014
#
# Regime 3:
#   latent0: rho=-0.3795 ( 0.4321)  b= 0.3171 ( 0.8645)  mu_stat≈ 0.229847  var_stat≈ 2.858374e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0444 ( 0.0145)  b=-0.0102 ( 0.0132)  mu_stat≈-0.010648  var_stat≈ 2.606644e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent2: rho= 0.1068 ( 0.2708)  b= 0.0252 ( 0.0809)  mu_stat≈ 0.028213  var_stat≈ 4.733072e-01  half_life_steps≈ 0.31  half_life_years≈ 0.0012
#
# Regime 4:
#   latent0: rho=-0.0870 ( 0.5188)  b= 0.0027 ( 0.2492)  mu_stat≈ 0.002469  var_stat≈ 1.363656e+00  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0429 ( 0.0068)  b=-0.0066 ( 0.0106)  mu_stat≈-0.006892  var_stat≈ 1.862984e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent2: rho= 0.0155 ( 0.3974)  b=-0.0062 ( 0.1228)  mu_stat≈-0.006283  var_stat≈ 4.079132e-01  half_life_steps≈ 0.17  half_life_years≈ 0.0007
#
# Regime 5:
#   latent0: rho=-0.2463 ( 0.3609)  b= 0.0132 ( 0.0947)  mu_stat≈ 0.010579  var_stat≈ 9.604847e-01  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0385 ( 0.0083)  b=-0.0092 ( 0.0071)  mu_stat≈-0.009592  var_stat≈ 2.699406e-02  half_life_steps≈ 0.21  half_life_years≈ 0.0008
#   latent2: rho= 0.1247 ( 0.1239)  b=-0.0150 ( 0.0629)  mu_stat≈-0.017188  var_stat≈ 4.194528e-01  half_life_steps≈ 0.33  half_life_years≈ 0.0013
#
# Occupancy per regime (mean% (std%) across seeds):
#   RAW:   [15.1% (32.3%), 34.1% (46.7%), 0.2% (0.4%), 20.0% (41.5%), 0.9% (2.7%), 29.7% (47.8%)]
#   CUSUM: [16.6% (35.2%), 32.6% (46.9%), 0.1% (0.2%), 20.0% (41.8%), 0.7% (2.2%), 29.9% (48.1%)]
# ARI (mean pairwise across seeds):  RAW=0.224   CUSUM=0.209
#
# ========== STABILITY (security=TSM, batch=9  t0=2268  t1=3392) ==========
#
# Cs  (K_or_1, N, D) = (1, 4, 3)
# [ 0.0016 ( 0.0000) -0.0007 ( 0.0000)  0.0004 ( 0.0000)]
# [ 1.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  1.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  1.0000 ( 0.0000)]
#
# ds  (K_or_1, N) = (1, 4)
# [ 0.0004 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
#
# inv_etas  (K_or_1, N) = (6, 4)
# [ 7.9940 ( 0.0000) -0.2859 ( 0.0000)  0.6153 ( 0.0000)  0.0665 ( 0.0000)]    [ 7.9940 ( 0.0000) -0.2859 ( 0.0000)  0.6153 ( 0.0000)  0.0665 ( 0.0000)]    [ 7.9940 ( 0.0000) -0.2859 ( 0.0000)  0.6153 ( 0.0000)  0.0665 ( 0.0000)]    [ 7.9940 ( 0.0000) -0.2859 ( 0.0000)  0.6153 ( 0.0000)  0.0665 ( 0.0000)]    [ 7.9940 ( 0.0000) -0.2859 ( 0.0000)  0.6153 ( 0.0000)  0.0665 ( 0.0000)]    [ 7.9940 ( 0.0000) -0.2859 ( 0.0000)  0.6153 ( 0.0000)  0.0665 ( 0.0000)]
#
# As  (K, D, D) = (6, 3, 3)
# [ 0.0273 ( 0.4073)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.0619 ( 0.4534)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.0663 ( 0.1691)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.1500 ( 0.2407)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.1885 ( 0.2655)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]    [-0.0556 ( 0.1719)  0.0000 ( 0.0000)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0482 ( 0.0080)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0494 ( 0.0070)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0519 ( 0.0091)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0480 ( 0.0063)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0456 ( 0.0138)  0.0000 ( 0.0000)]    [ 0.0000 ( 0.0000)  0.0512 ( 0.0049)  0.0000 ( 0.0000)]
# [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1322 ( 0.0245)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1364 ( 0.0221)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1322 ( 0.0250)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1389 ( 0.0147)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1309 ( 0.0269)]    [ 0.0000 ( 0.0000)  0.0000 ( 0.0000)  0.1352 ( 0.0292)]
#
# bs  (K, D) = (6, 3)
# [ 0.4141 ( 0.6127) -0.0250 ( 0.0053)  0.0013 ( 0.0484)]    [ 0.4432 ( 0.6188) -0.0152 ( 0.0120)  0.0053 ( 0.0553)]    [ 0.1594 ( 0.1754) -0.0204 ( 0.0037)  0.0069 ( 0.0284)]    [ 0.1999 ( 0.2358) -0.0222 ( 0.0049)  0.0091 ( 0.0280)]    [ 0.2788 ( 0.2878) -0.0203 ( 0.0073)  0.0058 ( 0.0264)]    [ 0.1078 ( 0.1738) -0.0248 ( 0.0048)  0.0080 ( 0.0314)]
#
# sigmasq  (K, D) = (6, 3)
# [ 0.8794 ( 2.0048)  0.0183 ( 0.0124)  0.0343 ( 0.0226)]    [ 0.9182 ( 1.9939)  0.0199 ( 0.0139)  0.0374 ( 0.0256)]    [ 0.3678 ( 0.2304)  0.0244 ( 0.0147)  0.0484 ( 0.0308)]    [ 0.4053 ( 0.2256)  0.0274 ( 0.0142)  0.0536 ( 0.0294)]    [ 0.3401 ( 0.2139)  0.0231 ( 0.0137)  0.0452 ( 0.0287)]    [ 0.4982 ( 0.1870)  0.0332 ( 0.0104)  0.0649 ( 0.0220)]
#
# Rs  (K, D) = (6, 3)
# [ 0.1566 ( 0.7754)  0.1504 ( 0.5184) -0.1831 ( 0.5103)]    [ 0.3147 ( 0.8437)  0.0276 ( 0.2660)  0.1905 ( 0.5027)]    [ 0.1743 ( 0.9257) -0.0831 ( 0.2514)  0.0440 ( 0.5370)]    [ 0.0152 ( 0.8239)  0.0201 ( 0.2391) -0.0707 ( 0.6941)]    [ 0.0046 ( 0.8319) -0.1797 ( 0.4836) -0.1451 ( 0.4837)]    [-0.6581 ( 0.6816)  0.0605 ( 0.2335)  0.1572 ( 0.8760)]
#
# r  (K,) = (6,)
# [-1.2165 ( 1.5621) -0.1118 ( 3.1711)  0.0065 ( 4.0790)  0.4532 ( 4.3002) -1.3099 ( 2.0304)  2.1785 ( 4.8833)]
#
# Interpretable AR(1) parameters (mean±std over seeds)
# Regime 0:
#   latent0: rho= 0.0273 ( 0.4073)  b= 0.4141 ( 0.6127)  mu_stat≈ 0.425719  var_stat≈ 8.800580e-01  half_life_steps≈ 0.19  half_life_years≈ 0.0008
#   latent1: rho= 0.0482 ( 0.0080)  b=-0.0250 ( 0.0053)  mu_stat≈-0.026274  var_stat≈ 1.829525e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.1322 ( 0.0245)  b= 0.0013 ( 0.0484)  mu_stat≈ 0.001548  var_stat≈ 3.490251e-02  half_life_steps≈ 0.34  half_life_years≈ 0.0014
#
# Regime 1:
#   latent0: rho=-0.0619 ( 0.4534)  b= 0.4432 ( 0.6188)  mu_stat≈ 0.417366  var_stat≈ 9.216989e-01  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0494 ( 0.0070)  b=-0.0152 ( 0.0120)  mu_stat≈-0.015998  var_stat≈ 1.995184e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.1364 ( 0.0221)  b= 0.0053 ( 0.0553)  mu_stat≈ 0.006140  var_stat≈ 3.808442e-02  half_life_steps≈ 0.35  half_life_years≈ 0.0014
#
# Regime 2:
#   latent0: rho=-0.0663 ( 0.1691)  b= 0.1594 ( 0.1754)  mu_stat≈ 0.149487  var_stat≈ 3.694044e-01  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0519 ( 0.0091)  b=-0.0204 ( 0.0037)  mu_stat≈-0.021548  var_stat≈ 2.448513e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.1322 ( 0.0250)  b= 0.0069 ( 0.0284)  mu_stat≈ 0.007959  var_stat≈ 4.924531e-02  half_life_steps≈ 0.34  half_life_years≈ 0.0014
#
# Regime 3:
#   latent0: rho=-0.1500 ( 0.2407)  b= 0.1999 ( 0.2358)  mu_stat≈ 0.173823  var_stat≈ 4.145885e-01  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0480 ( 0.0063)  b=-0.0222 ( 0.0049)  mu_stat≈-0.023297  var_stat≈ 2.750651e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.1389 ( 0.0147)  b= 0.0091 ( 0.0280)  mu_stat≈ 0.010553  var_stat≈ 5.469599e-02  half_life_steps≈ 0.35  half_life_years≈ 0.0014
#
# Regime 4:
#   latent0: rho=-0.1885 ( 0.2655)  b= 0.2788 ( 0.2878)  mu_stat≈ 0.234576  var_stat≈ 3.525981e-01  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0456 ( 0.0138)  b=-0.0203 ( 0.0073)  mu_stat≈-0.021314  var_stat≈ 2.317971e-02  half_life_steps≈ 0.22  half_life_years≈ 0.0009
#   latent2: rho= 0.1309 ( 0.0269)  b= 0.0058 ( 0.0264)  mu_stat≈ 0.006621  var_stat≈ 4.601483e-02  half_life_steps≈ 0.34  half_life_years≈ 0.0014
#
# Regime 5:
#   latent0: rho=-0.0556 ( 0.1719)  b= 0.1078 ( 0.1738)  mu_stat≈ 0.102073  var_stat≈ 4.997526e-01  half_life_steps≈ inf  half_life_years≈ nan
#   latent1: rho= 0.0512 ( 0.0049)  b=-0.0248 ( 0.0048)  mu_stat≈-0.026134  var_stat≈ 3.327706e-02  half_life_steps≈ 0.23  half_life_years≈ 0.0009
#   latent2: rho= 0.1352 ( 0.0292)  b= 0.0080 ( 0.0314)  mu_stat≈ 0.009264  var_stat≈ 6.606607e-02  half_life_steps≈ 0.35  half_life_years≈ 0.0014
#
# Occupancy per regime (mean% (std%) across seeds):
#   RAW:   [0.2% (0.2%), 10.0% (31.6%), 20.0% (42.0%), 29.8% (47.9%), 0.2% (0.5%), 39.9% (51.5%)]
#   CUSUM: [0.0% (0.1%), 10.0% (31.6%), 20.0% (42.1%), 29.9% (48.1%), 0.1% (0.2%), 40.0% (51.6%)]
# ARI (mean pairwise across seeds):  RAW=0.567   CUSUM=0.424
